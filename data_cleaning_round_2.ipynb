# %%
import pandas as pd
import scipy.sparse as sp
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
# imort 'data/merged.csv'
df = pd.read_csv('data/df_clean.csv')

# %%
df.head().T
# Out:
#                                                      0  \
# Unnamed: 0                                           0
# POSTED_SPEED_LIMIT                                  25
# STREET_NO                                           33
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# INJURIES_NO_INDICATION                               1
# INJURIES_UNKNOWN                                     0
# CRASH_HOUR                                          17
# CRASH_DAY_OF_WEEK                                    5
# CRASH_MONTH                                          3
# LATITUDE                                       41.8828
# LONGITUDE                                     -87.6322
# ...

# %%
# drop Unnamed: 0
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.head().T
# Out:
#                                                      0  \
# POSTED_SPEED_LIMIT                                  25
# STREET_NO                                           33
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# INJURIES_NO_INDICATION                               1
# INJURIES_UNKNOWN                                     0
# CRASH_HOUR                                          17
# CRASH_DAY_OF_WEEK                                    5
# CRASH_MONTH                                          3
# LATITUDE                                       41.8828
# LONGITUDE                                     -87.6322
# CRASH_UNIT_ID                                   598511
# ...

# %%
# drop FIRST_CONTACT_POINT, LATITUDE, LONGITUDE, CRASH_UNIT_ID, UNIT_NO
df.drop(['FIRST_CONTACT_POINT', 'LATITUDE', 'LONGITUDE', 'CRASH_UNIT_ID', 'UNIT_NO'], axis=1, inplace=True)

# %%
df.head().T
# Out:
#                                                      0  \
# POSTED_SPEED_LIMIT                                  25
# STREET_NO                                           33
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# INJURIES_NO_INDICATION                               1
# INJURIES_UNKNOWN                                     0
# CRASH_HOUR                                          17
# CRASH_DAY_OF_WEEK                                    5
# CRASH_MONTH                                          3
# NUM_PASSENGERS                                       0
# VEHICLE_YEAR                                      2016
# OCCUPANT_CNT                                         0
# ...

# %%
# drop TRAFFIC_CONTROL_DEVICE, CRASH_DATE_y, STREET_NO, INJURIES_NO_INDICATION, INJURIES_UNKNOWN
df.drop(['TRAFFIC_CONTROL_DEVICE', 'CRASH_DATE_y', 'STREET_NO', 'INJURIES_NO_INDICATION', 'INJURIES_UNKNOWN'], axis=1, inplace=True)

# %%
df.head().T
# Out:
#                                                      0  \
# POSTED_SPEED_LIMIT                                  25
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# CRASH_HOUR                                          17
# CRASH_DAY_OF_WEEK                                    5
# CRASH_MONTH                                          3
# NUM_PASSENGERS                                       0
# VEHICLE_YEAR                                      2016
# OCCUPANT_CNT                                         0
# MANEUVER                                        PARKED
# VEHICLE_USE                                   PERSONAL
# VEHICLE_TYPE                                 PASSENGER
# ...

# %%
# drop VEHICLE_USE
df.drop('VEHICLE_USE', axis=1, inplace=True)

# %%
df.head().T
# Out:
#                                                      0  \
# POSTED_SPEED_LIMIT                                  25
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# CRASH_HOUR                                          17
# CRASH_DAY_OF_WEEK                                    5
# CRASH_MONTH                                          3
# NUM_PASSENGERS                                       0
# VEHICLE_YEAR                                      2016
# OCCUPANT_CNT                                         0
# MANEUVER                                        PARKED
# VEHICLE_TYPE                                 PASSENGER
# VEHICLE_DEFECT                                    NONE
# ...

# %%
# list what's in VEHICLE_DEFECT
df['VEHICLE_DEFECT'].value_counts()
# Out:
# NONE            5075
# UNKNOWN         3275
# BRAKES            44
# OTHER             37
# TIRES              9
# WHEELS             4
# STEERING           3
# SUSPENSION         2
# WINDOWS            1
# LIGHTS             1
# CARGO              1
# ENGINE/MOTOR       1
# Name: VEHICLE_DEFECT, dtype: int64

# %%
# # drop all rows with VEHICLE_DEFECT == 'UNKNOWN' and 'NONE'
# df = df[df['VEHICLE_DEFECT'] != 'UNKNOWN']
# df = df[df['VEHICLE_DEFECT'] != 'NONE']

# %%
len(df)
# Out:
# 8453

# %%
# drop VEHCILE_DEFECT
df.drop('VEHICLE_DEFECT', axis=1, inplace=True)

# %%
# list what's in VEHICLE_DEFECT
# df['VEHICLE_DEFECT'].value_counts()

# %%
# drop VEHICLE_TYPE
df.drop('VEHICLE_TYPE', axis=1, inplace=True)

# %%
df.head().T
# Out:
#                                                      0  \
# POSTED_SPEED_LIMIT                                  25
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# CRASH_HOUR                                          17
# CRASH_DAY_OF_WEEK                                    5
# CRASH_MONTH                                          3
# NUM_PASSENGERS                                       0
# VEHICLE_YEAR                                      2016
# OCCUPANT_CNT                                         0
# MANEUVER                                        PARKED
# MODEL                                              300
# MAKE                                          CHRYSLER
# ...

# %%
# DROP DAMAGE
df.drop('DAMAGE', axis=1, inplace=True)
# Drop MODEL
df.drop('MODEL', axis=1, inplace=True)

# %%
df.head().T
# Out:
#                                                      0  \
# POSTED_SPEED_LIMIT                                  25
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# CRASH_HOUR                                          17
# CRASH_DAY_OF_WEEK                                    5
# CRASH_MONTH                                          3
# NUM_PASSENGERS                                       0
# VEHICLE_YEAR                                      2016
# OCCUPANT_CNT                                         0
# MANEUVER                                        PARKED
# MAKE                                          CHRYSLER
# UNIT_TYPE                                       PARKED
# ...

# %%
# DROP CRASH_TYPE
df.drop('CRASH_TYPE', axis=1, inplace=True)

# %%
# remove FIRST_CRASH_TYPE, MAKE, DATE_POLICE_NOTIFIED, MAKE
df.drop(['FIRST_CRASH_TYPE', 'MAKE', 'DATE_POLICE_NOTIFIED'], axis=1, inplace=True)

# %%
# DROP UNIT_TYPE
df.drop('UNIT_TYPE', axis=1, inplace=True)

# %%
# DROP CRASH_DATE_x
df.drop('CRASH_DATE_x', axis=1, inplace=True)

# %%
# export df_clean to csv
df.to_csv('data/df_clean.csv')

# %%
len(df)
# Out:
# 8453
