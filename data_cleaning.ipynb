# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Data Sources
#
# [crashes](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Crashes/85ca-t3if)
#
# [vehicles](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Vehicles/68nd-jvt3)
#
# [people](https://data.cityofchicago.org/Transportation/Traffic-Crashes-People/u6pd-qa9d)

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import scipy.sparse as sp
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %% [markdown]
# ## Importing The Data

# %%
d_crashes = pd.read_csv('data/Traffic_Crashes_-_Crashes.csv')
d_vehicles = pd.read_csv('data/Traffic_Crashes_-_Vehicles.csv')
# Out:
# c:\Anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (19,21,40,41,42,44,48,49,50,53,55,58,59,61,71) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### Look at the dimensions of the matrices

# %%
d_crashes.shape
# Out:
# (732329, 49)

# %%
d_crashes.head()
# Out:
#                                      CRASH_RECORD_ID     RD_NO  \
# 0  79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...  JC199149
# 1  792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...  JB422857
# 2  0115ade9a755e835255508463f7e9c4a9a0b47e9304238...  JF318029
# 3  05b1982cdba5d8a00e7e76ad1ecdab0e598429f78481d2...  JF378711
# 4  017040c61958d2fa977c956b2bd2d6759ef7754496dc96...  JF324552
#
#   CRASH_DATE_EST_I              CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0              NaN  03/25/2019 02:43:00 PM                  30
# 1              NaN  09/05/2018 08:40:00 AM                  30
# 2              NaN  07/15/2022 12:45:00 AM                  30
# 3              NaN  08/29/2022 11:30:00 AM                  30
# 4              NaN  07/15/2022 06:50:00 PM                  30
#
#   TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 1            NO CONTROLS           NO CONTROLS             CLEAR
# 2                UNKNOWN               UNKNOWN             CLEAR
# 3         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 4         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
#
#        LIGHTING_CONDITION FIRST_CRASH_TYPE  ... INJURIES_NON_INCAPACITATING  \
# 0                DAYLIGHT          TURNING  ...                         0.0
# 1                DAYLIGHT            ANGLE  ...                         0.0
# 2  DARKNESS, LIGHTED ROAD            ANGLE  ...                         0.0
# 3                DAYLIGHT         REAR END  ...                         0.0
# 4                DAYLIGHT         REAR END  ...                         0.0
#
#    INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN  \
# 0                            1.0                    2.0              0.0
# 1                            0.0                    2.0              0.0
# 2                            0.0                    2.0              0.0
# 3                            0.0                    3.0              0.0
# 4                            0.0                    2.0              0.0
#
#   CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH   LATITUDE  LONGITUDE  \
# 0         14                 2           3  41.884547 -87.641201
# 1          8                 4           9  41.968562 -87.740659
# 2          0                 6           7  41.886336 -87.716203
# 3         11                 2           8  41.749348 -87.721097
# 4         18                 6           7  41.925111 -87.667997
#
#                                    LOCATION
# 0   POINT (-87.64120093714 41.884547224337)
# 1  POINT (-87.740659314632 41.968562453871)
# 2  POINT (-87.716203130599 41.886336409761)
# 3  POINT (-87.721096727406 41.749348170421)
# 4  POINT (-87.667997321599 41.925110815832)
#
# [5 rows x 49 columns]

# %%
d_vehicles.shape
# Out:
# (1491796, 72)

# %%
d_vehicles.head()
# Out:
#    CRASH_UNIT_ID                                    CRASH_RECORD_ID     RD_NO  \
# 0        1554880  91a5d08b2b701f2d37cbb52ecdbeb09579bc7f2ebc60b3...  JG223284
# 1         749947  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...  JC451435
# 2         749949  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...  JC451435
# 3         749950  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...  JC451435
# 4        1554881  91a5d08b2b701f2d37cbb52ecdbeb09579bc7f2ebc60b3...  JG223284
#
#                CRASH_DATE  UNIT_NO UNIT_TYPE  NUM_PASSENGERS  VEHICLE_ID  \
# 0  04/14/2023 02:05:00 PM        1    DRIVER             NaN   1478881.0
# 1  09/28/2019 03:30:00 AM        1    DRIVER             NaN    834816.0
# 2  09/28/2019 03:30:00 AM        2    PARKED             NaN    834819.0
# 3  09/28/2019 03:30:00 AM        3    PARKED             NaN    834817.0
# 4  04/14/2023 02:05:00 PM        2    DRIVER             1.0   1478892.0
#
#   CMRC_VEH_I                              MAKE  ... TRAILER1_LENGTH  \
# 0        NaN                              FORD  ...             NaN
# 1        NaN                             HONDA  ...             NaN
# 2        NaN                            TOYOTA  ...             NaN
# 3        NaN  GENERAL MOTORS CORPORATION (GMC)  ...             NaN
# 4        NaN                             ISUZU  ...             NaN
#
#   TRAILER2_LENGTH  TOTAL_VEHICLE_LENGTH AXLE_CNT VEHICLE_CONFIG  \
# 0             NaN                   NaN      NaN            NaN
# 1             NaN                   NaN      NaN            NaN
# 2             NaN                   NaN      NaN            NaN
# 3             NaN                   NaN      NaN            NaN
# 4             NaN                   NaN      NaN            NaN
#
#   CARGO_BODY_TYPE LOAD_TYPE HAZMAT_OUT_OF_SERVICE_I MCS_OUT_OF_SERVICE_I  \
# 0             NaN       NaN                     NaN                  NaN
# 1             NaN       NaN                     NaN                  NaN
# 2             NaN       NaN                     NaN                  NaN
# 3             NaN       NaN                     NaN                  NaN
# 4             NaN       NaN                     NaN                  NaN
#
#   HAZMAT_CLASS
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 72 columns]

# %% [markdown]
# ### Merging The Frames

# %%
# Merge d_crashes and d_vehicles on CRASH_RECORD_ID
df = pd.merge(d_crashes, d_vehicles, on='CRASH_RECORD_ID')

# %%
df.shape
# Out:
# (1491794, 120)

# %%
df.head()
# Out:
#                                      CRASH_RECORD_ID   RD_NO_x  \
# 0  79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...  JC199149
# 1  79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...  JC199149
# 2  792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...  JB422857
# 3  792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...  JB422857
# 4  0115ade9a755e835255508463f7e9c4a9a0b47e9304238...  JF318029
#
#   CRASH_DATE_EST_I            CRASH_DATE_x  POSTED_SPEED_LIMIT  \
# 0              NaN  03/25/2019 02:43:00 PM                  30
# 1              NaN  03/25/2019 02:43:00 PM                  30
# 2              NaN  09/05/2018 08:40:00 AM                  30
# 3              NaN  09/05/2018 08:40:00 AM                  30
# 4              NaN  07/15/2022 12:45:00 AM                  30
#
#   TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 1         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 2            NO CONTROLS           NO CONTROLS             CLEAR
# 3            NO CONTROLS           NO CONTROLS             CLEAR
# 4                UNKNOWN               UNKNOWN             CLEAR
#
#        LIGHTING_CONDITION FIRST_CRASH_TYPE  ... TRAILER1_LENGTH  \
# 0                DAYLIGHT          TURNING  ...             NaN
# 1                DAYLIGHT          TURNING  ...             NaN
# 2                DAYLIGHT            ANGLE  ...             NaN
# 3                DAYLIGHT            ANGLE  ...             NaN
# 4  DARKNESS, LIGHTED ROAD            ANGLE  ...             NaN
#
#    TRAILER2_LENGTH TOTAL_VEHICLE_LENGTH AXLE_CNT VEHICLE_CONFIG  \
# 0              NaN                  NaN      NaN            NaN
# 1              NaN                  NaN      NaN            NaN
# 2              NaN                  NaN      NaN            NaN
# 3              NaN                  NaN      NaN            NaN
# 4              NaN                  NaN      NaN            NaN
#
#   CARGO_BODY_TYPE LOAD_TYPE HAZMAT_OUT_OF_SERVICE_I MCS_OUT_OF_SERVICE_I  \
# 0             NaN       NaN                     NaN                  NaN
# 1             NaN       NaN                     NaN                  NaN
# 2             NaN       NaN                     NaN                  NaN
# 3             NaN       NaN                     NaN                  NaN
# 4             NaN       NaN                     NaN                  NaN
#
#   HAZMAT_CLASS
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 120 columns]

# %% [markdown]
# ## Check dimensions

# %%
print(d_crashes.shape[1] + d_vehicles.shape[1])
# Out:
# 121

# %% [markdown]
# ## Initial Drop

# %%
'''
drom from df 
CMV_ID
USDOT_NO
CCMC_NO
ILCC_NO
COMMERCIAL_SRC
GVWR
CARRIER_NAME
CARRIER_STATE
CARRIER_CITY
HAZMAT_PLACARDS_I
HAZMAT_NAME
UN_NO
HAZMAT_PRESENT_I
HAZMAT_REPORT_I
HAZMAT_REPORT_NO
MCS_REPORT_I
MCS_REPORT_NO
HAZMAT_VIO_CAUSE_CRASH_I
MCS_VIO_CAUSE_CRASH_I
IDOT_PERMIT_NO
WIDE_LOAD_I
TRAILER1_WIDTH
TRAILER2_WIDTH
TRAILER1_LENGTH
TRAILER2_LENGTH
TOTAL_VEHICLE_LENGTH
AXLE_CNT
VEHICLE_CONFIG
CARGO_BODY_TYPE
LOAD_TYPE
HAZMAT_OUT_OF_SERVICE_I
MCS_OUT_OF_SERVICE_I
HAZMAT_CLASS
PHOTOS_TAKEN_I
STATEMENTS_TAKEN_I
DOORING_I
WORK_ZONE_I
WORK_ZONE_TYPE
WORKERS_PRESENT_I
TOWED_I
FIRE_I
TOWED_BY
TOWED_TO
AREA_00_I
AREA_01_I
AREA_02_I
AREA_03_I
AREA_04_I
AREA_05_I
AREA_06_I
AREA_07_I
AREA_08_I
AREA_09_I
AREA_10_I
AREA_11_I
AREA_12_I
AREA_99_I
'''

df.drop(columns=['CMV_ID',
                 'USDOT_NO',
                 'CCMC_NO',
                 'ILCC_NO',
                 'COMMERCIAL_SRC',
                 'GVWR',
                 'CARRIER_NAME',
                 'CARRIER_STATE',
                 'CARRIER_CITY',
                 'HAZMAT_PLACARDS_I',
                 'HAZMAT_NAME',
                 'UN_NO',
                 'HAZMAT_PRESENT_I',
                 'HAZMAT_REPORT_I',
                 'HAZMAT_REPORT_NO',
                 'MCS_REPORT_I',
                 'MCS_REPORT_NO',
                 'HAZMAT_VIO_CAUSE_CRASH_I',
                 'MCS_VIO_CAUSE_CRASH_I',
                 'IDOT_PERMIT_NO',
                 'WIDE_LOAD_I',
                 'TRAILER1_WIDTH',
                 'TRAILER2_WIDTH',
                 'TRAILER1_LENGTH',
                 'TRAILER2_LENGTH',
                 'TOTAL_VEHICLE_LENGTH',
                 'AXLE_CNT',
                 'VEHICLE_CONFIG',
                 'CARGO_BODY_TYPE',
                 'LOAD_TYPE',
                 'HAZMAT_OUT_OF_SERVICE_I',
                 'MCS_OUT_OF_SERVICE_I',
                 'HAZMAT_CLASS',
                 
                 'PHOTOS_TAKEN_I',
                 'STATEMENTS_TAKEN_I',
                 'DOORING_I',
                 'WORK_ZONE_I',
                 'WORK_ZONE_TYPE',
                 'WORKERS_PRESENT_I',
                 
                 'TOWED_I',
                 'FIRE_I',
                 
                 'TOWED_BY',
                 'TOWED_TO',
                 'AREA_00_I',
                 'AREA_01_I',
                 'AREA_02_I',
                 'AREA_03_I',
                 'AREA_04_I',
                 'AREA_05_I',
                 'AREA_06_I',
                 'AREA_07_I',
                 'AREA_08_I',
                 'AREA_09_I',
                 'AREA_10_I',
                 'AREA_11_I',
                 'AREA_12_I',
                 'AREA_99_I',
                 
                 'BEAT_OF_OCCURRENCE',
                 'VEHICLE_ID',
                 'LANE_CNT',
                 ], inplace=True)

# %%
df.shape
# Out:
# (1491794, 60)

# %%
# remove all rows where PRIM_CONTRIBUTORY_CAUSE is UNABLE TO DETERMINE and NOT APPLICABLE
df = df[df['PRIM_CONTRIBUTORY_CAUSE'] != 'NOT APPLICABLE']
df = df[df['PRIM_CONTRIBUTORY_CAUSE'] != 'UNABLE TO DETERMINE']

# %%
# check
df['PRIM_CONTRIBUTORY_CAUSE'].value_counts()
# Out:
# FAILING TO YIELD RIGHT-OF-WAY                                                       164915
# FOLLOWING TOO CLOSELY                                                               151936
# IMPROPER OVERTAKING/PASSING                                                          73063
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               66695
# IMPROPER BACKING                                                                     58478
# IMPROPER LANE USAGE                                                                  54856
# IMPROPER TURNING/NO SIGNAL                                                           49008
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  47434
# DISREGARDING TRAFFIC SIGNALS                                                         30303
# WEATHER                                                                              21949
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     20053
# DISREGARDING STOP SIGN                                                               16971
# DISTRACTION - FROM INSIDE VEHICLE                                                    10788
# PHYSICAL CONDITION OF DRIVER                                                          9547
# EQUIPMENT - VEHICLE CONDITION                                                         9473
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    8439
# DRIVING ON WRONG SIDE/WRONG WAY                                                       8435
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                  8154
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    6156
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      4166
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   3398
# DISREGARDING OTHER TRAFFIC SIGNS                                                      3083
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     2547
# ROAD CONSTRUCTION/MAINTENANCE                                                         2414
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                              2344
# CELL PHONE USE OTHER THAN TEXTING                                                     2135
# DISREGARDING ROAD MARKINGS                                                            1786
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       1667
# TURNING RIGHT ON RED                                                                  1092
# ANIMAL                                                                                 984
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)            724
# RELATED TO BUS STOP                                                                    644
# TEXTING                                                                                631
# DISREGARDING YIELD SIGN                                                                509
# PASSING STOPPED SCHOOL BUS                                                             181
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 156
# OBSTRUCTED CROSSWALKS                                                                  138
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                               42
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64

# %% [markdown]
# phone
# TEXTING
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)
# CELL PHONE USE OTHER THAN TEXTING
#
#
# knowledge
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT
# BICYCLE ADVANCING LEGALLY ON RED LIGHT
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
#
#
# etc
# OBSTRUCTED CROSSWALKS
#
#
# mad
# PASSING STOPPED SCHOOL BUS
#
# mistake
# IMPROPER BACKING
# IMPROPER LANE USAGE
# IMPROPER TURNING/NO SIGNAL
#
# DISREGARDING YIELD SIGN
#
# ANIMAL

# %%
df.shape
# Out:
# (845294, 60)

# %%
df.head().T
# Out:
#                                                                                0  \
# CRASH_RECORD_ID                79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...
# RD_NO_x                                                                 JC199149
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              03/25/2019 02:43:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                          ONE-WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                      INJURY AND / OR TOW DUE TO CRASH
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      03/25/2019 03:17:00 PM
# PRIM_CONTRIBUTORY_CAUSE                               IMPROPER TURNING/NO SIGNAL
# SEC_CONTRIBUTORY_CAUSE                       DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# STREET_NO                                                                    536
# STREET_DIRECTION                                                               W
# STREET_NAME                                                          RANDOLPH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                         REPORTED, NOT EVIDENT
# INJURIES_TOTAL                                                                 1
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  1
# INJURIES_NO_INDICATION                                                         2
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    14
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    3
# LATITUDE                                                                 41.8845
# LONGITUDE                                                               -87.6412
# LOCATION                                 POINT (-87.64120093714 41.884547224337)
# CRASH_UNIT_ID                                                             611178
# RD_NO_y                                                                 JC199149
# CRASH_DATE_y                                              03/25/2019 02:43:00 PM
# UNIT_NO                                                                        1
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                                 1
# CMRC_VEH_I                                                                   NaN
# MAKE                                                                   CHEVROLET
# MODEL                                                                      CRUZE
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                2017
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                    RIDESHARE SERVICE
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                            TURNING LEFT
# OCCUPANT_CNT                                                                   2
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                   FRONT-LEFT
#
#                                                                                1  \
# CRASH_RECORD_ID                79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...
# RD_NO_x                                                                 JC199149
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              03/25/2019 02:43:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                          ONE-WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                      INJURY AND / OR TOW DUE TO CRASH
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      03/25/2019 03:17:00 PM
# PRIM_CONTRIBUTORY_CAUSE                               IMPROPER TURNING/NO SIGNAL
# SEC_CONTRIBUTORY_CAUSE                       DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# STREET_NO                                                                    536
# STREET_DIRECTION                                                               W
# STREET_NAME                                                          RANDOLPH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                         REPORTED, NOT EVIDENT
# INJURIES_TOTAL                                                                 1
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  1
# INJURIES_NO_INDICATION                                                         2
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    14
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    3
# LATITUDE                                                                 41.8845
# LONGITUDE                                                               -87.6412
# LOCATION                                 POINT (-87.64120093714 41.884547224337)
# CRASH_UNIT_ID                                                             611179
# RD_NO_y                                                                 JC199149
# CRASH_DATE_y                                              03/25/2019 02:43:00 PM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                      CAMRY
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                2010
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                   1
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                  FRONT-RIGHT
#
#                                                                                2  \
# CRASH_RECORD_ID                792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...
# RD_NO_x                                                                 JB422857
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              09/05/2018 08:40:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                           ANGLE
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      09/05/2018 09:00:00 AM
# PRIM_CONTRIBUTORY_CAUSE        VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...
# SEC_CONTRIBUTORY_CAUSE                             FAILING TO YIELD RIGHT-OF-WAY
# STREET_NO                                                                   4821
# STREET_DIRECTION                                                               N
# STREET_NAME                                                           ELSTON AVE
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         2
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                     8
# CRASH_DAY_OF_WEEK                                                              4
# CRASH_MONTH                                                                    9
# LATITUDE                                                                 41.9686
# LONGITUDE                                                               -87.7407
# LOCATION                                POINT (-87.740659314632 41.968562453871)
# CRASH_UNIT_ID                                                             470531
# RD_NO_y                                                                 JB422857
# CRASH_DATE_y                                              09/05/2018 08:40:00 AM
# UNIT_NO                                                                        1
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                    4RUNNER
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                2002
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                         SPORT UTILITY VEHICLE (SUV)
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                               N
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                   1
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                        FRONT
#
#                                                                                3  \
# CRASH_RECORD_ID                792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...
# RD_NO_x                                                                 JB422857
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              09/05/2018 08:40:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                           ANGLE
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      09/05/2018 09:00:00 AM
# PRIM_CONTRIBUTORY_CAUSE        VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...
# SEC_CONTRIBUTORY_CAUSE                             FAILING TO YIELD RIGHT-OF-WAY
# STREET_NO                                                                   4821
# STREET_DIRECTION                                                               N
# STREET_NAME                                                           ELSTON AVE
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         2
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                     8
# CRASH_DAY_OF_WEEK                                                              4
# CRASH_MONTH                                                                    9
# LATITUDE                                                                 41.9686
# LONGITUDE                                                               -87.7407
# LOCATION                                POINT (-87.740659314632 41.968562453871)
# CRASH_UNIT_ID                                                             470532
# RD_NO_y                                                                 JB422857
# CRASH_DATE_y                                              09/05/2018 08:40:00 AM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                      CAMRY
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                2014
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                              SE
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                   1
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                   REAR-RIGHT
#
#                                                                                6
# CRASH_RECORD_ID                05b1982cdba5d8a00e7e76ad1ecdab0e598429f78481d2...
# RD_NO_x                                                                 JF378711
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              08/29/2022 11:30:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                        REAR END
# TRAFFICWAY_TYPE                                                         FOUR WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                             $501 - $1,500
# DATE_POLICE_NOTIFIED                                      09/01/2022 11:30:00 AM
# PRIM_CONTRIBUTORY_CAUSE                             DISREGARDING TRAFFIC SIGNALS
# SEC_CONTRIBUTORY_CAUSE                                            NOT APPLICABLE
# STREET_NO                                                                   3939
# STREET_DIRECTION                                                               W
# STREET_NAME                                                              79TH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         3
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    11
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    8
# LATITUDE                                                                 41.7493
# LONGITUDE                                                               -87.7211
# LOCATION                                POINT (-87.721096727406 41.749348170421)
# CRASH_UNIT_ID                                                            1410559
# RD_NO_y                                                                 JF378711
# CRASH_DATE_y                                              08/29/2022 11:30:00 AM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                                     UNKNOWN
# MODEL                                               OTHER (EXPLAIN IN NARRATIVE)
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                 NaN
# VEHICLE_DEFECT                                                           UNKNOWN
# VEHICLE_TYPE                                             TRACTOR W/ SEMI-TRAILER
# VEHICLE_USE                                             COMMERCIAL - SINGLE UNIT
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                   1
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                      UNKNOWN

# %% [markdown]
# ## Chopping down the data
#
# There's just too much
#
# Do after the initial clean to get a better sample.

# %%
df.shape
# Out:
# (845294, 60)

# %%
df = df.sample(frac=0.02, random_state=42)

# %%
df.shape
# Out:
# (16906, 60)

# %%
'''
Group the PRIM_CONTRIBUTORY_CAUSE as follows: 

    Failures to Follow Traffic Rules:
        FAILING TO YIELD RIGHT-OF-WAY
        FOLLOWING TOO CLOSELY
        IMPROPER OVERTAKING/PASSING
        FAILING TO REDUCE SPEED TO AVOID CRASH
        IMPROPER BACKING
        IMPROPER LANE USAGE
        IMPROPER TURNING/NO SIGNAL
        DISREGARDING TRAFFIC SIGNALS
        DISREGARDING STOP SIGN
        DISREGARDING OTHER TRAFFIC SIGNS
        DISREGARDING YIELD SIGN

    Driver Behavior and Awareness:
        DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
        OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER
        DISTRACTION - FROM INSIDE VEHICLE
        PHYSICAL CONDITION OF DRIVER
        UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)
        DISTRACTION - FROM OUTSIDE VEHICLE
        HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)
        CELL PHONE USE OTHER THAN TEXTING
        TEXTING

    Environmental Factors:
        WEATHER
        VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)
        ROAD CONSTRUCTION/MAINTENANCE
        ROAD ENGINEERING/SURFACE/MARKING DEFECTS

    Vehicle-related Issues:
        EQUIPMENT - VEHICLE CONDITION

    Other Specific Circumstances:
        EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST
        ANIMAL
        RELATED TO BUS STOP
        BICYCLE ADVANCING LEGALLY ON RED LIGHT
        OBSTRUCTED CROSSWALKS
        MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT
        PASSING STOPPED SCHOOL BUS
'''
# Out:
# '\nGroup the PRIM_CONTRIBUTORY_CAUSE as follows: \n\n    Failures to Follow Traffic Rules:\n        FAILING TO YIELD RIGHT-OF-WAY\n        FOLLOWING TOO CLOSELY\n        IMPROPER OVERTAKING/PASSING\n        FAILING TO REDUCE SPEED TO AVOID CRASH\n        IMPROPER BACKING\n        IMPROPER LANE USAGE\n        IMPROPER TURNING/NO SIGNAL\n        DISREGARDING TRAFFIC SIGNALS\n        DISREGARDING STOP SIGN\n        DISREGARDING OTHER TRAFFIC SIGNS\n        DISREGARDING YIELD SIGN\n\n    Driver Behavior and Awareness:\n        DRIVING SKILLS/KNOWLEDGE/EXPERIENCE\n        OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER\n        DISTRACTION - FROM INSIDE VEHICLE\n        PHYSICAL CONDITION OF DRIVER\n        UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)\n        DISTRACTION - FROM OUTSIDE VEHICLE\n        HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)\n        CELL PHONE USE OTHER THAN TEXTING\n        TEXTING\n\n    Environmental Factors:\n        WEATHER\n        VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)\n        ROAD CONSTRUCTION/MAINTENANCE\n        ROAD ENGINEERING/SURFACE/MARKING DEFECTS\n\n    Vehicle-related Issues:\n        EQUIPMENT - VEHICLE CONDITION\n\n    Other Specific Circumstances:\n        EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST\n        ANIMAL\n        RELATED TO BUS STOP\n        BICYCLE ADVANCING LEGALLY ON RED LIGHT\n        OBSTRUCTED CROSSWALKS\n        MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT\n        PASSING STOPPED SCHOOL BUS\n'

# %%
# # Define the target groups
# target_groups = {
#     'Failures to Follow Traffic Rules': [
#         'FAILING TO YIELD RIGHT-OF-WAY',
#         'FOLLOWING TOO CLOSELY',
#         'IMPROPER OVERTAKING/PASSING',
#         'FAILING TO REDUCE SPEED TO AVOID CRASH',
#         'IMPROPER BACKING',
#         'IMPROPER LANE USAGE',
#         'IMPROPER TURNING/NO SIGNAL',
#         'DISREGARDING TRAFFIC SIGNALS',
#         'DISREGARDING STOP SIGN',
#         'DISREGARDING OTHER TRAFFIC SIGNS',
#         'DISREGARDING YIELD SIGN'
#     ],
#     'Driver Behavior and Awareness': [
#         'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE',
#         'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
#         'DISTRACTION - FROM INSIDE VEHICLE',
#         'PHYSICAL CONDITION OF DRIVER',
#         'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
#         'DISTRACTION - FROM OUTSIDE VEHICLE',
#         'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)',
#         'CELL PHONE USE OTHER THAN TEXTING',
#         'TEXTING'
#     ],
#     'Environmental Factors': [
#         'WEATHER',
#         'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
#         'ROAD CONSTRUCTION/MAINTENANCE',
#         'ROAD ENGINEERING/SURFACE/MARKING DEFECTS'
#     ],
#     'Vehicle-related Issues': [
#         'EQUIPMENT - VEHICLE CONDITION'
#     ],
#     'Other Specific Circumstances': [
#         'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
#         'ANIMAL',
#         'RELATED TO BUS STOP',
#         'BICYCLE ADVANCING LEGALLY ON RED LIGHT',
#         'OBSTRUCTED CROSSWALKS',
#         'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT',
#         'PASSING STOPPED SCHOOL BUS'
#     ]
# }

# # Create a new column for the grouped targets
# df['GROUPED_TARGET'] = ''

# # Group the targets based on the defined groups
# for group, targets in target_groups.items():
#     df.loc[df['PRIM_CONTRIBUTORY_CAUSE'].isin(targets), 'GROUPED_TARGET'] = group

# # Cut out the df_targets with the grouped targets
# df_targets = df[['GROUPED_TARGET']]

# # Print the unique grouped targets
# print(df_targets['GROUPED_TARGET'].unique())

# %%
import pandas as pd

# Define the target groups
target_groups = {
    'Failures to Follow Traffic Rules': [
        'FAILING TO YIELD RIGHT-OF-WAY',
        'FOLLOWING TOO CLOSELY',
        'IMPROPER OVERTAKING/PASSING',
        'FAILING TO REDUCE SPEED TO AVOID CRASH',
        'IMPROPER BACKING',
        'IMPROPER LANE USAGE',
        'IMPROPER TURNING/NO SIGNAL',
        'DISREGARDING TRAFFIC SIGNALS',
        'DISREGARDING STOP SIGN',
        'DISREGARDING OTHER TRAFFIC SIGNS',
        'DISREGARDING YIELD SIGN'
    ],
    'Driver Behavior and Awareness': [
        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE',
        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
        'DISTRACTION - FROM INSIDE VEHICLE',
        'PHYSICAL CONDITION OF DRIVER',
        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
        'DISTRACTION - FROM OUTSIDE VEHICLE',
        'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)',
        'CELL PHONE USE OTHER THAN TEXTING',
        'TEXTING'
    ],
    'Environmental Factors': [
        'WEATHER',
        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
        'ROAD CONSTRUCTION/MAINTENANCE',
        'ROAD ENGINEERING/SURFACE/MARKING DEFECTS'
    ],
    'Vehicle-related Issues': [
        'EQUIPMENT - VEHICLE CONDITION'
    ],
    'Other Specific Circumstances': [
        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
        'ANIMAL',
        'RELATED TO BUS STOP',
        'BICYCLE ADVANCING LEGALLY ON RED LIGHT',
        'OBSTRUCTED CROSSWALKS',
        'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT',
        'PASSING STOPPED SCHOOL BUS'
    ]
}

# Group the targets based on the defined groups
for group, targets in target_groups.items():
    df.loc[df['PRIM_CONTRIBUTORY_CAUSE'].isin(targets), 'PRIM_CONTRIBUTORY_CAUSE'] = group

# Cut out the df_targets with the grouped targets
df_targets = df[['PRIM_CONTRIBUTORY_CAUSE']]

# Print the unique grouped targets
print(df_targets['PRIM_CONTRIBUTORY_CAUSE'].unique())
# Out:
# ['Driver Behavior and Awareness' 'Failures to Follow Traffic Rules'
#  'Vehicle-related Issues' 'Other Specific Circumstances'
#  'EXCEEDING SAFE SPEED FOR CONDITIONS' 'Environmental Factors'
#  'DRIVING ON WRONG SIDE/WRONG WAY' 'DISREGARDING ROAD MARKINGS'
#  'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)'
#  'EXCEEDING AUTHORIZED SPEED LIMIT' 'TURNING RIGHT ON RED']

# %% [markdown]
# ## Cleaning Leftover Columns

# %% [markdown]
# ### Split Into categorical and numerical

# %% [markdown]
# Now that they have been merged on CRASH_RECORD_ID, I'm going to remove that column, and create a new index

# %%
df = df.drop('CRASH_RECORD_ID', axis=1)

# %%
df = df.reset_index(drop=True)

# %%
index = df.index

# %%
print(index)
# Out:
# RangeIndex(start=0, stop=16906, step=1)

# %%
# split df into categorical and numerical dataframes
df_cat = df.select_dtypes(include='object')
df_num = df.select_dtypes(exclude='object')

# %%
# df_cat = categorical_data.reset_index(drop=True)
# df_num = numerical_data.reset_index(drop=True)

# %% [markdown]
# #### Numerical Cleaning

# %% [markdown]
# Okay so everything that is left over with the numerical columns should be able to be filled with 0.

# %%
# check df_num for nulls
df_num.isnull().sum()
# Out:
# POSTED_SPEED_LIMIT                   0
# STREET_NO                            0
# NUM_UNITS                            0
# INJURIES_TOTAL                       8
# INJURIES_FATAL                       8
# INJURIES_INCAPACITATING              8
# INJURIES_NON_INCAPACITATING          8
# INJURIES_REPORTED_NOT_EVIDENT        8
# INJURIES_NO_INDICATION               8
# INJURIES_UNKNOWN                     8
# CRASH_HOUR                           0
# CRASH_DAY_OF_WEEK                    0
# CRASH_MONTH                          0
# LATITUDE                           118
# LONGITUDE                          118
# CRASH_UNIT_ID                        0
# UNIT_NO                              0
# NUM_PASSENGERS                   13963
# VEHICLE_YEAR                      2313
# OCCUPANT_CNT                       355
# dtype: int64

# %%
# fill all missing values in df_num with 0
df_num.fillna(0, inplace=True)
# Out:
# c:\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %% [markdown]
# #### categorical cleaning

# %%
df_cat.isna().sum()
# Out:
# RD_NO_x                      102
# CRASH_DATE_EST_I           16032
# CRASH_DATE_x                   0
# TRAFFIC_CONTROL_DEVICE         0
# DEVICE_CONDITION               0
# WEATHER_CONDITION              0
# LIGHTING_CONDITION             0
# FIRST_CRASH_TYPE               0
# TRAFFICWAY_TYPE                0
# ALIGNMENT                      0
# ROADWAY_SURFACE_COND           0
# ROAD_DEFECT                    0
# REPORT_TYPE                  556
# CRASH_TYPE                     0
# INTERSECTION_RELATED_I     12023
# NOT_RIGHT_OF_WAY_I         16311
# HIT_AND_RUN_I              12813
# DAMAGE                         0
# DATE_POLICE_NOTIFIED           0
# PRIM_CONTRIBUTORY_CAUSE        0
# SEC_CONTRIBUTORY_CAUSE         0
# STREET_DIRECTION               0
# STREET_NAME                    0
# MOST_SEVERE_INJURY             8
# LOCATION                     118
# RD_NO_y                      109
# CRASH_DATE_y                   0
# UNIT_TYPE                     22
# CMRC_VEH_I                 16541
# MAKE                         355
# MODEL                        357
# LIC_PLATE_STATE             1539
# VEHICLE_DEFECT               355
# VEHICLE_TYPE                 355
# VEHICLE_USE                  355
# TRAVEL_DIRECTION             355
# MANEUVER                     355
# EXCEED_SPEED_LIMIT_I       16858
# FIRST_CONTACT_POINT          387
# dtype: int64

# %%
# print out the value_counts for every column in df_cat
for col in df_cat.columns:
    print(col)
    print(df_cat[col].value_counts())
    print('')
# Out:
# RD_NO_x
# JB258280    3
# JD202266    2
# JB399744    2
# JB375109    2
# JB253839    2
#            ..
# JG188541    1
# JE321764    1
# JC558937    1
# JB382084    1
# JB184136    1
# Name: RD_NO_x, Length: 16613, dtype: int64
#
# CRASH_DATE_EST_I
# Y    742
# N    132
# Name: CRASH_DATE_EST_I, dtype: int64
#
# CRASH_DATE_x
# 05/10/2018 03:56:00 PM    3
# 12/03/2020 01:30:00 PM    3
# 02/02/2023 03:00:00 PM    3
# 01/21/2020 01:00:00 PM    3
# 03/17/2019 04:15:00 PM    3
#                          ..
# 02/14/2016 05:54:00 PM    1
# 05/27/2023 11:00:00 PM    1
# 05/10/2022 05:03:00 PM    1
# 12/08/2017 04:00:00 PM    1
# 03/24/2019 09:55:00 PM    1
# Name: CRASH_DATE_x, Length: 16491, dtype: int64
#
# TRAFFIC_CONTROL_DEVICE
# NO CONTROLS                 8574
# TRAFFIC SIGNAL              5705
# STOP SIGN/FLASHER           2035
# UNKNOWN                      330
# OTHER                        120
# LANE USE MARKING              32
# OTHER WARNING SIGN            21
# YIELD                         20
# OTHER REG. SIGN               17
# RAILROAD CROSSING GATE        14
# SCHOOL ZONE                   10
# FLASHING CONTROL SIGNAL        9
# PEDESTRIAN CROSSING SIGN       7
# POLICE/FLAGMAN                 4
# DELINEATORS                    3
# OTHER RAILROAD CROSSING        3
# NO PASSING                     2
# Name: TRAFFIC_CONTROL_DEVICE, dtype: int64
#
# DEVICE_CONDITION
# NO CONTROLS                 8759
# FUNCTIONING PROPERLY        7183
# UNKNOWN                      668
# OTHER                        124
# FUNCTIONING IMPROPERLY        98
# NOT FUNCTIONING               62
# WORN REFLECTIVE MATERIAL       8
# MISSING                        4
# Name: DEVICE_CONDITION, dtype: int64
#
# WEATHER_CONDITION
# CLEAR                     13505
# RAIN                       1611
# SNOW                        702
# CLOUDY/OVERCAST             625
# UNKNOWN                     331
# OTHER                        47
# FREEZING RAIN/DRIZZLE        30
# SLEET/HAIL                   25
# FOG/SMOKE/HAZE               21
# BLOWING SNOW                  5
# SEVERE CROSS WIND GATE        4
# Name: WEATHER_CONDITION, dtype: int64
#
# LIGHTING_CONDITION
# DAYLIGHT                  11266
# DARKNESS, LIGHTED ROAD     3906
# DARKNESS                    729
# DUSK                        527
# DAWN                        273
# UNKNOWN                     205
# Name: LIGHTING_CONDITION, dtype: int64
#
# FIRST_CRASH_TYPE
# REAR END                        4626
# TURNING                         2917
# SIDESWIPE SAME DIRECTION        2678
# PARKED MOTOR VEHICLE            2633
# ANGLE                           2242
# PEDESTRIAN                       379
# FIXED OBJECT                     366
# SIDESWIPE OPPOSITE DIRECTION     276
# PEDALCYCLIST                     220
# REAR TO FRONT                    189
# HEAD ON                          163
# REAR TO SIDE                      93
# OTHER OBJECT                      62
# REAR TO REAR                      28
# OTHER NONCOLLISION                24
# OVERTURNED                         5
# ANIMAL                             5
# Name: FIRST_CRASH_TYPE, dtype: int64
#
# TRAFFICWAY_TYPE
# NOT DIVIDED                        7457
# DIVIDED - W/MEDIAN (NOT RAISED)    3102
# ONE-WAY                            1919
# FOUR WAY                           1153
# DIVIDED - W/MEDIAN BARRIER         1080
# PARKING LOT                         862
# OTHER                               420
# T-INTERSECTION                      220
# ALLEY                               200
# CENTER TURN LANE                    152
# UNKNOWN                              96
# RAMP                                 54
# DRIVEWAY                             45
# UNKNOWN INTERSECTION TYPE            44
# Y-INTERSECTION                       31
# FIVE POINT, OR MORE                  26
# TRAFFIC ROUTE                        18
# NOT REPORTED                         15
# ROUNDABOUT                            6
# L-INTERSECTION                        6
# Name: TRAFFICWAY_TYPE, dtype: int64
#
# ALIGNMENT
# STRAIGHT AND LEVEL       16452
# STRAIGHT ON GRADE          248
# CURVE, LEVEL               127
# STRAIGHT ON HILLCREST       43
# CURVE ON GRADE              31
# CURVE ON HILLCREST           5
# Name: ALIGNMENT, dtype: int64
#
# ROADWAY_SURFACE_COND
# DRY                12841
# WET                 2469
# UNKNOWN              740
# SNOW OR SLUSH        667
# ICE                  142
# OTHER                 39
# SAND, MUD, DIRT        8
# Name: ROADWAY_SURFACE_COND, dtype: int64
#
# ROAD_DEFECT
# NO DEFECTS           14428
# UNKNOWN               2178
# RUT, HOLES              95
# OTHER                   86
# WORN SURFACE            74
# SHOULDER DEFECT         37
# DEBRIS ON ROADWAY        8
# Name: ROAD_DEFECT, dtype: int64
#
# REPORT_TYPE
# NOT ON SCENE (DESK REPORT)    8256
# ON SCENE                      8091
# AMENDED                          3
# Name: REPORT_TYPE, dtype: int64
#
# CRASH_TYPE
# NO INJURY / DRIVE AWAY              11558
# INJURY AND / OR TOW DUE TO CRASH     5348
# Name: CRASH_TYPE, dtype: int64
#
# INTERSECTION_RELATED_I
# Y    4665
# N     218
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# Y    539
# N     56
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# Y    3860
# N     233
# Name: HIT_AND_RUN_I, dtype: int64
#
# DAMAGE
# OVER $1,500      10907
# $501 - $1,500     4149
# $500 OR LESS      1850
# Name: DAMAGE, dtype: int64
#
# DATE_POLICE_NOTIFIED
# 05/10/2018 03:57:00 PM    3
# 11/16/2018 11:54:00 AM    3
# 10/31/2021 04:00:00 AM    3
# 03/14/2022 08:45:00 AM    3
# 07/17/2018 01:15:00 PM    3
#                          ..
# 12/07/2017 08:08:00 PM    1
# 08/13/2021 01:03:00 PM    1
# 05/09/2022 01:46:00 PM    1
# 03/22/2022 03:15:00 PM    1
# 09/16/2016 09:30:00 AM    1
# Name: DATE_POLICE_NOTIFIED, Length: 16595, dtype: int64
#
# PRIM_CONTRIBUTORY_CAUSE
# Failures to Follow Traffic Rules                                               13404
# Driver Behavior and Awareness                                                   2165
# Environmental Factors                                                            653
# Vehicle-related Issues                                                           202
# DRIVING ON WRONG SIDE/WRONG WAY                                                  169
# Other Specific Circumstances                                                      98
# EXCEEDING AUTHORIZED SPEED LIMIT                                                  82
# EXCEEDING SAFE SPEED FOR CONDITIONS                                               67
# DISREGARDING ROAD MARKINGS                                                        32
# TURNING RIGHT ON RED                                                              20
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)       14
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64
#
# SEC_CONTRIBUTORY_CAUSE
# NOT APPLICABLE                                                                      6358
# UNABLE TO DETERMINE                                                                 3970
# FAILING TO REDUCE SPEED TO AVOID CRASH                                              1127
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  888
# FAILING TO YIELD RIGHT-OF-WAY                                                        888
# FOLLOWING TOO CLOSELY                                                                825
# IMPROPER OVERTAKING/PASSING                                                          428
# IMPROPER LANE USAGE                                                                  379
# WEATHER                                                                              351
# IMPROPER TURNING/NO SIGNAL                                                           313
# IMPROPER BACKING                                                                     221
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     199
# DISREGARDING STOP SIGN                                                                88
# DISREGARDING TRAFFIC SIGNALS                                                          86
# PHYSICAL CONDITION OF DRIVER                                                          83
# DISTRACTION - FROM INSIDE VEHICLE                                                     81
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                  72
# DRIVING ON WRONG SIDE/WRONG WAY                                                       67
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      61
# EQUIPMENT - VEHICLE CONDITION                                                         59
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   56
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    47
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    38
# ROAD CONSTRUCTION/MAINTENANCE                                                         37
# DISREGARDING OTHER TRAFFIC SIGNS                                                      29
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       26
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                              20
# DISREGARDING ROAD MARKINGS                                                            18
# CELL PHONE USE OTHER THAN TEXTING                                                     15
# TURNING RIGHT ON RED                                                                  14
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     13
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)           10
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                10
# RELATED TO BUS STOP                                                                    8
# ANIMAL                                                                                 7
# PASSING STOPPED SCHOOL BUS                                                             4
# DISREGARDING YIELD SIGN                                                                4
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                              3
# OBSTRUCTED CROSSWALKS                                                                  2
# TEXTING                                                                                1
# Name: SEC_CONTRIBUTORY_CAUSE, dtype: int64
#
# STREET_DIRECTION
# W    6061
# S    5621
# N    4066
# E    1158
# Name: STREET_DIRECTION, dtype: int64
#
# STREET_NAME
# WESTERN AVE     478
# PULASKI RD      421
# ASHLAND AVE     396
# CICERO AVE      390
# HALSTED ST      372
#                ...
# JEFFERY DR        1
# 126TH ST          1
# IMLAY ST          1
# STRATFORD PL      1
# HOMAN BLVD        1
# Name: STREET_NAME, Length: 926, dtype: int64
#
# MOST_SEVERE_INJURY
# NO INDICATION OF INJURY     14087
# NONINCAPACITATING INJURY     1609
# REPORTED, NOT EVIDENT         841
# INCAPACITATING INJURY         335
# FATAL                          26
# Name: MOST_SEVERE_INJURY, dtype: int64
#
# LOCATION
# POINT (-87.905309125103 41.976201139024)    28
# POINT (-87.619928173678 41.900958919109)    17
# POINT (-87.580147768689 41.791420282098)    17
# POINT (-87.585971992965 41.751460603167)    14
# POINT (-87.617027423234 41.896804972416)    10
#                                             ..
# POINT (-87.670673940197 41.998711970787)     1
# POINT (-87.715515708101 41.864558261649)     1
# POINT (-87.566328751221 41.763838583945)     1
# POINT (-87.683002425991 41.924955755277)     1
# POINT (-87.710852540776 41.880727706056)     1
# Name: LOCATION, Length: 14346, dtype: int64
#
# RD_NO_y
# JB258280    3
# JA506271    2
# JF287057    2
# JB375109    2
# JE111849    2
#            ..
# JE400230    1
# JG188541    1
# JE321764    1
# JC558937    1
# JB184136    1
# Name: RD_NO_y, Length: 16606, dtype: int64
#
# CRASH_DATE_y
# 05/10/2018 03:56:00 PM    3
# 12/03/2020 01:30:00 PM    3
# 02/02/2023 03:00:00 PM    3
# 01/21/2020 01:00:00 PM    3
# 03/17/2019 04:15:00 PM    3
#                          ..
# 02/14/2016 05:54:00 PM    1
# 05/27/2023 11:00:00 PM    1
# 05/10/2022 05:03:00 PM    1
# 12/08/2017 04:00:00 PM    1
# 03/24/2019 09:55:00 PM    1
# Name: CRASH_DATE_y, Length: 16491, dtype: int64
#
# UNIT_TYPE
# DRIVER                 14915
# PARKED                  1547
# PEDESTRIAN               201
# BICYCLE                  120
# DRIVERLESS                91
# NON-MOTOR VEHICLE          8
# NON-CONTACT VEHICLE        2
# Name: UNIT_TYPE, dtype: int64
#
# CMRC_VEH_I
# Y    229
# N    136
# Name: CMRC_VEH_I, dtype: int64
#
# MAKE
# CHEVROLET                                 2046
# FORD                                      1735
# NISSAN                                    1393
# HONDA                                     1240
# TOYOTA MOTOR COMPANY, LTD.                1152
#                                           ...
# DAIMLER                                      1
# TRANSCRAFT CORP.                             1
# FRIGGSTAD MANUFACTURING, LTD. (CANADA)       1
# KENWORTH NORTHWEST, INC., SEATTLE, WA        1
# NORTH AMERICAN BUS INDUSTRIES                1
# Name: MAKE, Length: 173, dtype: int64
#
# MODEL
# UNKNOWN                                               1737
# OTHER (EXPLAIN IN NARRATIVE)                          1047
# CAMRY                                                  560
# COROLLA                                                391
# CIVIC                                                  335
#                                                       ...
# SUNFIRE                                                  1
# AMERICAN TRAILER & MFG. CO. (SEE ALSO TRANSPORTER)       1
# Cirrus                                                   1
# CLUB WAGON E250                                          1
# J-10 (for vehicle years 1989 to present)                 1
# Name: MODEL, Length: 876, dtype: int64
#
# LIC_PLATE_STATE
# IL    14148
# IN      311
# XX      205
# WI      101
# FL       72
# MI       61
# TX       47
# OH       39
# MO       36
# AZ       34
# CA       29
# IA       29
# MN       22
# GA       22
# TN       21
# NY       17
# OK       16
# PA       12
# KY       10
# AL        9
# WA        9
# MS        9
# KS        8
# NB        8
# CT        8
# LA        8
# NC        7
# MA        7
# CO        7
# VA        7
# NJ        7
# MD        5
# SC        4
# VT        3
# AR        3
# ND        3
# ID        3
# UT        3
# OR        3
# SD        2
# AK        2
# NV        2
# NM        2
# NH        1
# MT        1
# RI        1
# ME        1
# DE        1
# WV        1
# Name: LIC_PLATE_STATE, dtype: int64
#
# VEHICLE_DEFECT
# NONE            10055
# UNKNOWN          6295
# BRAKES             82
# OTHER              77
# TIRES              16
# WHEELS              6
# STEERING            6
# LIGHTS              4
# SUSPENSION          3
# CARGO               2
# ENGINE/MOTOR        2
# WINDOWS             2
# SIGNALS             1
# Name: VEHICLE_DEFECT, dtype: int64
#
# VEHICLE_TYPE
# PASSENGER                                 10955
# SPORT UTILITY VEHICLE (SUV)                2393
# VAN/MINI-VAN                                858
# UNKNOWN/NA                                  787
# PICKUP                                      544
# TRUCK - SINGLE UNIT                         346
# BUS OVER 15 PASS.                           176
# OTHER                                       171
# TRACTOR W/ SEMI-TRAILER                     165
# BUS UP TO 15 PASS.                           49
# MOTORCYCLE (OVER 150CC)                      40
# TRACTOR W/O SEMI-TRAILER                     18
# SINGLE UNIT TRUCK WITH TRAILER               18
# OTHER VEHICLE WITH TRAILER                   17
# MOPED OR MOTORIZED BICYCLE                    5
# MOTOR DRIVEN CYCLE                            4
# RECREATIONAL OFF-HIGHWAY VEHICLE (ROV)        1
# ALL-TERRAIN VEHICLE (ATV)                     1
# 3-WHEELED MOTORCYCLE (2 REAR WHEELS)          1
# AUTOCYCLE                                     1
# FARM EQUIPMENT                                1
# Name: VEHICLE_TYPE, dtype: int64
#
# VEHICLE_USE
# PERSONAL                        11661
# UNKNOWN/NA                       2446
# NOT IN USE                        657
# OTHER                             533
# COMMERCIAL - SINGLE UNIT          245
# TAXI/FOR HIRE                     212
# RIDESHARE SERVICE                 184
# CTA                               118
# POLICE                            114
# CONSTRUCTION/MAINTENANCE           92
# COMMERCIAL - MULTI-UNIT            79
# OTHER TRANSIT                      49
# TOW TRUCK                          37
# SCHOOL BUS                         36
# AMBULANCE                          23
# STATE OWNED                        16
# MASS TRANSIT                       15
# FIRE                               15
# DRIVER EDUCATION                   12
# AGRICULTURE                         3
# CAMPER/RV - TOWED/MULTI-UNIT        2
# LAWN CARE/LANDSCAPING               2
# Name: VEHICLE_USE, dtype: int64
#
# TRAVEL_DIRECTION
# N          3976
# S          3960
# E          3650
# W          3533
# UNKNOWN     603
# SE          247
# NW          225
# NE          183
# SW          174
# Name: TRAVEL_DIRECTION, dtype: int64
#
# MANEUVER
# STRAIGHT AHEAD                        8357
# PARKED                                1554
# SLOW/STOP IN TRAFFIC                  1458
# TURNING LEFT                          1199
# BACKING                                735
# TURNING RIGHT                          585
# PASSING/OVERTAKING                     523
# UNKNOWN/NA                             374
# CHANGING LANES                         360
# ENTERING TRAFFIC LANE FROM PARKING     257
# OTHER                                  255
# STARTING IN TRAFFIC                    124
# U-TURN                                 117
# MERGING                                109
# ENTER FROM DRIVE/ALLEY                  84
# LEAVING TRAFFIC LANE TO PARK            82
# AVOIDING VEHICLES/OBJECTS               81
# SKIDDING/CONTROL LOSS                   77
# PARKED IN TRAFFIC LANE                  53
# DRIVING WRONG WAY                       49
# SLOW/STOP - LEFT TURN                   44
# SLOW/STOP - LOAD/UNLOAD                 23
# NEGOTIATING A CURVE                     22
# SLOW/STOP - RIGHT TURN                  18
# TURNING ON RED                           7
# DIVERGING                                3
# DRIVERLESS                               1
# Name: MANEUVER, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# Y    35
# N    13
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64
#
# FIRST_CONTACT_POINT
# FRONT                 3592
# REAR                  2384
# SIDE-RIGHT            1099
# FRONT-LEFT            1082
# SIDE-LEFT             1039
# FRONT-RIGHT            978
# FRONT-RIGHT-CORNER     957
# FRONT-LEFT-CORNER      948
# REAR-LEFT              813
# UNKNOWN                748
# OTHER                  492
# REAR-RIGHT             422
# REAR-LEFT-CORNER       357
# REAR-RIGHT-CORNER      335
# TOTAL (ALL AREAS)      296
# SIDE-LEFT-REAR         228
# SIDE-RIGHT-REAR        167
# SIDE-RIGHT-FRONT       139
# ROOF                   131
# SIDE-LEFT-FRONT        131
# NONE                   116
# UNDER CARRIAGE          50
# TOP                     15
# Name: FIRST_CONTACT_POINT, dtype: int64

# %%
df_cat_dropped_cols = df_cat.drop(columns=['RD_NO_x',
                'CRASH_DATE_EST_I', 
                'REPORT_TYPE', 
                'STREET_DIRECTION',
                'STREET_NAME',
                'LOCATION', 
                'RD_NO_y', 
                'CMRC_VEH_I', 
                'LIC_PLATE_STATE', 
                'TRAVEL_DIRECTION'
                 ])

# %%
df_cat_dropped_cols.isna().sum()
# Out:
# CRASH_DATE_x                   0
# TRAFFIC_CONTROL_DEVICE         0
# DEVICE_CONDITION               0
# WEATHER_CONDITION              0
# LIGHTING_CONDITION             0
# FIRST_CRASH_TYPE               0
# TRAFFICWAY_TYPE                0
# ALIGNMENT                      0
# ROADWAY_SURFACE_COND           0
# ROAD_DEFECT                    0
# CRASH_TYPE                     0
# INTERSECTION_RELATED_I     12023
# NOT_RIGHT_OF_WAY_I         16311
# HIT_AND_RUN_I              12813
# DAMAGE                         0
# DATE_POLICE_NOTIFIED           0
# PRIM_CONTRIBUTORY_CAUSE        0
# SEC_CONTRIBUTORY_CAUSE         0
# MOST_SEVERE_INJURY             8
# CRASH_DATE_y                   0
# UNIT_TYPE                     22
# MAKE                         355
# MODEL                        357
# VEHICLE_DEFECT               355
# VEHICLE_TYPE                 355
# VEHICLE_USE                  355
# MANEUVER                     355
# EXCEED_SPEED_LIMIT_I       16858
# FIRST_CONTACT_POINT          387
# dtype: int64

# %% [markdown]
# ## Getting target variable

# %%
'''
remove
PRIM_CONTRIBUTORY_CAUSE
and
SEC_CONTRIBUTORY_CAUSE
from df_cat_dropped_cols
assign it to it's own dataframe called df_targets,
and then export df_targets to csv
'''

# Specifically I'm going to make prim cause the target and remove secondary, maybe I'll come back to it if I have time.
df_targets = df_cat_dropped_cols[['PRIM_CONTRIBUTORY_CAUSE']]
df_cat_dropped_cols.drop(columns=['PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE'], inplace=True)
df_targets.to_csv('data/df_targets.csv')

# %%
df_targets.isna().sum()
# Out:
# PRIM_CONTRIBUTORY_CAUSE    0
# dtype: int64

# %%
df_targets.dtypes
# Out:
# PRIM_CONTRIBUTORY_CAUSE    object
# dtype: object

# %%
df_targets.value_counts()

# give me the value counts for each column in df_targets
for col in df_targets.columns:
    print(col)
    print(df_targets[col].value_counts())
    print('')
# Out:
# PRIM_CONTRIBUTORY_CAUSE
# Failures to Follow Traffic Rules                                               13404
# Driver Behavior and Awareness                                                   2165
# Environmental Factors                                                            653
# Vehicle-related Issues                                                           202
# DRIVING ON WRONG SIDE/WRONG WAY                                                  169
# Other Specific Circumstances                                                      98
# EXCEEDING AUTHORIZED SPEED LIMIT                                                  82
# EXCEEDING SAFE SPEED FOR CONDITIONS                                               67
# DISREGARDING ROAD MARKINGS                                                        32
# TURNING RIGHT ON RED                                                              20
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)       14
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64

# %% [markdown]
# ## splitting into ordinal and nominal

# %%
'''
assign to df_cat_ordinal 
INTERSECTION_RELATED_I
NOT_RIGHT_OF_WAY_I
HIT_AND_RUN_I
and EXCEED_SPEED_LIMIT_I
'''
df_cat_ordinal = df_cat_dropped_cols[['INTERSECTION_RELATED_I',
                                        'NOT_RIGHT_OF_WAY_I',
                                        'HIT_AND_RUN_I',
                                        'EXCEED_SPEED_LIMIT_I'
                                        ]]

# assign the rest to nominal
df_cat_nominal = df_cat_dropped_cols.drop(columns=['INTERSECTION_RELATED_I',
                                        'NOT_RIGHT_OF_WAY_I',
                                        'HIT_AND_RUN_I',
                                        'EXCEED_SPEED_LIMIT_I'
                                        ])

# %% [markdown]
# ### ordinal

# %%
# list nulls in ordinal
df_cat_ordinal.isna().sum()
# Out:
# INTERSECTION_RELATED_I    12023
# NOT_RIGHT_OF_WAY_I        16311
# HIT_AND_RUN_I             12813
# EXCEED_SPEED_LIMIT_I      16858
# dtype: int64

# %%
for col in df_cat_ordinal.columns:
    print(col)
    print(df_cat_ordinal[col].value_counts())
    print('')
# Out:
# INTERSECTION_RELATED_I
# Y    4665
# N     218
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# Y    539
# N     56
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# Y    3860
# N     233
# Name: HIT_AND_RUN_I, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# Y    35
# N    13
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64

# %%
# fill all nulls in ordinal with 'N'
df_cat_ordinal_filled = df_cat_ordinal.fillna('N')

# %%
df_cat_ordinal_filled.isna().sum()
# Out:
# INTERSECTION_RELATED_I    0
# NOT_RIGHT_OF_WAY_I        0
# HIT_AND_RUN_I             0
# EXCEED_SPEED_LIMIT_I      0
# dtype: int64

# %%
for col in df_cat_ordinal_filled.columns:
    print(col)
    print(df_cat_ordinal_filled[col].value_counts())
    print('')
# Out:
# INTERSECTION_RELATED_I
# N    12241
# Y     4665
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# N    16367
# Y      539
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# N    13046
# Y     3860
# Name: HIT_AND_RUN_I, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# N    16871
# Y       35
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64

# %% [markdown]
# ### nominal

# %%
# list nulls in nominal
df_cat_nominal.isna().sum()
# Out:
# CRASH_DATE_x                0
# TRAFFIC_CONTROL_DEVICE      0
# DEVICE_CONDITION            0
# WEATHER_CONDITION           0
# LIGHTING_CONDITION          0
# FIRST_CRASH_TYPE            0
# TRAFFICWAY_TYPE             0
# ALIGNMENT                   0
# ROADWAY_SURFACE_COND        0
# ROAD_DEFECT                 0
# CRASH_TYPE                  0
# DAMAGE                      0
# DATE_POLICE_NOTIFIED        0
# MOST_SEVERE_INJURY          8
# CRASH_DATE_y                0
# UNIT_TYPE                  22
# MAKE                      355
# MODEL                     357
# VEHICLE_DEFECT            355
# VEHICLE_TYPE              355
# VEHICLE_USE               355
# MANEUVER                  355
# FIRST_CONTACT_POINT       387
# dtype: int64

# %%
# assign the columnsn in df_cat_nominal with nulls to df_cat_nominal_null
df_cat_nominal_null = df_cat_nominal[['FIRST_CONTACT_POINT',
                                      'MANEUVER',
                                      'VEHICLE_USE',
                                      'VEHICLE_TYPE',
                                      'VEHICLE_DEFECT',
                                      'MODEL',
                                      'MAKE',
                                      'UNIT_TYPE',
                                      'MOST_SEVERE_INJURY']]

# assign the rest to df_cat_nominal_nonull
df_cat_nominal_nonull = df_cat_nominal.drop(columns=['FIRST_CONTACT_POINT',
                                                    'MANEUVER',
                                                    'VEHICLE_USE',
                                                    'VEHICLE_TYPE',
                                                    'VEHICLE_DEFECT',
                                                    'MODEL',
                                                    'MAKE',
                                                    'UNIT_TYPE',
                                                    'MOST_SEVERE_INJURY'])

# %%
# check that the split worked
df_cat_nominal_null.isna().sum()
# Out:
# FIRST_CONTACT_POINT    387
# MANEUVER               355
# VEHICLE_USE            355
# VEHICLE_TYPE           355
# VEHICLE_DEFECT         355
# MODEL                  357
# MAKE                   355
# UNIT_TYPE               22
# MOST_SEVERE_INJURY       8
# dtype: int64

# %%
df_cat_nominal_nonull.isna().sum()
# Out:
# CRASH_DATE_x              0
# TRAFFIC_CONTROL_DEVICE    0
# DEVICE_CONDITION          0
# WEATHER_CONDITION         0
# LIGHTING_CONDITION        0
# FIRST_CRASH_TYPE          0
# TRAFFICWAY_TYPE           0
# ALIGNMENT                 0
# ROADWAY_SURFACE_COND      0
# ROAD_DEFECT               0
# CRASH_TYPE                0
# DAMAGE                    0
# DATE_POLICE_NOTIFIED      0
# CRASH_DATE_y              0
# dtype: int64

# %%
# how many columns are in df_cat_nominal_null?
print(len(df_cat_nominal_null.columns))

# how many columns are in df_cat_nominal_nonull?
print(len(df_cat_nominal_nonull.columns))
# Out:
# 9
# 14

# %%
print(9 + 15)
# Out:
# 24

# %%
# how many columsn were in df_cat_nominal?
print(len(df_cat_nominal.columns))
# Out:
# 23

# %%
for col in df_cat_nominal_null.columns:
    print(col)
    print(df_cat_nominal_null[col].value_counts())
    print('')
# Out:
# FIRST_CONTACT_POINT
# FRONT                 3592
# REAR                  2384
# SIDE-RIGHT            1099
# FRONT-LEFT            1082
# SIDE-LEFT             1039
# FRONT-RIGHT            978
# FRONT-RIGHT-CORNER     957
# FRONT-LEFT-CORNER      948
# REAR-LEFT              813
# UNKNOWN                748
# OTHER                  492
# REAR-RIGHT             422
# REAR-LEFT-CORNER       357
# REAR-RIGHT-CORNER      335
# TOTAL (ALL AREAS)      296
# SIDE-LEFT-REAR         228
# SIDE-RIGHT-REAR        167
# SIDE-RIGHT-FRONT       139
# ROOF                   131
# SIDE-LEFT-FRONT        131
# NONE                   116
# UNDER CARRIAGE          50
# TOP                     15
# Name: FIRST_CONTACT_POINT, dtype: int64
#
# MANEUVER
# STRAIGHT AHEAD                        8357
# PARKED                                1554
# SLOW/STOP IN TRAFFIC                  1458
# TURNING LEFT                          1199
# BACKING                                735
# TURNING RIGHT                          585
# PASSING/OVERTAKING                     523
# UNKNOWN/NA                             374
# CHANGING LANES                         360
# ENTERING TRAFFIC LANE FROM PARKING     257
# OTHER                                  255
# STARTING IN TRAFFIC                    124
# U-TURN                                 117
# MERGING                                109
# ENTER FROM DRIVE/ALLEY                  84
# LEAVING TRAFFIC LANE TO PARK            82
# AVOIDING VEHICLES/OBJECTS               81
# SKIDDING/CONTROL LOSS                   77
# PARKED IN TRAFFIC LANE                  53
# DRIVING WRONG WAY                       49
# SLOW/STOP - LEFT TURN                   44
# SLOW/STOP - LOAD/UNLOAD                 23
# NEGOTIATING A CURVE                     22
# SLOW/STOP - RIGHT TURN                  18
# TURNING ON RED                           7
# DIVERGING                                3
# DRIVERLESS                               1
# Name: MANEUVER, dtype: int64
#
# VEHICLE_USE
# PERSONAL                        11661
# UNKNOWN/NA                       2446
# NOT IN USE                        657
# OTHER                             533
# COMMERCIAL - SINGLE UNIT          245
# TAXI/FOR HIRE                     212
# RIDESHARE SERVICE                 184
# CTA                               118
# POLICE                            114
# CONSTRUCTION/MAINTENANCE           92
# COMMERCIAL - MULTI-UNIT            79
# OTHER TRANSIT                      49
# TOW TRUCK                          37
# SCHOOL BUS                         36
# AMBULANCE                          23
# STATE OWNED                        16
# MASS TRANSIT                       15
# FIRE                               15
# DRIVER EDUCATION                   12
# AGRICULTURE                         3
# CAMPER/RV - TOWED/MULTI-UNIT        2
# LAWN CARE/LANDSCAPING               2
# Name: VEHICLE_USE, dtype: int64
#
# VEHICLE_TYPE
# PASSENGER                                 10955
# SPORT UTILITY VEHICLE (SUV)                2393
# VAN/MINI-VAN                                858
# UNKNOWN/NA                                  787
# PICKUP                                      544
# TRUCK - SINGLE UNIT                         346
# BUS OVER 15 PASS.                           176
# OTHER                                       171
# TRACTOR W/ SEMI-TRAILER                     165
# BUS UP TO 15 PASS.                           49
# MOTORCYCLE (OVER 150CC)                      40
# TRACTOR W/O SEMI-TRAILER                     18
# SINGLE UNIT TRUCK WITH TRAILER               18
# OTHER VEHICLE WITH TRAILER                   17
# MOPED OR MOTORIZED BICYCLE                    5
# MOTOR DRIVEN CYCLE                            4
# RECREATIONAL OFF-HIGHWAY VEHICLE (ROV)        1
# ALL-TERRAIN VEHICLE (ATV)                     1
# 3-WHEELED MOTORCYCLE (2 REAR WHEELS)          1
# AUTOCYCLE                                     1
# FARM EQUIPMENT                                1
# Name: VEHICLE_TYPE, dtype: int64
#
# VEHICLE_DEFECT
# NONE            10055
# UNKNOWN          6295
# BRAKES             82
# OTHER              77
# TIRES              16
# WHEELS              6
# STEERING            6
# LIGHTS              4
# SUSPENSION          3
# CARGO               2
# ENGINE/MOTOR        2
# WINDOWS             2
# SIGNALS             1
# Name: VEHICLE_DEFECT, dtype: int64
#
# MODEL
# UNKNOWN                                               1737
# OTHER (EXPLAIN IN NARRATIVE)                          1047
# CAMRY                                                  560
# COROLLA                                                391
# CIVIC                                                  335
#                                                       ...
# SUNFIRE                                                  1
# AMERICAN TRAILER & MFG. CO. (SEE ALSO TRANSPORTER)       1
# Cirrus                                                   1
# CLUB WAGON E250                                          1
# J-10 (for vehicle years 1989 to present)                 1
# Name: MODEL, Length: 876, dtype: int64
#
# MAKE
# CHEVROLET                                 2046
# FORD                                      1735
# NISSAN                                    1393
# HONDA                                     1240
# TOYOTA MOTOR COMPANY, LTD.                1152
#                                           ...
# DAIMLER                                      1
# TRANSCRAFT CORP.                             1
# FRIGGSTAD MANUFACTURING, LTD. (CANADA)       1
# KENWORTH NORTHWEST, INC., SEATTLE, WA        1
# NORTH AMERICAN BUS INDUSTRIES                1
# Name: MAKE, Length: 173, dtype: int64
#
# UNIT_TYPE
# DRIVER                 14915
# PARKED                  1547
# PEDESTRIAN               201
# BICYCLE                  120
# DRIVERLESS                91
# NON-MOTOR VEHICLE          8
# NON-CONTACT VEHICLE        2
# Name: UNIT_TYPE, dtype: int64
#
# MOST_SEVERE_INJURY
# NO INDICATION OF INJURY     14087
# NONINCAPACITATING INJURY     1609
# REPORTED, NOT EVIDENT         841
# INCAPACITATING INJURY         335
# FATAL                          26
# Name: MOST_SEVERE_INJURY, dtype: int64

# %%
'''Fill the following columns with 'UNKNOWN' in df_cat_nominal_null:
MOST_SEVERE_INJURY
UNIT_TYPE
MAKE
MODEL
VEHICLE_DEFECT
FIRST_CONTACT_POINT
'''

df_cat_nominal_null['MOST_SEVERE_INJURY'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['UNIT_TYPE'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['MAKE'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['MODEL'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['VEHICLE_DEFECT'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['FIRST_CONTACT_POINT'].fillna('UNKNOWN', inplace=True)
# Out:
# c:\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
'''Fill the following columns with 'UNKNOWN/NA' in df_cat_nominal_null:
VEHICLE_TYPE
VEHICLE_USE
MANUEVER
'''

df_cat_nominal_null['VEHICLE_TYPE'].fillna('UNKNOWN/NA', inplace=True)
df_cat_nominal_null['VEHICLE_USE'].fillna('UNKNOWN/NA', inplace=True)
df_cat_nominal_null['MANEUVER'].fillna('UNKNOWN/NA', inplace=True)

# %% [markdown]
# ## Combining nominal and ordinal again

# %%
# combine df_cat_nominal_null and df_cat_nominal_nonull into df_cat_nominal_filled
df_cat_nominal_filled = pd.concat([df_cat_nominal_null, df_cat_nominal_nonull], axis=1)

# combine df_cat_nominal_filled and df_cat_ordinal_filled into df_cat_filled
df_cat_filled = pd.concat([df_cat_nominal_filled, df_cat_ordinal_filled], axis=1)

# %% [markdown]
# ## Combining everything again

# %%
# Combine df_cat_filled and df_num into df_clean

df_clean = pd.concat([df_num, df_cat_filled], axis=1)

# %%
df_clean.head().T
# Out:
#                                                      0  \
# POSTED_SPEED_LIMIT                                  25
# STREET_NO                                           33
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# INJURIES_NO_INDICATION                               1
# INJURIES_UNKNOWN                                     0
# CRASH_HOUR                                          17
# CRASH_DAY_OF_WEEK                                    5
# CRASH_MONTH                                          3
# LATITUDE                                       41.8828
# LONGITUDE                                     -87.6322
# CRASH_UNIT_ID                                   598511
# UNIT_NO                                              2
# NUM_PASSENGERS                                       0
# VEHICLE_YEAR                                      2016
# OCCUPANT_CNT                                         0
# FIRST_CONTACT_POINT                               REAR
# MANEUVER                                        PARKED
# VEHICLE_USE                                   PERSONAL
# VEHICLE_TYPE                                 PASSENGER
# VEHICLE_DEFECT                                    NONE
# MODEL                                              300
# MAKE                                          CHRYSLER
# UNIT_TYPE                                       PARKED
# MOST_SEVERE_INJURY             NO INDICATION OF INJURY
# CRASH_DATE_x                    03/07/2019 05:10:00 PM
# TRAFFIC_CONTROL_DEVICE                     NO CONTROLS
# DEVICE_CONDITION                           NO CONTROLS
# WEATHER_CONDITION                                CLEAR
# LIGHTING_CONDITION                            DAYLIGHT
# FIRST_CRASH_TYPE                  PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                ONE-WAY
# ALIGNMENT                           STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                               DRY
# ROAD_DEFECT                                 NO DEFECTS
# CRASH_TYPE                      NO INJURY / DRIVE AWAY
# DAMAGE                                   $501 - $1,500
# DATE_POLICE_NOTIFIED            03/07/2019 05:35:00 PM
# CRASH_DATE_y                    03/07/2019 05:10:00 PM
# INTERSECTION_RELATED_I                               N
# NOT_RIGHT_OF_WAY_I                                   N
# HIT_AND_RUN_I                                        N
# EXCEED_SPEED_LIMIT_I                                 N
#
#                                                      1  \
# POSTED_SPEED_LIMIT                                  20
# STREET_NO                                         4300
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# INJURIES_NO_INDICATION                               2
# INJURIES_UNKNOWN                                     0
# CRASH_HOUR                                          11
# CRASH_DAY_OF_WEEK                                    6
# CRASH_MONTH                                         11
# LATITUDE                                       41.8148
# LONGITUDE                                     -87.7423
# CRASH_UNIT_ID                                   532437
# UNIT_NO                                              2
# NUM_PASSENGERS                                       0
# VEHICLE_YEAR                                      1999
# OCCUPANT_CNT                                         1
# FIRST_CONTACT_POINT                              FRONT
# MANEUVER                                STRAIGHT AHEAD
# VEHICLE_USE                                   PERSONAL
# VEHICLE_TYPE                                    PICKUP
# VEHICLE_DEFECT                                    NONE
# MODEL                                        SILVERADO
# MAKE                                         CHEVROLET
# UNIT_TYPE                                       DRIVER
# MOST_SEVERE_INJURY             NO INDICATION OF INJURY
# CRASH_DATE_x                    11/30/2018 11:30:00 AM
# TRAFFIC_CONTROL_DEVICE               STOP SIGN/FLASHER
# DEVICE_CONDITION                  FUNCTIONING PROPERLY
# WEATHER_CONDITION                                CLEAR
# LIGHTING_CONDITION                            DAYLIGHT
# FIRST_CRASH_TYPE                                 ANGLE
# TRAFFICWAY_TYPE                            NOT DIVIDED
# ALIGNMENT                           STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                               WET
# ROAD_DEFECT                                 NO DEFECTS
# CRASH_TYPE                      NO INJURY / DRIVE AWAY
# DAMAGE                                     OVER $1,500
# DATE_POLICE_NOTIFIED            11/30/2018 11:50:00 AM
# CRASH_DATE_y                    11/30/2018 11:30:00 AM
# INTERSECTION_RELATED_I                               N
# NOT_RIGHT_OF_WAY_I                                   N
# HIT_AND_RUN_I                                        N
# EXCEED_SPEED_LIMIT_I                                 N
#
#                                                               2  \
# POSTED_SPEED_LIMIT                                           30
# STREET_NO                                                  2198
# NUM_UNITS                                                     1
# INJURIES_TOTAL                                                0
# INJURIES_FATAL                                                0
# INJURIES_INCAPACITATING                                       0
# INJURIES_NON_INCAPACITATING                                   0
# INJURIES_REPORTED_NOT_EVIDENT                                 0
# INJURIES_NO_INDICATION                                        1
# INJURIES_UNKNOWN                                              0
# CRASH_HOUR                                                   19
# CRASH_DAY_OF_WEEK                                             4
# CRASH_MONTH                                                  10
# LATITUDE                                                41.8524
# LONGITUDE                                              -87.6662
# CRASH_UNIT_ID                                            756632
# UNIT_NO                                                       1
# NUM_PASSENGERS                                                0
# VEHICLE_YEAR                                               2000
# OCCUPANT_CNT                                                  1
# FIRST_CONTACT_POINT                                       FRONT
# MANEUVER                                         STRAIGHT AHEAD
# VEHICLE_USE                                            PERSONAL
# VEHICLE_TYPE                                          PASSENGER
# VEHICLE_DEFECT                                           BRAKES
# MODEL                                                  Explorer
# MAKE                                                       FORD
# UNIT_TYPE                                                DRIVER
# MOST_SEVERE_INJURY                      NO INDICATION OF INJURY
# CRASH_DATE_x                             10/09/2019 07:00:00 PM
# TRAFFIC_CONTROL_DEVICE                              NO CONTROLS
# DEVICE_CONDITION                                    NO CONTROLS
# WEATHER_CONDITION                                         CLEAR
# LIGHTING_CONDITION                                     DAYLIGHT
# FIRST_CRASH_TYPE                                   FIXED OBJECT
# TRAFFICWAY_TYPE                 DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                    STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                        DRY
# ROAD_DEFECT                                          NO DEFECTS
# CRASH_TYPE                     INJURY AND / OR TOW DUE TO CRASH
# DAMAGE                                              OVER $1,500
# DATE_POLICE_NOTIFIED                     10/09/2019 07:00:00 PM
# CRASH_DATE_y                             10/09/2019 07:00:00 PM
# INTERSECTION_RELATED_I                                        N
# NOT_RIGHT_OF_WAY_I                                            N
# HIT_AND_RUN_I                                                 N
# EXCEED_SPEED_LIMIT_I                                          N
#
#                                                              3  \
# POSTED_SPEED_LIMIT                                          30
# STREET_NO                                                 2800
# NUM_UNITS                                                    2
# INJURIES_TOTAL                                               0
# INJURIES_FATAL                                               0
# INJURIES_INCAPACITATING                                      0
# INJURIES_NON_INCAPACITATING                                  0
# INJURIES_REPORTED_NOT_EVIDENT                                0
# INJURIES_NO_INDICATION                                       2
# INJURIES_UNKNOWN                                             0
# CRASH_HOUR                                                  10
# CRASH_DAY_OF_WEEK                                            5
# CRASH_MONTH                                                  7
# LATITUDE                                               41.8666
# LONGITUDE                                              -87.696
# CRASH_UNIT_ID                                           179946
# UNIT_NO                                                      2
# NUM_PASSENGERS                                               0
# VEHICLE_YEAR                                                 0
# OCCUPANT_CNT                                                 1
# FIRST_CONTACT_POINT                                       REAR
# MANEUVER                                               BACKING
# VEHICLE_USE                                         UNKNOWN/NA
# VEHICLE_TYPE                                        UNKNOWN/NA
# VEHICLE_DEFECT                                         UNKNOWN
# MODEL                                                  UNKNOWN
# MAKE                                                   UNKNOWN
# UNIT_TYPE                                               DRIVER
# MOST_SEVERE_INJURY                     NO INDICATION OF INJURY
# CRASH_DATE_x                            07/06/2017 10:00:00 AM
# TRAFFIC_CONTROL_DEVICE                          TRAFFIC SIGNAL
# DEVICE_CONDITION                          FUNCTIONING PROPERLY
# WEATHER_CONDITION                                        CLEAR
# LIGHTING_CONDITION                                    DAYLIGHT
# FIRST_CRASH_TYPE                                      REAR END
# TRAFFICWAY_TYPE                DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                   STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                       DRY
# ROAD_DEFECT                                         NO DEFECTS
# CRASH_TYPE                              NO INJURY / DRIVE AWAY
# DAMAGE                                             OVER $1,500
# DATE_POLICE_NOTIFIED                    07/06/2017 02:30:00 PM
# CRASH_DATE_y                            07/06/2017 10:00:00 AM
# INTERSECTION_RELATED_I                                       Y
# NOT_RIGHT_OF_WAY_I                                           N
# HIT_AND_RUN_I                                                N
# EXCEED_SPEED_LIMIT_I                                         N
#
#                                                              4
# POSTED_SPEED_LIMIT                                          30
# STREET_NO                                                 7739
# NUM_UNITS                                                    2
# INJURIES_TOTAL                                               0
# INJURIES_FATAL                                               0
# INJURIES_INCAPACITATING                                      0
# INJURIES_NON_INCAPACITATING                                  0
# INJURIES_REPORTED_NOT_EVIDENT                                0
# INJURIES_NO_INDICATION                                       2
# INJURIES_UNKNOWN                                             0
# CRASH_HOUR                                                  15
# CRASH_DAY_OF_WEEK                                            6
# CRASH_MONTH                                                 11
# LATITUDE                                               42.0222
# LONGITUDE                                             -87.6667
# CRASH_UNIT_ID                                            98704
# UNIT_NO                                                      1
# NUM_PASSENGERS                                               0
# VEHICLE_YEAR                                              2016
# OCCUPANT_CNT                                                 1
# FIRST_CONTACT_POINT                                 FRONT-LEFT
# MANEUVER                                                 OTHER
# VEHICLE_USE                                           PERSONAL
# VEHICLE_TYPE                                         PASSENGER
# VEHICLE_DEFECT                                            NONE
# MODEL                                                  MUSTANG
# MAKE                                                      FORD
# UNIT_TYPE                                               DRIVER
# MOST_SEVERE_INJURY                     NO INDICATION OF INJURY
# CRASH_DATE_x                            11/18/2016 03:17:00 PM
# TRAFFIC_CONTROL_DEVICE                             NO CONTROLS
# DEVICE_CONDITION                                   NO CONTROLS
# WEATHER_CONDITION                                        CLEAR
# LIGHTING_CONDITION                                    DAYLIGHT
# FIRST_CRASH_TYPE                      SIDESWIPE SAME DIRECTION
# TRAFFICWAY_TYPE                DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                   STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                       WET
# ROAD_DEFECT                                         NO DEFECTS
# CRASH_TYPE                              NO INJURY / DRIVE AWAY
# DAMAGE                                             OVER $1,500
# DATE_POLICE_NOTIFIED                    11/18/2016 04:05:00 PM
# CRASH_DATE_y                            11/18/2016 03:17:00 PM
# INTERSECTION_RELATED_I                                       N
# NOT_RIGHT_OF_WAY_I                                           N
# HIT_AND_RUN_I                                                N
# EXCEED_SPEED_LIMIT_I                                         N

# %% [markdown]
# # Exporting the cleaned data

# %%
# export df_clean to csv
df_clean.to_csv('data/df_clean.csv')

# %%
df_clean.shape
# Out:
# (16906, 47)

# %%
df_clean.isna().sum()
# Out:
# POSTED_SPEED_LIMIT               0
# STREET_NO                        0
# NUM_UNITS                        0
# INJURIES_TOTAL                   0
# INJURIES_FATAL                   0
# INJURIES_INCAPACITATING          0
# INJURIES_NON_INCAPACITATING      0
# INJURIES_REPORTED_NOT_EVIDENT    0
# INJURIES_NO_INDICATION           0
# INJURIES_UNKNOWN                 0
# CRASH_HOUR                       0
# CRASH_DAY_OF_WEEK                0
# CRASH_MONTH                      0
# LATITUDE                         0
# LONGITUDE                        0
# CRASH_UNIT_ID                    0
# UNIT_NO                          0
# NUM_PASSENGERS                   0
# VEHICLE_YEAR                     0
# OCCUPANT_CNT                     0
# FIRST_CONTACT_POINT              0
# MANEUVER                         0
# VEHICLE_USE                      0
# VEHICLE_TYPE                     0
# VEHICLE_DEFECT                   0
# MODEL                            0
# MAKE                             0
# UNIT_TYPE                        0
# MOST_SEVERE_INJURY               0
# CRASH_DATE_x                     0
# TRAFFIC_CONTROL_DEVICE           0
# DEVICE_CONDITION                 0
# WEATHER_CONDITION                0
# LIGHTING_CONDITION               0
# FIRST_CRASH_TYPE                 0
# TRAFFICWAY_TYPE                  0
# ALIGNMENT                        0
# ROADWAY_SURFACE_COND             0
# ROAD_DEFECT                      0
# CRASH_TYPE                       0
# DAMAGE                           0
# DATE_POLICE_NOTIFIED             0
# CRASH_DATE_y                     0
# INTERSECTION_RELATED_I           0
# NOT_RIGHT_OF_WAY_I               0
# HIT_AND_RUN_I                    0
# EXCEED_SPEED_LIMIT_I             0
# dtype: int64
