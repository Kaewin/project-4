# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Data Sources
#
# [crashes](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Crashes/85ca-t3if)
#
# [vehicles](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Vehicles/68nd-jvt3)
#
# [people](https://data.cityofchicago.org/Transportation/Traffic-Crashes-People/u6pd-qa9d)

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import scipy.sparse as sp
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
# imort 'data/merged.csv'
df = pd.read_csv('data/merged.csv')
# Out:
# C:\Users\gerba\AppData\Local\Temp\ipykernel_23412\3896017220.py:2: DtypeWarning: Columns (30,31,32,33,69,88,89,90,92,96,97,98,101,103,106,107,109,119) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/merged.csv')

# %% [markdown]
# ## Initial Drop

# %%
'''
drom from df 
CMV_ID
USDOT_NO
CCMC_NO
ILCC_NO
COMMERCIAL_SRC
GVWR
CARRIER_NAME
CARRIER_STATE
CARRIER_CITY
HAZMAT_PLACARDS_I
HAZMAT_NAME
UN_NO
HAZMAT_PRESENT_I
HAZMAT_REPORT_I
HAZMAT_REPORT_NO
MCS_REPORT_I
MCS_REPORT_NO
HAZMAT_VIO_CAUSE_CRASH_I
MCS_VIO_CAUSE_CRASH_I
IDOT_PERMIT_NO
WIDE_LOAD_I
TRAILER1_WIDTH
TRAILER2_WIDTH
TRAILER1_LENGTH
TRAILER2_LENGTH
TOTAL_VEHICLE_LENGTH
AXLE_CNT
VEHICLE_CONFIG
CARGO_BODY_TYPE
LOAD_TYPE
HAZMAT_OUT_OF_SERVICE_I
MCS_OUT_OF_SERVICE_I
HAZMAT_CLASS
PHOTOS_TAKEN_I
STATEMENTS_TAKEN_I
DOORING_I
WORK_ZONE_I
WORK_ZONE_TYPE
WORKERS_PRESENT_I
TOWED_I
FIRE_I
TOWED_BY
TOWED_TO
AREA_00_I
AREA_01_I
AREA_02_I
AREA_03_I
AREA_04_I
AREA_05_I
AREA_06_I
AREA_07_I
AREA_08_I
AREA_09_I
AREA_10_I
AREA_11_I
AREA_12_I
AREA_99_I
'''

df.drop(columns=['CMV_ID',
                 'USDOT_NO',
                 'CCMC_NO',
                 'ILCC_NO',
                 'COMMERCIAL_SRC',
                 'GVWR',
                 'CARRIER_NAME',
                 'CARRIER_STATE',
                 'CARRIER_CITY',
                 'HAZMAT_PLACARDS_I',
                 'HAZMAT_NAME',
                 'UN_NO',
                 'HAZMAT_PRESENT_I',
                 'HAZMAT_REPORT_I',
                 'HAZMAT_REPORT_NO',
                 'MCS_REPORT_I',
                 'MCS_REPORT_NO',
                 'HAZMAT_VIO_CAUSE_CRASH_I',
                 'MCS_VIO_CAUSE_CRASH_I',
                 'IDOT_PERMIT_NO',
                 'WIDE_LOAD_I',
                 'TRAILER1_WIDTH',
                 'TRAILER2_WIDTH',
                 'TRAILER1_LENGTH',
                 'TRAILER2_LENGTH',
                 'TOTAL_VEHICLE_LENGTH',
                 'AXLE_CNT',
                 'VEHICLE_CONFIG',
                 'CARGO_BODY_TYPE',
                 'LOAD_TYPE',
                 'HAZMAT_OUT_OF_SERVICE_I',
                 'MCS_OUT_OF_SERVICE_I',
                 'HAZMAT_CLASS',
                 
                 'PHOTOS_TAKEN_I',
                 'STATEMENTS_TAKEN_I',
                 'DOORING_I',
                 'WORK_ZONE_I',
                 'WORK_ZONE_TYPE',
                 'WORKERS_PRESENT_I',
                 
                 'TOWED_I',
                 'FIRE_I',
                 
                 'TOWED_BY',
                 'TOWED_TO',
                 'AREA_00_I',
                 'AREA_01_I',
                 'AREA_02_I',
                 'AREA_03_I',
                 'AREA_04_I',
                 'AREA_05_I',
                 'AREA_06_I',
                 'AREA_07_I',
                 'AREA_08_I',
                 'AREA_09_I',
                 'AREA_10_I',
                 'AREA_11_I',
                 'AREA_12_I',
                 'AREA_99_I',
                 
                 'BEAT_OF_OCCURRENCE',
                 'VEHICLE_ID',
                 'LANE_CNT',
                 ], inplace=True)

# %%
df.shape
# Out:
# (1491794, 60)

# %%
# remove all rows where PRIM_CONTRIBUTORY_CAUSE is UNABLE TO DETERMINE and NOT APPLICABLE
df = df[df['PRIM_CONTRIBUTORY_CAUSE'] != 'NOT APPLICABLE']
df = df[df['PRIM_CONTRIBUTORY_CAUSE'] != 'UNABLE TO DETERMINE']

# %%
# check
df['PRIM_CONTRIBUTORY_CAUSE'].value_counts()
# Out:
# FAILING TO YIELD RIGHT-OF-WAY                                                       164915
# FOLLOWING TOO CLOSELY                                                               151936
# IMPROPER OVERTAKING/PASSING                                                          73063
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               66695
# IMPROPER BACKING                                                                     58478
# IMPROPER LANE USAGE                                                                  54856
# IMPROPER TURNING/NO SIGNAL                                                           49008
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  47434
# DISREGARDING TRAFFIC SIGNALS                                                         30303
# WEATHER                                                                              21949
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     20053
# DISREGARDING STOP SIGN                                                               16971
# DISTRACTION - FROM INSIDE VEHICLE                                                    10788
# PHYSICAL CONDITION OF DRIVER                                                          9547
# EQUIPMENT - VEHICLE CONDITION                                                         9473
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    8439
# DRIVING ON WRONG SIDE/WRONG WAY                                                       8435
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                  8154
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    6156
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      4166
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   3398
# DISREGARDING OTHER TRAFFIC SIGNS                                                      3083
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     2547
# ROAD CONSTRUCTION/MAINTENANCE                                                         2414
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                              2344
# CELL PHONE USE OTHER THAN TEXTING                                                     2135
# DISREGARDING ROAD MARKINGS                                                            1786
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       1667
# TURNING RIGHT ON RED                                                                  1092
# ANIMAL                                                                                 984
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)            724
# RELATED TO BUS STOP                                                                    644
# TEXTING                                                                                631
# DISREGARDING YIELD SIGN                                                                509
# PASSING STOPPED SCHOOL BUS                                                             181
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 156
# OBSTRUCTED CROSSWALKS                                                                  138
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                               42
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64

# %%
df.shape
# Out:
# (845294, 60)

# %%
df.head().T
# Out:
#                                                                                0  \
# CRASH_RECORD_ID                79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...
# RD_NO_x                                                                 JC199149
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              03/25/2019 02:43:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                          ONE-WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                      INJURY AND / OR TOW DUE TO CRASH
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      03/25/2019 03:17:00 PM
# PRIM_CONTRIBUTORY_CAUSE                               IMPROPER TURNING/NO SIGNAL
# SEC_CONTRIBUTORY_CAUSE                       DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# STREET_NO                                                                    536
# STREET_DIRECTION                                                               W
# STREET_NAME                                                          RANDOLPH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                         REPORTED, NOT EVIDENT
# INJURIES_TOTAL                                                               1.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                1.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                    14
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    3
# LATITUDE                                                               41.884547
# LONGITUDE                                                             -87.641201
# LOCATION                                 POINT (-87.64120093714 41.884547224337)
# CRASH_UNIT_ID                                                             611178
# RD_NO_y                                                                 JC199149
# CRASH_DATE_y                                              03/25/2019 02:43:00 PM
# UNIT_NO                                                                        1
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               1.0
# CMRC_VEH_I                                                                   NaN
# MAKE                                                                   CHEVROLET
# MODEL                                                                      CRUZE
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                              2017.0
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                    RIDESHARE SERVICE
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                            TURNING LEFT
# OCCUPANT_CNT                                                                 2.0
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                   FRONT-LEFT
#
#                                                                                1  \
# CRASH_RECORD_ID                79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...
# RD_NO_x                                                                 JC199149
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              03/25/2019 02:43:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                          ONE-WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                      INJURY AND / OR TOW DUE TO CRASH
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      03/25/2019 03:17:00 PM
# PRIM_CONTRIBUTORY_CAUSE                               IMPROPER TURNING/NO SIGNAL
# SEC_CONTRIBUTORY_CAUSE                       DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# STREET_NO                                                                    536
# STREET_DIRECTION                                                               W
# STREET_NAME                                                          RANDOLPH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                         REPORTED, NOT EVIDENT
# INJURIES_TOTAL                                                               1.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                1.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                    14
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    3
# LATITUDE                                                               41.884547
# LONGITUDE                                                             -87.641201
# LOCATION                                 POINT (-87.64120093714 41.884547224337)
# CRASH_UNIT_ID                                                             611179
# RD_NO_y                                                                 JC199149
# CRASH_DATE_y                                              03/25/2019 02:43:00 PM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                      CAMRY
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                              2010.0
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                 1.0
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                  FRONT-RIGHT
#
#                                                                                2  \
# CRASH_RECORD_ID                792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...
# RD_NO_x                                                                 JB422857
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              09/05/2018 08:40:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                           ANGLE
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      09/05/2018 09:00:00 AM
# PRIM_CONTRIBUTORY_CAUSE        VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...
# SEC_CONTRIBUTORY_CAUSE                             FAILING TO YIELD RIGHT-OF-WAY
# STREET_NO                                                                   4821
# STREET_DIRECTION                                                               N
# STREET_NAME                                                           ELSTON AVE
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                               0.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                0.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                     8
# CRASH_DAY_OF_WEEK                                                              4
# CRASH_MONTH                                                                    9
# LATITUDE                                                               41.968562
# LONGITUDE                                                             -87.740659
# LOCATION                                POINT (-87.740659314632 41.968562453871)
# CRASH_UNIT_ID                                                             470531
# RD_NO_y                                                                 JB422857
# CRASH_DATE_y                                              09/05/2018 08:40:00 AM
# UNIT_NO                                                                        1
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                    4RUNNER
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                              2002.0
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                         SPORT UTILITY VEHICLE (SUV)
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                               N
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                 1.0
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                        FRONT
#
#                                                                                3  \
# CRASH_RECORD_ID                792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...
# RD_NO_x                                                                 JB422857
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              09/05/2018 08:40:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                           ANGLE
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      09/05/2018 09:00:00 AM
# PRIM_CONTRIBUTORY_CAUSE        VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...
# SEC_CONTRIBUTORY_CAUSE                             FAILING TO YIELD RIGHT-OF-WAY
# STREET_NO                                                                   4821
# STREET_DIRECTION                                                               N
# STREET_NAME                                                           ELSTON AVE
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                               0.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                0.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                     8
# CRASH_DAY_OF_WEEK                                                              4
# CRASH_MONTH                                                                    9
# LATITUDE                                                               41.968562
# LONGITUDE                                                             -87.740659
# LOCATION                                POINT (-87.740659314632 41.968562453871)
# CRASH_UNIT_ID                                                             470532
# RD_NO_y                                                                 JB422857
# CRASH_DATE_y                                              09/05/2018 08:40:00 AM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                      CAMRY
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                              2014.0
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                              SE
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                 1.0
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                   REAR-RIGHT
#
#                                                                                6
# CRASH_RECORD_ID                05b1982cdba5d8a00e7e76ad1ecdab0e598429f78481d2...
# RD_NO_x                                                                 JF378711
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              08/29/2022 11:30:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                        REAR END
# TRAFFICWAY_TYPE                                                         FOUR WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                             $501 - $1,500
# DATE_POLICE_NOTIFIED                                      09/01/2022 11:30:00 AM
# PRIM_CONTRIBUTORY_CAUSE                             DISREGARDING TRAFFIC SIGNALS
# SEC_CONTRIBUTORY_CAUSE                                            NOT APPLICABLE
# STREET_NO                                                                   3939
# STREET_DIRECTION                                                               W
# STREET_NAME                                                              79TH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                               0.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                0.0
# INJURIES_NO_INDICATION                                                       3.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                    11
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    8
# LATITUDE                                                               41.749348
# LONGITUDE                                                             -87.721097
# LOCATION                                POINT (-87.721096727406 41.749348170421)
# CRASH_UNIT_ID                                                            1410559
# RD_NO_y                                                                 JF378711
# CRASH_DATE_y                                              08/29/2022 11:30:00 AM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                                     UNKNOWN
# MODEL                                               OTHER (EXPLAIN IN NARRATIVE)
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                 NaN
# VEHICLE_DEFECT                                                           UNKNOWN
# VEHICLE_TYPE                                             TRACTOR W/ SEMI-TRAILER
# VEHICLE_USE                                             COMMERCIAL - SINGLE UNIT
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                 1.0
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                      UNKNOWN

# %% [markdown]
# # fixme I had to move this code to later, and it's redundant, so I just removed the dataframe from being merged back later

# %%
# '''Also drop the following columns:
# EXCEED_SPEED_LIMIT_I
# HIT_AND_RUN_I
# NOT_RIGHT_OF_WAY_I
# INTERSECTION_RELATED_I	
# '''

# df.drop(columns=['EXCEED_SPEED_LIMIT_I',
#                  'HIT_AND_RUN_I',
#                  'NOT_RIGHT_OF_WAY_I',
#                  'INTERSECTION_RELATED_I',
#                  ], inplace=True)

# df.shape

# %% [markdown]
# ## Chopping down the data
#
# There's just too much
#
# Do after the initial clean to get a better sample.

# %%
df.shape
# Out:
# (845294, 60)

# %%
df = df.sample(frac=0.1, random_state=42)

# %%
df.shape
# Out:
# (84529, 60)

# %%
# Define the target groups
target_groups = {
    'Failures to Follow Traffic Rules': [
        'FAILING TO YIELD RIGHT-OF-WAY',
        'FOLLOWING TOO CLOSELY',
        'IMPROPER OVERTAKING/PASSING',
        'FAILING TO REDUCE SPEED TO AVOID CRASH',
        'IMPROPER BACKING',
        'IMPROPER LANE USAGE',
        'IMPROPER TURNING/NO SIGNAL',
        'DISREGARDING TRAFFIC SIGNALS',
        'DISREGARDING STOP SIGN',
        'DISREGARDING OTHER TRAFFIC SIGNS',
        'DISREGARDING YIELD SIGN',
        'EXCEEDING SAFE SPEED FOR CONDITIONS', 
        'DRIVING ON WRONG SIDE/WRONG WAY', 
        'EXCEEDING AUTHORIZED SPEED LIMIT',
        'TURNING RIGHT ON RED', 
        'DISREGARDING ROAD MARKINGS'
    ],
    'Driver Behavior and Awareness': [
        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE',
        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
        'DISTRACTION - FROM INSIDE VEHICLE',
        'PHYSICAL CONDITION OF DRIVER',
        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
        'DISTRACTION - FROM OUTSIDE VEHICLE',
        'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)',
        'CELL PHONE USE OTHER THAN TEXTING',
        'TEXTING', 
        'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)'
    ],
    'Environmental Factors': [
        'WEATHER',
        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
        'ROAD CONSTRUCTION/MAINTENANCE',
        'ROAD ENGINEERING/SURFACE/MARKING DEFECTS'
    ],
    'Vehicle-related Issues': [
        'EQUIPMENT - VEHICLE CONDITION'
    ],
    'Other Specific Circumstances': [
        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
        'ANIMAL',
        'RELATED TO BUS STOP',
        'BICYCLE ADVANCING LEGALLY ON RED LIGHT',
        'OBSTRUCTED CROSSWALKS',
        'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT',
        'PASSING STOPPED SCHOOL BUS'
    ]
}

# Group the targets based on the defined groups
for group, targets in target_groups.items():
    df.loc[df['PRIM_CONTRIBUTORY_CAUSE'].isin(targets), 'PRIM_CONTRIBUTORY_CAUSE'] = group

# Cut out the df_targets with the grouped targets
df_targets = df[['PRIM_CONTRIBUTORY_CAUSE']]

# Print the unique grouped targets
print(df_targets['PRIM_CONTRIBUTORY_CAUSE'].unique())
# Out:
# ['Driver Behavior and Awareness' 'Failures to Follow Traffic Rules'
#  'Vehicle-related Issues' 'Other Specific Circumstances'
#  'Environmental Factors']

# %% [markdown]
# ## Cleaning Leftover Columns

# %% [markdown]
# ### Split Into categorical and numerical

# %% [markdown]
# Now that they have been merged on CRASH_RECORD_ID, I'm going to remove that column, and create a new index

# %%
df = df.drop('CRASH_RECORD_ID', axis=1)

# %%
df = df.reset_index(drop=True)

# %%
index = df.index

# %%
print(index)
# Out:
# RangeIndex(start=0, stop=84529, step=1)

# %%
# split df into categorical and numerical dataframes
df_cat = df.select_dtypes(include='object')
df_num = df.select_dtypes(exclude='object')

# %%
# df_cat = categorical_data.reset_index(drop=True)
# df_num = numerical_data.reset_index(drop=True)

# %% [markdown]
# #### Numerical Cleaning

# %% [markdown]
# Okay so everything that is left over with the numerical columns should be able to be filled with 0.

# %%
# check df_num for nulls
df_num.isnull().sum()
# Out:
# POSTED_SPEED_LIMIT                   0
# STREET_NO                            0
# NUM_UNITS                            0
# INJURIES_TOTAL                      53
# INJURIES_FATAL                      53
# INJURIES_INCAPACITATING             53
# INJURIES_NON_INCAPACITATING         53
# INJURIES_REPORTED_NOT_EVIDENT       53
# INJURIES_NO_INDICATION              53
# INJURIES_UNKNOWN                    53
# CRASH_HOUR                           0
# CRASH_DAY_OF_WEEK                    0
# CRASH_MONTH                          0
# LATITUDE                           628
# LONGITUDE                          628
# CRASH_UNIT_ID                        0
# UNIT_NO                              0
# NUM_PASSENGERS                   70032
# VEHICLE_YEAR                     11534
# OCCUPANT_CNT                      1812
# dtype: int64

# %%
# fill all missing values in df_num with 0
df_num.fillna(0, inplace=True)

# %% [markdown]
# #### categorical cleaning

# %%
df_cat.isna().sum()
# Out:
# RD_NO_x                      492
# CRASH_DATE_EST_I           80331
# CRASH_DATE_x                   0
# TRAFFIC_CONTROL_DEVICE         0
# DEVICE_CONDITION               0
# WEATHER_CONDITION              0
# LIGHTING_CONDITION             0
# FIRST_CRASH_TYPE               0
# TRAFFICWAY_TYPE                0
# ALIGNMENT                      0
# ROADWAY_SURFACE_COND           0
# ROAD_DEFECT                    0
# REPORT_TYPE                 2721
# CRASH_TYPE                     0
# INTERSECTION_RELATED_I     60026
# NOT_RIGHT_OF_WAY_I         81543
# HIT_AND_RUN_I              64360
# DAMAGE                         0
# DATE_POLICE_NOTIFIED           0
# PRIM_CONTRIBUTORY_CAUSE        0
# SEC_CONTRIBUTORY_CAUSE         0
# STREET_DIRECTION               0
# STREET_NAME                    0
# MOST_SEVERE_INJURY            53
# LOCATION                     628
# RD_NO_y                      533
# CRASH_DATE_y                   0
# UNIT_TYPE                    115
# CMRC_VEH_I                 82780
# MAKE                        1813
# MODEL                       1820
# LIC_PLATE_STATE             7588
# VEHICLE_DEFECT              1812
# VEHICLE_TYPE                1812
# VEHICLE_USE                 1812
# TRAVEL_DIRECTION            1812
# MANEUVER                    1812
# EXCEED_SPEED_LIMIT_I       84303
# FIRST_CONTACT_POINT         1952
# dtype: int64

# %%
# print out the value_counts for every column in df_cat
for col in df_cat.columns:
    print(col)
    print(df_cat[col].value_counts())
    print('')
# Out:
# RD_NO_x
# JG128293    4
# JD231781    4
# JD224890    3
# JA373631    3
# JD160054    3
#            ..
# JB136751    1
# JF490890    1
# JC417825    1
# HZ173439    1
# JE466864    1
# Name: RD_NO_x, Length: 79219, dtype: int64
#
# CRASH_DATE_EST_I
# Y    3544
# N     654
# Name: CRASH_DATE_EST_I, dtype: int64
#
# CRASH_DATE_x
# 11/10/2017 10:30:00 AM    7
# 03/14/2017 08:00:00 AM    6
# 07/06/2018 03:30:00 PM    6
# 11/06/2017 06:00:00 PM    6
# 05/27/2022 02:00:00 PM    5
#                          ..
# 11/08/2019 07:20:00 PM    1
# 02/02/2017 12:15:00 PM    1
# 05/01/2019 06:00:00 PM    1
# 05/30/2021 02:00:00 AM    1
# 12/05/2021 12:15:00 PM    1
# Name: CRASH_DATE_x, Length: 75087, dtype: int64
#
# TRAFFIC_CONTROL_DEVICE
# NO CONTROLS                 42947
# TRAFFIC SIGNAL              28261
# STOP SIGN/FLASHER           10243
# UNKNOWN                      1625
# OTHER                         630
# LANE USE MARKING              180
# YIELD                         154
# OTHER REG. SIGN                98
# OTHER WARNING SIGN             78
# PEDESTRIAN CROSSING SIGN       62
# RAILROAD CROSSING GATE         59
# DELINEATORS                    43
# POLICE/FLAGMAN                 42
# SCHOOL ZONE                    38
# FLASHING CONTROL SIGNAL        31
# OTHER RAILROAD CROSSING        21
# NO PASSING                      7
# RR CROSSING SIGN                7
# BICYCLE CROSSING SIGN           3
# Name: TRAFFIC_CONTROL_DEVICE, dtype: int64
#
# DEVICE_CONDITION
# NO CONTROLS                 43853
# FUNCTIONING PROPERLY        35886
# UNKNOWN                      3346
# OTHER                         671
# FUNCTIONING IMPROPERLY        473
# NOT FUNCTIONING               249
# WORN REFLECTIVE MATERIAL       37
# MISSING                        14
# Name: DEVICE_CONDITION, dtype: int64
#
# WEATHER_CONDITION
# CLEAR                     67861
# RAIN                       7949
# SNOW                       3306
# CLOUDY/OVERCAST            2925
# UNKNOWN                    1768
# OTHER                       238
# FREEZING RAIN/DRIZZLE       183
# FOG/SMOKE/HAZE              130
# SLEET/HAIL                  111
# BLOWING SNOW                 45
# SEVERE CROSS WIND GATE       13
# Name: WEATHER_CONDITION, dtype: int64
#
# LIGHTING_CONDITION
# DAYLIGHT                  56315
# DARKNESS, LIGHTED ROAD    19526
# DARKNESS                   3624
# DUSK                       2509
# DAWN                       1407
# UNKNOWN                    1148
# Name: LIGHTING_CONDITION, dtype: int64
#
# FIRST_CRASH_TYPE
# REAR END                        22749
# TURNING                         14900
# SIDESWIPE SAME DIRECTION        13641
# PARKED MOTOR VEHICLE            12867
# ANGLE                           11343
# PEDESTRIAN                       1877
# FIXED OBJECT                     1853
# SIDESWIPE OPPOSITE DIRECTION     1277
# PEDALCYCLIST                     1192
# HEAD ON                           847
# REAR TO FRONT                     839
# REAR TO SIDE                      485
# OTHER OBJECT                      345
# REAR TO REAR                      127
# OTHER NONCOLLISION                106
# ANIMAL                             43
# OVERTURNED                         31
# TRAIN                               7
# Name: FIRST_CRASH_TYPE, dtype: int64
#
# TRAFFICWAY_TYPE
# NOT DIVIDED                        37434
# DIVIDED - W/MEDIAN (NOT RAISED)    15316
# ONE-WAY                             9286
# FOUR WAY                            5959
# DIVIDED - W/MEDIAN BARRIER          5507
# PARKING LOT                         4239
# OTHER                               2145
# T-INTERSECTION                      1193
# ALLEY                               1000
# CENTER TURN LANE                     799
# UNKNOWN                              465
# RAMP                                 282
# UNKNOWN INTERSECTION TYPE            233
# DRIVEWAY                             218
# FIVE POINT, OR MORE                  137
# TRAFFIC ROUTE                        118
# Y-INTERSECTION                       108
# NOT REPORTED                          52
# L-INTERSECTION                        20
# ROUNDABOUT                            18
# Name: TRAFFICWAY_TYPE, dtype: int64
#
# ALIGNMENT
# STRAIGHT AND LEVEL       82209
# STRAIGHT ON GRADE         1250
# CURVE, LEVEL               622
# STRAIGHT ON HILLCREST      265
# CURVE ON GRADE             147
# CURVE ON HILLCREST          36
# Name: ALIGNMENT, dtype: int64
#
# ROADWAY_SURFACE_COND
# DRY                64475
# WET                12237
# UNKNOWN             3687
# SNOW OR SLUSH       3192
# ICE                  716
# OTHER                193
# SAND, MUD, DIRT       29
# Name: ROADWAY_SURFACE_COND, dtype: int64
#
# ROAD_DEFECT
# NO DEFECTS           72200
# UNKNOWN              10815
# RUT, HOLES             472
# OTHER                  463
# WORN SURFACE           353
# SHOULDER DEFECT        164
# DEBRIS ON ROADWAY       62
# Name: ROAD_DEFECT, dtype: int64
#
# REPORT_TYPE
# NOT ON SCENE (DESK REPORT)    41192
# ON SCENE                      40593
# AMENDED                          23
# Name: REPORT_TYPE, dtype: int64
#
# CRASH_TYPE
# NO INJURY / DRIVE AWAY              57300
# INJURY AND / OR TOW DUE TO CRASH    27229
# Name: CRASH_TYPE, dtype: int64
#
# INTERSECTION_RELATED_I
# Y    23453
# N     1050
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# Y    2683
# N     303
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# Y    19061
# N     1108
# Name: HIT_AND_RUN_I, dtype: int64
#
# DAMAGE
# OVER $1,500      54566
# $501 - $1,500    20902
# $500 OR LESS      9061
# Name: DAMAGE, dtype: int64
#
# DATE_POLICE_NOTIFIED
# 10/12/2020 04:00:00 PM    5
# 12/11/2017 06:00:00 PM    5
# 11/10/2017 12:00:00 PM    5
# 02/01/2023 06:30:00 PM    5
# 02/13/2019 03:00:00 PM    5
#                          ..
# 06/25/2017 05:10:00 PM    1
# 01/29/2019 04:15:00 PM    1
# 02/04/2022 10:40:00 AM    1
# 10/10/2019 06:36:00 AM    1
# 12/05/2021 12:23:00 PM    1
# Name: DATE_POLICE_NOTIFIED, Length: 76976, dtype: int64
#
# PRIM_CONTRIBUTORY_CAUSE
# Failures to Follow Traffic Rules    68902
# Driver Behavior and Awareness       10761
# Environmental Factors                3449
# Vehicle-related Issues                955
# Other Specific Circumstances          462
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64
#
# SEC_CONTRIBUTORY_CAUSE
# NOT APPLICABLE                                                                      31539
# UNABLE TO DETERMINE                                                                 19942
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               5648
# FAILING TO YIELD RIGHT-OF-WAY                                                        4564
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  4313
# FOLLOWING TOO CLOSELY                                                                4019
# IMPROPER OVERTAKING/PASSING                                                          2237
# IMPROPER LANE USAGE                                                                  1965
# WEATHER                                                                              1668
# IMPROPER TURNING/NO SIGNAL                                                           1531
# IMPROPER BACKING                                                                     1069
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER      959
# DISREGARDING TRAFFIC SIGNALS                                                          555
# DISREGARDING STOP SIGN                                                                464
# DISTRACTION - FROM INSIDE VEHICLE                                                     461
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                  421
# PHYSICAL CONDITION OF DRIVER                                                          409
# DRIVING ON WRONG SIDE/WRONG WAY                                                       300
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      299
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   285
# EQUIPMENT - VEHICLE CONDITION                                                         283
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    254
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    244
# ROAD CONSTRUCTION/MAINTENANCE                                                         137
# DISREGARDING OTHER TRAFFIC SIGNS                                                      131
# DISREGARDING ROAD MARKINGS                                                            131
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       119
# CELL PHONE USE OTHER THAN TEXTING                                                     100
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                               84
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                      60
# TURNING RIGHT ON RED                                                                   60
# RELATED TO BUS STOP                                                                    53
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)            52
# ANIMAL                                                                                 40
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 40
# DISREGARDING YIELD SIGN                                                                33
# TEXTING                                                                                29
# PASSING STOPPED SCHOOL BUS                                                             14
# OBSTRUCTED CROSSWALKS                                                                   9
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                               8
# Name: SEC_CONTRIBUTORY_CAUSE, dtype: int64
#
# STREET_DIRECTION
# W    30494
# S    28199
# N    20162
# E     5674
# Name: STREET_DIRECTION, dtype: int64
#
# STREET_NAME
# WESTERN AVE    2390
# PULASKI RD     2102
# ASHLAND AVE    2010
# CICERO AVE     1949
# HALSTED ST     1795
#                ...
# MUSEUM DR         1
# DOMINICK ST       1
# MANKATO AVE       1
# PATTON AVE        1
# LEMONT AVE        1
# Name: STREET_NAME, Length: 1238, dtype: int64
#
# MOST_SEVERE_INJURY
# NO INDICATION OF INJURY     69913
# NONINCAPACITATING INJURY     8315
# REPORTED, NOT EVIDENT        4371
# INCAPACITATING INJURY        1773
# FATAL                         104
# Name: MOST_SEVERE_INJURY, dtype: int64
#
# LOCATION
# POINT (-87.905309125103 41.976201139024)    125
# POINT (-87.619928173678 41.900958919109)     71
# POINT (-87.580147768689 41.791420282098)     65
# POINT (-87.585971992965 41.751460603167)     61
# POINT (-87.585275565077 41.722257273006)     47
#                                            ...
# POINT (-87.67034985567 41.910484408377)       1
# POINT (-87.75726362208 41.917296724881)       1
# POINT (-87.65328285522 41.736046135003)       1
# POINT (-87.735957031738 41.877742206751)      1
# POINT (-87.669283608713 41.721030194448)      1
# Name: LOCATION, Length: 53342, dtype: int64
#
# RD_NO_y
# JD231781    4
# JG128293    4
# JD169092    3
# JC204623    3
# JC231754    3
#            ..
# JC417825    1
# HZ173439    1
# JB569248    1
# HY519056    1
# JE466864    1
# Name: RD_NO_y, Length: 79179, dtype: int64
#
# CRASH_DATE_y
# 11/10/2017 10:30:00 AM    7
# 07/06/2018 03:30:00 PM    6
# 11/06/2017 06:00:00 PM    6
# 03/14/2017 08:00:00 AM    6
# 08/24/2018 01:30:00 PM    5
#                          ..
# 07/20/2016 04:10:00 PM    1
# 11/08/2019 07:20:00 PM    1
# 02/02/2017 12:15:00 PM    1
# 05/01/2019 06:00:00 PM    1
# 12/05/2021 12:15:00 PM    1
# Name: CRASH_DATE_y, Length: 75088, dtype: int64
#
# UNIT_TYPE
# DRIVER                 74797
# PARKED                  7412
# PEDESTRIAN               998
# BICYCLE                  605
# DRIVERLESS               518
# NON-MOTOR VEHICLE         62
# NON-CONTACT VEHICLE       16
# DISABLED VEHICLE           5
# EQUESTRIAN                 1
# Name: UNIT_TYPE, dtype: int64
#
# CMRC_VEH_I
# Y    1161
# N     588
# Name: CMRC_VEH_I, dtype: int64
#
# MAKE
# CHEVROLET                                                      10147
# FORD                                                            8474
# NISSAN                                                          6945
# HONDA                                                           6370
# TOYOTA MOTOR COMPANY, LTD.                                      5452
#                                                                ...
# POWERLINE PRODUCTS, DIV. WHITE OAK,INC.                            1
# CASCADE CORPORATION                                                1
# A & B TRAILER MANUFACTURING COMPANY, INC. (CROWN POINT, IN)        1
# HUSQVARNA                                                          1
# W.F. MICKEY BODY CO., INC.                                         1
# Name: MAKE, Length: 376, dtype: int64
#
# MODEL
# UNKNOWN                                    8960
# OTHER (EXPLAIN IN NARRATIVE)               5257
# CAMRY                                      2762
# COROLLA                                    1749
# CIVIC                                      1691
#                                            ...
# HUSQVARNA                                     1
# CASCADE CORP.                                 1
# RX8                                           1
# POWERLINE PRODUCTS, DIV. WHITE OAK,INC.       1
# SENECA                                        1
# Name: MODEL, Length: 1363, dtype: int64
#
# LIC_PLATE_STATE
# IL    70845
# IN     1573
# XX     1047
# WI      528
# MI      336
# FL      302
# TX      253
# OH      211
# AZ      186
# MO      166
# CA      147
# IA      145
# MN      143
# TN      110
# GA       86
# OK       67
# PA       67
# NY       64
# KY       51
# MS       47
# NJ       47
# AL       46
# VA       43
# WA       37
# NC       36
# MD       34
# CO       34
# LA       30
# KS       29
# NB       27
# MA       23
# ME       22
# AR       22
# SC       18
# OR       16
# CT       16
# UT       13
# MT       11
# NV       10
# ND       10
# NH        6
# ID        5
# SD        5
# DC        5
# NM        4
# VT        4
# AK        4
# RI        3
# WV        3
# DE        2
# WY        2
# Name: LIC_PLATE_STATE, dtype: int64
#
# VEHICLE_DEFECT
# NONE                50357
# UNKNOWN             31422
# OTHER                 384
# BRAKES                366
# TIRES                  68
# STEERING               42
# WHEELS                 27
# SUSPENSION             18
# ENGINE/MOTOR           10
# LIGHTS                  9
# WINDOWS                 4
# FUEL SYSTEM             4
# CARGO                   2
# TRAILER COUPLING        2
# SIGNALS                 1
# EXHAUST                 1
# Name: VEHICLE_DEFECT, dtype: int64
#
# VEHICLE_TYPE
# PASSENGER                                 54689
# SPORT UTILITY VEHICLE (SUV)               11946
# VAN/MINI-VAN                               4244
# UNKNOWN/NA                                 4049
# PICKUP                                     2648
# TRUCK - SINGLE UNIT                        1648
# BUS OVER 15 PASS.                           970
# TRACTOR W/ SEMI-TRAILER                     845
# OTHER                                       839
# MOTORCYCLE (OVER 150CC)                     234
# BUS UP TO 15 PASS.                          206
# SINGLE UNIT TRUCK WITH TRAILER              114
# TRACTOR W/O SEMI-TRAILER                    112
# OTHER VEHICLE WITH TRAILER                   95
# MOPED OR MOTORIZED BICYCLE                   29
# MOTOR DRIVEN CYCLE                           23
# AUTOCYCLE                                    10
# FARM EQUIPMENT                                5
# 3-WHEELED MOTORCYCLE (2 REAR WHEELS)          5
# ALL-TERRAIN VEHICLE (ATV)                     3
# RECREATIONAL OFF-HIGHWAY VEHICLE (ROV)        2
# SNOWMOBILE                                    1
# Name: VEHICLE_TYPE, dtype: int64
#
# VEHICLE_USE
# PERSONAL                        58750
# UNKNOWN/NA                      12088
# NOT IN USE                       3104
# OTHER                            2614
# TAXI/FOR HIRE                    1139
# COMMERCIAL - SINGLE UNIT         1135
# RIDESHARE SERVICE                 818
# CTA                               650
# POLICE                            591
# CONSTRUCTION/MAINTENANCE          430
# COMMERCIAL - MULTI-UNIT           378
# OTHER TRANSIT                     226
# SCHOOL BUS                        222
# TOW TRUCK                         190
# AMBULANCE                          81
# STATE OWNED                        71
# FIRE                               70
# DRIVER EDUCATION                   57
# MASS TRANSIT                       50
# LAWN CARE/LANDSCAPING              34
# AGRICULTURE                         9
# CAMPER/RV - TOWED/MULTI-UNIT        4
# CAMPER/RV - SINGLE UNIT             4
# HOUSE TRAILER                       1
# MILITARY                            1
# Name: VEHICLE_USE, dtype: int64
#
# TRAVEL_DIRECTION
# N          20062
# S          19637
# W          18048
# E          17870
# UNKNOWN     2933
# SE          1232
# NW          1090
# NE           927
# SW           918
# Name: TRAVEL_DIRECTION, dtype: int64
#
# MANEUVER
# STRAIGHT AHEAD                        41830
# PARKED                                 7544
# SLOW/STOP IN TRAFFIC                   7435
# TURNING LEFT                           5843
# BACKING                                3579
# TURNING RIGHT                          3100
# PASSING/OVERTAKING                     2789
# CHANGING LANES                         1919
# UNKNOWN/NA                             1845
# OTHER                                  1225
# ENTERING TRAFFIC LANE FROM PARKING     1108
# U-TURN                                  639
# MERGING                                 615
# STARTING IN TRAFFIC                     545
# SKIDDING/CONTROL LOSS                   455
# ENTER FROM DRIVE/ALLEY                  417
# AVOIDING VEHICLES/OBJECTS               415
# LEAVING TRAFFIC LANE TO PARK            369
# PARKED IN TRAFFIC LANE                  219
# SLOW/STOP - LEFT TURN                   203
# DRIVING WRONG WAY                       192
# SLOW/STOP - RIGHT TURN                  137
# NEGOTIATING A CURVE                     116
# SLOW/STOP - LOAD/UNLOAD                  90
# TURNING ON RED                           45
# DRIVERLESS                               31
# DIVERGING                                 8
# DISABLED                                  4
# Name: MANEUVER, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# Y    179
# N     47
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64
#
# FIRST_CONTACT_POINT
# FRONT                 18144
# REAR                  11910
# SIDE-RIGHT             5459
# SIDE-LEFT              5444
# FRONT-LEFT             5082
# FRONT-RIGHT            4858
# FRONT-LEFT-CORNER      4820
# FRONT-RIGHT-CORNER     4662
# REAR-LEFT              4040
# UNKNOWN                3718
# OTHER                  2427
# REAR-RIGHT             2154
# REAR-LEFT-CORNER       1838
# TOTAL (ALL AREAS)      1586
# REAR-RIGHT-CORNER      1509
# SIDE-LEFT-REAR         1133
# SIDE-RIGHT-REAR         848
# SIDE-LEFT-FRONT         697
# SIDE-RIGHT-FRONT        658
# ROOF                    631
# NONE                    600
# UNDER CARRIAGE          284
# TOP                      75
# Name: FIRST_CONTACT_POINT, dtype: int64

# %%
df_cat_dropped_cols = df_cat.drop(columns=['RD_NO_x',
                'CRASH_DATE_EST_I', 
                'REPORT_TYPE', 
                'STREET_DIRECTION',
                'STREET_NAME',
                'LOCATION', 
                'RD_NO_y', 
                'CMRC_VEH_I', 
                'LIC_PLATE_STATE', 
                'TRAVEL_DIRECTION'
                 ])

# %%
df_cat_dropped_cols.isna().sum()
# Out:
# CRASH_DATE_x                   0
# TRAFFIC_CONTROL_DEVICE         0
# DEVICE_CONDITION               0
# WEATHER_CONDITION              0
# LIGHTING_CONDITION             0
# FIRST_CRASH_TYPE               0
# TRAFFICWAY_TYPE                0
# ALIGNMENT                      0
# ROADWAY_SURFACE_COND           0
# ROAD_DEFECT                    0
# CRASH_TYPE                     0
# INTERSECTION_RELATED_I     60026
# NOT_RIGHT_OF_WAY_I         81543
# HIT_AND_RUN_I              64360
# DAMAGE                         0
# DATE_POLICE_NOTIFIED           0
# PRIM_CONTRIBUTORY_CAUSE        0
# SEC_CONTRIBUTORY_CAUSE         0
# MOST_SEVERE_INJURY            53
# CRASH_DATE_y                   0
# UNIT_TYPE                    115
# MAKE                        1813
# MODEL                       1820
# VEHICLE_DEFECT              1812
# VEHICLE_TYPE                1812
# VEHICLE_USE                 1812
# MANEUVER                    1812
# EXCEED_SPEED_LIMIT_I       84303
# FIRST_CONTACT_POINT         1952
# dtype: int64

# %% [markdown]
# ## Getting target variable

# %%
'''
remove
PRIM_CONTRIBUTORY_CAUSE
and
SEC_CONTRIBUTORY_CAUSE
from df_cat_dropped_cols
assign it to it's own dataframe called df_targets,
and then export df_targets to csv
'''

# Specifically I'm going to make prim cause the target and remove secondary, maybe I'll come back to it if I have time.
df_targets = df_cat_dropped_cols[['PRIM_CONTRIBUTORY_CAUSE']]
df_cat_dropped_cols.drop(columns=['PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE'], inplace=True)
df_targets.to_csv('data/df_targets.csv')

# %%
df_targets.isna().sum()
# Out:
# PRIM_CONTRIBUTORY_CAUSE    0
# dtype: int64

# %%
df_targets.dtypes
# Out:
# PRIM_CONTRIBUTORY_CAUSE    object
# dtype: object

# %%
df_targets.value_counts()

# give me the value counts for each column in df_targets
for col in df_targets.columns:
    print(col)
    print(df_targets[col].value_counts())
    print('')
# Out:
# PRIM_CONTRIBUTORY_CAUSE
# Failures to Follow Traffic Rules    68902
# Driver Behavior and Awareness       10761
# Environmental Factors                3449
# Vehicle-related Issues                955
# Other Specific Circumstances          462
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64

# %% [markdown]
# ## splitting into ordinal and nominal

# %%
'''
assign to df_cat_ordinal 
INTERSECTION_RELATED_I
NOT_RIGHT_OF_WAY_I
HIT_AND_RUN_I
and EXCEED_SPEED_LIMIT_I
'''
df_cat_ordinal = df_cat_dropped_cols[['INTERSECTION_RELATED_I',
                                        'NOT_RIGHT_OF_WAY_I',
                                        'HIT_AND_RUN_I',
                                        'EXCEED_SPEED_LIMIT_I'
                                        ]]

# assign the rest to nominal
df_cat_nominal = df_cat_dropped_cols.drop(columns=['INTERSECTION_RELATED_I',
                                        'NOT_RIGHT_OF_WAY_I',
                                        'HIT_AND_RUN_I',
                                        'EXCEED_SPEED_LIMIT_I'
                                        ])

# %% [markdown]
# ### ordinal

# %%
# list nulls in ordinal
df_cat_ordinal.isna().sum()
# Out:
# INTERSECTION_RELATED_I    60026
# NOT_RIGHT_OF_WAY_I        81543
# HIT_AND_RUN_I             64360
# EXCEED_SPEED_LIMIT_I      84303
# dtype: int64

# %%
for col in df_cat_ordinal.columns:
    print(col)
    print(df_cat_ordinal[col].value_counts())
    print('')
# Out:
# INTERSECTION_RELATED_I
# Y    23453
# N     1050
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# Y    2683
# N     303
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# Y    19061
# N     1108
# Name: HIT_AND_RUN_I, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# Y    179
# N     47
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64

# %%
# fill all nulls in ordinal with 'N'
df_cat_ordinal_filled = df_cat_ordinal.fillna('N')

# %%
df_cat_ordinal_filled.isna().sum()
# Out:
# INTERSECTION_RELATED_I    0
# NOT_RIGHT_OF_WAY_I        0
# HIT_AND_RUN_I             0
# EXCEED_SPEED_LIMIT_I      0
# dtype: int64

# %%
for col in df_cat_ordinal_filled.columns:
    print(col)
    print(df_cat_ordinal_filled[col].value_counts())
    print('')
# Out:
# INTERSECTION_RELATED_I
# N    61076
# Y    23453
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# N    81846
# Y     2683
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# N    65468
# Y    19061
# Name: HIT_AND_RUN_I, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# N    84350
# Y      179
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64

# %% [markdown]
# ### nominal

# %%
# list nulls in nominal
df_cat_nominal.isna().sum()
# Out:
# CRASH_DATE_x                 0
# TRAFFIC_CONTROL_DEVICE       0
# DEVICE_CONDITION             0
# WEATHER_CONDITION            0
# LIGHTING_CONDITION           0
# FIRST_CRASH_TYPE             0
# TRAFFICWAY_TYPE              0
# ALIGNMENT                    0
# ROADWAY_SURFACE_COND         0
# ROAD_DEFECT                  0
# CRASH_TYPE                   0
# DAMAGE                       0
# DATE_POLICE_NOTIFIED         0
# MOST_SEVERE_INJURY          53
# CRASH_DATE_y                 0
# UNIT_TYPE                  115
# MAKE                      1813
# MODEL                     1820
# VEHICLE_DEFECT            1812
# VEHICLE_TYPE              1812
# VEHICLE_USE               1812
# MANEUVER                  1812
# FIRST_CONTACT_POINT       1952
# dtype: int64

# %%
# assign the columnsn in df_cat_nominal with nulls to df_cat_nominal_null
df_cat_nominal_null = df_cat_nominal[['FIRST_CONTACT_POINT',
                                      'MANEUVER',
                                      'VEHICLE_USE',
                                      'VEHICLE_TYPE',
                                      'VEHICLE_DEFECT',
                                      'MODEL',
                                      'MAKE',
                                      'UNIT_TYPE',
                                      'MOST_SEVERE_INJURY']]

# assign the rest to df_cat_nominal_nonull
df_cat_nominal_nonull = df_cat_nominal.drop(columns=['FIRST_CONTACT_POINT',
                                                    'MANEUVER',
                                                    'VEHICLE_USE',
                                                    'VEHICLE_TYPE',
                                                    'VEHICLE_DEFECT',
                                                    'MODEL',
                                                    'MAKE',
                                                    'UNIT_TYPE',
                                                    'MOST_SEVERE_INJURY'])

# %%
# check that the split worked
df_cat_nominal_null.isna().sum()
# Out:
# FIRST_CONTACT_POINT    1952
# MANEUVER               1812
# VEHICLE_USE            1812
# VEHICLE_TYPE           1812
# VEHICLE_DEFECT         1812
# MODEL                  1820
# MAKE                   1813
# UNIT_TYPE               115
# MOST_SEVERE_INJURY       53
# dtype: int64

# %%
df_cat_nominal_nonull.isna().sum()
# Out:
# CRASH_DATE_x              0
# TRAFFIC_CONTROL_DEVICE    0
# DEVICE_CONDITION          0
# WEATHER_CONDITION         0
# LIGHTING_CONDITION        0
# FIRST_CRASH_TYPE          0
# TRAFFICWAY_TYPE           0
# ALIGNMENT                 0
# ROADWAY_SURFACE_COND      0
# ROAD_DEFECT               0
# CRASH_TYPE                0
# DAMAGE                    0
# DATE_POLICE_NOTIFIED      0
# CRASH_DATE_y              0
# dtype: int64

# %%
# how many columns are in df_cat_nominal_null?
print(len(df_cat_nominal_null.columns))

# how many columns are in df_cat_nominal_nonull?
print(len(df_cat_nominal_nonull.columns))
# Out:
# 9
# 14

# %%
print(9 + 15)
# Out:
# 24

# %%
# how many columsn were in df_cat_nominal?
print(len(df_cat_nominal.columns))
# Out:
# 23

# %%
for col in df_cat_nominal_null.columns:
    print(col)
    print(df_cat_nominal_null[col].value_counts())
    print('')
# Out:
# FIRST_CONTACT_POINT
# FRONT                 18144
# REAR                  11910
# SIDE-RIGHT             5459
# SIDE-LEFT              5444
# FRONT-LEFT             5082
# FRONT-RIGHT            4858
# FRONT-LEFT-CORNER      4820
# FRONT-RIGHT-CORNER     4662
# REAR-LEFT              4040
# UNKNOWN                3718
# OTHER                  2427
# REAR-RIGHT             2154
# REAR-LEFT-CORNER       1838
# TOTAL (ALL AREAS)      1586
# REAR-RIGHT-CORNER      1509
# SIDE-LEFT-REAR         1133
# SIDE-RIGHT-REAR         848
# SIDE-LEFT-FRONT         697
# SIDE-RIGHT-FRONT        658
# ROOF                    631
# NONE                    600
# UNDER CARRIAGE          284
# TOP                      75
# Name: FIRST_CONTACT_POINT, dtype: int64
#
# MANEUVER
# STRAIGHT AHEAD                        41830
# PARKED                                 7544
# SLOW/STOP IN TRAFFIC                   7435
# TURNING LEFT                           5843
# BACKING                                3579
# TURNING RIGHT                          3100
# PASSING/OVERTAKING                     2789
# CHANGING LANES                         1919
# UNKNOWN/NA                             1845
# OTHER                                  1225
# ENTERING TRAFFIC LANE FROM PARKING     1108
# U-TURN                                  639
# MERGING                                 615
# STARTING IN TRAFFIC                     545
# SKIDDING/CONTROL LOSS                   455
# ENTER FROM DRIVE/ALLEY                  417
# AVOIDING VEHICLES/OBJECTS               415
# LEAVING TRAFFIC LANE TO PARK            369
# PARKED IN TRAFFIC LANE                  219
# SLOW/STOP - LEFT TURN                   203
# DRIVING WRONG WAY                       192
# SLOW/STOP - RIGHT TURN                  137
# NEGOTIATING A CURVE                     116
# SLOW/STOP - LOAD/UNLOAD                  90
# TURNING ON RED                           45
# DRIVERLESS                               31
# DIVERGING                                 8
# DISABLED                                  4
# Name: MANEUVER, dtype: int64
#
# VEHICLE_USE
# PERSONAL                        58750
# UNKNOWN/NA                      12088
# NOT IN USE                       3104
# OTHER                            2614
# TAXI/FOR HIRE                    1139
# COMMERCIAL - SINGLE UNIT         1135
# RIDESHARE SERVICE                 818
# CTA                               650
# POLICE                            591
# CONSTRUCTION/MAINTENANCE          430
# COMMERCIAL - MULTI-UNIT           378
# OTHER TRANSIT                     226
# SCHOOL BUS                        222
# TOW TRUCK                         190
# AMBULANCE                          81
# STATE OWNED                        71
# FIRE                               70
# DRIVER EDUCATION                   57
# MASS TRANSIT                       50
# LAWN CARE/LANDSCAPING              34
# AGRICULTURE                         9
# CAMPER/RV - TOWED/MULTI-UNIT        4
# CAMPER/RV - SINGLE UNIT             4
# HOUSE TRAILER                       1
# MILITARY                            1
# Name: VEHICLE_USE, dtype: int64
#
# VEHICLE_TYPE
# PASSENGER                                 54689
# SPORT UTILITY VEHICLE (SUV)               11946
# VAN/MINI-VAN                               4244
# UNKNOWN/NA                                 4049
# PICKUP                                     2648
# TRUCK - SINGLE UNIT                        1648
# BUS OVER 15 PASS.                           970
# TRACTOR W/ SEMI-TRAILER                     845
# OTHER                                       839
# MOTORCYCLE (OVER 150CC)                     234
# BUS UP TO 15 PASS.                          206
# SINGLE UNIT TRUCK WITH TRAILER              114
# TRACTOR W/O SEMI-TRAILER                    112
# OTHER VEHICLE WITH TRAILER                   95
# MOPED OR MOTORIZED BICYCLE                   29
# MOTOR DRIVEN CYCLE                           23
# AUTOCYCLE                                    10
# FARM EQUIPMENT                                5
# 3-WHEELED MOTORCYCLE (2 REAR WHEELS)          5
# ALL-TERRAIN VEHICLE (ATV)                     3
# RECREATIONAL OFF-HIGHWAY VEHICLE (ROV)        2
# SNOWMOBILE                                    1
# Name: VEHICLE_TYPE, dtype: int64
#
# VEHICLE_DEFECT
# NONE                50357
# UNKNOWN             31422
# OTHER                 384
# BRAKES                366
# TIRES                  68
# STEERING               42
# WHEELS                 27
# SUSPENSION             18
# ENGINE/MOTOR           10
# LIGHTS                  9
# WINDOWS                 4
# FUEL SYSTEM             4
# CARGO                   2
# TRAILER COUPLING        2
# SIGNALS                 1
# EXHAUST                 1
# Name: VEHICLE_DEFECT, dtype: int64
#
# MODEL
# UNKNOWN                                    8960
# OTHER (EXPLAIN IN NARRATIVE)               5257
# CAMRY                                      2762
# COROLLA                                    1749
# CIVIC                                      1691
#                                            ...
# HUSQVARNA                                     1
# CASCADE CORP.                                 1
# RX8                                           1
# POWERLINE PRODUCTS, DIV. WHITE OAK,INC.       1
# SENECA                                        1
# Name: MODEL, Length: 1363, dtype: int64
#
# MAKE
# CHEVROLET                                                      10147
# FORD                                                            8474
# NISSAN                                                          6945
# HONDA                                                           6370
# TOYOTA MOTOR COMPANY, LTD.                                      5452
#                                                                ...
# POWERLINE PRODUCTS, DIV. WHITE OAK,INC.                            1
# CASCADE CORPORATION                                                1
# A & B TRAILER MANUFACTURING COMPANY, INC. (CROWN POINT, IN)        1
# HUSQVARNA                                                          1
# W.F. MICKEY BODY CO., INC.                                         1
# Name: MAKE, Length: 376, dtype: int64
#
# UNIT_TYPE
# DRIVER                 74797
# PARKED                  7412
# PEDESTRIAN               998
# BICYCLE                  605
# DRIVERLESS               518
# NON-MOTOR VEHICLE         62
# NON-CONTACT VEHICLE       16
# DISABLED VEHICLE           5
# EQUESTRIAN                 1
# Name: UNIT_TYPE, dtype: int64
#
# MOST_SEVERE_INJURY
# NO INDICATION OF INJURY     69913
# NONINCAPACITATING INJURY     8315
# REPORTED, NOT EVIDENT        4371
# INCAPACITATING INJURY        1773
# FATAL                         104
# Name: MOST_SEVERE_INJURY, dtype: int64

# %%
'''Fill the following columns with 'UNKNOWN' in df_cat_nominal_null:
MOST_SEVERE_INJURY
UNIT_TYPE
MAKE
MODEL
VEHICLE_DEFECT
FIRST_CONTACT_POINT
'''

df_cat_nominal_null['MOST_SEVERE_INJURY'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['UNIT_TYPE'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['MAKE'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['MODEL'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['VEHICLE_DEFECT'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['FIRST_CONTACT_POINT'].fillna('UNKNOWN', inplace=True)
# Out:
# C:\Users\gerba\AppData\Local\Temp\ipykernel_23412\848517612.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['MOST_SEVERE_INJURY'].fillna('UNKNOWN', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_23412\848517612.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['UNIT_TYPE'].fillna('UNKNOWN', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_23412\848517612.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['MAKE'].fillna('UNKNOWN', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_23412\848517612.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['MODEL'].fillna('UNKNOWN', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_23412\848517612.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['VEHICLE_DEFECT'].fillna('UNKNOWN', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_23412\848517612.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['FIRST_CONTACT_POINT'].fillna('UNKNOWN', inplace=True)

# %%
'''Fill the following columns with 'UNKNOWN/NA' in df_cat_nominal_null:
VEHICLE_TYPE
VEHICLE_USE
MANUEVER
'''

df_cat_nominal_null['VEHICLE_TYPE'].fillna('UNKNOWN/NA', inplace=True)
df_cat_nominal_null['VEHICLE_USE'].fillna('UNKNOWN/NA', inplace=True)
df_cat_nominal_null['MANEUVER'].fillna('UNKNOWN/NA', inplace=True)
# Out:
# C:\Users\gerba\AppData\Local\Temp\ipykernel_23412\4055445953.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['VEHICLE_TYPE'].fillna('UNKNOWN/NA', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_23412\4055445953.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['VEHICLE_USE'].fillna('UNKNOWN/NA', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_23412\4055445953.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['MANEUVER'].fillna('UNKNOWN/NA', inplace=True)

# %% [markdown]
# ## Combining nominal and ordinal again

# %% [markdown]
# modifying this because the ordinal columsn don't seem to contribute anything

# %%
# combine df_cat_nominal_null and df_cat_nominal_nonull into df_cat_nominal_filled
df_cat_nominal_filled = pd.concat([df_cat_nominal_null, df_cat_nominal_nonull], axis=1)

# combine df_cat_nominal_filled and df_cat_ordinal_filled into df_cat_filled
# df_cat_filled = pd.concat([df_cat_nominal_filled, df_cat_ordinal_filled], axis=1)

# %% [markdown]
# ## Combining everything again

# %%
# Combine df_cat_filled and df_num into df_clean

df_clean = pd.concat([df_num, df_cat_nominal_filled], axis=1)

# %%
df_clean.head().T
# Out:
#                                                      0  \
# POSTED_SPEED_LIMIT                                  25
# STREET_NO                                           33
# NUM_UNITS                                            2
# INJURIES_TOTAL                                     0.0
# INJURIES_FATAL                                     0.0
# INJURIES_INCAPACITATING                            0.0
# INJURIES_NON_INCAPACITATING                        0.0
# INJURIES_REPORTED_NOT_EVIDENT                      0.0
# INJURIES_NO_INDICATION                             1.0
# INJURIES_UNKNOWN                                   0.0
# CRASH_HOUR                                          17
# CRASH_DAY_OF_WEEK                                    5
# CRASH_MONTH                                          3
# LATITUDE                                     41.882798
# LONGITUDE                                   -87.632242
# CRASH_UNIT_ID                                   598511
# UNIT_NO                                              2
# NUM_PASSENGERS                                     0.0
# VEHICLE_YEAR                                    2016.0
# OCCUPANT_CNT                                       0.0
# FIRST_CONTACT_POINT                               REAR
# MANEUVER                                        PARKED
# VEHICLE_USE                                   PERSONAL
# VEHICLE_TYPE                                 PASSENGER
# VEHICLE_DEFECT                                    NONE
# MODEL                                              300
# MAKE                                          CHRYSLER
# UNIT_TYPE                                       PARKED
# MOST_SEVERE_INJURY             NO INDICATION OF INJURY
# CRASH_DATE_x                    03/07/2019 05:10:00 PM
# TRAFFIC_CONTROL_DEVICE                     NO CONTROLS
# DEVICE_CONDITION                           NO CONTROLS
# WEATHER_CONDITION                                CLEAR
# LIGHTING_CONDITION                            DAYLIGHT
# FIRST_CRASH_TYPE                  PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                ONE-WAY
# ALIGNMENT                           STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                               DRY
# ROAD_DEFECT                                 NO DEFECTS
# CRASH_TYPE                      NO INJURY / DRIVE AWAY
# DAMAGE                                   $501 - $1,500
# DATE_POLICE_NOTIFIED            03/07/2019 05:35:00 PM
# CRASH_DATE_y                    03/07/2019 05:10:00 PM
#
#                                                      1  \
# POSTED_SPEED_LIMIT                                  20
# STREET_NO                                         4300
# NUM_UNITS                                            2
# INJURIES_TOTAL                                     0.0
# INJURIES_FATAL                                     0.0
# INJURIES_INCAPACITATING                            0.0
# INJURIES_NON_INCAPACITATING                        0.0
# INJURIES_REPORTED_NOT_EVIDENT                      0.0
# INJURIES_NO_INDICATION                             2.0
# INJURIES_UNKNOWN                                   0.0
# CRASH_HOUR                                          11
# CRASH_DAY_OF_WEEK                                    6
# CRASH_MONTH                                         11
# LATITUDE                                     41.814835
# LONGITUDE                                   -87.742283
# CRASH_UNIT_ID                                   532437
# UNIT_NO                                              2
# NUM_PASSENGERS                                     0.0
# VEHICLE_YEAR                                    1999.0
# OCCUPANT_CNT                                       1.0
# FIRST_CONTACT_POINT                              FRONT
# MANEUVER                                STRAIGHT AHEAD
# VEHICLE_USE                                   PERSONAL
# VEHICLE_TYPE                                    PICKUP
# VEHICLE_DEFECT                                    NONE
# MODEL                                        SILVERADO
# MAKE                                         CHEVROLET
# UNIT_TYPE                                       DRIVER
# MOST_SEVERE_INJURY             NO INDICATION OF INJURY
# CRASH_DATE_x                    11/30/2018 11:30:00 AM
# TRAFFIC_CONTROL_DEVICE               STOP SIGN/FLASHER
# DEVICE_CONDITION                  FUNCTIONING PROPERLY
# WEATHER_CONDITION                                CLEAR
# LIGHTING_CONDITION                            DAYLIGHT
# FIRST_CRASH_TYPE                                 ANGLE
# TRAFFICWAY_TYPE                            NOT DIVIDED
# ALIGNMENT                           STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                               WET
# ROAD_DEFECT                                 NO DEFECTS
# CRASH_TYPE                      NO INJURY / DRIVE AWAY
# DAMAGE                                     OVER $1,500
# DATE_POLICE_NOTIFIED            11/30/2018 11:50:00 AM
# CRASH_DATE_y                    11/30/2018 11:30:00 AM
#
#                                                               2  \
# POSTED_SPEED_LIMIT                                           30
# STREET_NO                                                  2198
# NUM_UNITS                                                     1
# INJURIES_TOTAL                                              0.0
# INJURIES_FATAL                                              0.0
# INJURIES_INCAPACITATING                                     0.0
# INJURIES_NON_INCAPACITATING                                 0.0
# INJURIES_REPORTED_NOT_EVIDENT                               0.0
# INJURIES_NO_INDICATION                                      1.0
# INJURIES_UNKNOWN                                            0.0
# CRASH_HOUR                                                   19
# CRASH_DAY_OF_WEEK                                             4
# CRASH_MONTH                                                  10
# LATITUDE                                              41.852375
# LONGITUDE                                            -87.666171
# CRASH_UNIT_ID                                            756632
# UNIT_NO                                                       1
# NUM_PASSENGERS                                              0.0
# VEHICLE_YEAR                                             2000.0
# OCCUPANT_CNT                                                1.0
# FIRST_CONTACT_POINT                                       FRONT
# MANEUVER                                         STRAIGHT AHEAD
# VEHICLE_USE                                            PERSONAL
# VEHICLE_TYPE                                          PASSENGER
# VEHICLE_DEFECT                                           BRAKES
# MODEL                                                  Explorer
# MAKE                                                       FORD
# UNIT_TYPE                                                DRIVER
# MOST_SEVERE_INJURY                      NO INDICATION OF INJURY
# CRASH_DATE_x                             10/09/2019 07:00:00 PM
# TRAFFIC_CONTROL_DEVICE                              NO CONTROLS
# DEVICE_CONDITION                                    NO CONTROLS
# WEATHER_CONDITION                                         CLEAR
# LIGHTING_CONDITION                                     DAYLIGHT
# FIRST_CRASH_TYPE                                   FIXED OBJECT
# TRAFFICWAY_TYPE                 DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                    STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                        DRY
# ROAD_DEFECT                                          NO DEFECTS
# CRASH_TYPE                     INJURY AND / OR TOW DUE TO CRASH
# DAMAGE                                              OVER $1,500
# DATE_POLICE_NOTIFIED                     10/09/2019 07:00:00 PM
# CRASH_DATE_y                             10/09/2019 07:00:00 PM
#
#                                                              3  \
# POSTED_SPEED_LIMIT                                          30
# STREET_NO                                                 2800
# NUM_UNITS                                                    2
# INJURIES_TOTAL                                             0.0
# INJURIES_FATAL                                             0.0
# INJURIES_INCAPACITATING                                    0.0
# INJURIES_NON_INCAPACITATING                                0.0
# INJURIES_REPORTED_NOT_EVIDENT                              0.0
# INJURIES_NO_INDICATION                                     2.0
# INJURIES_UNKNOWN                                           0.0
# CRASH_HOUR                                                  10
# CRASH_DAY_OF_WEEK                                            5
# CRASH_MONTH                                                  7
# LATITUDE                                              41.86662
# LONGITUDE                                           -87.695971
# CRASH_UNIT_ID                                           179946
# UNIT_NO                                                      2
# NUM_PASSENGERS                                             0.0
# VEHICLE_YEAR                                               0.0
# OCCUPANT_CNT                                               1.0
# FIRST_CONTACT_POINT                                       REAR
# MANEUVER                                               BACKING
# VEHICLE_USE                                         UNKNOWN/NA
# VEHICLE_TYPE                                        UNKNOWN/NA
# VEHICLE_DEFECT                                         UNKNOWN
# MODEL                                                  UNKNOWN
# MAKE                                                   UNKNOWN
# UNIT_TYPE                                               DRIVER
# MOST_SEVERE_INJURY                     NO INDICATION OF INJURY
# CRASH_DATE_x                            07/06/2017 10:00:00 AM
# TRAFFIC_CONTROL_DEVICE                          TRAFFIC SIGNAL
# DEVICE_CONDITION                          FUNCTIONING PROPERLY
# WEATHER_CONDITION                                        CLEAR
# LIGHTING_CONDITION                                    DAYLIGHT
# FIRST_CRASH_TYPE                                      REAR END
# TRAFFICWAY_TYPE                DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                   STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                       DRY
# ROAD_DEFECT                                         NO DEFECTS
# CRASH_TYPE                              NO INJURY / DRIVE AWAY
# DAMAGE                                             OVER $1,500
# DATE_POLICE_NOTIFIED                    07/06/2017 02:30:00 PM
# CRASH_DATE_y                            07/06/2017 10:00:00 AM
#
#                                                              4
# POSTED_SPEED_LIMIT                                          30
# STREET_NO                                                 7739
# NUM_UNITS                                                    2
# INJURIES_TOTAL                                             0.0
# INJURIES_FATAL                                             0.0
# INJURIES_INCAPACITATING                                    0.0
# INJURIES_NON_INCAPACITATING                                0.0
# INJURIES_REPORTED_NOT_EVIDENT                              0.0
# INJURIES_NO_INDICATION                                     2.0
# INJURIES_UNKNOWN                                           0.0
# CRASH_HOUR                                                  15
# CRASH_DAY_OF_WEEK                                            6
# CRASH_MONTH                                                 11
# LATITUDE                                             42.022164
# LONGITUDE                                           -87.666715
# CRASH_UNIT_ID                                            98704
# UNIT_NO                                                      1
# NUM_PASSENGERS                                             0.0
# VEHICLE_YEAR                                            2016.0
# OCCUPANT_CNT                                               1.0
# FIRST_CONTACT_POINT                                 FRONT-LEFT
# MANEUVER                                                 OTHER
# VEHICLE_USE                                           PERSONAL
# VEHICLE_TYPE                                         PASSENGER
# VEHICLE_DEFECT                                            NONE
# MODEL                                                  MUSTANG
# MAKE                                                      FORD
# UNIT_TYPE                                               DRIVER
# MOST_SEVERE_INJURY                     NO INDICATION OF INJURY
# CRASH_DATE_x                            11/18/2016 03:17:00 PM
# TRAFFIC_CONTROL_DEVICE                             NO CONTROLS
# DEVICE_CONDITION                                   NO CONTROLS
# WEATHER_CONDITION                                        CLEAR
# LIGHTING_CONDITION                                    DAYLIGHT
# FIRST_CRASH_TYPE                      SIDESWIPE SAME DIRECTION
# TRAFFICWAY_TYPE                DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                   STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                       WET
# ROAD_DEFECT                                         NO DEFECTS
# CRASH_TYPE                              NO INJURY / DRIVE AWAY
# DAMAGE                                             OVER $1,500
# DATE_POLICE_NOTIFIED                    11/18/2016 04:05:00 PM
# CRASH_DATE_y                            11/18/2016 03:17:00 PM

# %% [markdown]
# # Exporting the cleaned data

# %%
# export df_clean to csv
df_clean.to_csv('data/df_clean.csv')

# %%
df_clean.shape
# Out:
# (84529, 43)

# %%
df_clean.isna().sum()
# Out:
# POSTED_SPEED_LIMIT               0
# STREET_NO                        0
# NUM_UNITS                        0
# INJURIES_TOTAL                   0
# INJURIES_FATAL                   0
# INJURIES_INCAPACITATING          0
# INJURIES_NON_INCAPACITATING      0
# INJURIES_REPORTED_NOT_EVIDENT    0
# INJURIES_NO_INDICATION           0
# INJURIES_UNKNOWN                 0
# CRASH_HOUR                       0
# CRASH_DAY_OF_WEEK                0
# CRASH_MONTH                      0
# LATITUDE                         0
# LONGITUDE                        0
# CRASH_UNIT_ID                    0
# UNIT_NO                          0
# NUM_PASSENGERS                   0
# VEHICLE_YEAR                     0
# OCCUPANT_CNT                     0
# FIRST_CONTACT_POINT              0
# MANEUVER                         0
# VEHICLE_USE                      0
# VEHICLE_TYPE                     0
# VEHICLE_DEFECT                   0
# MODEL                            0
# MAKE                             0
# UNIT_TYPE                        0
# MOST_SEVERE_INJURY               0
# CRASH_DATE_x                     0
# TRAFFIC_CONTROL_DEVICE           0
# DEVICE_CONDITION                 0
# WEATHER_CONDITION                0
# LIGHTING_CONDITION               0
# FIRST_CRASH_TYPE                 0
# TRAFFICWAY_TYPE                  0
# ALIGNMENT                        0
# ROADWAY_SURFACE_COND             0
# ROAD_DEFECT                      0
# CRASH_TYPE                       0
# DAMAGE                           0
# DATE_POLICE_NOTIFIED             0
# CRASH_DATE_y                     0
# dtype: int64
