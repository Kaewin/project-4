# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Data Sources
#
# [crashes](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Crashes/85ca-t3if)
#
# [vehicles](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Vehicles/68nd-jvt3)
#
# [people](https://data.cityofchicago.org/Transportation/Traffic-Crashes-People/u6pd-qa9d)

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import scipy.sparse as sp
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
# imort 'data/merged.csv'
df = pd.read_csv('data/merged.csv')
# Out:
# c:\Anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (30,31,32,33,69,88,89,90,92,96,97,98,101,103,106,107,109,119) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## Initial Drop

# %%
'''
drom from df 
CMV_ID
USDOT_NO
CCMC_NO
ILCC_NO
COMMERCIAL_SRC
GVWR
CARRIER_NAME
CARRIER_STATE
CARRIER_CITY
HAZMAT_PLACARDS_I
HAZMAT_NAME
UN_NO
HAZMAT_PRESENT_I
HAZMAT_REPORT_I
HAZMAT_REPORT_NO
MCS_REPORT_I
MCS_REPORT_NO
HAZMAT_VIO_CAUSE_CRASH_I
MCS_VIO_CAUSE_CRASH_I
IDOT_PERMIT_NO
WIDE_LOAD_I
TRAILER1_WIDTH
TRAILER2_WIDTH
TRAILER1_LENGTH
TRAILER2_LENGTH
TOTAL_VEHICLE_LENGTH
AXLE_CNT
VEHICLE_CONFIG
CARGO_BODY_TYPE
LOAD_TYPE
HAZMAT_OUT_OF_SERVICE_I
MCS_OUT_OF_SERVICE_I
HAZMAT_CLASS
PHOTOS_TAKEN_I
STATEMENTS_TAKEN_I
DOORING_I
WORK_ZONE_I
WORK_ZONE_TYPE
WORKERS_PRESENT_I
TOWED_I
FIRE_I
TOWED_BY
TOWED_TO
AREA_00_I
AREA_01_I
AREA_02_I
AREA_03_I
AREA_04_I
AREA_05_I
AREA_06_I
AREA_07_I
AREA_08_I
AREA_09_I
AREA_10_I
AREA_11_I
AREA_12_I
AREA_99_I
'''

df.drop(columns=['CMV_ID',
                 'USDOT_NO',
                 'CCMC_NO',
                 'ILCC_NO',
                 'COMMERCIAL_SRC',
                 'GVWR',
                 'CARRIER_NAME',
                 'CARRIER_STATE',
                 'CARRIER_CITY',
                 'HAZMAT_PLACARDS_I',
                 'HAZMAT_NAME',
                 'UN_NO',
                 'HAZMAT_PRESENT_I',
                 'HAZMAT_REPORT_I',
                 'HAZMAT_REPORT_NO',
                 'MCS_REPORT_I',
                 'MCS_REPORT_NO',
                 'HAZMAT_VIO_CAUSE_CRASH_I',
                 'MCS_VIO_CAUSE_CRASH_I',
                 'IDOT_PERMIT_NO',
                 'WIDE_LOAD_I',
                 'TRAILER1_WIDTH',
                 'TRAILER2_WIDTH',
                 'TRAILER1_LENGTH',
                 'TRAILER2_LENGTH',
                 'TOTAL_VEHICLE_LENGTH',
                 'AXLE_CNT',
                 'VEHICLE_CONFIG',
                 'CARGO_BODY_TYPE',
                 'LOAD_TYPE',
                 'HAZMAT_OUT_OF_SERVICE_I',
                 'MCS_OUT_OF_SERVICE_I',
                 'HAZMAT_CLASS',
                 
                 'PHOTOS_TAKEN_I',
                 'STATEMENTS_TAKEN_I',
                 'DOORING_I',
                 'WORK_ZONE_I',
                 'WORK_ZONE_TYPE',
                 'WORKERS_PRESENT_I',
                 
                 'TOWED_I',
                 'FIRE_I',
                 
                 'TOWED_BY',
                 'TOWED_TO',
                 'AREA_00_I',
                 'AREA_01_I',
                 'AREA_02_I',
                 'AREA_03_I',
                 'AREA_04_I',
                 'AREA_05_I',
                 'AREA_06_I',
                 'AREA_07_I',
                 'AREA_08_I',
                 'AREA_09_I',
                 'AREA_10_I',
                 'AREA_11_I',
                 'AREA_12_I',
                 'AREA_99_I',
                 
                 'BEAT_OF_OCCURRENCE',
                 'VEHICLE_ID',
                 'LANE_CNT',
                 ], inplace=True)

# %%
df.shape
# Out:
# (1491794, 60)

# %%
# remove all rows where PRIM_CONTRIBUTORY_CAUSE is UNABLE TO DETERMINE and NOT APPLICABLE
df = df[df['PRIM_CONTRIBUTORY_CAUSE'] != 'NOT APPLICABLE']
df = df[df['PRIM_CONTRIBUTORY_CAUSE'] != 'UNABLE TO DETERMINE']

# %%
# check
df['PRIM_CONTRIBUTORY_CAUSE'].value_counts()
# Out:
# FAILING TO YIELD RIGHT-OF-WAY                                                       164915
# FOLLOWING TOO CLOSELY                                                               151936
# IMPROPER OVERTAKING/PASSING                                                          73063
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               66695
# IMPROPER BACKING                                                                     58478
# IMPROPER LANE USAGE                                                                  54856
# IMPROPER TURNING/NO SIGNAL                                                           49008
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  47434
# DISREGARDING TRAFFIC SIGNALS                                                         30303
# WEATHER                                                                              21949
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     20053
# DISREGARDING STOP SIGN                                                               16971
# DISTRACTION - FROM INSIDE VEHICLE                                                    10788
# PHYSICAL CONDITION OF DRIVER                                                          9547
# EQUIPMENT - VEHICLE CONDITION                                                         9473
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    8439
# DRIVING ON WRONG SIDE/WRONG WAY                                                       8435
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                  8154
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    6156
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      4166
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   3398
# DISREGARDING OTHER TRAFFIC SIGNS                                                      3083
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     2547
# ROAD CONSTRUCTION/MAINTENANCE                                                         2414
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                              2344
# CELL PHONE USE OTHER THAN TEXTING                                                     2135
# DISREGARDING ROAD MARKINGS                                                            1786
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       1667
# TURNING RIGHT ON RED                                                                  1092
# ANIMAL                                                                                 984
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)            724
# RELATED TO BUS STOP                                                                    644
# TEXTING                                                                                631
# DISREGARDING YIELD SIGN                                                                509
# PASSING STOPPED SCHOOL BUS                                                             181
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 156
# OBSTRUCTED CROSSWALKS                                                                  138
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                               42
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64

# %%
df.shape
# Out:
# (845294, 60)

# %%
df.head().T
# Out:
#                                                                                0  \
# CRASH_RECORD_ID                79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...
# RD_NO_x                                                                 JC199149
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              03/25/2019 02:43:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                          ONE-WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                      INJURY AND / OR TOW DUE TO CRASH
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      03/25/2019 03:17:00 PM
# PRIM_CONTRIBUTORY_CAUSE                               IMPROPER TURNING/NO SIGNAL
# SEC_CONTRIBUTORY_CAUSE                       DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# STREET_NO                                                                    536
# STREET_DIRECTION                                                               W
# STREET_NAME                                                          RANDOLPH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                         REPORTED, NOT EVIDENT
# INJURIES_TOTAL                                                                 1
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  1
# INJURIES_NO_INDICATION                                                         2
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    14
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    3
# LATITUDE                                                                 41.8845
# LONGITUDE                                                               -87.6412
# LOCATION                                 POINT (-87.64120093714 41.884547224337)
# CRASH_UNIT_ID                                                             611178
# RD_NO_y                                                                 JC199149
# CRASH_DATE_y                                              03/25/2019 02:43:00 PM
# UNIT_NO                                                                        1
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                                 1
# CMRC_VEH_I                                                                   NaN
# MAKE                                                                   CHEVROLET
# MODEL                                                                      CRUZE
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                2017
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                    RIDESHARE SERVICE
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                            TURNING LEFT
# OCCUPANT_CNT                                                                   2
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                   FRONT-LEFT
#
#                                                                                1  \
# CRASH_RECORD_ID                79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...
# RD_NO_x                                                                 JC199149
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              03/25/2019 02:43:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                          ONE-WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                      INJURY AND / OR TOW DUE TO CRASH
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      03/25/2019 03:17:00 PM
# PRIM_CONTRIBUTORY_CAUSE                               IMPROPER TURNING/NO SIGNAL
# SEC_CONTRIBUTORY_CAUSE                       DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# STREET_NO                                                                    536
# STREET_DIRECTION                                                               W
# STREET_NAME                                                          RANDOLPH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                         REPORTED, NOT EVIDENT
# INJURIES_TOTAL                                                                 1
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  1
# INJURIES_NO_INDICATION                                                         2
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    14
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    3
# LATITUDE                                                                 41.8845
# LONGITUDE                                                               -87.6412
# LOCATION                                 POINT (-87.64120093714 41.884547224337)
# CRASH_UNIT_ID                                                             611179
# RD_NO_y                                                                 JC199149
# CRASH_DATE_y                                              03/25/2019 02:43:00 PM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                      CAMRY
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                2010
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                   1
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                  FRONT-RIGHT
#
#                                                                                2  \
# CRASH_RECORD_ID                792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...
# RD_NO_x                                                                 JB422857
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              09/05/2018 08:40:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                           ANGLE
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      09/05/2018 09:00:00 AM
# PRIM_CONTRIBUTORY_CAUSE        VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...
# SEC_CONTRIBUTORY_CAUSE                             FAILING TO YIELD RIGHT-OF-WAY
# STREET_NO                                                                   4821
# STREET_DIRECTION                                                               N
# STREET_NAME                                                           ELSTON AVE
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         2
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                     8
# CRASH_DAY_OF_WEEK                                                              4
# CRASH_MONTH                                                                    9
# LATITUDE                                                                 41.9686
# LONGITUDE                                                               -87.7407
# LOCATION                                POINT (-87.740659314632 41.968562453871)
# CRASH_UNIT_ID                                                             470531
# RD_NO_y                                                                 JB422857
# CRASH_DATE_y                                              09/05/2018 08:40:00 AM
# UNIT_NO                                                                        1
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                    4RUNNER
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                2002
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                         SPORT UTILITY VEHICLE (SUV)
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                               N
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                   1
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                        FRONT
#
#                                                                                3  \
# CRASH_RECORD_ID                792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...
# RD_NO_x                                                                 JB422857
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              09/05/2018 08:40:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                           ANGLE
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      09/05/2018 09:00:00 AM
# PRIM_CONTRIBUTORY_CAUSE        VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...
# SEC_CONTRIBUTORY_CAUSE                             FAILING TO YIELD RIGHT-OF-WAY
# STREET_NO                                                                   4821
# STREET_DIRECTION                                                               N
# STREET_NAME                                                           ELSTON AVE
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         2
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                     8
# CRASH_DAY_OF_WEEK                                                              4
# CRASH_MONTH                                                                    9
# LATITUDE                                                                 41.9686
# LONGITUDE                                                               -87.7407
# LOCATION                                POINT (-87.740659314632 41.968562453871)
# CRASH_UNIT_ID                                                             470532
# RD_NO_y                                                                 JB422857
# CRASH_DATE_y                                              09/05/2018 08:40:00 AM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                      CAMRY
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                2014
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                              SE
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                   1
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                   REAR-RIGHT
#
#                                                                                6
# CRASH_RECORD_ID                05b1982cdba5d8a00e7e76ad1ecdab0e598429f78481d2...
# RD_NO_x                                                                 JF378711
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              08/29/2022 11:30:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                        REAR END
# TRAFFICWAY_TYPE                                                         FOUR WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                             $501 - $1,500
# DATE_POLICE_NOTIFIED                                      09/01/2022 11:30:00 AM
# PRIM_CONTRIBUTORY_CAUSE                             DISREGARDING TRAFFIC SIGNALS
# SEC_CONTRIBUTORY_CAUSE                                            NOT APPLICABLE
# STREET_NO                                                                   3939
# STREET_DIRECTION                                                               W
# STREET_NAME                                                              79TH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         3
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    11
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    8
# LATITUDE                                                                 41.7493
# LONGITUDE                                                               -87.7211
# LOCATION                                POINT (-87.721096727406 41.749348170421)
# CRASH_UNIT_ID                                                            1410559
# RD_NO_y                                                                 JF378711
# CRASH_DATE_y                                              08/29/2022 11:30:00 AM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                                     UNKNOWN
# MODEL                                               OTHER (EXPLAIN IN NARRATIVE)
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                 NaN
# VEHICLE_DEFECT                                                           UNKNOWN
# VEHICLE_TYPE                                             TRACTOR W/ SEMI-TRAILER
# VEHICLE_USE                                             COMMERCIAL - SINGLE UNIT
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                   1
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                      UNKNOWN

# %% [markdown]
# # fixme I had to move this code to later, and it's redundant, so I just removed the dataframe from being merged back later

# %%
# '''Also drop the following columns:
# EXCEED_SPEED_LIMIT_I
# HIT_AND_RUN_I
# NOT_RIGHT_OF_WAY_I
# INTERSECTION_RELATED_I	
# '''

# df.drop(columns=['EXCEED_SPEED_LIMIT_I',
#                  'HIT_AND_RUN_I',
#                  'NOT_RIGHT_OF_WAY_I',
#                  'INTERSECTION_RELATED_I',
#                  ], inplace=True)

# df.shape

# %% [markdown]
# ## Chopping down the data
#
# There's just too much
#
# Do after the initial clean to get a better sample.

# %%
df.shape
# Out:
# (845294, 60)

# %%
df = df.sample(frac=0.01, random_state=42)

# %%
df.shape
# Out:
# (8453, 60)

# %%
# Define the target groups
target_groups = {
    'Failures to Follow Traffic Rules': [
        'FAILING TO YIELD RIGHT-OF-WAY',
        'FOLLOWING TOO CLOSELY',
        'IMPROPER OVERTAKING/PASSING',
        'FAILING TO REDUCE SPEED TO AVOID CRASH',
        'IMPROPER BACKING',
        'IMPROPER LANE USAGE',
        'IMPROPER TURNING/NO SIGNAL',
        'DISREGARDING TRAFFIC SIGNALS',
        'DISREGARDING STOP SIGN',
        'DISREGARDING OTHER TRAFFIC SIGNS',
        'DISREGARDING YIELD SIGN',
        'EXCEEDING SAFE SPEED FOR CONDITIONS', 
        'DRIVING ON WRONG SIDE/WRONG WAY', 
        'EXCEEDING AUTHORIZED SPEED LIMIT',
        'TURNING RIGHT ON RED', 
        'DISREGARDING ROAD MARKINGS'
    ],
    'Driver Behavior and Awareness': [
        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE',
        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
        'DISTRACTION - FROM INSIDE VEHICLE',
        'PHYSICAL CONDITION OF DRIVER',
        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
        'DISTRACTION - FROM OUTSIDE VEHICLE',
        'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)',
        'CELL PHONE USE OTHER THAN TEXTING',
        'TEXTING', 
        'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)'
    ],
    'Environmental Factors': [
        'WEATHER',
        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
        'ROAD CONSTRUCTION/MAINTENANCE',
        'ROAD ENGINEERING/SURFACE/MARKING DEFECTS'
    ],
    'Vehicle-related Issues': [
        'EQUIPMENT - VEHICLE CONDITION'
    ],
    'Other Specific Circumstances': [
        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
        'ANIMAL',
        'RELATED TO BUS STOP',
        'BICYCLE ADVANCING LEGALLY ON RED LIGHT',
        'OBSTRUCTED CROSSWALKS',
        'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT',
        'PASSING STOPPED SCHOOL BUS'
    ]
}

# Group the targets based on the defined groups
for group, targets in target_groups.items():
    df.loc[df['PRIM_CONTRIBUTORY_CAUSE'].isin(targets), 'PRIM_CONTRIBUTORY_CAUSE'] = group

# Cut out the df_targets with the grouped targets
df_targets = df[['PRIM_CONTRIBUTORY_CAUSE']]

# Print the unique grouped targets
print(df_targets['PRIM_CONTRIBUTORY_CAUSE'].unique())
# Out:
# ['Driver Behavior and Awareness' 'Failures to Follow Traffic Rules'
#  'Vehicle-related Issues' 'Other Specific Circumstances'
#  'Environmental Factors']

# %% [markdown]
# ## Cleaning Leftover Columns

# %% [markdown]
# ### Split Into categorical and numerical

# %% [markdown]
# Now that they have been merged on CRASH_RECORD_ID, I'm going to remove that column, and create a new index

# %%
df = df.drop('CRASH_RECORD_ID', axis=1)

# %%
df = df.reset_index(drop=True)

# %%
index = df.index

# %%
print(index)
# Out:
# RangeIndex(start=0, stop=8453, step=1)

# %%
# split df into categorical and numerical dataframes
df_cat = df.select_dtypes(include='object')
df_num = df.select_dtypes(exclude='object')

# %%
# df_cat = categorical_data.reset_index(drop=True)
# df_num = numerical_data.reset_index(drop=True)

# %% [markdown]
# #### Numerical Cleaning

# %% [markdown]
# Okay so everything that is left over with the numerical columns should be able to be filled with 0.

# %%
# check df_num for nulls
df_num.isnull().sum()
# Out:
# POSTED_SPEED_LIMIT                  0
# STREET_NO                           0
# NUM_UNITS                           0
# INJURIES_TOTAL                      1
# INJURIES_FATAL                      1
# INJURIES_INCAPACITATING             1
# INJURIES_NON_INCAPACITATING         1
# INJURIES_REPORTED_NOT_EVIDENT       1
# INJURIES_NO_INDICATION              1
# INJURIES_UNKNOWN                    1
# CRASH_HOUR                          0
# CRASH_DAY_OF_WEEK                   0
# CRASH_MONTH                         0
# LATITUDE                           54
# LONGITUDE                          54
# CRASH_UNIT_ID                       0
# UNIT_NO                             0
# NUM_PASSENGERS                   6997
# VEHICLE_YEAR                     1142
# OCCUPANT_CNT                      180
# dtype: int64

# %%
# fill all missing values in df_num with 0
df_num.fillna(0, inplace=True)
# Out:
# c:\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %% [markdown]
# #### categorical cleaning

# %%
df_cat.isna().sum()
# Out:
# RD_NO_x                      53
# CRASH_DATE_EST_I           8029
# CRASH_DATE_x                  0
# TRAFFIC_CONTROL_DEVICE        0
# DEVICE_CONDITION              0
# WEATHER_CONDITION             0
# LIGHTING_CONDITION            0
# FIRST_CRASH_TYPE              0
# TRAFFICWAY_TYPE               0
# ALIGNMENT                     0
# ROADWAY_SURFACE_COND          0
# ROAD_DEFECT                   0
# REPORT_TYPE                 277
# CRASH_TYPE                    0
# INTERSECTION_RELATED_I     6016
# NOT_RIGHT_OF_WAY_I         8152
# HIT_AND_RUN_I              6456
# DAMAGE                        0
# DATE_POLICE_NOTIFIED          0
# PRIM_CONTRIBUTORY_CAUSE       0
# SEC_CONTRIBUTORY_CAUSE        0
# STREET_DIRECTION              0
# STREET_NAME                   0
# MOST_SEVERE_INJURY            1
# LOCATION                     54
# RD_NO_y                      57
# CRASH_DATE_y                  0
# UNIT_TYPE                    13
# CMRC_VEH_I                 8266
# MAKE                        180
# MODEL                       180
# LIC_PLATE_STATE             766
# VEHICLE_DEFECT              180
# VEHICLE_TYPE                180
# VEHICLE_USE                 180
# TRAVEL_DIRECTION            180
# MANEUVER                    180
# EXCEED_SPEED_LIMIT_I       8430
# FIRST_CONTACT_POINT         199
# dtype: int64

# %%
# print out the value_counts for every column in df_cat
for col in df_cat.columns:
    print(col)
    print(df_cat[col].value_counts())
    print('')
# Out:
# RD_NO_x
# JA249116    2
# JB518075    2
# JA288295    2
# JA506271    2
# JB165417    2
#            ..
# JA441715    1
# JC251655    1
# JE375415    1
# JF132628    1
# JC129554    1
# Name: RD_NO_x, Length: 8362, dtype: int64
#
# CRASH_DATE_EST_I
# Y    362
# N     62
# Name: CRASH_DATE_EST_I, dtype: int64
#
# CRASH_DATE_x
# 03/17/2019 04:15:00 PM    3
# 11/15/2019 07:30:00 AM    2
# 05/03/2019 05:10:00 PM    2
# 06/01/2017 02:00:00 PM    2
# 04/12/2023 08:00:00 AM    2
#                          ..
# 02/28/2018 03:00:00 PM    1
# 03/15/2023 08:00:00 AM    1
# 01/07/2018 05:00:00 PM    1
# 06/25/2020 01:14:00 PM    1
# 06/04/2021 05:20:00 PM    1
# Name: CRASH_DATE_x, Length: 8353, dtype: int64
#
# TRAFFIC_CONTROL_DEVICE
# NO CONTROLS                 4314
# TRAFFIC SIGNAL              2842
# STOP SIGN/FLASHER           1015
# UNKNOWN                      156
# OTHER                         55
# LANE USE MARKING              15
# OTHER REG. SIGN               10
# YIELD                         10
# OTHER WARNING SIGN            10
# RAILROAD CROSSING GATE         8
# SCHOOL ZONE                    6
# OTHER RAILROAD CROSSING        3
# FLASHING CONTROL SIGNAL        3
# PEDESTRIAN CROSSING SIGN       2
# DELINEATORS                    2
# NO PASSING                     1
# POLICE/FLAGMAN                 1
# Name: TRAFFIC_CONTROL_DEVICE, dtype: int64
#
# DEVICE_CONDITION
# NO CONTROLS                 4392
# FUNCTIONING PROPERLY        3603
# UNKNOWN                      305
# OTHER                         66
# FUNCTIONING IMPROPERLY        51
# NOT FUNCTIONING               30
# WORN REFLECTIVE MATERIAL       4
# MISSING                        2
# Name: DEVICE_CONDITION, dtype: int64
#
# WEATHER_CONDITION
# CLEAR                     6787
# RAIN                       775
# SNOW                       341
# CLOUDY/OVERCAST            330
# UNKNOWN                    157
# OTHER                       26
# SLEET/HAIL                  13
# FREEZING RAIN/DRIZZLE       10
# FOG/SMOKE/HAZE              10
# BLOWING SNOW                 2
# SEVERE CROSS WIND GATE       2
# Name: WEATHER_CONDITION, dtype: int64
#
# LIGHTING_CONDITION
# DAYLIGHT                  5641
# DARKNESS, LIGHTED ROAD    1953
# DARKNESS                   352
# DUSK                       252
# DAWN                       154
# UNKNOWN                    101
# Name: LIGHTING_CONDITION, dtype: int64
#
# FIRST_CRASH_TYPE
# REAR END                        2299
# TURNING                         1481
# SIDESWIPE SAME DIRECTION        1330
# PARKED MOTOR VEHICLE            1287
# ANGLE                           1150
# PEDESTRIAN                       192
# FIXED OBJECT                     186
# SIDESWIPE OPPOSITE DIRECTION     128
# PEDALCYCLIST                     119
# REAR TO FRONT                     90
# HEAD ON                           83
# REAR TO SIDE                      42
# OTHER OBJECT                      30
# REAR TO REAR                      16
# OTHER NONCOLLISION                14
# ANIMAL                             4
# OVERTURNED                         2
# Name: FIRST_CRASH_TYPE, dtype: int64
#
# TRAFFICWAY_TYPE
# NOT DIVIDED                        3756
# DIVIDED - W/MEDIAN (NOT RAISED)    1545
# ONE-WAY                             955
# FOUR WAY                            591
# DIVIDED - W/MEDIAN BARRIER          528
# PARKING LOT                         417
# OTHER                               193
# T-INTERSECTION                      116
# ALLEY                                99
# CENTER TURN LANE                     73
# UNKNOWN                              50
# RAMP                                 32
# DRIVEWAY                             20
# UNKNOWN INTERSECTION TYPE            18
# Y-INTERSECTION                       16
# FIVE POINT, OR MORE                  15
# TRAFFIC ROUTE                        12
# NOT REPORTED                         12
# ROUNDABOUT                            3
# L-INTERSECTION                        2
# Name: TRAFFICWAY_TYPE, dtype: int64
#
# ALIGNMENT
# STRAIGHT AND LEVEL       8210
# STRAIGHT ON GRADE         130
# CURVE, LEVEL               68
# STRAIGHT ON HILLCREST      26
# CURVE ON GRADE             16
# CURVE ON HILLCREST          3
# Name: ALIGNMENT, dtype: int64
#
# ROADWAY_SURFACE_COND
# DRY                6483
# WET                1172
# UNKNOWN             365
# SNOW OR SLUSH       340
# ICE                  70
# OTHER                20
# SAND, MUD, DIRT       3
# Name: ROADWAY_SURFACE_COND, dtype: int64
#
# ROAD_DEFECT
# NO DEFECTS           7255
# UNKNOWN              1055
# RUT, HOLES             46
# OTHER                  41
# WORN SURFACE           39
# SHOULDER DEFECT        15
# DEBRIS ON ROADWAY       2
# Name: ROAD_DEFECT, dtype: int64
#
# REPORT_TYPE
# NOT ON SCENE (DESK REPORT)    4128
# ON SCENE                      4048
# Name: REPORT_TYPE, dtype: int64
#
# CRASH_TYPE
# NO INJURY / DRIVE AWAY              5753
# INJURY AND / OR TOW DUE TO CRASH    2700
# Name: CRASH_TYPE, dtype: int64
#
# INTERSECTION_RELATED_I
# Y    2327
# N     110
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# Y    274
# N     27
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# Y    1884
# N     113
# Name: HIT_AND_RUN_I, dtype: int64
#
# DAMAGE
# OVER $1,500      5411
# $501 - $1,500    2119
# $500 OR LESS      923
# Name: DAMAGE, dtype: int64
#
# DATE_POLICE_NOTIFIED
# 04/12/2022 11:15:00 AM    2
# 06/21/2018 04:19:00 PM    2
# 03/17/2019 04:23:00 PM    2
# 12/21/2018 12:15:00 PM    2
# 04/27/2022 11:15:00 AM    2
#                          ..
# 02/14/2019 01:00:00 PM    1
# 04/08/2017 09:40:00 PM    1
# 04/08/2019 09:03:00 PM    1
# 02/24/2023 10:45:00 PM    1
# 01/31/2021 09:50:00 PM    1
# Name: DATE_POLICE_NOTIFIED, Length: 8392, dtype: int64
#
# PRIM_CONTRIBUTORY_CAUSE
# Failures to Follow Traffic Rules    6920
# Driver Behavior and Awareness       1049
# Environmental Factors                316
# Vehicle-related Issues               108
# Other Specific Circumstances          60
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64
#
# SEC_CONTRIBUTORY_CAUSE
# NOT APPLICABLE                                                                      3213
# UNABLE TO DETERMINE                                                                 1941
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               574
# FAILING TO YIELD RIGHT-OF-WAY                                                        445
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  440
# FOLLOWING TOO CLOSELY                                                                395
# IMPROPER OVERTAKING/PASSING                                                          213
# IMPROPER LANE USAGE                                                                  197
# WEATHER                                                                              173
# IMPROPER TURNING/NO SIGNAL                                                           165
# IMPROPER BACKING                                                                     106
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     106
# PHYSICAL CONDITION OF DRIVER                                                          46
# DISREGARDING STOP SIGN                                                                45
# DISTRACTION - FROM INSIDE VEHICLE                                                     40
# DRIVING ON WRONG SIDE/WRONG WAY                                                       38
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                  38
# DISREGARDING TRAFFIC SIGNALS                                                          36
# EQUIPMENT - VEHICLE CONDITION                                                         33
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      31
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   30
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    25
# ROAD CONSTRUCTION/MAINTENANCE                                                         20
# DISREGARDING OTHER TRAFFIC SIGNS                                                      15
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    14
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       14
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     10
# DISREGARDING ROAD MARKINGS                                                             9
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                               8
# CELL PHONE USE OTHER THAN TEXTING                                                      7
# TURNING RIGHT ON RED                                                                   6
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)            5
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 3
# ANIMAL                                                                                 3
# RELATED TO BUS STOP                                                                    3
# DISREGARDING YIELD SIGN                                                                2
# PASSING STOPPED SCHOOL BUS                                                             1
# TEXTING                                                                                1
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                              1
# OBSTRUCTED CROSSWALKS                                                                  1
# Name: SEC_CONTRIBUTORY_CAUSE, dtype: int64
#
# STREET_DIRECTION
# W    3020
# S    2760
# N    2054
# E     619
# Name: STREET_DIRECTION, dtype: int64
#
# STREET_NAME
# WESTERN AVE      243
# PULASKI RD       199
# ASHLAND AVE      187
# CICERO AVE       176
# HALSTED ST       169
#                 ...
# EGGLESTON AVE      1
# DANIEL DR          1
# 67TH PL            1
# GETTYSBURG ST      1
# NEWCASTLE AVE      1
# Name: STREET_NAME, Length: 761, dtype: int64
#
# MOST_SEVERE_INJURY
# NO INDICATION OF INJURY     7024
# NONINCAPACITATING INJURY     831
# REPORTED, NOT EVIDENT        425
# INCAPACITATING INJURY        158
# FATAL                         14
# Name: MOST_SEVERE_INJURY, dtype: int64
#
# LOCATION
# POINT (-87.905309125103 41.976201139024)    16
# POINT (-87.585971992965 41.751460603167)     9
# POINT (-87.619928173678 41.900958919109)     8
# POINT (-87.580147768689 41.791420282098)     7
# POINT (-87.617027423234 41.896804972416)     7
#                                             ..
# POINT (-87.629542771589 41.761883916299)     1
# POINT (-87.692129848551 41.90193012416)      1
# POINT (-87.701172244853 41.885091888021)     1
# POINT (-87.707531487839 41.798849122206)     1
# POINT (-87.615658005255 41.787616470301)     1
# Name: LOCATION, Length: 7674, dtype: int64
#
# RD_NO_y
# JE444482    2
# JB518075    2
# JC545907    2
# JB556307    2
# JA249116    2
#            ..
# JF132628    1
# JF478976    1
# JC141688    1
# JA514764    1
# JC129554    1
# Name: RD_NO_y, Length: 8358, dtype: int64
#
# CRASH_DATE_y
# 03/17/2019 04:15:00 PM    3
# 11/15/2019 07:30:00 AM    2
# 05/03/2019 05:10:00 PM    2
# 06/01/2017 02:00:00 PM    2
# 04/12/2023 08:00:00 AM    2
#                          ..
# 02/28/2018 03:00:00 PM    1
# 03/15/2023 08:00:00 AM    1
# 01/07/2018 05:00:00 PM    1
# 06/25/2020 01:14:00 PM    1
# 06/04/2021 05:20:00 PM    1
# Name: CRASH_DATE_y, Length: 8353, dtype: int64
#
# UNIT_TYPE
# DRIVER                 7465
# PARKED                  765
# PEDESTRIAN              100
# BICYCLE                  64
# DRIVERLESS               42
# NON-MOTOR VEHICLE         3
# NON-CONTACT VEHICLE       1
# Name: UNIT_TYPE, dtype: int64
#
# CMRC_VEH_I
# Y    117
# N     70
# Name: CMRC_VEH_I, dtype: int64
#
# MAKE
# CHEVROLET                           1031
# FORD                                 888
# NISSAN                               725
# HONDA                                630
# TOYOTA MOTOR COMPANY, LTD.           596
#                                     ...
# INTERSTATE PRODUCTS                    1
# SMART                                  1
# CUMMINS ENGINE COMPANY                 1
# FONTAINE TRUCK EQUIPMENT COMPANY       1
# STARCRAFT CORP.                        1
# Name: MAKE, Length: 132, dtype: int64
#
# MODEL
# UNKNOWN                         834
# OTHER (EXPLAIN IN NARRATIVE)    501
# CAMRY                           270
# COROLLA                         196
# CIVIC                           162
#                                ...
# DEERE, JOHN; DEERE & CO.          1
# 740i                              1
# Aztek                             1
# STARCRAFT CORP.                   1
# VEGA                              1
# Name: MODEL, Length: 718, dtype: int64
#
# LIC_PLATE_STATE
# IL    7068
# IN     169
# XX      98
# WI      56
# FL      33
# MI      31
# TX      22
# MO      19
# AZ      16
# IA      15
# CA      15
# OH      14
# MN      13
# GA      12
# TN      12
# OK      11
# NY       9
# WA       7
# MS       6
# PA       5
# LA       5
# NB       4
# AL       4
# MA       4
# NJ       4
# CO       3
# KS       3
# VA       3
# CT       3
# SD       2
# MD       2
# SC       2
# NC       2
# AR       2
# KY       2
# DE       1
# RI       1
# ME       1
# WV       1
# UT       1
# NM       1
# NV       1
# ID       1
# VT       1
# NH       1
# OR       1
# Name: LIC_PLATE_STATE, dtype: int64
#
# VEHICLE_DEFECT
# NONE            5075
# UNKNOWN         3095
# BRAKES            44
# OTHER             37
# TIRES              9
# WHEELS             4
# STEERING           3
# SUSPENSION         2
# WINDOWS            1
# LIGHTS             1
# ENGINE/MOTOR       1
# CARGO              1
# Name: VEHICLE_DEFECT, dtype: int64
#
# VEHICLE_TYPE
# PASSENGER                         5483
# SPORT UTILITY VEHICLE (SUV)       1195
# VAN/MINI-VAN                       428
# UNKNOWN/NA                         368
# PICKUP                             279
# TRUCK - SINGLE UNIT                183
# OTHER                               92
# BUS OVER 15 PASS.                   84
# TRACTOR W/ SEMI-TRAILER             81
# BUS UP TO 15 PASS.                  24
# MOTORCYCLE (OVER 150CC)             22
# OTHER VEHICLE WITH TRAILER          13
# TRACTOR W/O SEMI-TRAILER             8
# SINGLE UNIT TRUCK WITH TRAILER       7
# MOTOR DRIVEN CYCLE                   2
# MOPED OR MOTORIZED BICYCLE           2
# FARM EQUIPMENT                       1
# AUTOCYCLE                            1
# Name: VEHICLE_TYPE, dtype: int64
#
# VEHICLE_USE
# PERSONAL                        5884
# UNKNOWN/NA                      1160
# NOT IN USE                       327
# OTHER                            285
# COMMERCIAL - SINGLE UNIT         126
# TAXI/FOR HIRE                    119
# RIDESHARE SERVICE                 80
# POLICE                            51
# CTA                               51
# CONSTRUCTION/MAINTENANCE          45
# COMMERCIAL - MULTI-UNIT           42
# OTHER TRANSIT                     20
# SCHOOL BUS                        20
# TOW TRUCK                         16
# AMBULANCE                         11
# DRIVER EDUCATION                  10
# MASS TRANSIT                       8
# STATE OWNED                        8
# FIRE                               6
# CAMPER/RV - TOWED/MULTI-UNIT       2
# LAWN CARE/LANDSCAPING              1
# AGRICULTURE                        1
# Name: VEHICLE_USE, dtype: int64
#
# TRAVEL_DIRECTION
# S          1980
# N          1959
# E          1881
# W          1784
# UNKNOWN     272
# SE          113
# NW          111
# NE           89
# SW           84
# Name: TRAVEL_DIRECTION, dtype: int64
#
# MANEUVER
# STRAIGHT AHEAD                        4166
# PARKED                                 771
# SLOW/STOP IN TRAFFIC                   725
# TURNING LEFT                           613
# BACKING                                360
# TURNING RIGHT                          298
# PASSING/OVERTAKING                     267
# UNKNOWN/NA                             194
# CHANGING LANES                         184
# ENTERING TRAFFIC LANE FROM PARKING     143
# OTHER                                  121
# STARTING IN TRAFFIC                     65
# MERGING                                 55
# U-TURN                                  53
# AVOIDING VEHICLES/OBJECTS               47
# LEAVING TRAFFIC LANE TO PARK            38
# ENTER FROM DRIVE/ALLEY                  35
# SKIDDING/CONTROL LOSS                   34
# DRIVING WRONG WAY                       31
# PARKED IN TRAFFIC LANE                  25
# SLOW/STOP - LEFT TURN                   20
# NEGOTIATING A CURVE                     11
# SLOW/STOP - LOAD/UNLOAD                 10
# SLOW/STOP - RIGHT TURN                   3
# TURNING ON RED                           3
# DIVERGING                                1
# Name: MANEUVER, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# Y    18
# N     5
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64
#
# FIRST_CONTACT_POINT
# FRONT                 1816
# REAR                  1204
# FRONT-LEFT             564
# SIDE-LEFT              541
# SIDE-RIGHT             535
# FRONT-LEFT-CORNER      493
# FRONT-RIGHT            484
# FRONT-RIGHT-CORNER     462
# REAR-LEFT              392
# UNKNOWN                357
# OTHER                  254
# REAR-RIGHT             195
# REAR-LEFT-CORNER       177
# REAR-RIGHT-CORNER      163
# TOTAL (ALL AREAS)      153
# SIDE-LEFT-REAR          99
# SIDE-RIGHT-REAR         88
# SIDE-RIGHT-FRONT        66
# ROOF                    64
# SIDE-LEFT-FRONT         62
# NONE                    51
# UNDER CARRIAGE          28
# TOP                      6
# Name: FIRST_CONTACT_POINT, dtype: int64

# %%
df_cat_dropped_cols = df_cat.drop(columns=['RD_NO_x',
                'CRASH_DATE_EST_I', 
                'REPORT_TYPE', 
                'STREET_DIRECTION',
                'STREET_NAME',
                'LOCATION', 
                'RD_NO_y', 
                'CMRC_VEH_I', 
                'LIC_PLATE_STATE', 
                'TRAVEL_DIRECTION'
                 ])

# %%
df_cat_dropped_cols.isna().sum()
# Out:
# CRASH_DATE_x                  0
# TRAFFIC_CONTROL_DEVICE        0
# DEVICE_CONDITION              0
# WEATHER_CONDITION             0
# LIGHTING_CONDITION            0
# FIRST_CRASH_TYPE              0
# TRAFFICWAY_TYPE               0
# ALIGNMENT                     0
# ROADWAY_SURFACE_COND          0
# ROAD_DEFECT                   0
# CRASH_TYPE                    0
# INTERSECTION_RELATED_I     6016
# NOT_RIGHT_OF_WAY_I         8152
# HIT_AND_RUN_I              6456
# DAMAGE                        0
# DATE_POLICE_NOTIFIED          0
# PRIM_CONTRIBUTORY_CAUSE       0
# SEC_CONTRIBUTORY_CAUSE        0
# MOST_SEVERE_INJURY            1
# CRASH_DATE_y                  0
# UNIT_TYPE                    13
# MAKE                        180
# MODEL                       180
# VEHICLE_DEFECT              180
# VEHICLE_TYPE                180
# VEHICLE_USE                 180
# MANEUVER                    180
# EXCEED_SPEED_LIMIT_I       8430
# FIRST_CONTACT_POINT         199
# dtype: int64

# %% [markdown]
# ## Getting target variable

# %%
'''
remove
PRIM_CONTRIBUTORY_CAUSE
and
SEC_CONTRIBUTORY_CAUSE
from df_cat_dropped_cols
assign it to it's own dataframe called df_targets,
and then export df_targets to csv
'''

# Specifically I'm going to make prim cause the target and remove secondary, maybe I'll come back to it if I have time.
df_targets = df_cat_dropped_cols[['PRIM_CONTRIBUTORY_CAUSE']]
df_cat_dropped_cols.drop(columns=['PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE'], inplace=True)
df_targets.to_csv('data/df_targets.csv')

# %%
df_targets.isna().sum()
# Out:
# PRIM_CONTRIBUTORY_CAUSE    0
# dtype: int64

# %%
df_targets.dtypes
# Out:
# PRIM_CONTRIBUTORY_CAUSE    object
# dtype: object

# %%
df_targets.value_counts()

# give me the value counts for each column in df_targets
for col in df_targets.columns:
    print(col)
    print(df_targets[col].value_counts())
    print('')
# Out:
# PRIM_CONTRIBUTORY_CAUSE
# Failures to Follow Traffic Rules    6920
# Driver Behavior and Awareness       1049
# Environmental Factors                316
# Vehicle-related Issues               108
# Other Specific Circumstances          60
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64

# %% [markdown]
# ## splitting into ordinal and nominal

# %%
'''
assign to df_cat_ordinal 
INTERSECTION_RELATED_I
NOT_RIGHT_OF_WAY_I
HIT_AND_RUN_I
and EXCEED_SPEED_LIMIT_I
'''
df_cat_ordinal = df_cat_dropped_cols[['INTERSECTION_RELATED_I',
                                        'NOT_RIGHT_OF_WAY_I',
                                        'HIT_AND_RUN_I',
                                        'EXCEED_SPEED_LIMIT_I'
                                        ]]

# assign the rest to nominal
df_cat_nominal = df_cat_dropped_cols.drop(columns=['INTERSECTION_RELATED_I',
                                        'NOT_RIGHT_OF_WAY_I',
                                        'HIT_AND_RUN_I',
                                        'EXCEED_SPEED_LIMIT_I'
                                        ])

# %% [markdown]
# ### ordinal

# %%
# list nulls in ordinal
df_cat_ordinal.isna().sum()
# Out:
# INTERSECTION_RELATED_I    6016
# NOT_RIGHT_OF_WAY_I        8152
# HIT_AND_RUN_I             6456
# EXCEED_SPEED_LIMIT_I      8430
# dtype: int64

# %%
for col in df_cat_ordinal.columns:
    print(col)
    print(df_cat_ordinal[col].value_counts())
    print('')
# Out:
# INTERSECTION_RELATED_I
# Y    2327
# N     110
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# Y    274
# N     27
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# Y    1884
# N     113
# Name: HIT_AND_RUN_I, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# Y    18
# N     5
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64

# %%
# fill all nulls in ordinal with 'N'
df_cat_ordinal_filled = df_cat_ordinal.fillna('N')

# %%
df_cat_ordinal_filled.isna().sum()
# Out:
# INTERSECTION_RELATED_I    0
# NOT_RIGHT_OF_WAY_I        0
# HIT_AND_RUN_I             0
# EXCEED_SPEED_LIMIT_I      0
# dtype: int64

# %%
for col in df_cat_ordinal_filled.columns:
    print(col)
    print(df_cat_ordinal_filled[col].value_counts())
    print('')
# Out:
# INTERSECTION_RELATED_I
# N    6126
# Y    2327
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# N    8179
# Y     274
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# N    6569
# Y    1884
# Name: HIT_AND_RUN_I, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# N    8435
# Y      18
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64

# %% [markdown]
# ### nominal

# %%
# list nulls in nominal
df_cat_nominal.isna().sum()
# Out:
# CRASH_DATE_x                0
# TRAFFIC_CONTROL_DEVICE      0
# DEVICE_CONDITION            0
# WEATHER_CONDITION           0
# LIGHTING_CONDITION          0
# FIRST_CRASH_TYPE            0
# TRAFFICWAY_TYPE             0
# ALIGNMENT                   0
# ROADWAY_SURFACE_COND        0
# ROAD_DEFECT                 0
# CRASH_TYPE                  0
# DAMAGE                      0
# DATE_POLICE_NOTIFIED        0
# MOST_SEVERE_INJURY          1
# CRASH_DATE_y                0
# UNIT_TYPE                  13
# MAKE                      180
# MODEL                     180
# VEHICLE_DEFECT            180
# VEHICLE_TYPE              180
# VEHICLE_USE               180
# MANEUVER                  180
# FIRST_CONTACT_POINT       199
# dtype: int64

# %%
# assign the columnsn in df_cat_nominal with nulls to df_cat_nominal_null
df_cat_nominal_null = df_cat_nominal[['FIRST_CONTACT_POINT',
                                      'MANEUVER',
                                      'VEHICLE_USE',
                                      'VEHICLE_TYPE',
                                      'VEHICLE_DEFECT',
                                      'MODEL',
                                      'MAKE',
                                      'UNIT_TYPE',
                                      'MOST_SEVERE_INJURY']]

# assign the rest to df_cat_nominal_nonull
df_cat_nominal_nonull = df_cat_nominal.drop(columns=['FIRST_CONTACT_POINT',
                                                    'MANEUVER',
                                                    'VEHICLE_USE',
                                                    'VEHICLE_TYPE',
                                                    'VEHICLE_DEFECT',
                                                    'MODEL',
                                                    'MAKE',
                                                    'UNIT_TYPE',
                                                    'MOST_SEVERE_INJURY'])

# %%
# check that the split worked
df_cat_nominal_null.isna().sum()
# Out:
# FIRST_CONTACT_POINT    199
# MANEUVER               180
# VEHICLE_USE            180
# VEHICLE_TYPE           180
# VEHICLE_DEFECT         180
# MODEL                  180
# MAKE                   180
# UNIT_TYPE               13
# MOST_SEVERE_INJURY       1
# dtype: int64

# %%
df_cat_nominal_nonull.isna().sum()
# Out:
# CRASH_DATE_x              0
# TRAFFIC_CONTROL_DEVICE    0
# DEVICE_CONDITION          0
# WEATHER_CONDITION         0
# LIGHTING_CONDITION        0
# FIRST_CRASH_TYPE          0
# TRAFFICWAY_TYPE           0
# ALIGNMENT                 0
# ROADWAY_SURFACE_COND      0
# ROAD_DEFECT               0
# CRASH_TYPE                0
# DAMAGE                    0
# DATE_POLICE_NOTIFIED      0
# CRASH_DATE_y              0
# dtype: int64

# %%
# how many columns are in df_cat_nominal_null?
print(len(df_cat_nominal_null.columns))

# how many columns are in df_cat_nominal_nonull?
print(len(df_cat_nominal_nonull.columns))
# Out:
# 9
# 14

# %%
print(9 + 15)
# Out:
# 24

# %%
# how many columsn were in df_cat_nominal?
print(len(df_cat_nominal.columns))
# Out:
# 23

# %%
for col in df_cat_nominal_null.columns:
    print(col)
    print(df_cat_nominal_null[col].value_counts())
    print('')
# Out:
# FIRST_CONTACT_POINT
# FRONT                 1816
# REAR                  1204
# FRONT-LEFT             564
# SIDE-LEFT              541
# SIDE-RIGHT             535
# FRONT-LEFT-CORNER      493
# FRONT-RIGHT            484
# FRONT-RIGHT-CORNER     462
# REAR-LEFT              392
# UNKNOWN                357
# OTHER                  254
# REAR-RIGHT             195
# REAR-LEFT-CORNER       177
# REAR-RIGHT-CORNER      163
# TOTAL (ALL AREAS)      153
# SIDE-LEFT-REAR          99
# SIDE-RIGHT-REAR         88
# SIDE-RIGHT-FRONT        66
# ROOF                    64
# SIDE-LEFT-FRONT         62
# NONE                    51
# UNDER CARRIAGE          28
# TOP                      6
# Name: FIRST_CONTACT_POINT, dtype: int64
#
# MANEUVER
# STRAIGHT AHEAD                        4166
# PARKED                                 771
# SLOW/STOP IN TRAFFIC                   725
# TURNING LEFT                           613
# BACKING                                360
# TURNING RIGHT                          298
# PASSING/OVERTAKING                     267
# UNKNOWN/NA                             194
# CHANGING LANES                         184
# ENTERING TRAFFIC LANE FROM PARKING     143
# OTHER                                  121
# STARTING IN TRAFFIC                     65
# MERGING                                 55
# U-TURN                                  53
# AVOIDING VEHICLES/OBJECTS               47
# LEAVING TRAFFIC LANE TO PARK            38
# ENTER FROM DRIVE/ALLEY                  35
# SKIDDING/CONTROL LOSS                   34
# DRIVING WRONG WAY                       31
# PARKED IN TRAFFIC LANE                  25
# SLOW/STOP - LEFT TURN                   20
# NEGOTIATING A CURVE                     11
# SLOW/STOP - LOAD/UNLOAD                 10
# SLOW/STOP - RIGHT TURN                   3
# TURNING ON RED                           3
# DIVERGING                                1
# Name: MANEUVER, dtype: int64
#
# VEHICLE_USE
# PERSONAL                        5884
# UNKNOWN/NA                      1160
# NOT IN USE                       327
# OTHER                            285
# COMMERCIAL - SINGLE UNIT         126
# TAXI/FOR HIRE                    119
# RIDESHARE SERVICE                 80
# POLICE                            51
# CTA                               51
# CONSTRUCTION/MAINTENANCE          45
# COMMERCIAL - MULTI-UNIT           42
# OTHER TRANSIT                     20
# SCHOOL BUS                        20
# TOW TRUCK                         16
# AMBULANCE                         11
# DRIVER EDUCATION                  10
# MASS TRANSIT                       8
# STATE OWNED                        8
# FIRE                               6
# CAMPER/RV - TOWED/MULTI-UNIT       2
# LAWN CARE/LANDSCAPING              1
# AGRICULTURE                        1
# Name: VEHICLE_USE, dtype: int64
#
# VEHICLE_TYPE
# PASSENGER                         5483
# SPORT UTILITY VEHICLE (SUV)       1195
# VAN/MINI-VAN                       428
# UNKNOWN/NA                         368
# PICKUP                             279
# TRUCK - SINGLE UNIT                183
# OTHER                               92
# BUS OVER 15 PASS.                   84
# TRACTOR W/ SEMI-TRAILER             81
# BUS UP TO 15 PASS.                  24
# MOTORCYCLE (OVER 150CC)             22
# OTHER VEHICLE WITH TRAILER          13
# TRACTOR W/O SEMI-TRAILER             8
# SINGLE UNIT TRUCK WITH TRAILER       7
# MOTOR DRIVEN CYCLE                   2
# MOPED OR MOTORIZED BICYCLE           2
# FARM EQUIPMENT                       1
# AUTOCYCLE                            1
# Name: VEHICLE_TYPE, dtype: int64
#
# VEHICLE_DEFECT
# NONE            5075
# UNKNOWN         3095
# BRAKES            44
# OTHER             37
# TIRES              9
# WHEELS             4
# STEERING           3
# SUSPENSION         2
# WINDOWS            1
# LIGHTS             1
# ENGINE/MOTOR       1
# CARGO              1
# Name: VEHICLE_DEFECT, dtype: int64
#
# MODEL
# UNKNOWN                         834
# OTHER (EXPLAIN IN NARRATIVE)    501
# CAMRY                           270
# COROLLA                         196
# CIVIC                           162
#                                ...
# DEERE, JOHN; DEERE & CO.          1
# 740i                              1
# Aztek                             1
# STARCRAFT CORP.                   1
# VEGA                              1
# Name: MODEL, Length: 718, dtype: int64
#
# MAKE
# CHEVROLET                           1031
# FORD                                 888
# NISSAN                               725
# HONDA                                630
# TOYOTA MOTOR COMPANY, LTD.           596
#                                     ...
# INTERSTATE PRODUCTS                    1
# SMART                                  1
# CUMMINS ENGINE COMPANY                 1
# FONTAINE TRUCK EQUIPMENT COMPANY       1
# STARCRAFT CORP.                        1
# Name: MAKE, Length: 132, dtype: int64
#
# UNIT_TYPE
# DRIVER                 7465
# PARKED                  765
# PEDESTRIAN              100
# BICYCLE                  64
# DRIVERLESS               42
# NON-MOTOR VEHICLE         3
# NON-CONTACT VEHICLE       1
# Name: UNIT_TYPE, dtype: int64
#
# MOST_SEVERE_INJURY
# NO INDICATION OF INJURY     7024
# NONINCAPACITATING INJURY     831
# REPORTED, NOT EVIDENT        425
# INCAPACITATING INJURY        158
# FATAL                         14
# Name: MOST_SEVERE_INJURY, dtype: int64

# %%
'''Fill the following columns with 'UNKNOWN' in df_cat_nominal_null:
MOST_SEVERE_INJURY
UNIT_TYPE
MAKE
MODEL
VEHICLE_DEFECT
FIRST_CONTACT_POINT
'''

df_cat_nominal_null['MOST_SEVERE_INJURY'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['UNIT_TYPE'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['MAKE'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['MODEL'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['VEHICLE_DEFECT'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['FIRST_CONTACT_POINT'].fillna('UNKNOWN', inplace=True)
# Out:
# c:\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
'''Fill the following columns with 'UNKNOWN/NA' in df_cat_nominal_null:
VEHICLE_TYPE
VEHICLE_USE
MANUEVER
'''

df_cat_nominal_null['VEHICLE_TYPE'].fillna('UNKNOWN/NA', inplace=True)
df_cat_nominal_null['VEHICLE_USE'].fillna('UNKNOWN/NA', inplace=True)
df_cat_nominal_null['MANEUVER'].fillna('UNKNOWN/NA', inplace=True)

# %% [markdown]
# ## Combining nominal and ordinal again

# %% [markdown]
# modifying this because the ordinal columsn don't seem to contribute anything

# %%
# combine df_cat_nominal_null and df_cat_nominal_nonull into df_cat_nominal_filled
df_cat_nominal_filled = pd.concat([df_cat_nominal_null, df_cat_nominal_nonull], axis=1)

# combine df_cat_nominal_filled and df_cat_ordinal_filled into df_cat_filled
# df_cat_filled = pd.concat([df_cat_nominal_filled, df_cat_ordinal_filled], axis=1)

# %% [markdown]
# ## Combining everything again

# %%
# Combine df_cat_filled and df_num into df_clean

df_clean = pd.concat([df_num, df_cat_nominal_filled], axis=1)

# %%
df_clean.head().T
# Out:
#                                                      0  \
# POSTED_SPEED_LIMIT                                  25
# STREET_NO                                           33
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# INJURIES_NO_INDICATION                               1
# INJURIES_UNKNOWN                                     0
# CRASH_HOUR                                          17
# CRASH_DAY_OF_WEEK                                    5
# CRASH_MONTH                                          3
# LATITUDE                                       41.8828
# LONGITUDE                                     -87.6322
# CRASH_UNIT_ID                                   598511
# UNIT_NO                                              2
# NUM_PASSENGERS                                       0
# VEHICLE_YEAR                                      2016
# OCCUPANT_CNT                                         0
# FIRST_CONTACT_POINT                               REAR
# MANEUVER                                        PARKED
# VEHICLE_USE                                   PERSONAL
# VEHICLE_TYPE                                 PASSENGER
# VEHICLE_DEFECT                                    NONE
# MODEL                                              300
# MAKE                                          CHRYSLER
# UNIT_TYPE                                       PARKED
# MOST_SEVERE_INJURY             NO INDICATION OF INJURY
# CRASH_DATE_x                    03/07/2019 05:10:00 PM
# TRAFFIC_CONTROL_DEVICE                     NO CONTROLS
# DEVICE_CONDITION                           NO CONTROLS
# WEATHER_CONDITION                                CLEAR
# LIGHTING_CONDITION                            DAYLIGHT
# FIRST_CRASH_TYPE                  PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                ONE-WAY
# ALIGNMENT                           STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                               DRY
# ROAD_DEFECT                                 NO DEFECTS
# CRASH_TYPE                      NO INJURY / DRIVE AWAY
# DAMAGE                                   $501 - $1,500
# DATE_POLICE_NOTIFIED            03/07/2019 05:35:00 PM
# CRASH_DATE_y                    03/07/2019 05:10:00 PM
#
#                                                      1  \
# POSTED_SPEED_LIMIT                                  20
# STREET_NO                                         4300
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# INJURIES_NO_INDICATION                               2
# INJURIES_UNKNOWN                                     0
# CRASH_HOUR                                          11
# CRASH_DAY_OF_WEEK                                    6
# CRASH_MONTH                                         11
# LATITUDE                                       41.8148
# LONGITUDE                                     -87.7423
# CRASH_UNIT_ID                                   532437
# UNIT_NO                                              2
# NUM_PASSENGERS                                       0
# VEHICLE_YEAR                                      1999
# OCCUPANT_CNT                                         1
# FIRST_CONTACT_POINT                              FRONT
# MANEUVER                                STRAIGHT AHEAD
# VEHICLE_USE                                   PERSONAL
# VEHICLE_TYPE                                    PICKUP
# VEHICLE_DEFECT                                    NONE
# MODEL                                        SILVERADO
# MAKE                                         CHEVROLET
# UNIT_TYPE                                       DRIVER
# MOST_SEVERE_INJURY             NO INDICATION OF INJURY
# CRASH_DATE_x                    11/30/2018 11:30:00 AM
# TRAFFIC_CONTROL_DEVICE               STOP SIGN/FLASHER
# DEVICE_CONDITION                  FUNCTIONING PROPERLY
# WEATHER_CONDITION                                CLEAR
# LIGHTING_CONDITION                            DAYLIGHT
# FIRST_CRASH_TYPE                                 ANGLE
# TRAFFICWAY_TYPE                            NOT DIVIDED
# ALIGNMENT                           STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                               WET
# ROAD_DEFECT                                 NO DEFECTS
# CRASH_TYPE                      NO INJURY / DRIVE AWAY
# DAMAGE                                     OVER $1,500
# DATE_POLICE_NOTIFIED            11/30/2018 11:50:00 AM
# CRASH_DATE_y                    11/30/2018 11:30:00 AM
#
#                                                               2  \
# POSTED_SPEED_LIMIT                                           30
# STREET_NO                                                  2198
# NUM_UNITS                                                     1
# INJURIES_TOTAL                                                0
# INJURIES_FATAL                                                0
# INJURIES_INCAPACITATING                                       0
# INJURIES_NON_INCAPACITATING                                   0
# INJURIES_REPORTED_NOT_EVIDENT                                 0
# INJURIES_NO_INDICATION                                        1
# INJURIES_UNKNOWN                                              0
# CRASH_HOUR                                                   19
# CRASH_DAY_OF_WEEK                                             4
# CRASH_MONTH                                                  10
# LATITUDE                                                41.8524
# LONGITUDE                                              -87.6662
# CRASH_UNIT_ID                                            756632
# UNIT_NO                                                       1
# NUM_PASSENGERS                                                0
# VEHICLE_YEAR                                               2000
# OCCUPANT_CNT                                                  1
# FIRST_CONTACT_POINT                                       FRONT
# MANEUVER                                         STRAIGHT AHEAD
# VEHICLE_USE                                            PERSONAL
# VEHICLE_TYPE                                          PASSENGER
# VEHICLE_DEFECT                                           BRAKES
# MODEL                                                  Explorer
# MAKE                                                       FORD
# UNIT_TYPE                                                DRIVER
# MOST_SEVERE_INJURY                      NO INDICATION OF INJURY
# CRASH_DATE_x                             10/09/2019 07:00:00 PM
# TRAFFIC_CONTROL_DEVICE                              NO CONTROLS
# DEVICE_CONDITION                                    NO CONTROLS
# WEATHER_CONDITION                                         CLEAR
# LIGHTING_CONDITION                                     DAYLIGHT
# FIRST_CRASH_TYPE                                   FIXED OBJECT
# TRAFFICWAY_TYPE                 DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                    STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                        DRY
# ROAD_DEFECT                                          NO DEFECTS
# CRASH_TYPE                     INJURY AND / OR TOW DUE TO CRASH
# DAMAGE                                              OVER $1,500
# DATE_POLICE_NOTIFIED                     10/09/2019 07:00:00 PM
# CRASH_DATE_y                             10/09/2019 07:00:00 PM
#
#                                                              3  \
# POSTED_SPEED_LIMIT                                          30
# STREET_NO                                                 2800
# NUM_UNITS                                                    2
# INJURIES_TOTAL                                               0
# INJURIES_FATAL                                               0
# INJURIES_INCAPACITATING                                      0
# INJURIES_NON_INCAPACITATING                                  0
# INJURIES_REPORTED_NOT_EVIDENT                                0
# INJURIES_NO_INDICATION                                       2
# INJURIES_UNKNOWN                                             0
# CRASH_HOUR                                                  10
# CRASH_DAY_OF_WEEK                                            5
# CRASH_MONTH                                                  7
# LATITUDE                                               41.8666
# LONGITUDE                                              -87.696
# CRASH_UNIT_ID                                           179946
# UNIT_NO                                                      2
# NUM_PASSENGERS                                               0
# VEHICLE_YEAR                                                 0
# OCCUPANT_CNT                                                 1
# FIRST_CONTACT_POINT                                       REAR
# MANEUVER                                               BACKING
# VEHICLE_USE                                         UNKNOWN/NA
# VEHICLE_TYPE                                        UNKNOWN/NA
# VEHICLE_DEFECT                                         UNKNOWN
# MODEL                                                  UNKNOWN
# MAKE                                                   UNKNOWN
# UNIT_TYPE                                               DRIVER
# MOST_SEVERE_INJURY                     NO INDICATION OF INJURY
# CRASH_DATE_x                            07/06/2017 10:00:00 AM
# TRAFFIC_CONTROL_DEVICE                          TRAFFIC SIGNAL
# DEVICE_CONDITION                          FUNCTIONING PROPERLY
# WEATHER_CONDITION                                        CLEAR
# LIGHTING_CONDITION                                    DAYLIGHT
# FIRST_CRASH_TYPE                                      REAR END
# TRAFFICWAY_TYPE                DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                   STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                       DRY
# ROAD_DEFECT                                         NO DEFECTS
# CRASH_TYPE                              NO INJURY / DRIVE AWAY
# DAMAGE                                             OVER $1,500
# DATE_POLICE_NOTIFIED                    07/06/2017 02:30:00 PM
# CRASH_DATE_y                            07/06/2017 10:00:00 AM
#
#                                                              4
# POSTED_SPEED_LIMIT                                          30
# STREET_NO                                                 7739
# NUM_UNITS                                                    2
# INJURIES_TOTAL                                               0
# INJURIES_FATAL                                               0
# INJURIES_INCAPACITATING                                      0
# INJURIES_NON_INCAPACITATING                                  0
# INJURIES_REPORTED_NOT_EVIDENT                                0
# INJURIES_NO_INDICATION                                       2
# INJURIES_UNKNOWN                                             0
# CRASH_HOUR                                                  15
# CRASH_DAY_OF_WEEK                                            6
# CRASH_MONTH                                                 11
# LATITUDE                                               42.0222
# LONGITUDE                                             -87.6667
# CRASH_UNIT_ID                                            98704
# UNIT_NO                                                      1
# NUM_PASSENGERS                                               0
# VEHICLE_YEAR                                              2016
# OCCUPANT_CNT                                                 1
# FIRST_CONTACT_POINT                                 FRONT-LEFT
# MANEUVER                                                 OTHER
# VEHICLE_USE                                           PERSONAL
# VEHICLE_TYPE                                         PASSENGER
# VEHICLE_DEFECT                                            NONE
# MODEL                                                  MUSTANG
# MAKE                                                      FORD
# UNIT_TYPE                                               DRIVER
# MOST_SEVERE_INJURY                     NO INDICATION OF INJURY
# CRASH_DATE_x                            11/18/2016 03:17:00 PM
# TRAFFIC_CONTROL_DEVICE                             NO CONTROLS
# DEVICE_CONDITION                                   NO CONTROLS
# WEATHER_CONDITION                                        CLEAR
# LIGHTING_CONDITION                                    DAYLIGHT
# FIRST_CRASH_TYPE                      SIDESWIPE SAME DIRECTION
# TRAFFICWAY_TYPE                DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                   STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                       WET
# ROAD_DEFECT                                         NO DEFECTS
# CRASH_TYPE                              NO INJURY / DRIVE AWAY
# DAMAGE                                             OVER $1,500
# DATE_POLICE_NOTIFIED                    11/18/2016 04:05:00 PM
# CRASH_DATE_y                            11/18/2016 03:17:00 PM

# %% [markdown]
# # Exporting the cleaned data

# %%
# export df_clean to csv
df_clean.to_csv('data/df_clean.csv')

# %%
df_clean.shape
# Out:
# (8453, 43)

# %%
df_clean.isna().sum()
# Out:
# POSTED_SPEED_LIMIT               0
# STREET_NO                        0
# NUM_UNITS                        0
# INJURIES_TOTAL                   0
# INJURIES_FATAL                   0
# INJURIES_INCAPACITATING          0
# INJURIES_NON_INCAPACITATING      0
# INJURIES_REPORTED_NOT_EVIDENT    0
# INJURIES_NO_INDICATION           0
# INJURIES_UNKNOWN                 0
# CRASH_HOUR                       0
# CRASH_DAY_OF_WEEK                0
# CRASH_MONTH                      0
# LATITUDE                         0
# LONGITUDE                        0
# CRASH_UNIT_ID                    0
# UNIT_NO                          0
# NUM_PASSENGERS                   0
# VEHICLE_YEAR                     0
# OCCUPANT_CNT                     0
# FIRST_CONTACT_POINT              0
# MANEUVER                         0
# VEHICLE_USE                      0
# VEHICLE_TYPE                     0
# VEHICLE_DEFECT                   0
# MODEL                            0
# MAKE                             0
# UNIT_TYPE                        0
# MOST_SEVERE_INJURY               0
# CRASH_DATE_x                     0
# TRAFFIC_CONTROL_DEVICE           0
# DEVICE_CONDITION                 0
# WEATHER_CONDITION                0
# LIGHTING_CONDITION               0
# FIRST_CRASH_TYPE                 0
# TRAFFICWAY_TYPE                  0
# ALIGNMENT                        0
# ROADWAY_SURFACE_COND             0
# ROAD_DEFECT                      0
# CRASH_TYPE                       0
# DAMAGE                           0
# DATE_POLICE_NOTIFIED             0
# CRASH_DATE_y                     0
# dtype: int64
