# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Data Sources
#
# [crashes](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Crashes/85ca-t3if)
#
# [vehicles](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Vehicles/68nd-jvt3)
#
# [people](https://data.cityofchicago.org/Transportation/Traffic-Crashes-People/u6pd-qa9d)

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import scipy.sparse as sp
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %% [markdown]
# ## Importing The Data

# %%
d_crashes = pd.read_csv('data/Traffic_Crashes_-_Crashes.csv')
d_vehicles = pd.read_csv('data/Traffic_Crashes_-_Vehicles.csv')
# Out:
# c:\Anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (19,21,40,41,42,44,48,49,50,53,55,58,59,61,71) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### Look at the dimensions of the matrices

# %%
d_crashes.shape
# Out:
# (732329, 49)

# %%
d_crashes.head()
# Out:
#                                      CRASH_RECORD_ID     RD_NO  \
# 0  79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...  JC199149
# 1  792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...  JB422857
# 2  0115ade9a755e835255508463f7e9c4a9a0b47e9304238...  JF318029
# 3  05b1982cdba5d8a00e7e76ad1ecdab0e598429f78481d2...  JF378711
# 4  017040c61958d2fa977c956b2bd2d6759ef7754496dc96...  JF324552
#
#   CRASH_DATE_EST_I              CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0              NaN  03/25/2019 02:43:00 PM                  30
# 1              NaN  09/05/2018 08:40:00 AM                  30
# 2              NaN  07/15/2022 12:45:00 AM                  30
# 3              NaN  08/29/2022 11:30:00 AM                  30
# 4              NaN  07/15/2022 06:50:00 PM                  30
#
#   TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 1            NO CONTROLS           NO CONTROLS             CLEAR
# 2                UNKNOWN               UNKNOWN             CLEAR
# 3         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 4         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
#
#        LIGHTING_CONDITION FIRST_CRASH_TYPE  ... INJURIES_NON_INCAPACITATING  \
# 0                DAYLIGHT          TURNING  ...                         0.0
# 1                DAYLIGHT            ANGLE  ...                         0.0
# 2  DARKNESS, LIGHTED ROAD            ANGLE  ...                         0.0
# 3                DAYLIGHT         REAR END  ...                         0.0
# 4                DAYLIGHT         REAR END  ...                         0.0
#
#    INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN  \
# 0                            1.0                    2.0              0.0
# 1                            0.0                    2.0              0.0
# 2                            0.0                    2.0              0.0
# 3                            0.0                    3.0              0.0
# 4                            0.0                    2.0              0.0
#
#   CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH   LATITUDE  LONGITUDE  \
# 0         14                 2           3  41.884547 -87.641201
# 1          8                 4           9  41.968562 -87.740659
# 2          0                 6           7  41.886336 -87.716203
# 3         11                 2           8  41.749348 -87.721097
# 4         18                 6           7  41.925111 -87.667997
#
#                                    LOCATION
# 0   POINT (-87.64120093714 41.884547224337)
# 1  POINT (-87.740659314632 41.968562453871)
# 2  POINT (-87.716203130599 41.886336409761)
# 3  POINT (-87.721096727406 41.749348170421)
# 4  POINT (-87.667997321599 41.925110815832)
#
# [5 rows x 49 columns]

# %%
d_vehicles.shape
# Out:
# (1491796, 72)

# %%
d_vehicles.head()
# Out:
#    CRASH_UNIT_ID                                    CRASH_RECORD_ID     RD_NO  \
# 0        1554880  91a5d08b2b701f2d37cbb52ecdbeb09579bc7f2ebc60b3...  JG223284
# 1         749947  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...  JC451435
# 2         749949  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...  JC451435
# 3         749950  81dc0de2ed92aa62baccab641fa377be7feb1cc47e6554...  JC451435
# 4        1554881  91a5d08b2b701f2d37cbb52ecdbeb09579bc7f2ebc60b3...  JG223284
#
#                CRASH_DATE  UNIT_NO UNIT_TYPE  NUM_PASSENGERS  VEHICLE_ID  \
# 0  04/14/2023 02:05:00 PM        1    DRIVER             NaN   1478881.0
# 1  09/28/2019 03:30:00 AM        1    DRIVER             NaN    834816.0
# 2  09/28/2019 03:30:00 AM        2    PARKED             NaN    834819.0
# 3  09/28/2019 03:30:00 AM        3    PARKED             NaN    834817.0
# 4  04/14/2023 02:05:00 PM        2    DRIVER             1.0   1478892.0
#
#   CMRC_VEH_I                              MAKE  ... TRAILER1_LENGTH  \
# 0        NaN                              FORD  ...             NaN
# 1        NaN                             HONDA  ...             NaN
# 2        NaN                            TOYOTA  ...             NaN
# 3        NaN  GENERAL MOTORS CORPORATION (GMC)  ...             NaN
# 4        NaN                             ISUZU  ...             NaN
#
#   TRAILER2_LENGTH  TOTAL_VEHICLE_LENGTH AXLE_CNT VEHICLE_CONFIG  \
# 0             NaN                   NaN      NaN            NaN
# 1             NaN                   NaN      NaN            NaN
# 2             NaN                   NaN      NaN            NaN
# 3             NaN                   NaN      NaN            NaN
# 4             NaN                   NaN      NaN            NaN
#
#   CARGO_BODY_TYPE LOAD_TYPE HAZMAT_OUT_OF_SERVICE_I MCS_OUT_OF_SERVICE_I  \
# 0             NaN       NaN                     NaN                  NaN
# 1             NaN       NaN                     NaN                  NaN
# 2             NaN       NaN                     NaN                  NaN
# 3             NaN       NaN                     NaN                  NaN
# 4             NaN       NaN                     NaN                  NaN
#
#   HAZMAT_CLASS
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 72 columns]

# %% [markdown]
# ### Merging The Frames

# %%
# Merge d_crashes and d_vehicles on CRASH_RECORD_ID
df = pd.merge(d_crashes, d_vehicles, on='CRASH_RECORD_ID')

# %%
# export the merged dataframe to csv so it doesn't redo it every time
df.to_csv('data/merged.csv', index=False)

# %%
# use an if statement to check if the data has been exported to csv
# if it has, then read the csv file
# if not, then merge the two dataframes

# %%
df.shape
# Out:
# (1491794, 120)

# %%
df.head()
# Out:
#                                      CRASH_RECORD_ID   RD_NO_x  \
# 0  79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...  JC199149
# 1  79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...  JC199149
# 2  792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...  JB422857
# 3  792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...  JB422857
# 4  0115ade9a755e835255508463f7e9c4a9a0b47e9304238...  JF318029
#
#   CRASH_DATE_EST_I            CRASH_DATE_x  POSTED_SPEED_LIMIT  \
# 0              NaN  03/25/2019 02:43:00 PM                  30
# 1              NaN  03/25/2019 02:43:00 PM                  30
# 2              NaN  09/05/2018 08:40:00 AM                  30
# 3              NaN  09/05/2018 08:40:00 AM                  30
# 4              NaN  07/15/2022 12:45:00 AM                  30
#
#   TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 1         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 2            NO CONTROLS           NO CONTROLS             CLEAR
# 3            NO CONTROLS           NO CONTROLS             CLEAR
# 4                UNKNOWN               UNKNOWN             CLEAR
#
#        LIGHTING_CONDITION FIRST_CRASH_TYPE  ... TRAILER1_LENGTH  \
# 0                DAYLIGHT          TURNING  ...             NaN
# 1                DAYLIGHT          TURNING  ...             NaN
# 2                DAYLIGHT            ANGLE  ...             NaN
# 3                DAYLIGHT            ANGLE  ...             NaN
# 4  DARKNESS, LIGHTED ROAD            ANGLE  ...             NaN
#
#    TRAILER2_LENGTH TOTAL_VEHICLE_LENGTH AXLE_CNT VEHICLE_CONFIG  \
# 0              NaN                  NaN      NaN            NaN
# 1              NaN                  NaN      NaN            NaN
# 2              NaN                  NaN      NaN            NaN
# 3              NaN                  NaN      NaN            NaN
# 4              NaN                  NaN      NaN            NaN
#
#   CARGO_BODY_TYPE LOAD_TYPE HAZMAT_OUT_OF_SERVICE_I MCS_OUT_OF_SERVICE_I  \
# 0             NaN       NaN                     NaN                  NaN
# 1             NaN       NaN                     NaN                  NaN
# 2             NaN       NaN                     NaN                  NaN
# 3             NaN       NaN                     NaN                  NaN
# 4             NaN       NaN                     NaN                  NaN
#
#   HAZMAT_CLASS
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 120 columns]

# %% [markdown]
# ## Check dimensions

# %%
print(d_crashes.shape[1] + d_vehicles.shape[1])
# Out:
# 121

# %% [markdown]
# ## Initial Drop

# %%
'''
drom from df 
CMV_ID
USDOT_NO
CCMC_NO
ILCC_NO
COMMERCIAL_SRC
GVWR
CARRIER_NAME
CARRIER_STATE
CARRIER_CITY
HAZMAT_PLACARDS_I
HAZMAT_NAME
UN_NO
HAZMAT_PRESENT_I
HAZMAT_REPORT_I
HAZMAT_REPORT_NO
MCS_REPORT_I
MCS_REPORT_NO
HAZMAT_VIO_CAUSE_CRASH_I
MCS_VIO_CAUSE_CRASH_I
IDOT_PERMIT_NO
WIDE_LOAD_I
TRAILER1_WIDTH
TRAILER2_WIDTH
TRAILER1_LENGTH
TRAILER2_LENGTH
TOTAL_VEHICLE_LENGTH
AXLE_CNT
VEHICLE_CONFIG
CARGO_BODY_TYPE
LOAD_TYPE
HAZMAT_OUT_OF_SERVICE_I
MCS_OUT_OF_SERVICE_I
HAZMAT_CLASS
PHOTOS_TAKEN_I
STATEMENTS_TAKEN_I
DOORING_I
WORK_ZONE_I
WORK_ZONE_TYPE
WORKERS_PRESENT_I
TOWED_I
FIRE_I
TOWED_BY
TOWED_TO
AREA_00_I
AREA_01_I
AREA_02_I
AREA_03_I
AREA_04_I
AREA_05_I
AREA_06_I
AREA_07_I
AREA_08_I
AREA_09_I
AREA_10_I
AREA_11_I
AREA_12_I
AREA_99_I
'''

df.drop(columns=['CMV_ID',
                 'USDOT_NO',
                 'CCMC_NO',
                 'ILCC_NO',
                 'COMMERCIAL_SRC',
                 'GVWR',
                 'CARRIER_NAME',
                 'CARRIER_STATE',
                 'CARRIER_CITY',
                 'HAZMAT_PLACARDS_I',
                 'HAZMAT_NAME',
                 'UN_NO',
                 'HAZMAT_PRESENT_I',
                 'HAZMAT_REPORT_I',
                 'HAZMAT_REPORT_NO',
                 'MCS_REPORT_I',
                 'MCS_REPORT_NO',
                 'HAZMAT_VIO_CAUSE_CRASH_I',
                 'MCS_VIO_CAUSE_CRASH_I',
                 'IDOT_PERMIT_NO',
                 'WIDE_LOAD_I',
                 'TRAILER1_WIDTH',
                 'TRAILER2_WIDTH',
                 'TRAILER1_LENGTH',
                 'TRAILER2_LENGTH',
                 'TOTAL_VEHICLE_LENGTH',
                 'AXLE_CNT',
                 'VEHICLE_CONFIG',
                 'CARGO_BODY_TYPE',
                 'LOAD_TYPE',
                 'HAZMAT_OUT_OF_SERVICE_I',
                 'MCS_OUT_OF_SERVICE_I',
                 'HAZMAT_CLASS',
                 
                 'PHOTOS_TAKEN_I',
                 'STATEMENTS_TAKEN_I',
                 'DOORING_I',
                 'WORK_ZONE_I',
                 'WORK_ZONE_TYPE',
                 'WORKERS_PRESENT_I',
                 
                 'TOWED_I',
                 'FIRE_I',
                 
                 'TOWED_BY',
                 'TOWED_TO',
                 'AREA_00_I',
                 'AREA_01_I',
                 'AREA_02_I',
                 'AREA_03_I',
                 'AREA_04_I',
                 'AREA_05_I',
                 'AREA_06_I',
                 'AREA_07_I',
                 'AREA_08_I',
                 'AREA_09_I',
                 'AREA_10_I',
                 'AREA_11_I',
                 'AREA_12_I',
                 'AREA_99_I',
                 
                 'BEAT_OF_OCCURRENCE',
                 'VEHICLE_ID',
                 'LANE_CNT',
                 ], inplace=True)

# %%
df.shape
# Out:
# (1491794, 60)

# %%
# remove all rows where PRIM_CONTRIBUTORY_CAUSE is UNABLE TO DETERMINE and NOT APPLICABLE
df = df[df['PRIM_CONTRIBUTORY_CAUSE'] != 'NOT APPLICABLE']
df = df[df['PRIM_CONTRIBUTORY_CAUSE'] != 'UNABLE TO DETERMINE']

# %%
# check
df['PRIM_CONTRIBUTORY_CAUSE'].value_counts()
# Out:
# FAILING TO YIELD RIGHT-OF-WAY                                                       164915
# FOLLOWING TOO CLOSELY                                                               151936
# IMPROPER OVERTAKING/PASSING                                                          73063
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               66695
# IMPROPER BACKING                                                                     58478
# IMPROPER LANE USAGE                                                                  54856
# IMPROPER TURNING/NO SIGNAL                                                           49008
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  47434
# DISREGARDING TRAFFIC SIGNALS                                                         30303
# WEATHER                                                                              21949
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     20053
# DISREGARDING STOP SIGN                                                               16971
# DISTRACTION - FROM INSIDE VEHICLE                                                    10788
# PHYSICAL CONDITION OF DRIVER                                                          9547
# EQUIPMENT - VEHICLE CONDITION                                                         9473
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    8439
# DRIVING ON WRONG SIDE/WRONG WAY                                                       8435
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                  8154
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    6156
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      4166
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   3398
# DISREGARDING OTHER TRAFFIC SIGNS                                                      3083
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     2547
# ROAD CONSTRUCTION/MAINTENANCE                                                         2414
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                              2344
# CELL PHONE USE OTHER THAN TEXTING                                                     2135
# DISREGARDING ROAD MARKINGS                                                            1786
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       1667
# TURNING RIGHT ON RED                                                                  1092
# ANIMAL                                                                                 984
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)            724
# RELATED TO BUS STOP                                                                    644
# TEXTING                                                                                631
# DISREGARDING YIELD SIGN                                                                509
# PASSING STOPPED SCHOOL BUS                                                             181
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 156
# OBSTRUCTED CROSSWALKS                                                                  138
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                               42
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64

# %% [markdown]
# phone
# TEXTING
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)
# CELL PHONE USE OTHER THAN TEXTING
#
#
# knowledge
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT
# BICYCLE ADVANCING LEGALLY ON RED LIGHT
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
#
#
# etc
# OBSTRUCTED CROSSWALKS
#
#
# mad
# PASSING STOPPED SCHOOL BUS
#
# mistake
# IMPROPER BACKING
# IMPROPER LANE USAGE
# IMPROPER TURNING/NO SIGNAL
#
# DISREGARDING YIELD SIGN
#
# ANIMAL

# %%
df.shape
# Out:
# (845294, 60)

# %%
df.head().T
# Out:
#                                                                                0  \
# CRASH_RECORD_ID                79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...
# RD_NO_x                                                                 JC199149
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              03/25/2019 02:43:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                          ONE-WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                      INJURY AND / OR TOW DUE TO CRASH
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      03/25/2019 03:17:00 PM
# PRIM_CONTRIBUTORY_CAUSE                               IMPROPER TURNING/NO SIGNAL
# SEC_CONTRIBUTORY_CAUSE                       DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# STREET_NO                                                                    536
# STREET_DIRECTION                                                               W
# STREET_NAME                                                          RANDOLPH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                         REPORTED, NOT EVIDENT
# INJURIES_TOTAL                                                                 1
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  1
# INJURIES_NO_INDICATION                                                         2
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    14
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    3
# LATITUDE                                                                 41.8845
# LONGITUDE                                                               -87.6412
# LOCATION                                 POINT (-87.64120093714 41.884547224337)
# CRASH_UNIT_ID                                                             611178
# RD_NO_y                                                                 JC199149
# CRASH_DATE_y                                              03/25/2019 02:43:00 PM
# UNIT_NO                                                                        1
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                                 1
# CMRC_VEH_I                                                                   NaN
# MAKE                                                                   CHEVROLET
# MODEL                                                                      CRUZE
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                2017
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                    RIDESHARE SERVICE
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                            TURNING LEFT
# OCCUPANT_CNT                                                                   2
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                   FRONT-LEFT
#
#                                                                                1  \
# CRASH_RECORD_ID                79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...
# RD_NO_x                                                                 JC199149
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              03/25/2019 02:43:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                          ONE-WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                      INJURY AND / OR TOW DUE TO CRASH
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      03/25/2019 03:17:00 PM
# PRIM_CONTRIBUTORY_CAUSE                               IMPROPER TURNING/NO SIGNAL
# SEC_CONTRIBUTORY_CAUSE                       DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# STREET_NO                                                                    536
# STREET_DIRECTION                                                               W
# STREET_NAME                                                          RANDOLPH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                         REPORTED, NOT EVIDENT
# INJURIES_TOTAL                                                                 1
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  1
# INJURIES_NO_INDICATION                                                         2
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    14
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    3
# LATITUDE                                                                 41.8845
# LONGITUDE                                                               -87.6412
# LOCATION                                 POINT (-87.64120093714 41.884547224337)
# CRASH_UNIT_ID                                                             611179
# RD_NO_y                                                                 JC199149
# CRASH_DATE_y                                              03/25/2019 02:43:00 PM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                      CAMRY
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                2010
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                   1
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                  FRONT-RIGHT
#
#                                                                                2  \
# CRASH_RECORD_ID                792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...
# RD_NO_x                                                                 JB422857
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              09/05/2018 08:40:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                           ANGLE
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      09/05/2018 09:00:00 AM
# PRIM_CONTRIBUTORY_CAUSE        VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...
# SEC_CONTRIBUTORY_CAUSE                             FAILING TO YIELD RIGHT-OF-WAY
# STREET_NO                                                                   4821
# STREET_DIRECTION                                                               N
# STREET_NAME                                                           ELSTON AVE
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         2
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                     8
# CRASH_DAY_OF_WEEK                                                              4
# CRASH_MONTH                                                                    9
# LATITUDE                                                                 41.9686
# LONGITUDE                                                               -87.7407
# LOCATION                                POINT (-87.740659314632 41.968562453871)
# CRASH_UNIT_ID                                                             470531
# RD_NO_y                                                                 JB422857
# CRASH_DATE_y                                              09/05/2018 08:40:00 AM
# UNIT_NO                                                                        1
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                    4RUNNER
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                2002
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                         SPORT UTILITY VEHICLE (SUV)
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                               N
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                   1
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                        FRONT
#
#                                                                                3  \
# CRASH_RECORD_ID                792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...
# RD_NO_x                                                                 JB422857
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              09/05/2018 08:40:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                           ANGLE
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      09/05/2018 09:00:00 AM
# PRIM_CONTRIBUTORY_CAUSE        VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...
# SEC_CONTRIBUTORY_CAUSE                             FAILING TO YIELD RIGHT-OF-WAY
# STREET_NO                                                                   4821
# STREET_DIRECTION                                                               N
# STREET_NAME                                                           ELSTON AVE
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         2
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                     8
# CRASH_DAY_OF_WEEK                                                              4
# CRASH_MONTH                                                                    9
# LATITUDE                                                                 41.9686
# LONGITUDE                                                               -87.7407
# LOCATION                                POINT (-87.740659314632 41.968562453871)
# CRASH_UNIT_ID                                                             470532
# RD_NO_y                                                                 JB422857
# CRASH_DATE_y                                              09/05/2018 08:40:00 AM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                      CAMRY
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                2014
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                              SE
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                   1
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                   REAR-RIGHT
#
#                                                                                6
# CRASH_RECORD_ID                05b1982cdba5d8a00e7e76ad1ecdab0e598429f78481d2...
# RD_NO_x                                                                 JF378711
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              08/29/2022 11:30:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                        REAR END
# TRAFFICWAY_TYPE                                                         FOUR WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                             $501 - $1,500
# DATE_POLICE_NOTIFIED                                      09/01/2022 11:30:00 AM
# PRIM_CONTRIBUTORY_CAUSE                             DISREGARDING TRAFFIC SIGNALS
# SEC_CONTRIBUTORY_CAUSE                                            NOT APPLICABLE
# STREET_NO                                                                   3939
# STREET_DIRECTION                                                               W
# STREET_NAME                                                              79TH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                                 0
# INJURIES_FATAL                                                                 0
# INJURIES_INCAPACITATING                                                        0
# INJURIES_NON_INCAPACITATING                                                    0
# INJURIES_REPORTED_NOT_EVIDENT                                                  0
# INJURIES_NO_INDICATION                                                         3
# INJURIES_UNKNOWN                                                               0
# CRASH_HOUR                                                                    11
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    8
# LATITUDE                                                                 41.7493
# LONGITUDE                                                               -87.7211
# LOCATION                                POINT (-87.721096727406 41.749348170421)
# CRASH_UNIT_ID                                                            1410559
# RD_NO_y                                                                 JF378711
# CRASH_DATE_y                                              08/29/2022 11:30:00 AM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                                     UNKNOWN
# MODEL                                               OTHER (EXPLAIN IN NARRATIVE)
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                 NaN
# VEHICLE_DEFECT                                                           UNKNOWN
# VEHICLE_TYPE                                             TRACTOR W/ SEMI-TRAILER
# VEHICLE_USE                                             COMMERCIAL - SINGLE UNIT
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                   1
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                      UNKNOWN

# %% [markdown]
# ## Chopping down the data
#
# There's just too much
#
# Do after the initial clean to get a better sample.

# %%
df.shape
# Out:
# (845294, 60)

# %%
df = df.sample(frac=0.05, random_state=42)

# %%
df.shape
# Out:
# (42265, 60)

# %%
# Define the target groups
target_groups = {
    'Failures to Follow Traffic Rules': [
        'FAILING TO YIELD RIGHT-OF-WAY',
        'FOLLOWING TOO CLOSELY',
        'IMPROPER OVERTAKING/PASSING',
        'FAILING TO REDUCE SPEED TO AVOID CRASH',
        'IMPROPER BACKING',
        'IMPROPER LANE USAGE',
        'IMPROPER TURNING/NO SIGNAL',
        'DISREGARDING TRAFFIC SIGNALS',
        'DISREGARDING STOP SIGN',
        'DISREGARDING OTHER TRAFFIC SIGNS',
        'DISREGARDING YIELD SIGN',
        'EXCEEDING SAFE SPEED FOR CONDITIONS', 
        'DRIVING ON WRONG SIDE/WRONG WAY', 
        'EXCEEDING AUTHORIZED SPEED LIMIT',
        'TURNING RIGHT ON RED', 
        'DISREGARDING ROAD MARKINGS'
    ],
    'Driver Behavior and Awareness': [
        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE',
        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
        'DISTRACTION - FROM INSIDE VEHICLE',
        'PHYSICAL CONDITION OF DRIVER',
        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
        'DISTRACTION - FROM OUTSIDE VEHICLE',
        'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)',
        'CELL PHONE USE OTHER THAN TEXTING',
        'TEXTING', 
        'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)'
    ],
    'Environmental Factors': [
        'WEATHER',
        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
        'ROAD CONSTRUCTION/MAINTENANCE',
        'ROAD ENGINEERING/SURFACE/MARKING DEFECTS'
    ],
    'Vehicle-related Issues': [
        'EQUIPMENT - VEHICLE CONDITION'
    ],
    'Other Specific Circumstances': [
        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
        'ANIMAL',
        'RELATED TO BUS STOP',
        'BICYCLE ADVANCING LEGALLY ON RED LIGHT',
        'OBSTRUCTED CROSSWALKS',
        'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT',
        'PASSING STOPPED SCHOOL BUS'
    ]
}

# Group the targets based on the defined groups
for group, targets in target_groups.items():
    df.loc[df['PRIM_CONTRIBUTORY_CAUSE'].isin(targets), 'PRIM_CONTRIBUTORY_CAUSE'] = group

# Cut out the df_targets with the grouped targets
df_targets = df[['PRIM_CONTRIBUTORY_CAUSE']]

# Print the unique grouped targets
print(df_targets['PRIM_CONTRIBUTORY_CAUSE'].unique())
# Out:
# ['Driver Behavior and Awareness' 'Failures to Follow Traffic Rules'
#  'Vehicle-related Issues' 'Other Specific Circumstances'
#  'Environmental Factors']

# %% [markdown]
# ## Cleaning Leftover Columns

# %% [markdown]
# ### Split Into categorical and numerical

# %% [markdown]
# Now that they have been merged on CRASH_RECORD_ID, I'm going to remove that column, and create a new index

# %%
df = df.drop('CRASH_RECORD_ID', axis=1)

# %%
df = df.reset_index(drop=True)

# %%
index = df.index

# %%
print(index)
# Out:
# RangeIndex(start=0, stop=42265, step=1)

# %%
# split df into categorical and numerical dataframes
df_cat = df.select_dtypes(include='object')
df_num = df.select_dtypes(exclude='object')

# %%
# df_cat = categorical_data.reset_index(drop=True)
# df_num = numerical_data.reset_index(drop=True)

# %% [markdown]
# #### Numerical Cleaning

# %% [markdown]
# Okay so everything that is left over with the numerical columns should be able to be filled with 0.

# %%
# check df_num for nulls
df_num.isnull().sum()
# Out:
# POSTED_SPEED_LIMIT                   0
# STREET_NO                            0
# NUM_UNITS                            0
# INJURIES_TOTAL                      25
# INJURIES_FATAL                      25
# INJURIES_INCAPACITATING             25
# INJURIES_NON_INCAPACITATING         25
# INJURIES_REPORTED_NOT_EVIDENT       25
# INJURIES_NO_INDICATION              25
# INJURIES_UNKNOWN                    25
# CRASH_HOUR                           0
# CRASH_DAY_OF_WEEK                    0
# CRASH_MONTH                          0
# LATITUDE                           318
# LONGITUDE                          318
# CRASH_UNIT_ID                        0
# UNIT_NO                              0
# NUM_PASSENGERS                   34986
# VEHICLE_YEAR                      5776
# OCCUPANT_CNT                       906
# dtype: int64

# %%
# fill all missing values in df_num with 0
df_num.fillna(0, inplace=True)
# Out:
# c:\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %% [markdown]
# #### categorical cleaning

# %%
df_cat.isna().sum()
# Out:
# RD_NO_x                      259
# CRASH_DATE_EST_I           40134
# CRASH_DATE_x                   0
# TRAFFIC_CONTROL_DEVICE         0
# DEVICE_CONDITION               0
# WEATHER_CONDITION              0
# LIGHTING_CONDITION             0
# FIRST_CRASH_TYPE               0
# TRAFFICWAY_TYPE                0
# ALIGNMENT                      0
# ROADWAY_SURFACE_COND           0
# ROAD_DEFECT                    0
# REPORT_TYPE                 1381
# CRASH_TYPE                     0
# INTERSECTION_RELATED_I     30031
# NOT_RIGHT_OF_WAY_I         40772
# HIT_AND_RUN_I              32147
# DAMAGE                         0
# DATE_POLICE_NOTIFIED           0
# PRIM_CONTRIBUTORY_CAUSE        0
# SEC_CONTRIBUTORY_CAUSE         0
# STREET_DIRECTION               0
# STREET_NAME                    0
# MOST_SEVERE_INJURY            25
# LOCATION                     318
# RD_NO_y                      276
# CRASH_DATE_y                   0
# UNIT_TYPE                     60
# CMRC_VEH_I                 41380
# MAKE                         906
# MODEL                        912
# LIC_PLATE_STATE             3802
# VEHICLE_DEFECT               906
# VEHICLE_TYPE                 906
# VEHICLE_USE                  906
# TRAVEL_DIRECTION             906
# MANEUVER                     906
# EXCEED_SPEED_LIMIT_I       42147
# FIRST_CONTACT_POINT          974
# dtype: int64

# %%
# print out the value_counts for every column in df_cat
for col in df_cat.columns:
    print(col)
    print(df_cat[col].value_counts())
    print('')
# Out:
# RD_NO_x
# JD224890    3
# JD429949    3
# JG108188    3
# JB207135    3
# JB258280    3
#            ..
# JF254808    1
# JC458617    1
# HZ489032    1
# JA509778    1
# JD152184    1
# Name: RD_NO_x, Length: 40821, dtype: int64
#
# CRASH_DATE_EST_I
# Y    1810
# N     321
# Name: CRASH_DATE_EST_I, dtype: int64
#
# CRASH_DATE_x
# 11/10/2017 10:30:00 AM    5
# 02/08/2018 08:50:00 AM    5
# 11/06/2017 06:00:00 PM    4
# 01/20/2019 08:00:00 AM    4
# 07/06/2018 03:30:00 PM    4
#                          ..
# 07/02/2020 04:00:00 PM    1
# 01/11/2021 01:05:00 PM    1
# 05/06/2022 02:56:00 PM    1
# 03/12/2020 04:40:00 PM    1
# 08/17/2019 12:00:00 PM    1
# Name: CRASH_DATE_x, Length: 39800, dtype: int64
#
# TRAFFIC_CONTROL_DEVICE
# NO CONTROLS                 21383
# TRAFFIC SIGNAL              14252
# STOP SIGN/FLASHER            5096
# UNKNOWN                       837
# OTHER                         317
# LANE USE MARKING               83
# YIELD                          66
# OTHER REG. SIGN                51
# OTHER WARNING SIGN             41
# RAILROAD CROSSING GATE         30
# PEDESTRIAN CROSSING SIGN       27
# SCHOOL ZONE                    21
# POLICE/FLAGMAN                 16
# FLASHING CONTROL SIGNAL        14
# DELINEATORS                    14
# OTHER RAILROAD CROSSING         9
# NO PASSING                      6
# RR CROSSING SIGN                1
# BICYCLE CROSSING SIGN           1
# Name: TRAFFIC_CONTROL_DEVICE, dtype: int64
#
# DEVICE_CONDITION
# NO CONTROLS                 21835
# FUNCTIONING PROPERLY        18009
# UNKNOWN                      1697
# OTHER                         327
# FUNCTIONING IMPROPERLY        240
# NOT FUNCTIONING               129
# WORN REFLECTIVE MATERIAL       20
# MISSING                         8
# Name: DEVICE_CONDITION, dtype: int64
#
# WEATHER_CONDITION
# CLEAR                     33844
# RAIN                       3989
# SNOW                       1705
# CLOUDY/OVERCAST            1489
# UNKNOWN                     884
# OTHER                       116
# FREEZING RAIN/DRIZZLE        89
# FOG/SMOKE/HAZE               65
# SLEET/HAIL                   57
# BLOWING SNOW                 21
# SEVERE CROSS WIND GATE        6
# Name: WEATHER_CONDITION, dtype: int64
#
# LIGHTING_CONDITION
# DAYLIGHT                  28190
# DARKNESS, LIGHTED ROAD     9728
# DARKNESS                   1763
# DUSK                       1270
# DAWN                        724
# UNKNOWN                     590
# Name: LIGHTING_CONDITION, dtype: int64
#
# FIRST_CRASH_TYPE
# REAR END                        11468
# TURNING                          7410
# SIDESWIPE SAME DIRECTION         6812
# PARKED MOTOR VEHICLE             6426
# ANGLE                            5666
# PEDESTRIAN                        938
# FIXED OBJECT                      928
# SIDESWIPE OPPOSITE DIRECTION      646
# PEDALCYCLIST                      576
# HEAD ON                           433
# REAR TO FRONT                     424
# REAR TO SIDE                      233
# OTHER OBJECT                      148
# REAR TO REAR                       70
# OTHER NONCOLLISION                 57
# ANIMAL                             16
# OVERTURNED                         10
# TRAIN                               4
# Name: FIRST_CRASH_TYPE, dtype: int64
#
# TRAFFICWAY_TYPE
# NOT DIVIDED                        18742
# DIVIDED - W/MEDIAN (NOT RAISED)     7697
# ONE-WAY                             4659
# FOUR WAY                            2941
# DIVIDED - W/MEDIAN BARRIER          2765
# PARKING LOT                         2134
# OTHER                               1016
# T-INTERSECTION                       575
# ALLEY                                492
# CENTER TURN LANE                     413
# UNKNOWN                              243
# RAMP                                 132
# UNKNOWN INTERSECTION TYPE            115
# DRIVEWAY                             109
# FIVE POINT, OR MORE                   61
# Y-INTERSECTION                        60
# TRAFFIC ROUTE                         59
# NOT REPORTED                          31
# L-INTERSECTION                        11
# ROUNDABOUT                            10
# Name: TRAFFICWAY_TYPE, dtype: int64
#
# ALIGNMENT
# STRAIGHT AND LEVEL       41128
# STRAIGHT ON GRADE          625
# CURVE, LEVEL               304
# STRAIGHT ON HILLCREST      122
# CURVE ON GRADE              72
# CURVE ON HILLCREST          14
# Name: ALIGNMENT, dtype: int64
#
# ROADWAY_SURFACE_COND
# DRY                32205
# WET                 6130
# UNKNOWN             1820
# SNOW OR SLUSH       1629
# ICE                  360
# OTHER                102
# SAND, MUD, DIRT       19
# Name: ROADWAY_SURFACE_COND, dtype: int64
#
# ROAD_DEFECT
# NO DEFECTS           36178
# UNKNOWN               5342
# RUT, HOLES             228
# OTHER                  226
# WORN SURFACE           179
# SHOULDER DEFECT         84
# DEBRIS ON ROADWAY       28
# Name: ROAD_DEFECT, dtype: int64
#
# REPORT_TYPE
# NOT ON SCENE (DESK REPORT)    20559
# ON SCENE                      20312
# AMENDED                          13
# Name: REPORT_TYPE, dtype: int64
#
# CRASH_TYPE
# NO INJURY / DRIVE AWAY              28724
# INJURY AND / OR TOW DUE TO CRASH    13541
# Name: CRASH_TYPE, dtype: int64
#
# INTERSECTION_RELATED_I
# Y    11689
# N      545
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# Y    1331
# N     162
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# Y    9567
# N     551
# Name: HIT_AND_RUN_I, dtype: int64
#
# DAMAGE
# OVER $1,500      27378
# $501 - $1,500    10360
# $500 OR LESS      4527
# Name: DAMAGE, dtype: int64
#
# DATE_POLICE_NOTIFIED
# 11/05/2019 06:40:00 PM    4
# 03/14/2022 08:45:00 AM    4
# 02/07/2021 06:10:00 PM    4
# 11/10/2017 12:00:00 PM    4
# 02/05/2020 05:00:00 PM    4
#                          ..
# 10/19/2018 09:00:00 PM    1
# 04/14/2020 07:55:00 PM    1
# 03/23/2022 03:02:00 PM    1
# 06/07/2017 04:07:00 PM    1
# 07/17/2019 05:38:00 PM    1
# Name: DATE_POLICE_NOTIFIED, Length: 40376, dtype: int64
#
# PRIM_CONTRIBUTORY_CAUSE
# Failures to Follow Traffic Rules    34427
# Driver Behavior and Awareness        5423
# Environmental Factors                1709
# Vehicle-related Issues                484
# Other Specific Circumstances          222
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64
#
# SEC_CONTRIBUTORY_CAUSE
# NOT APPLICABLE                                                                      15701
# UNABLE TO DETERMINE                                                                  9924
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               2886
# FAILING TO YIELD RIGHT-OF-WAY                                                        2276
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  2201
# FOLLOWING TOO CLOSELY                                                                2039
# IMPROPER OVERTAKING/PASSING                                                          1125
# IMPROPER LANE USAGE                                                                   969
# WEATHER                                                                               861
# IMPROPER TURNING/NO SIGNAL                                                            763
# IMPROPER BACKING                                                                      553
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER      491
# DISREGARDING TRAFFIC SIGNALS                                                          260
# DISREGARDING STOP SIGN                                                                234
# DISTRACTION - FROM INSIDE VEHICLE                                                     207
# PHYSICAL CONDITION OF DRIVER                                                          206
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                  205
# EQUIPMENT - VEHICLE CONDITION                                                         153
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      152
# DRIVING ON WRONG SIDE/WRONG WAY                                                       140
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   138
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    133
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    115
# ROAD CONSTRUCTION/MAINTENANCE                                                          73
# DISREGARDING ROAD MARKINGS                                                             64
# DISREGARDING OTHER TRAFFIC SIGNS                                                       61
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                        55
# CELL PHONE USE OTHER THAN TEXTING                                                      47
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                               41
# TURNING RIGHT ON RED                                                                   30
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)            28
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                      25
# RELATED TO BUS STOP                                                                    24
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 20
# ANIMAL                                                                                 19
# DISREGARDING YIELD SIGN                                                                14
# TEXTING                                                                                12
# PASSING STOPPED SCHOOL BUS                                                             10
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                               5
# OBSTRUCTED CROSSWALKS                                                                   5
# Name: SEC_CONTRIBUTORY_CAUSE, dtype: int64
#
# STREET_DIRECTION
# W    15227
# S    14144
# N    10028
# E     2866
# Name: STREET_DIRECTION, dtype: int64
#
# STREET_NAME
# WESTERN AVE    1189
# PULASKI RD     1071
# ASHLAND AVE    1036
# CICERO AVE      996
# HALSTED ST      900
#                ...
# LEONARD AVE       1
# HOWE ST           1
# GERMANIA PL       1
# GOODMAN ST        1
# MALTA ST          1
# Name: STREET_NAME, Length: 1124, dtype: int64
#
# MOST_SEVERE_INJURY
# NO INDICATION OF INJURY     34990
# NONINCAPACITATING INJURY     4132
# REPORTED, NOT EVIDENT        2158
# INCAPACITATING INJURY         904
# FATAL                          56
# Name: MOST_SEVERE_INJURY, dtype: int64
#
# LOCATION
# POINT (-87.905309125103 41.976201139024)    66
# POINT (-87.619928173678 41.900958919109)    33
# POINT (-87.580147768689 41.791420282098)    31
# POINT (-87.585971992965 41.751460603167)    25
# POINT (-87.617635891755 41.880856047671)    22
#                                             ..
# POINT (-87.625899280801 41.892622238548)     1
# POINT (-87.657443812396 41.931501717398)     1
# POINT (-87.661906529225 42.006649348358)     1
# POINT (-87.666236705777 41.855861943811)     1
# POINT (-87.631363383923 41.831099226938)     1
# Name: LOCATION, Length: 31069, dtype: int64
#
# RD_NO_y
# JD429949    3
# JG108188    3
# JB258280    3
# JD224890    3
# JB207135    3
#            ..
# JF254808    1
# JC458617    1
# HZ489032    1
# JA509778    1
# JF390565    1
# Name: RD_NO_y, Length: 40805, dtype: int64
#
# CRASH_DATE_y
# 11/10/2017 10:30:00 AM    5
# 02/08/2018 08:50:00 AM    5
# 01/15/2020 07:30:00 AM    4
# 07/06/2018 03:30:00 PM    4
# 05/25/2018 10:30:00 AM    4
#                          ..
# 02/07/2018 08:25:00 AM    1
# 07/02/2020 04:00:00 PM    1
# 01/11/2021 01:05:00 PM    1
# 05/06/2022 02:56:00 PM    1
# 08/17/2019 12:00:00 PM    1
# Name: CRASH_DATE_y, Length: 39800, dtype: int64
#
# UNIT_TYPE
# DRIVER                 37389
# PARKED                  3724
# PEDESTRIAN               502
# BICYCLE                  303
# DRIVERLESS               250
# NON-MOTOR VEHICLE         28
# NON-CONTACT VEHICLE        6
# DISABLED VEHICLE           3
# Name: UNIT_TYPE, dtype: int64
#
# CMRC_VEH_I
# Y    562
# N    323
# Name: CMRC_VEH_I, dtype: int64
#
# MAKE
# CHEVROLET                                     5063
# FORD                                          4255
# NISSAN                                        3488
# HONDA                                         3162
# TOYOTA MOTOR COMPANY, LTD.                    2714
#                                               ...
# FLYING DUTCHMAN                                  1
# AXLE & EQUIPMENT SALES CO., NAPERVILLE, IN       1
# WESTERN STAR                                     1
# BANTAM CRANE                                     1
# NORTH AMERICAN BUS INDUSTRIES                    1
# Name: MAKE, Length: 270, dtype: int64
#
# MODEL
# UNKNOWN                         4474
# OTHER (EXPLAIN IN NARRATIVE)    2621
# CAMRY                           1334
# COROLLA                          905
# CIVIC                            837
#                                 ...
# TIBURON                            1
# 113                                1
# YUKON DELTA                        1
# SPORTWAGON                         1
# STORM                              1
# Name: MODEL, Length: 1145, dtype: int64
#
# LIC_PLATE_STATE
# IL    35445
# IN      771
# XX      527
# WI      251
# FL      167
# MI      166
# TX      125
# OH       99
# MO       90
# AZ       88
# MN       77
# CA       71
# IA       64
# TN       54
# GA       47
# OK       36
# NY       33
# PA       28
# NC       25
# KY       22
# AL       21
# MS       21
# VA       21
# NJ       20
# NB       17
# CO       17
# WA       17
# LA       16
# KS       14
# MA       12
# SC       12
# MD       10
# CT       10
# AR        9
# OR        8
# ME        7
# ND        7
# MT        5
# ID        5
# NV        5
# UT        4
# VT        3
# NH        3
# RI        2
# SD        2
# AK        2
# WV        2
# DC        2
# NM        2
# DE        1
# Name: LIC_PLATE_STATE, dtype: int64
#
# VEHICLE_DEFECT
# NONE                25216
# UNKNOWN             15685
# BRAKES                181
# OTHER                 178
# TIRES                  33
# STEERING               21
# WHEELS                 11
# SUSPENSION             10
# LIGHTS                  7
# ENGINE/MOTOR            7
# FUEL SYSTEM             2
# WINDOWS                 2
# TRAILER COUPLING        2
# CARGO                   2
# EXHAUST                 1
# SIGNALS                 1
# Name: VEHICLE_DEFECT, dtype: int64
#
# VEHICLE_TYPE
# PASSENGER                                 27303
# SPORT UTILITY VEHICLE (SUV)                5969
# VAN/MINI-VAN                               2139
# UNKNOWN/NA                                 2058
# PICKUP                                     1363
# TRUCK - SINGLE UNIT                         833
# BUS OVER 15 PASS.                           474
# OTHER                                       415
# TRACTOR W/ SEMI-TRAILER                     411
# BUS UP TO 15 PASS.                          109
# MOTORCYCLE (OVER 150CC)                     108
# TRACTOR W/O SEMI-TRAILER                     54
# SINGLE UNIT TRUCK WITH TRAILER               48
# OTHER VEHICLE WITH TRAILER                   41
# MOPED OR MOTORIZED BICYCLE                   11
# MOTOR DRIVEN CYCLE                            9
# AUTOCYCLE                                     5
# FARM EQUIPMENT                                3
# 3-WHEELED MOTORCYCLE (2 REAR WHEELS)          3
# RECREATIONAL OFF-HIGHWAY VEHICLE (ROV)        2
# ALL-TERRAIN VEHICLE (ATV)                     1
# Name: VEHICLE_TYPE, dtype: int64
#
# VEHICLE_USE
# PERSONAL                        29316
# UNKNOWN/NA                       6098
# NOT IN USE                       1570
# OTHER                            1306
# COMMERCIAL - SINGLE UNIT          588
# TAXI/FOR HIRE                     529
# RIDESHARE SERVICE                 435
# CTA                               316
# POLICE                            290
# CONSTRUCTION/MAINTENANCE          212
# COMMERCIAL - MULTI-UNIT           189
# SCHOOL BUS                        116
# OTHER TRANSIT                     115
# TOW TRUCK                          94
# AMBULANCE                          44
# FIRE                               34
# STATE OWNED                        30
# DRIVER EDUCATION                   28
# MASS TRANSIT                       26
# LAWN CARE/LANDSCAPING              13
# AGRICULTURE                         5
# CAMPER/RV - SINGLE UNIT             3
# CAMPER/RV - TOWED/MULTI-UNIT        2
# Name: VEHICLE_USE, dtype: int64
#
# TRAVEL_DIRECTION
# N          10050
# S           9846
# E           8967
# W           8940
# UNKNOWN     1481
# SE           636
# NW           546
# SW           448
# NE           445
# Name: TRAVEL_DIRECTION, dtype: int64
#
# MANEUVER
# STRAIGHT AHEAD                        20864
# PARKED                                 3772
# SLOW/STOP IN TRAFFIC                   3707
# TURNING LEFT                           2977
# BACKING                                1770
# TURNING RIGHT                          1533
# PASSING/OVERTAKING                     1424
# UNKNOWN/NA                              975
# CHANGING LANES                          929
# OTHER                                   601
# ENTERING TRAFFIC LANE FROM PARKING      563
# U-TURN                                  314
# MERGING                                 313
# STARTING IN TRAFFIC                     285
# SKIDDING/CONTROL LOSS                   225
# AVOIDING VEHICLES/OBJECTS               202
# ENTER FROM DRIVE/ALLEY                  198
# LEAVING TRAFFIC LANE TO PARK            191
# PARKED IN TRAFFIC LANE                  117
# SLOW/STOP - LEFT TURN                    96
# DRIVING WRONG WAY                        93
# SLOW/STOP - RIGHT TURN                   61
# NEGOTIATING A CURVE                      56
# SLOW/STOP - LOAD/UNLOAD                  44
# TURNING ON RED                           20
# DRIVERLESS                               19
# DIVERGING                                 7
# DISABLED                                  3
# Name: MANEUVER, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# Y    92
# N    26
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64
#
# FIRST_CONTACT_POINT
# FRONT                 9047
# REAR                  5953
# SIDE-RIGHT            2695
# SIDE-LEFT             2675
# FRONT-LEFT            2609
# FRONT-RIGHT           2444
# FRONT-LEFT-CORNER     2389
# FRONT-RIGHT-CORNER    2365
# REAR-LEFT             2065
# UNKNOWN               1826
# OTHER                 1225
# REAR-RIGHT            1091
# REAR-LEFT-CORNER       910
# REAR-RIGHT-CORNER      775
# TOTAL (ALL AREAS)      766
# SIDE-LEFT-REAR         572
# SIDE-RIGHT-REAR        430
# SIDE-LEFT-FRONT        336
# SIDE-RIGHT-FRONT       335
# ROOF                   316
# NONE                   303
# UNDER CARRIAGE         123
# TOP                     41
# Name: FIRST_CONTACT_POINT, dtype: int64

# %%
df_cat_dropped_cols = df_cat.drop(columns=['RD_NO_x',
                'CRASH_DATE_EST_I', 
                'REPORT_TYPE', 
                'STREET_DIRECTION',
                'STREET_NAME',
                'LOCATION', 
                'RD_NO_y', 
                'CMRC_VEH_I', 
                'LIC_PLATE_STATE', 
                'TRAVEL_DIRECTION'
                 ])

# %%
df_cat_dropped_cols.isna().sum()
# Out:
# CRASH_DATE_x                   0
# TRAFFIC_CONTROL_DEVICE         0
# DEVICE_CONDITION               0
# WEATHER_CONDITION              0
# LIGHTING_CONDITION             0
# FIRST_CRASH_TYPE               0
# TRAFFICWAY_TYPE                0
# ALIGNMENT                      0
# ROADWAY_SURFACE_COND           0
# ROAD_DEFECT                    0
# CRASH_TYPE                     0
# INTERSECTION_RELATED_I     30031
# NOT_RIGHT_OF_WAY_I         40772
# HIT_AND_RUN_I              32147
# DAMAGE                         0
# DATE_POLICE_NOTIFIED           0
# PRIM_CONTRIBUTORY_CAUSE        0
# SEC_CONTRIBUTORY_CAUSE         0
# MOST_SEVERE_INJURY            25
# CRASH_DATE_y                   0
# UNIT_TYPE                     60
# MAKE                         906
# MODEL                        912
# VEHICLE_DEFECT               906
# VEHICLE_TYPE                 906
# VEHICLE_USE                  906
# MANEUVER                     906
# EXCEED_SPEED_LIMIT_I       42147
# FIRST_CONTACT_POINT          974
# dtype: int64

# %% [markdown]
# ## Getting target variable

# %%
'''
remove
PRIM_CONTRIBUTORY_CAUSE
and
SEC_CONTRIBUTORY_CAUSE
from df_cat_dropped_cols
assign it to it's own dataframe called df_targets,
and then export df_targets to csv
'''

# Specifically I'm going to make prim cause the target and remove secondary, maybe I'll come back to it if I have time.
df_targets = df_cat_dropped_cols[['PRIM_CONTRIBUTORY_CAUSE']]
df_cat_dropped_cols.drop(columns=['PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE'], inplace=True)
df_targets.to_csv('data/df_targets.csv')

# %%
df_targets.isna().sum()
# Out:
# PRIM_CONTRIBUTORY_CAUSE    0
# dtype: int64

# %%
df_targets.dtypes
# Out:
# PRIM_CONTRIBUTORY_CAUSE    object
# dtype: object

# %%
df_targets.value_counts()

# give me the value counts for each column in df_targets
for col in df_targets.columns:
    print(col)
    print(df_targets[col].value_counts())
    print('')
# Out:
# PRIM_CONTRIBUTORY_CAUSE
# Failures to Follow Traffic Rules    34427
# Driver Behavior and Awareness        5423
# Environmental Factors                1709
# Vehicle-related Issues                484
# Other Specific Circumstances          222
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64

# %% [markdown]
# ## splitting into ordinal and nominal

# %%
'''
assign to df_cat_ordinal 
INTERSECTION_RELATED_I
NOT_RIGHT_OF_WAY_I
HIT_AND_RUN_I
and EXCEED_SPEED_LIMIT_I
'''
df_cat_ordinal = df_cat_dropped_cols[['INTERSECTION_RELATED_I',
                                        'NOT_RIGHT_OF_WAY_I',
                                        'HIT_AND_RUN_I',
                                        'EXCEED_SPEED_LIMIT_I'
                                        ]]

# assign the rest to nominal
df_cat_nominal = df_cat_dropped_cols.drop(columns=['INTERSECTION_RELATED_I',
                                        'NOT_RIGHT_OF_WAY_I',
                                        'HIT_AND_RUN_I',
                                        'EXCEED_SPEED_LIMIT_I'
                                        ])

# %% [markdown]
# ### ordinal

# %%
# list nulls in ordinal
df_cat_ordinal.isna().sum()
# Out:
# INTERSECTION_RELATED_I    30031
# NOT_RIGHT_OF_WAY_I        40772
# HIT_AND_RUN_I             32147
# EXCEED_SPEED_LIMIT_I      42147
# dtype: int64

# %%
for col in df_cat_ordinal.columns:
    print(col)
    print(df_cat_ordinal[col].value_counts())
    print('')
# Out:
# INTERSECTION_RELATED_I
# Y    11689
# N      545
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# Y    1331
# N     162
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# Y    9567
# N     551
# Name: HIT_AND_RUN_I, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# Y    92
# N    26
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64

# %%
# fill all nulls in ordinal with 'N'
df_cat_ordinal_filled = df_cat_ordinal.fillna('N')

# %%
df_cat_ordinal_filled.isna().sum()
# Out:
# INTERSECTION_RELATED_I    0
# NOT_RIGHT_OF_WAY_I        0
# HIT_AND_RUN_I             0
# EXCEED_SPEED_LIMIT_I      0
# dtype: int64

# %%
for col in df_cat_ordinal_filled.columns:
    print(col)
    print(df_cat_ordinal_filled[col].value_counts())
    print('')
# Out:
# INTERSECTION_RELATED_I
# N    30576
# Y    11689
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# N    40934
# Y     1331
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# N    32698
# Y     9567
# Name: HIT_AND_RUN_I, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# N    42173
# Y       92
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64

# %% [markdown]
# ### nominal

# %%
# list nulls in nominal
df_cat_nominal.isna().sum()
# Out:
# CRASH_DATE_x                0
# TRAFFIC_CONTROL_DEVICE      0
# DEVICE_CONDITION            0
# WEATHER_CONDITION           0
# LIGHTING_CONDITION          0
# FIRST_CRASH_TYPE            0
# TRAFFICWAY_TYPE             0
# ALIGNMENT                   0
# ROADWAY_SURFACE_COND        0
# ROAD_DEFECT                 0
# CRASH_TYPE                  0
# DAMAGE                      0
# DATE_POLICE_NOTIFIED        0
# MOST_SEVERE_INJURY         25
# CRASH_DATE_y                0
# UNIT_TYPE                  60
# MAKE                      906
# MODEL                     912
# VEHICLE_DEFECT            906
# VEHICLE_TYPE              906
# VEHICLE_USE               906
# MANEUVER                  906
# FIRST_CONTACT_POINT       974
# dtype: int64

# %%
# assign the columnsn in df_cat_nominal with nulls to df_cat_nominal_null
df_cat_nominal_null = df_cat_nominal[['FIRST_CONTACT_POINT',
                                      'MANEUVER',
                                      'VEHICLE_USE',
                                      'VEHICLE_TYPE',
                                      'VEHICLE_DEFECT',
                                      'MODEL',
                                      'MAKE',
                                      'UNIT_TYPE',
                                      'MOST_SEVERE_INJURY']]

# assign the rest to df_cat_nominal_nonull
df_cat_nominal_nonull = df_cat_nominal.drop(columns=['FIRST_CONTACT_POINT',
                                                    'MANEUVER',
                                                    'VEHICLE_USE',
                                                    'VEHICLE_TYPE',
                                                    'VEHICLE_DEFECT',
                                                    'MODEL',
                                                    'MAKE',
                                                    'UNIT_TYPE',
                                                    'MOST_SEVERE_INJURY'])

# %%
# check that the split worked
df_cat_nominal_null.isna().sum()
# Out:
# FIRST_CONTACT_POINT    974
# MANEUVER               906
# VEHICLE_USE            906
# VEHICLE_TYPE           906
# VEHICLE_DEFECT         906
# MODEL                  912
# MAKE                   906
# UNIT_TYPE               60
# MOST_SEVERE_INJURY      25
# dtype: int64

# %%
df_cat_nominal_nonull.isna().sum()
# Out:
# CRASH_DATE_x              0
# TRAFFIC_CONTROL_DEVICE    0
# DEVICE_CONDITION          0
# WEATHER_CONDITION         0
# LIGHTING_CONDITION        0
# FIRST_CRASH_TYPE          0
# TRAFFICWAY_TYPE           0
# ALIGNMENT                 0
# ROADWAY_SURFACE_COND      0
# ROAD_DEFECT               0
# CRASH_TYPE                0
# DAMAGE                    0
# DATE_POLICE_NOTIFIED      0
# CRASH_DATE_y              0
# dtype: int64

# %%
# how many columns are in df_cat_nominal_null?
print(len(df_cat_nominal_null.columns))

# how many columns are in df_cat_nominal_nonull?
print(len(df_cat_nominal_nonull.columns))
# Out:
# 9
# 14

# %%
print(9 + 15)
# Out:
# 24

# %%
# how many columsn were in df_cat_nominal?
print(len(df_cat_nominal.columns))
# Out:
# 23

# %%
for col in df_cat_nominal_null.columns:
    print(col)
    print(df_cat_nominal_null[col].value_counts())
    print('')
# Out:
# FIRST_CONTACT_POINT
# FRONT                 9047
# REAR                  5953
# SIDE-RIGHT            2695
# SIDE-LEFT             2675
# FRONT-LEFT            2609
# FRONT-RIGHT           2444
# FRONT-LEFT-CORNER     2389
# FRONT-RIGHT-CORNER    2365
# REAR-LEFT             2065
# UNKNOWN               1826
# OTHER                 1225
# REAR-RIGHT            1091
# REAR-LEFT-CORNER       910
# REAR-RIGHT-CORNER      775
# TOTAL (ALL AREAS)      766
# SIDE-LEFT-REAR         572
# SIDE-RIGHT-REAR        430
# SIDE-LEFT-FRONT        336
# SIDE-RIGHT-FRONT       335
# ROOF                   316
# NONE                   303
# UNDER CARRIAGE         123
# TOP                     41
# Name: FIRST_CONTACT_POINT, dtype: int64
#
# MANEUVER
# STRAIGHT AHEAD                        20864
# PARKED                                 3772
# SLOW/STOP IN TRAFFIC                   3707
# TURNING LEFT                           2977
# BACKING                                1770
# TURNING RIGHT                          1533
# PASSING/OVERTAKING                     1424
# UNKNOWN/NA                              975
# CHANGING LANES                          929
# OTHER                                   601
# ENTERING TRAFFIC LANE FROM PARKING      563
# U-TURN                                  314
# MERGING                                 313
# STARTING IN TRAFFIC                     285
# SKIDDING/CONTROL LOSS                   225
# AVOIDING VEHICLES/OBJECTS               202
# ENTER FROM DRIVE/ALLEY                  198
# LEAVING TRAFFIC LANE TO PARK            191
# PARKED IN TRAFFIC LANE                  117
# SLOW/STOP - LEFT TURN                    96
# DRIVING WRONG WAY                        93
# SLOW/STOP - RIGHT TURN                   61
# NEGOTIATING A CURVE                      56
# SLOW/STOP - LOAD/UNLOAD                  44
# TURNING ON RED                           20
# DRIVERLESS                               19
# DIVERGING                                 7
# DISABLED                                  3
# Name: MANEUVER, dtype: int64
#
# VEHICLE_USE
# PERSONAL                        29316
# UNKNOWN/NA                       6098
# NOT IN USE                       1570
# OTHER                            1306
# COMMERCIAL - SINGLE UNIT          588
# TAXI/FOR HIRE                     529
# RIDESHARE SERVICE                 435
# CTA                               316
# POLICE                            290
# CONSTRUCTION/MAINTENANCE          212
# COMMERCIAL - MULTI-UNIT           189
# SCHOOL BUS                        116
# OTHER TRANSIT                     115
# TOW TRUCK                          94
# AMBULANCE                          44
# FIRE                               34
# STATE OWNED                        30
# DRIVER EDUCATION                   28
# MASS TRANSIT                       26
# LAWN CARE/LANDSCAPING              13
# AGRICULTURE                         5
# CAMPER/RV - SINGLE UNIT             3
# CAMPER/RV - TOWED/MULTI-UNIT        2
# Name: VEHICLE_USE, dtype: int64
#
# VEHICLE_TYPE
# PASSENGER                                 27303
# SPORT UTILITY VEHICLE (SUV)                5969
# VAN/MINI-VAN                               2139
# UNKNOWN/NA                                 2058
# PICKUP                                     1363
# TRUCK - SINGLE UNIT                         833
# BUS OVER 15 PASS.                           474
# OTHER                                       415
# TRACTOR W/ SEMI-TRAILER                     411
# BUS UP TO 15 PASS.                          109
# MOTORCYCLE (OVER 150CC)                     108
# TRACTOR W/O SEMI-TRAILER                     54
# SINGLE UNIT TRUCK WITH TRAILER               48
# OTHER VEHICLE WITH TRAILER                   41
# MOPED OR MOTORIZED BICYCLE                   11
# MOTOR DRIVEN CYCLE                            9
# AUTOCYCLE                                     5
# FARM EQUIPMENT                                3
# 3-WHEELED MOTORCYCLE (2 REAR WHEELS)          3
# RECREATIONAL OFF-HIGHWAY VEHICLE (ROV)        2
# ALL-TERRAIN VEHICLE (ATV)                     1
# Name: VEHICLE_TYPE, dtype: int64
#
# VEHICLE_DEFECT
# NONE                25216
# UNKNOWN             15685
# BRAKES                181
# OTHER                 178
# TIRES                  33
# STEERING               21
# WHEELS                 11
# SUSPENSION             10
# LIGHTS                  7
# ENGINE/MOTOR            7
# FUEL SYSTEM             2
# WINDOWS                 2
# TRAILER COUPLING        2
# CARGO                   2
# EXHAUST                 1
# SIGNALS                 1
# Name: VEHICLE_DEFECT, dtype: int64
#
# MODEL
# UNKNOWN                         4474
# OTHER (EXPLAIN IN NARRATIVE)    2621
# CAMRY                           1334
# COROLLA                          905
# CIVIC                            837
#                                 ...
# TIBURON                            1
# 113                                1
# YUKON DELTA                        1
# SPORTWAGON                         1
# STORM                              1
# Name: MODEL, Length: 1145, dtype: int64
#
# MAKE
# CHEVROLET                                     5063
# FORD                                          4255
# NISSAN                                        3488
# HONDA                                         3162
# TOYOTA MOTOR COMPANY, LTD.                    2714
#                                               ...
# FLYING DUTCHMAN                                  1
# AXLE & EQUIPMENT SALES CO., NAPERVILLE, IN       1
# WESTERN STAR                                     1
# BANTAM CRANE                                     1
# NORTH AMERICAN BUS INDUSTRIES                    1
# Name: MAKE, Length: 270, dtype: int64
#
# UNIT_TYPE
# DRIVER                 37389
# PARKED                  3724
# PEDESTRIAN               502
# BICYCLE                  303
# DRIVERLESS               250
# NON-MOTOR VEHICLE         28
# NON-CONTACT VEHICLE        6
# DISABLED VEHICLE           3
# Name: UNIT_TYPE, dtype: int64
#
# MOST_SEVERE_INJURY
# NO INDICATION OF INJURY     34990
# NONINCAPACITATING INJURY     4132
# REPORTED, NOT EVIDENT        2158
# INCAPACITATING INJURY         904
# FATAL                          56
# Name: MOST_SEVERE_INJURY, dtype: int64

# %%
'''Fill the following columns with 'UNKNOWN' in df_cat_nominal_null:
MOST_SEVERE_INJURY
UNIT_TYPE
MAKE
MODEL
VEHICLE_DEFECT
FIRST_CONTACT_POINT
'''

df_cat_nominal_null['MOST_SEVERE_INJURY'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['UNIT_TYPE'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['MAKE'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['MODEL'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['VEHICLE_DEFECT'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['FIRST_CONTACT_POINT'].fillna('UNKNOWN', inplace=True)
# Out:
# c:\Anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
'''Fill the following columns with 'UNKNOWN/NA' in df_cat_nominal_null:
VEHICLE_TYPE
VEHICLE_USE
MANUEVER
'''

df_cat_nominal_null['VEHICLE_TYPE'].fillna('UNKNOWN/NA', inplace=True)
df_cat_nominal_null['VEHICLE_USE'].fillna('UNKNOWN/NA', inplace=True)
df_cat_nominal_null['MANEUVER'].fillna('UNKNOWN/NA', inplace=True)

# %% [markdown]
# ## Combining nominal and ordinal again

# %%
# combine df_cat_nominal_null and df_cat_nominal_nonull into df_cat_nominal_filled
df_cat_nominal_filled = pd.concat([df_cat_nominal_null, df_cat_nominal_nonull], axis=1)

# combine df_cat_nominal_filled and df_cat_ordinal_filled into df_cat_filled
df_cat_filled = pd.concat([df_cat_nominal_filled, df_cat_ordinal_filled], axis=1)

# %% [markdown]
# ## Combining everything again

# %%
# Combine df_cat_filled and df_num into df_clean

df_clean = pd.concat([df_num, df_cat_filled], axis=1)

# %%
df_clean.head().T
# Out:
#                                                      0  \
# POSTED_SPEED_LIMIT                                  25
# STREET_NO                                           33
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# INJURIES_NO_INDICATION                               1
# INJURIES_UNKNOWN                                     0
# CRASH_HOUR                                          17
# CRASH_DAY_OF_WEEK                                    5
# CRASH_MONTH                                          3
# LATITUDE                                       41.8828
# LONGITUDE                                     -87.6322
# CRASH_UNIT_ID                                   598511
# UNIT_NO                                              2
# NUM_PASSENGERS                                       0
# VEHICLE_YEAR                                      2016
# OCCUPANT_CNT                                         0
# FIRST_CONTACT_POINT                               REAR
# MANEUVER                                        PARKED
# VEHICLE_USE                                   PERSONAL
# VEHICLE_TYPE                                 PASSENGER
# VEHICLE_DEFECT                                    NONE
# MODEL                                              300
# MAKE                                          CHRYSLER
# UNIT_TYPE                                       PARKED
# MOST_SEVERE_INJURY             NO INDICATION OF INJURY
# CRASH_DATE_x                    03/07/2019 05:10:00 PM
# TRAFFIC_CONTROL_DEVICE                     NO CONTROLS
# DEVICE_CONDITION                           NO CONTROLS
# WEATHER_CONDITION                                CLEAR
# LIGHTING_CONDITION                            DAYLIGHT
# FIRST_CRASH_TYPE                  PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                ONE-WAY
# ALIGNMENT                           STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                               DRY
# ROAD_DEFECT                                 NO DEFECTS
# CRASH_TYPE                      NO INJURY / DRIVE AWAY
# DAMAGE                                   $501 - $1,500
# DATE_POLICE_NOTIFIED            03/07/2019 05:35:00 PM
# CRASH_DATE_y                    03/07/2019 05:10:00 PM
# INTERSECTION_RELATED_I                               N
# NOT_RIGHT_OF_WAY_I                                   N
# HIT_AND_RUN_I                                        N
# EXCEED_SPEED_LIMIT_I                                 N
#
#                                                      1  \
# POSTED_SPEED_LIMIT                                  20
# STREET_NO                                         4300
# NUM_UNITS                                            2
# INJURIES_TOTAL                                       0
# INJURIES_FATAL                                       0
# INJURIES_INCAPACITATING                              0
# INJURIES_NON_INCAPACITATING                          0
# INJURIES_REPORTED_NOT_EVIDENT                        0
# INJURIES_NO_INDICATION                               2
# INJURIES_UNKNOWN                                     0
# CRASH_HOUR                                          11
# CRASH_DAY_OF_WEEK                                    6
# CRASH_MONTH                                         11
# LATITUDE                                       41.8148
# LONGITUDE                                     -87.7423
# CRASH_UNIT_ID                                   532437
# UNIT_NO                                              2
# NUM_PASSENGERS                                       0
# VEHICLE_YEAR                                      1999
# OCCUPANT_CNT                                         1
# FIRST_CONTACT_POINT                              FRONT
# MANEUVER                                STRAIGHT AHEAD
# VEHICLE_USE                                   PERSONAL
# VEHICLE_TYPE                                    PICKUP
# VEHICLE_DEFECT                                    NONE
# MODEL                                        SILVERADO
# MAKE                                         CHEVROLET
# UNIT_TYPE                                       DRIVER
# MOST_SEVERE_INJURY             NO INDICATION OF INJURY
# CRASH_DATE_x                    11/30/2018 11:30:00 AM
# TRAFFIC_CONTROL_DEVICE               STOP SIGN/FLASHER
# DEVICE_CONDITION                  FUNCTIONING PROPERLY
# WEATHER_CONDITION                                CLEAR
# LIGHTING_CONDITION                            DAYLIGHT
# FIRST_CRASH_TYPE                                 ANGLE
# TRAFFICWAY_TYPE                            NOT DIVIDED
# ALIGNMENT                           STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                               WET
# ROAD_DEFECT                                 NO DEFECTS
# CRASH_TYPE                      NO INJURY / DRIVE AWAY
# DAMAGE                                     OVER $1,500
# DATE_POLICE_NOTIFIED            11/30/2018 11:50:00 AM
# CRASH_DATE_y                    11/30/2018 11:30:00 AM
# INTERSECTION_RELATED_I                               N
# NOT_RIGHT_OF_WAY_I                                   N
# HIT_AND_RUN_I                                        N
# EXCEED_SPEED_LIMIT_I                                 N
#
#                                                               2  \
# POSTED_SPEED_LIMIT                                           30
# STREET_NO                                                  2198
# NUM_UNITS                                                     1
# INJURIES_TOTAL                                                0
# INJURIES_FATAL                                                0
# INJURIES_INCAPACITATING                                       0
# INJURIES_NON_INCAPACITATING                                   0
# INJURIES_REPORTED_NOT_EVIDENT                                 0
# INJURIES_NO_INDICATION                                        1
# INJURIES_UNKNOWN                                              0
# CRASH_HOUR                                                   19
# CRASH_DAY_OF_WEEK                                             4
# CRASH_MONTH                                                  10
# LATITUDE                                                41.8524
# LONGITUDE                                              -87.6662
# CRASH_UNIT_ID                                            756632
# UNIT_NO                                                       1
# NUM_PASSENGERS                                                0
# VEHICLE_YEAR                                               2000
# OCCUPANT_CNT                                                  1
# FIRST_CONTACT_POINT                                       FRONT
# MANEUVER                                         STRAIGHT AHEAD
# VEHICLE_USE                                            PERSONAL
# VEHICLE_TYPE                                          PASSENGER
# VEHICLE_DEFECT                                           BRAKES
# MODEL                                                  Explorer
# MAKE                                                       FORD
# UNIT_TYPE                                                DRIVER
# MOST_SEVERE_INJURY                      NO INDICATION OF INJURY
# CRASH_DATE_x                             10/09/2019 07:00:00 PM
# TRAFFIC_CONTROL_DEVICE                              NO CONTROLS
# DEVICE_CONDITION                                    NO CONTROLS
# WEATHER_CONDITION                                         CLEAR
# LIGHTING_CONDITION                                     DAYLIGHT
# FIRST_CRASH_TYPE                                   FIXED OBJECT
# TRAFFICWAY_TYPE                 DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                    STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                        DRY
# ROAD_DEFECT                                          NO DEFECTS
# CRASH_TYPE                     INJURY AND / OR TOW DUE TO CRASH
# DAMAGE                                              OVER $1,500
# DATE_POLICE_NOTIFIED                     10/09/2019 07:00:00 PM
# CRASH_DATE_y                             10/09/2019 07:00:00 PM
# INTERSECTION_RELATED_I                                        N
# NOT_RIGHT_OF_WAY_I                                            N
# HIT_AND_RUN_I                                                 N
# EXCEED_SPEED_LIMIT_I                                          N
#
#                                                              3  \
# POSTED_SPEED_LIMIT                                          30
# STREET_NO                                                 2800
# NUM_UNITS                                                    2
# INJURIES_TOTAL                                               0
# INJURIES_FATAL                                               0
# INJURIES_INCAPACITATING                                      0
# INJURIES_NON_INCAPACITATING                                  0
# INJURIES_REPORTED_NOT_EVIDENT                                0
# INJURIES_NO_INDICATION                                       2
# INJURIES_UNKNOWN                                             0
# CRASH_HOUR                                                  10
# CRASH_DAY_OF_WEEK                                            5
# CRASH_MONTH                                                  7
# LATITUDE                                               41.8666
# LONGITUDE                                              -87.696
# CRASH_UNIT_ID                                           179946
# UNIT_NO                                                      2
# NUM_PASSENGERS                                               0
# VEHICLE_YEAR                                                 0
# OCCUPANT_CNT                                                 1
# FIRST_CONTACT_POINT                                       REAR
# MANEUVER                                               BACKING
# VEHICLE_USE                                         UNKNOWN/NA
# VEHICLE_TYPE                                        UNKNOWN/NA
# VEHICLE_DEFECT                                         UNKNOWN
# MODEL                                                  UNKNOWN
# MAKE                                                   UNKNOWN
# UNIT_TYPE                                               DRIVER
# MOST_SEVERE_INJURY                     NO INDICATION OF INJURY
# CRASH_DATE_x                            07/06/2017 10:00:00 AM
# TRAFFIC_CONTROL_DEVICE                          TRAFFIC SIGNAL
# DEVICE_CONDITION                          FUNCTIONING PROPERLY
# WEATHER_CONDITION                                        CLEAR
# LIGHTING_CONDITION                                    DAYLIGHT
# FIRST_CRASH_TYPE                                      REAR END
# TRAFFICWAY_TYPE                DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                   STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                       DRY
# ROAD_DEFECT                                         NO DEFECTS
# CRASH_TYPE                              NO INJURY / DRIVE AWAY
# DAMAGE                                             OVER $1,500
# DATE_POLICE_NOTIFIED                    07/06/2017 02:30:00 PM
# CRASH_DATE_y                            07/06/2017 10:00:00 AM
# INTERSECTION_RELATED_I                                       Y
# NOT_RIGHT_OF_WAY_I                                           N
# HIT_AND_RUN_I                                                N
# EXCEED_SPEED_LIMIT_I                                         N
#
#                                                              4
# POSTED_SPEED_LIMIT                                          30
# STREET_NO                                                 7739
# NUM_UNITS                                                    2
# INJURIES_TOTAL                                               0
# INJURIES_FATAL                                               0
# INJURIES_INCAPACITATING                                      0
# INJURIES_NON_INCAPACITATING                                  0
# INJURIES_REPORTED_NOT_EVIDENT                                0
# INJURIES_NO_INDICATION                                       2
# INJURIES_UNKNOWN                                             0
# CRASH_HOUR                                                  15
# CRASH_DAY_OF_WEEK                                            6
# CRASH_MONTH                                                 11
# LATITUDE                                               42.0222
# LONGITUDE                                             -87.6667
# CRASH_UNIT_ID                                            98704
# UNIT_NO                                                      1
# NUM_PASSENGERS                                               0
# VEHICLE_YEAR                                              2016
# OCCUPANT_CNT                                                 1
# FIRST_CONTACT_POINT                                 FRONT-LEFT
# MANEUVER                                                 OTHER
# VEHICLE_USE                                           PERSONAL
# VEHICLE_TYPE                                         PASSENGER
# VEHICLE_DEFECT                                            NONE
# MODEL                                                  MUSTANG
# MAKE                                                      FORD
# UNIT_TYPE                                               DRIVER
# MOST_SEVERE_INJURY                     NO INDICATION OF INJURY
# CRASH_DATE_x                            11/18/2016 03:17:00 PM
# TRAFFIC_CONTROL_DEVICE                             NO CONTROLS
# DEVICE_CONDITION                                   NO CONTROLS
# WEATHER_CONDITION                                        CLEAR
# LIGHTING_CONDITION                                    DAYLIGHT
# FIRST_CRASH_TYPE                      SIDESWIPE SAME DIRECTION
# TRAFFICWAY_TYPE                DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                   STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                       WET
# ROAD_DEFECT                                         NO DEFECTS
# CRASH_TYPE                              NO INJURY / DRIVE AWAY
# DAMAGE                                             OVER $1,500
# DATE_POLICE_NOTIFIED                    11/18/2016 04:05:00 PM
# CRASH_DATE_y                            11/18/2016 03:17:00 PM
# INTERSECTION_RELATED_I                                       N
# NOT_RIGHT_OF_WAY_I                                           N
# HIT_AND_RUN_I                                                N
# EXCEED_SPEED_LIMIT_I                                         N

# %% [markdown]
# # Exporting the cleaned data

# %%
# export df_clean to csv
df_clean.to_csv('data/df_clean.csv')

# %%
df_clean.shape
# Out:
# (42265, 47)

# %%
df_clean.isna().sum()
# Out:
# POSTED_SPEED_LIMIT               0
# STREET_NO                        0
# NUM_UNITS                        0
# INJURIES_TOTAL                   0
# INJURIES_FATAL                   0
# INJURIES_INCAPACITATING          0
# INJURIES_NON_INCAPACITATING      0
# INJURIES_REPORTED_NOT_EVIDENT    0
# INJURIES_NO_INDICATION           0
# INJURIES_UNKNOWN                 0
# CRASH_HOUR                       0
# CRASH_DAY_OF_WEEK                0
# CRASH_MONTH                      0
# LATITUDE                         0
# LONGITUDE                        0
# CRASH_UNIT_ID                    0
# UNIT_NO                          0
# NUM_PASSENGERS                   0
# VEHICLE_YEAR                     0
# OCCUPANT_CNT                     0
# FIRST_CONTACT_POINT              0
# MANEUVER                         0
# VEHICLE_USE                      0
# VEHICLE_TYPE                     0
# VEHICLE_DEFECT                   0
# MODEL                            0
# MAKE                             0
# UNIT_TYPE                        0
# MOST_SEVERE_INJURY               0
# CRASH_DATE_x                     0
# TRAFFIC_CONTROL_DEVICE           0
# DEVICE_CONDITION                 0
# WEATHER_CONDITION                0
# LIGHTING_CONDITION               0
# FIRST_CRASH_TYPE                 0
# TRAFFICWAY_TYPE                  0
# ALIGNMENT                        0
# ROADWAY_SURFACE_COND             0
# ROAD_DEFECT                      0
# CRASH_TYPE                       0
# DAMAGE                           0
# DATE_POLICE_NOTIFIED             0
# CRASH_DATE_y                     0
# INTERSECTION_RELATED_I           0
# NOT_RIGHT_OF_WAY_I               0
# HIT_AND_RUN_I                    0
# EXCEED_SPEED_LIMIT_I             0
# dtype: int64
