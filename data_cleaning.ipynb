# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Data Sources
#
# [crashes](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Crashes/85ca-t3if)
#
# [vehicles](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Vehicles/68nd-jvt3)
#
# [people](https://data.cityofchicago.org/Transportation/Traffic-Crashes-People/u6pd-qa9d)

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import scipy.sparse as sp
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
# imort 'data/merged.csv'
df = pd.read_csv('data/merged.csv')
# Out:
# C:\Users\gerba\AppData\Local\Temp\ipykernel_15996\3896017220.py:2: DtypeWarning: Columns (30,31,32,33,69,88,89,90,92,96,97,98,101,103,106,107,109,119) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/merged.csv')

# %% [markdown]
# ## Initial Drop

# %%
'''
drom from df 
CMV_ID
USDOT_NO
CCMC_NO
ILCC_NO
COMMERCIAL_SRC
GVWR
CARRIER_NAME
CARRIER_STATE
CARRIER_CITY
HAZMAT_PLACARDS_I
HAZMAT_NAME
UN_NO
HAZMAT_PRESENT_I
HAZMAT_REPORT_I
HAZMAT_REPORT_NO
MCS_REPORT_I
MCS_REPORT_NO
HAZMAT_VIO_CAUSE_CRASH_I
MCS_VIO_CAUSE_CRASH_I
IDOT_PERMIT_NO
WIDE_LOAD_I
TRAILER1_WIDTH
TRAILER2_WIDTH
TRAILER1_LENGTH
TRAILER2_LENGTH
TOTAL_VEHICLE_LENGTH
AXLE_CNT
VEHICLE_CONFIG
CARGO_BODY_TYPE
LOAD_TYPE
HAZMAT_OUT_OF_SERVICE_I
MCS_OUT_OF_SERVICE_I
HAZMAT_CLASS
PHOTOS_TAKEN_I
STATEMENTS_TAKEN_I
DOORING_I
WORK_ZONE_I
WORK_ZONE_TYPE
WORKERS_PRESENT_I
TOWED_I
FIRE_I
TOWED_BY
TOWED_TO
AREA_00_I
AREA_01_I
AREA_02_I
AREA_03_I
AREA_04_I
AREA_05_I
AREA_06_I
AREA_07_I
AREA_08_I
AREA_09_I
AREA_10_I
AREA_11_I
AREA_12_I
AREA_99_I
'''

df.drop(columns=['CMV_ID',
                 'USDOT_NO',
                 'CCMC_NO',
                 'ILCC_NO',
                 'COMMERCIAL_SRC',
                 'GVWR',
                 'CARRIER_NAME',
                 'CARRIER_STATE',
                 'CARRIER_CITY',
                 'HAZMAT_PLACARDS_I',
                 'HAZMAT_NAME',
                 'UN_NO',
                 'HAZMAT_PRESENT_I',
                 'HAZMAT_REPORT_I',
                 'HAZMAT_REPORT_NO',
                 'MCS_REPORT_I',
                 'MCS_REPORT_NO',
                 'HAZMAT_VIO_CAUSE_CRASH_I',
                 'MCS_VIO_CAUSE_CRASH_I',
                 'IDOT_PERMIT_NO',
                 'WIDE_LOAD_I',
                 'TRAILER1_WIDTH',
                 'TRAILER2_WIDTH',
                 'TRAILER1_LENGTH',
                 'TRAILER2_LENGTH',
                 'TOTAL_VEHICLE_LENGTH',
                 'AXLE_CNT',
                 'VEHICLE_CONFIG',
                 'CARGO_BODY_TYPE',
                 'LOAD_TYPE',
                 'HAZMAT_OUT_OF_SERVICE_I',
                 'MCS_OUT_OF_SERVICE_I',
                 'HAZMAT_CLASS',
                 
                 'PHOTOS_TAKEN_I',
                 'STATEMENTS_TAKEN_I',
                 'DOORING_I',
                 'WORK_ZONE_I',
                 'WORK_ZONE_TYPE',
                 'WORKERS_PRESENT_I',
                 
                 'TOWED_I',
                 'FIRE_I',
                 
                 'TOWED_BY',
                 'TOWED_TO',
                 'AREA_00_I',
                 'AREA_01_I',
                 'AREA_02_I',
                 'AREA_03_I',
                 'AREA_04_I',
                 'AREA_05_I',
                 'AREA_06_I',
                 'AREA_07_I',
                 'AREA_08_I',
                 'AREA_09_I',
                 'AREA_10_I',
                 'AREA_11_I',
                 'AREA_12_I',
                 'AREA_99_I',
                 
                 'BEAT_OF_OCCURRENCE',
                 'VEHICLE_ID',
                 'LANE_CNT',
                 ], inplace=True)

# %%
df.shape
# Out:
# (1491794, 60)

# %%
# remove all rows where PRIM_CONTRIBUTORY_CAUSE is UNABLE TO DETERMINE and NOT APPLICABLE
df = df[df['PRIM_CONTRIBUTORY_CAUSE'] != 'NOT APPLICABLE']
df = df[df['PRIM_CONTRIBUTORY_CAUSE'] != 'UNABLE TO DETERMINE']

# %%
# check
df['PRIM_CONTRIBUTORY_CAUSE'].value_counts()
# Out:
# FAILING TO YIELD RIGHT-OF-WAY                                                       164915
# FOLLOWING TOO CLOSELY                                                               151936
# IMPROPER OVERTAKING/PASSING                                                          73063
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               66695
# IMPROPER BACKING                                                                     58478
# IMPROPER LANE USAGE                                                                  54856
# IMPROPER TURNING/NO SIGNAL                                                           49008
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  47434
# DISREGARDING TRAFFIC SIGNALS                                                         30303
# WEATHER                                                                              21949
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     20053
# DISREGARDING STOP SIGN                                                               16971
# DISTRACTION - FROM INSIDE VEHICLE                                                    10788
# PHYSICAL CONDITION OF DRIVER                                                          9547
# EQUIPMENT - VEHICLE CONDITION                                                         9473
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    8439
# DRIVING ON WRONG SIDE/WRONG WAY                                                       8435
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                  8154
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    6156
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      4166
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   3398
# DISREGARDING OTHER TRAFFIC SIGNS                                                      3083
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     2547
# ROAD CONSTRUCTION/MAINTENANCE                                                         2414
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                              2344
# CELL PHONE USE OTHER THAN TEXTING                                                     2135
# DISREGARDING ROAD MARKINGS                                                            1786
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       1667
# TURNING RIGHT ON RED                                                                  1092
# ANIMAL                                                                                 984
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)            724
# RELATED TO BUS STOP                                                                    644
# TEXTING                                                                                631
# DISREGARDING YIELD SIGN                                                                509
# PASSING STOPPED SCHOOL BUS                                                             181
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 156
# OBSTRUCTED CROSSWALKS                                                                  138
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                               42
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64

# %%
df.shape
# Out:
# (845294, 60)

# %%
df.head().T
# Out:
#                                                                                0  \
# CRASH_RECORD_ID                79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...
# RD_NO_x                                                                 JC199149
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              03/25/2019 02:43:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                          ONE-WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                      INJURY AND / OR TOW DUE TO CRASH
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      03/25/2019 03:17:00 PM
# PRIM_CONTRIBUTORY_CAUSE                               IMPROPER TURNING/NO SIGNAL
# SEC_CONTRIBUTORY_CAUSE                       DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# STREET_NO                                                                    536
# STREET_DIRECTION                                                               W
# STREET_NAME                                                          RANDOLPH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                         REPORTED, NOT EVIDENT
# INJURIES_TOTAL                                                               1.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                1.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                    14
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    3
# LATITUDE                                                               41.884547
# LONGITUDE                                                             -87.641201
# LOCATION                                 POINT (-87.64120093714 41.884547224337)
# CRASH_UNIT_ID                                                             611178
# RD_NO_y                                                                 JC199149
# CRASH_DATE_y                                              03/25/2019 02:43:00 PM
# UNIT_NO                                                                        1
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               1.0
# CMRC_VEH_I                                                                   NaN
# MAKE                                                                   CHEVROLET
# MODEL                                                                      CRUZE
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                              2017.0
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                    RIDESHARE SERVICE
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                            TURNING LEFT
# OCCUPANT_CNT                                                                 2.0
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                   FRONT-LEFT
#
#                                                                                1  \
# CRASH_RECORD_ID                79c7a2ce89f446262efd86df3d72d18b04ba487024b7c4...
# RD_NO_x                                                                 JC199149
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              03/25/2019 02:43:00 PM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                         TURNING
# TRAFFICWAY_TYPE                                                          ONE-WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                                             ON SCENE
# CRASH_TYPE                                      INJURY AND / OR TOW DUE TO CRASH
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      03/25/2019 03:17:00 PM
# PRIM_CONTRIBUTORY_CAUSE                               IMPROPER TURNING/NO SIGNAL
# SEC_CONTRIBUTORY_CAUSE                       DRIVING SKILLS/KNOWLEDGE/EXPERIENCE
# STREET_NO                                                                    536
# STREET_DIRECTION                                                               W
# STREET_NAME                                                          RANDOLPH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                         REPORTED, NOT EVIDENT
# INJURIES_TOTAL                                                               1.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                1.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                    14
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    3
# LATITUDE                                                               41.884547
# LONGITUDE                                                             -87.641201
# LOCATION                                 POINT (-87.64120093714 41.884547224337)
# CRASH_UNIT_ID                                                             611179
# RD_NO_y                                                                 JC199149
# CRASH_DATE_y                                              03/25/2019 02:43:00 PM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                      CAMRY
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                              2010.0
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                 1.0
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                  FRONT-RIGHT
#
#                                                                                2  \
# CRASH_RECORD_ID                792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...
# RD_NO_x                                                                 JB422857
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              09/05/2018 08:40:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                           ANGLE
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      09/05/2018 09:00:00 AM
# PRIM_CONTRIBUTORY_CAUSE        VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...
# SEC_CONTRIBUTORY_CAUSE                             FAILING TO YIELD RIGHT-OF-WAY
# STREET_NO                                                                   4821
# STREET_DIRECTION                                                               N
# STREET_NAME                                                           ELSTON AVE
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                               0.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                0.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                     8
# CRASH_DAY_OF_WEEK                                                              4
# CRASH_MONTH                                                                    9
# LATITUDE                                                               41.968562
# LONGITUDE                                                             -87.740659
# LOCATION                                POINT (-87.740659314632 41.968562453871)
# CRASH_UNIT_ID                                                             470531
# RD_NO_y                                                                 JB422857
# CRASH_DATE_y                                              09/05/2018 08:40:00 AM
# UNIT_NO                                                                        1
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                    4RUNNER
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                              2002.0
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                         SPORT UTILITY VEHICLE (SUV)
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                               N
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                 1.0
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                        FRONT
#
#                                                                                3  \
# CRASH_RECORD_ID                792b539deaaad65ee5b4a9691d927a34d298eb33d42af0...
# RD_NO_x                                                                 JB422857
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              09/05/2018 08:40:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                               NO CONTROLS
# DEVICE_CONDITION                                                     NO CONTROLS
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                           ANGLE
# TRAFFICWAY_TYPE                                                      NOT DIVIDED
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                       NaN
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                               OVER $1,500
# DATE_POLICE_NOTIFIED                                      09/05/2018 09:00:00 AM
# PRIM_CONTRIBUTORY_CAUSE        VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...
# SEC_CONTRIBUTORY_CAUSE                             FAILING TO YIELD RIGHT-OF-WAY
# STREET_NO                                                                   4821
# STREET_DIRECTION                                                               N
# STREET_NAME                                                           ELSTON AVE
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                               0.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                0.0
# INJURIES_NO_INDICATION                                                       2.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                     8
# CRASH_DAY_OF_WEEK                                                              4
# CRASH_MONTH                                                                    9
# LATITUDE                                                               41.968562
# LONGITUDE                                                             -87.740659
# LOCATION                                POINT (-87.740659314632 41.968562453871)
# CRASH_UNIT_ID                                                             470532
# RD_NO_y                                                                 JB422857
# CRASH_DATE_y                                              09/05/2018 08:40:00 AM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                  TOYOTA MOTOR COMPANY, LTD.
# MODEL                                                                      CAMRY
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                              2014.0
# VEHICLE_DEFECT                                                              NONE
# VEHICLE_TYPE                                                           PASSENGER
# VEHICLE_USE                                                             PERSONAL
# TRAVEL_DIRECTION                                                              SE
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                 1.0
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                   REAR-RIGHT
#
#                                                                                6
# CRASH_RECORD_ID                05b1982cdba5d8a00e7e76ad1ecdab0e598429f78481d2...
# RD_NO_x                                                                 JF378711
# CRASH_DATE_EST_I                                                             NaN
# CRASH_DATE_x                                              08/29/2022 11:30:00 AM
# POSTED_SPEED_LIMIT                                                            30
# TRAFFIC_CONTROL_DEVICE                                            TRAFFIC SIGNAL
# DEVICE_CONDITION                                            FUNCTIONING PROPERLY
# WEATHER_CONDITION                                                          CLEAR
# LIGHTING_CONDITION                                                      DAYLIGHT
# FIRST_CRASH_TYPE                                                        REAR END
# TRAFFICWAY_TYPE                                                         FOUR WAY
# ALIGNMENT                                                     STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                                         DRY
# ROAD_DEFECT                                                           NO DEFECTS
# REPORT_TYPE                                           NOT ON SCENE (DESK REPORT)
# CRASH_TYPE                                                NO INJURY / DRIVE AWAY
# INTERSECTION_RELATED_I                                                         Y
# NOT_RIGHT_OF_WAY_I                                                           NaN
# HIT_AND_RUN_I                                                                NaN
# DAMAGE                                                             $501 - $1,500
# DATE_POLICE_NOTIFIED                                      09/01/2022 11:30:00 AM
# PRIM_CONTRIBUTORY_CAUSE                             DISREGARDING TRAFFIC SIGNALS
# SEC_CONTRIBUTORY_CAUSE                                            NOT APPLICABLE
# STREET_NO                                                                   3939
# STREET_DIRECTION                                                               W
# STREET_NAME                                                              79TH ST
# NUM_UNITS                                                                      2
# MOST_SEVERE_INJURY                                       NO INDICATION OF INJURY
# INJURIES_TOTAL                                                               0.0
# INJURIES_FATAL                                                               0.0
# INJURIES_INCAPACITATING                                                      0.0
# INJURIES_NON_INCAPACITATING                                                  0.0
# INJURIES_REPORTED_NOT_EVIDENT                                                0.0
# INJURIES_NO_INDICATION                                                       3.0
# INJURIES_UNKNOWN                                                             0.0
# CRASH_HOUR                                                                    11
# CRASH_DAY_OF_WEEK                                                              2
# CRASH_MONTH                                                                    8
# LATITUDE                                                               41.749348
# LONGITUDE                                                             -87.721097
# LOCATION                                POINT (-87.721096727406 41.749348170421)
# CRASH_UNIT_ID                                                            1410559
# RD_NO_y                                                                 JF378711
# CRASH_DATE_y                                              08/29/2022 11:30:00 AM
# UNIT_NO                                                                        2
# UNIT_TYPE                                                                 DRIVER
# NUM_PASSENGERS                                                               NaN
# CMRC_VEH_I                                                                   NaN
# MAKE                                                                     UNKNOWN
# MODEL                                               OTHER (EXPLAIN IN NARRATIVE)
# LIC_PLATE_STATE                                                               IL
# VEHICLE_YEAR                                                                 NaN
# VEHICLE_DEFECT                                                           UNKNOWN
# VEHICLE_TYPE                                             TRACTOR W/ SEMI-TRAILER
# VEHICLE_USE                                             COMMERCIAL - SINGLE UNIT
# TRAVEL_DIRECTION                                                               W
# MANEUVER                                                          STRAIGHT AHEAD
# OCCUPANT_CNT                                                                 1.0
# EXCEED_SPEED_LIMIT_I                                                         NaN
# FIRST_CONTACT_POINT                                                      UNKNOWN

# %% [markdown]
# # fixme I had to move this code to later, and it's redundant, so I just removed the dataframe from being merged back later

# %%
# '''Also drop the following columns:
# EXCEED_SPEED_LIMIT_I
# HIT_AND_RUN_I
# NOT_RIGHT_OF_WAY_I
# INTERSECTION_RELATED_I	
# '''

# df.drop(columns=['EXCEED_SPEED_LIMIT_I',
#                  'HIT_AND_RUN_I',
#                  'NOT_RIGHT_OF_WAY_I',
#                  'INTERSECTION_RELATED_I',
#                  ], inplace=True)

# df.shape

# %% [markdown]
# ## Chopping down the data
#
# There's just too much
#
# Do after the initial clean to get a better sample.

# %%
df.shape
# Out:
# (845294, 60)

# %%
df = df.sample(frac=0.25, random_state=42)

# %%
df.shape
# Out:
# (211324, 60)

# %%
# Define the target groups
target_groups = {
    'Failures to Follow Traffic Rules': [
        'FAILING TO YIELD RIGHT-OF-WAY',
        'FOLLOWING TOO CLOSELY',
        'IMPROPER OVERTAKING/PASSING',
        'FAILING TO REDUCE SPEED TO AVOID CRASH',
        'IMPROPER BACKING',
        'IMPROPER LANE USAGE',
        'IMPROPER TURNING/NO SIGNAL',
        'DISREGARDING TRAFFIC SIGNALS',
        'DISREGARDING STOP SIGN',
        'DISREGARDING OTHER TRAFFIC SIGNS',
        'DISREGARDING YIELD SIGN',
        'EXCEEDING SAFE SPEED FOR CONDITIONS', 
        'DRIVING ON WRONG SIDE/WRONG WAY', 
        'EXCEEDING AUTHORIZED SPEED LIMIT',
        'TURNING RIGHT ON RED', 
        'DISREGARDING ROAD MARKINGS'
    ],
    'Driver Behavior and Awareness': [
        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE',
        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
        'DISTRACTION - FROM INSIDE VEHICLE',
        'PHYSICAL CONDITION OF DRIVER',
        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
        'DISTRACTION - FROM OUTSIDE VEHICLE',
        'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)',
        'CELL PHONE USE OTHER THAN TEXTING',
        'TEXTING', 
        'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)'
    ],
    'Environmental Factors': [
        'WEATHER',
        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
        'ROAD CONSTRUCTION/MAINTENANCE',
        'ROAD ENGINEERING/SURFACE/MARKING DEFECTS'
    ],
    'Vehicle-related Issues': [
        'EQUIPMENT - VEHICLE CONDITION'
    ],
    'Other Specific Circumstances': [
        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
        'ANIMAL',
        'RELATED TO BUS STOP',
        'BICYCLE ADVANCING LEGALLY ON RED LIGHT',
        'OBSTRUCTED CROSSWALKS',
        'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT',
        'PASSING STOPPED SCHOOL BUS'
    ]
}

# Group the targets based on the defined groups
for group, targets in target_groups.items():
    df.loc[df['PRIM_CONTRIBUTORY_CAUSE'].isin(targets), 'PRIM_CONTRIBUTORY_CAUSE'] = group

# Cut out the df_targets with the grouped targets
df_targets = df[['PRIM_CONTRIBUTORY_CAUSE']]

# Print the unique grouped targets
print(df_targets['PRIM_CONTRIBUTORY_CAUSE'].unique())
# Out:
# ['Driver Behavior and Awareness' 'Failures to Follow Traffic Rules'
#  'Vehicle-related Issues' 'Other Specific Circumstances'
#  'Environmental Factors']

# %% [markdown]
# ## Cleaning Leftover Columns

# %% [markdown]
# ### Split Into categorical and numerical

# %% [markdown]
# Now that they have been merged on CRASH_RECORD_ID, I'm going to remove that column, and create a new index

# %%
df = df.drop('CRASH_RECORD_ID', axis=1)

# %%
df = df.reset_index(drop=True)

# %%
index = df.index

# %%
print(index)
# Out:
# RangeIndex(start=0, stop=211324, step=1)

# %%
# split df into categorical and numerical dataframes
df_cat = df.select_dtypes(include='object')
df_num = df.select_dtypes(exclude='object')

# %%
# df_cat = categorical_data.reset_index(drop=True)
# df_num = numerical_data.reset_index(drop=True)

# %% [markdown]
# #### Numerical Cleaning

# %% [markdown]
# Okay so everything that is left over with the numerical columns should be able to be filled with 0.

# %%
# check df_num for nulls
df_num.isnull().sum()
# Out:
# POSTED_SPEED_LIMIT                    0
# STREET_NO                             0
# NUM_UNITS                             0
# INJURIES_TOTAL                      163
# INJURIES_FATAL                      163
# INJURIES_INCAPACITATING             163
# INJURIES_NON_INCAPACITATING         163
# INJURIES_REPORTED_NOT_EVIDENT       163
# INJURIES_NO_INDICATION              163
# INJURIES_UNKNOWN                    163
# CRASH_HOUR                            0
# CRASH_DAY_OF_WEEK                     0
# CRASH_MONTH                           0
# LATITUDE                           1507
# LONGITUDE                          1507
# CRASH_UNIT_ID                         0
# UNIT_NO                               0
# NUM_PASSENGERS                   175133
# VEHICLE_YEAR                      29160
# OCCUPANT_CNT                       4642
# dtype: int64

# %%
# fill all missing values in df_num with 0
df_num.fillna(0, inplace=True)

# %% [markdown]
# #### categorical cleaning

# %%
df_cat.isna().sum()
# Out:
# RD_NO_x                      1251
# CRASH_DATE_EST_I           200757
# CRASH_DATE_x                    0
# TRAFFIC_CONTROL_DEVICE          0
# DEVICE_CONDITION                0
# WEATHER_CONDITION               0
# LIGHTING_CONDITION              0
# FIRST_CRASH_TYPE                0
# TRAFFICWAY_TYPE                 0
# ALIGNMENT                       0
# ROADWAY_SURFACE_COND            0
# ROAD_DEFECT                     0
# REPORT_TYPE                  6804
# CRASH_TYPE                      0
# INTERSECTION_RELATED_I     149918
# NOT_RIGHT_OF_WAY_I         203603
# HIT_AND_RUN_I              160607
# DAMAGE                          0
# DATE_POLICE_NOTIFIED            0
# PRIM_CONTRIBUTORY_CAUSE         0
# SEC_CONTRIBUTORY_CAUSE          0
# STREET_DIRECTION                1
# STREET_NAME                     0
# MOST_SEVERE_INJURY            165
# LOCATION                     1507
# RD_NO_y                      1341
# CRASH_DATE_y                    0
# UNIT_TYPE                     298
# CMRC_VEH_I                 206968
# MAKE                         4643
# MODEL                        4669
# LIC_PLATE_STATE             19088
# VEHICLE_DEFECT               4642
# VEHICLE_TYPE                 4642
# VEHICLE_USE                  4642
# TRAVEL_DIRECTION             4642
# MANEUVER                     4642
# EXCEED_SPEED_LIMIT_I       210799
# FIRST_CONTACT_POINT          5029
# dtype: int64

# %%
# print out the value_counts for every column in df_cat
for col in df_cat.columns:
    print(col)
    print(df_cat[col].value_counts())
    print('')
# Out:
# RD_NO_x
# JE120677    6
# JC547924    6
# JG128293    5
# JB424173    5
# JE194195    5
#            ..
# JG133628    1
# JF431106    1
# JC405180    1
# JE258768    1
# JB560498    1
# Name: RD_NO_x, Length: 180529, dtype: int64
#
# CRASH_DATE_EST_I
# Y    8909
# N    1658
# Name: CRASH_DATE_EST_I, dtype: int64
#
# CRASH_DATE_x
# 11/10/2017 10:30:00 AM    16
# 12/29/2020 05:00:00 PM    12
# 07/13/2018 03:30:00 PM     9
# 11/06/2017 06:00:00 PM     9
# 11/10/2017 10:00:00 AM     9
#                           ..
# 12/22/2017 07:35:00 PM     1
# 11/01/2022 08:30:00 AM     1
# 02/26/2017 03:00:00 PM     1
# 03/08/2016 01:35:00 PM     1
# 12/19/2018 10:30:00 PM     1
# Name: CRASH_DATE_x, Length: 160057, dtype: int64
#
# TRAFFIC_CONTROL_DEVICE
# NO CONTROLS                 107299
# TRAFFIC SIGNAL               70652
# STOP SIGN/FLASHER            25732
# UNKNOWN                       3978
# OTHER                         1499
# LANE USE MARKING               471
# YIELD                          405
# OTHER REG. SIGN                287
# OTHER WARNING SIGN             220
# PEDESTRIAN CROSSING SIGN       175
# RAILROAD CROSSING GATE         149
# DELINEATORS                     96
# POLICE/FLAGMAN                  91
# SCHOOL ZONE                     86
# FLASHING CONTROL SIGNAL         81
# OTHER RAILROAD CROSSING         57
# RR CROSSING SIGN                21
# NO PASSING                      17
# BICYCLE CROSSING SIGN            8
# Name: TRAFFIC_CONTROL_DEVICE, dtype: int64
#
# DEVICE_CONDITION
# NO CONTROLS                 109550
# FUNCTIONING PROPERLY         89747
# UNKNOWN                       8406
# OTHER                         1664
# FUNCTIONING IMPROPERLY        1206
# NOT FUNCTIONING                627
# WORN REFLECTIVE MATERIAL        93
# MISSING                         31
# Name: DEVICE_CONDITION, dtype: int64
#
# WEATHER_CONDITION
# CLEAR                     169580
# RAIN                       20109
# SNOW                        8327
# CLOUDY/OVERCAST             7117
# UNKNOWN                     4307
# OTHER                        665
# FREEZING RAIN/DRIZZLE        438
# FOG/SMOKE/HAZE               334
# SLEET/HAIL                   294
# BLOWING SNOW                 107
# SEVERE CROSS WIND GATE        46
# Name: WEATHER_CONDITION, dtype: int64
#
# LIGHTING_CONDITION
# DAYLIGHT                  140496
# DARKNESS, LIGHTED ROAD     49164
# DARKNESS                    8940
# DUSK                        6326
# DAWN                        3530
# UNKNOWN                     2868
# Name: LIGHTING_CONDITION, dtype: int64
#
# FIRST_CRASH_TYPE
# REAR END                        56543
# TURNING                         37080
# SIDESWIPE SAME DIRECTION        34328
# PARKED MOTOR VEHICLE            32204
# ANGLE                           28214
# PEDESTRIAN                       4757
# FIXED OBJECT                     4655
# SIDESWIPE OPPOSITE DIRECTION     3132
# PEDALCYCLIST                     3036
# HEAD ON                          2257
# REAR TO FRONT                    2145
# REAR TO SIDE                     1253
# OTHER OBJECT                      916
# REAR TO REAR                      315
# OTHER NONCOLLISION                304
# ANIMAL                            105
# OVERTURNED                         62
# TRAIN                              18
# Name: FIRST_CRASH_TYPE, dtype: int64
#
# TRAFFICWAY_TYPE
# NOT DIVIDED                        93197
# DIVIDED - W/MEDIAN (NOT RAISED)    38395
# ONE-WAY                            23294
# FOUR WAY                           15037
# DIVIDED - W/MEDIAN BARRIER         13836
# PARKING LOT                        10721
# OTHER                               5422
# T-INTERSECTION                      2916
# ALLEY                               2457
# CENTER TURN LANE                    1953
# UNKNOWN                             1094
# RAMP                                 697
# UNKNOWN INTERSECTION TYPE            585
# DRIVEWAY                             583
# FIVE POINT, OR MORE                  333
# TRAFFIC ROUTE                        284
# Y-INTERSECTION                       268
# NOT REPORTED                         158
# L-INTERSECTION                        51
# ROUNDABOUT                            43
# Name: TRAFFICWAY_TYPE, dtype: int64
#
# ALIGNMENT
# STRAIGHT AND LEVEL       205470
# STRAIGHT ON GRADE          3183
# CURVE, LEVEL               1600
# STRAIGHT ON HILLCREST       659
# CURVE ON GRADE              326
# CURVE ON HILLCREST           86
# Name: ALIGNMENT, dtype: int64
#
# ROADWAY_SURFACE_COND
# DRY                160825
# WET                 31002
# UNKNOWN              9191
# SNOW OR SLUSH        7999
# ICE                  1757
# OTHER                 479
# SAND, MUD, DIRT        71
# Name: ROADWAY_SURFACE_COND, dtype: int64
#
# ROAD_DEFECT
# NO DEFECTS           180520
# UNKNOWN               27019
# RUT, HOLES             1178
# OTHER                  1124
# WORN SURFACE            891
# SHOULDER DEFECT         432
# DEBRIS ON ROADWAY       160
# Name: ROAD_DEFECT, dtype: int64
#
# REPORT_TYPE
# NOT ON SCENE (DESK REPORT)    102846
# ON SCENE                      101605
# AMENDED                           69
# Name: REPORT_TYPE, dtype: int64
#
# CRASH_TYPE
# NO INJURY / DRIVE AWAY              143008
# INJURY AND / OR TOW DUE TO CRASH     68316
# Name: CRASH_TYPE, dtype: int64
#
# INTERSECTION_RELATED_I
# Y    58740
# N     2666
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# Y    6958
# N     763
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# Y    47982
# N     2735
# Name: HIT_AND_RUN_I, dtype: int64
#
# DAMAGE
# OVER $1,500      136106
# $501 - $1,500     52560
# $500 OR LESS      22658
# Name: DAMAGE, dtype: int64
#
# DATE_POLICE_NOTIFIED
# 12/11/2017 06:00:00 PM    9
# 10/12/2020 04:00:00 PM    9
# 07/01/2022 04:00:00 PM    8
# 07/20/2022 05:00:00 PM    7
# 02/14/2020 05:00:00 PM    7
#                          ..
# 06/11/2017 08:20:00 PM    1
# 08/29/2016 06:10:00 PM    1
# 12/11/2019 04:03:00 PM    1
# 03/23/2023 09:00:00 AM    1
# 12/19/2018 11:00:00 PM    1
# Name: DATE_POLICE_NOTIFIED, Length: 168320, dtype: int64
#
# PRIM_CONTRIBUTORY_CAUSE
# Failures to Follow Traffic Rules    172021
# Driver Behavior and Awareness        27045
# Environmental Factors                 8725
# Vehicle-related Issues                2363
# Other Specific Circumstances          1170
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64
#
# SEC_CONTRIBUTORY_CAUSE
# NOT APPLICABLE                                                                      78840
# UNABLE TO DETERMINE                                                                 49655
# FAILING TO REDUCE SPEED TO AVOID CRASH                                              14387
# FAILING TO YIELD RIGHT-OF-WAY                                                       11311
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                 10694
# FOLLOWING TOO CLOSELY                                                                9894
# IMPROPER OVERTAKING/PASSING                                                          5502
# IMPROPER LANE USAGE                                                                  5112
# WEATHER                                                                              3989
# IMPROPER TURNING/NO SIGNAL                                                           3691
# IMPROPER BACKING                                                                     2743
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     2466
# DISREGARDING TRAFFIC SIGNALS                                                         1484
# DISTRACTION - FROM INSIDE VEHICLE                                                    1204
# DISREGARDING STOP SIGN                                                               1113
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                 1097
# PHYSICAL CONDITION OF DRIVER                                                         1038
# DRIVING ON WRONG SIDE/WRONG WAY                                                       774
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      764
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   717
# EQUIPMENT - VEHICLE CONDITION                                                         713
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    704
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    593
# DISREGARDING ROAD MARKINGS                                                            358
# DISREGARDING OTHER TRAFFIC SIGNS                                                      356
# ROAD CONSTRUCTION/MAINTENANCE                                                         341
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       320
# CELL PHONE USE OTHER THAN TEXTING                                                     287
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                              217
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     160
# TURNING RIGHT ON RED                                                                  135
# RELATED TO BUS STOP                                                                   114
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)           113
# ANIMAL                                                                                106
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 91
# DISREGARDING YIELD SIGN                                                                79
# TEXTING                                                                                72
# PASSING STOPPED SCHOOL BUS                                                             42
# OBSTRUCTED CROSSWALKS                                                                  31
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                              17
# Name: SEC_CONTRIBUTORY_CAUSE, dtype: int64
#
# STREET_DIRECTION
# W    75925
# S    70474
# N    50446
# E    14478
# Name: STREET_DIRECTION, dtype: int64
#
# STREET_NAME
# WESTERN AVE            5983
# PULASKI RD             5189
# ASHLAND AVE            5100
# CICERO AVE             4816
# HALSTED ST             4491
#                        ...
# ERIKSEN DR                1
# DAN RYAN XPRS OB          1
# MARBLE PL                 1
# OUTER ARRIVAL DR IB       1
# MILTIMORE AVE             1
# Name: STREET_NAME, Length: 1370, dtype: int64
#
# MOST_SEVERE_INJURY
# NO INDICATION OF INJURY     174725
# NONINCAPACITATING INJURY     20660
# REPORTED, NOT EVIDENT        10919
# INCAPACITATING INJURY         4593
# FATAL                          262
# Name: MOST_SEVERE_INJURY, dtype: int64
#
# LOCATION
# POINT (-87.905309125103 41.976201139024)    313
# POINT (-87.619928173678 41.900958919109)    178
# POINT (-87.580147768689 41.791420282098)    153
# POINT (-87.585971992965 41.751460603167)    150
# POINT (-87.585275565077 41.722257273006)    118
#                                            ...
# POINT (-87.639847292087 41.903816098782)      1
# POINT (-87.774903138212 41.892317347326)      1
# POINT (-87.639579484028 41.932796319071)      1
# POINT (-87.660892801095 41.884638672974)      1
# POINT (-87.773545323077 41.985948824269)      1
# Name: LOCATION, Length: 99203, dtype: int64
#
# RD_NO_y
# JE120677    6
# JC547924    6
# JB424173    5
# JB299094    5
# JB207135    5
#            ..
# JE258768    1
# JB496896    1
# JB180822    1
# JF385691    1
# JB560498    1
# Name: RD_NO_y, Length: 180448, dtype: int64
#
# CRASH_DATE_y
# 11/10/2017 10:30:00 AM    16
# 12/29/2020 05:00:00 PM    12
# 12/22/2018 03:30:00 PM     9
# 11/10/2017 10:00:00 AM     9
# 11/06/2017 06:00:00 PM     9
#                           ..
# 02/26/2017 03:00:00 PM     1
# 03/08/2016 01:35:00 PM     1
# 05/27/2022 06:00:00 AM     1
# 07/11/2020 11:25:00 AM     1
# 12/19/2018 10:30:00 PM     1
# Name: CRASH_DATE_y, Length: 160061, dtype: int64
#
# UNIT_TYPE
# DRIVER                 187036
# PARKED                  18382
# PEDESTRIAN               2497
# BICYCLE                  1584
# DRIVERLESS               1308
# NON-MOTOR VEHICLE         155
# NON-CONTACT VEHICLE        42
# DISABLED VEHICLE           21
# EQUESTRIAN                  1
# Name: UNIT_TYPE, dtype: int64
#
# CMRC_VEH_I
# Y    2873
# N    1483
# Name: CMRC_VEH_I, dtype: int64
#
# MAKE
# CHEVROLET                                25229
# FORD                                     21446
# NISSAN                                   17383
# HONDA                                    15817
# TOYOTA MOTOR COMPANY, LTD.               13782
#                                          ...
# BEE BOB TRAILER                              1
# UTILITY TRAILER MANUFACTURING COMPANY        1
# ECO-BIKE ELEC MOTORCYCLE                     1
# CROSS TRUCK EQUIPMENT COMPANY                1
# ALL TERRAIN - WHEELS ONLY                    1
# Name: MAKE, Length: 572, dtype: int64
#
# MODEL
# UNKNOWN                         22321
# OTHER (EXPLAIN IN NARRATIVE)    13144
# CAMRY                            6921
# COROLLA                          4415
# CIVIC                            4233
#                                 ...
# VehiCross                           1
# TRIUMPH                             1
# 360 (various styles)                1
# AMIGO                               1
# ALL TERRAIN - WHEELS ONLY           1
# Name: MODEL, Length: 1709, dtype: int64
#
# LIC_PLATE_STATE
# IL    177052
# IN      3994
# XX      2660
# WI      1282
# MI       877
# FL       715
# TX       635
# OH       510
# AZ       455
# MO       372
# IA       371
# CA       334
# MN       324
# TN       271
# GA       234
# OK       172
# NY       159
# PA       153
# KY       135
# VA       118
# NC       114
# NJ       113
# MS       106
# AL       104
# CO        94
# MD        93
# WA        85
# NB        73
# LA        66
# KS        65
# AR        54
# ME        52
# MA        50
# SC        49
# NV        36
# OR        34
# CT        33
# UT        33
# MT        23
# ND        19
# ID        17
# NH        15
# SD        15
# NM        13
# WV        12
# AK         9
# DC         9
# VT         8
# DE         8
# RI         5
# WY         5
# HI         1
# Name: LIC_PLATE_STATE, dtype: int64
#
# VEHICLE_DEFECT
# NONE                125859
# UNKNOWN              78427
# BRAKES                 944
# OTHER                  924
# TIRES                  158
# STEERING               136
# WHEELS                  82
# SUSPENSION              52
# ENGINE/MOTOR            38
# FUEL SYSTEM             18
# LIGHTS                  17
# WINDOWS                 10
# CARGO                    5
# SIGNALS                  4
# EXHAUST                  4
# TRAILER COUPLING         2
# RESTRAINT SYSTEM         2
# Name: VEHICLE_DEFECT, dtype: int64
#
# VEHICLE_TYPE
# PASSENGER                                 136495
# SPORT UTILITY VEHICLE (SUV)                29863
# VAN/MINI-VAN                               10663
# UNKNOWN/NA                                 10262
# PICKUP                                      6739
# TRUCK - SINGLE UNIT                         4053
# BUS OVER 15 PASS.                           2365
# OTHER                                       2170
# TRACTOR W/ SEMI-TRAILER                     2007
# MOTORCYCLE (OVER 150CC)                      553
# BUS UP TO 15 PASS.                           512
# TRACTOR W/O SEMI-TRAILER                     290
# SINGLE UNIT TRUCK WITH TRAILER               271
# OTHER VEHICLE WITH TRAILER                   244
# MOPED OR MOTORIZED BICYCLE                    66
# MOTOR DRIVEN CYCLE                            44
# AUTOCYCLE                                     38
# ALL-TERRAIN VEHICLE (ATV)                     19
# FARM EQUIPMENT                                14
# 3-WHEELED MOTORCYCLE (2 REAR WHEELS)           8
# RECREATIONAL OFF-HIGHWAY VEHICLE (ROV)         4
# SNOWMOBILE                                     2
# Name: VEHICLE_TYPE, dtype: int64
#
# VEHICLE_USE
# PERSONAL                        146668
# UNKNOWN/NA                       30363
# NOT IN USE                        7740
# OTHER                             6502
# TAXI/FOR HIRE                     2915
# COMMERCIAL - SINGLE UNIT          2797
# RIDESHARE SERVICE                 2019
# CTA                               1544
# POLICE                            1468
# CONSTRUCTION/MAINTENANCE          1111
# COMMERCIAL - MULTI-UNIT            946
# OTHER TRANSIT                      600
# SCHOOL BUS                         558
# TOW TRUCK                          453
# AMBULANCE                          212
# STATE OWNED                        172
# FIRE                               170
# DRIVER EDUCATION                   162
# MASS TRANSIT                       135
# LAWN CARE/LANDSCAPING               93
# AGRICULTURE                         26
# CAMPER/RV - SINGLE UNIT             11
# MILITARY                             8
# CAMPER/RV - TOWED/MULTI-UNIT         5
# HOUSE TRAILER                        4
# Name: VEHICLE_USE, dtype: int64
#
# TRAVEL_DIRECTION
# N          50200
# S          49008
# W          45277
# E          44437
# UNKNOWN     7294
# SE          3058
# NW          2786
# NE          2315
# SW          2307
# Name: TRAVEL_DIRECTION, dtype: int64
#
# MANEUVER
# STRAIGHT AHEAD                        104377
# PARKED                                 18734
# SLOW/STOP IN TRAFFIC                   18695
# TURNING LEFT                           14658
# BACKING                                 9080
# TURNING RIGHT                           7708
# PASSING/OVERTAKING                      6785
# CHANGING LANES                          4911
# UNKNOWN/NA                              4615
# OTHER                                   3136
# ENTERING TRAFFIC LANE FROM PARKING      2779
# MERGING                                 1571
# U-TURN                                  1551
# STARTING IN TRAFFIC                     1423
# SKIDDING/CONTROL LOSS                   1154
# AVOIDING VEHICLES/OBJECTS               1023
# ENTER FROM DRIVE/ALLEY                   966
# LEAVING TRAFFIC LANE TO PARK             906
# PARKED IN TRAFFIC LANE                   546
# SLOW/STOP - LEFT TURN                    504
# DRIVING WRONG WAY                        471
# SLOW/STOP - RIGHT TURN                   322
# NEGOTIATING A CURVE                      285
# SLOW/STOP - LOAD/UNLOAD                  244
# TURNING ON RED                           109
# DRIVERLESS                                74
# DIVERGING                                 32
# DISABLED                                  23
# Name: MANEUVER, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# Y    407
# N    118
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64
#
# FIRST_CONTACT_POINT
# FRONT                 45193
# REAR                  29586
# SIDE-RIGHT            13504
# SIDE-LEFT             13420
# FRONT-LEFT            12721
# FRONT-LEFT-CORNER     12234
# FRONT-RIGHT           12106
# FRONT-RIGHT-CORNER    11673
# REAR-LEFT             10099
# UNKNOWN                9445
# OTHER                  6198
# REAR-RIGHT             5372
# REAR-LEFT-CORNER       4574
# TOTAL (ALL AREAS)      4037
# REAR-RIGHT-CORNER      3693
# SIDE-LEFT-REAR         2798
# SIDE-RIGHT-REAR        2209
# SIDE-LEFT-FRONT        1819
# SIDE-RIGHT-FRONT       1603
# ROOF                   1590
# NONE                   1535
# UNDER CARRIAGE          700
# TOP                     186
# Name: FIRST_CONTACT_POINT, dtype: int64

# %%
df_cat_dropped_cols = df_cat.drop(columns=['RD_NO_x',
                'CRASH_DATE_EST_I', 
                'REPORT_TYPE', 
                'STREET_DIRECTION',
                'STREET_NAME',
                'LOCATION', 
                'RD_NO_y', 
                'CMRC_VEH_I', 
                'LIC_PLATE_STATE', 
                'TRAVEL_DIRECTION'
                 ])

# %%
df_cat_dropped_cols.isna().sum()
# Out:
# CRASH_DATE_x                    0
# TRAFFIC_CONTROL_DEVICE          0
# DEVICE_CONDITION                0
# WEATHER_CONDITION               0
# LIGHTING_CONDITION              0
# FIRST_CRASH_TYPE                0
# TRAFFICWAY_TYPE                 0
# ALIGNMENT                       0
# ROADWAY_SURFACE_COND            0
# ROAD_DEFECT                     0
# CRASH_TYPE                      0
# INTERSECTION_RELATED_I     149918
# NOT_RIGHT_OF_WAY_I         203603
# HIT_AND_RUN_I              160607
# DAMAGE                          0
# DATE_POLICE_NOTIFIED            0
# PRIM_CONTRIBUTORY_CAUSE         0
# SEC_CONTRIBUTORY_CAUSE          0
# MOST_SEVERE_INJURY            165
# CRASH_DATE_y                    0
# UNIT_TYPE                     298
# MAKE                         4643
# MODEL                        4669
# VEHICLE_DEFECT               4642
# VEHICLE_TYPE                 4642
# VEHICLE_USE                  4642
# MANEUVER                     4642
# EXCEED_SPEED_LIMIT_I       210799
# FIRST_CONTACT_POINT          5029
# dtype: int64

# %% [markdown]
# ## Getting target variable

# %%
'''
remove
PRIM_CONTRIBUTORY_CAUSE
and
SEC_CONTRIBUTORY_CAUSE
from df_cat_dropped_cols
assign it to it's own dataframe called df_targets,
and then export df_targets to csv
'''

# Specifically I'm going to make prim cause the target and remove secondary, maybe I'll come back to it if I have time.
df_targets = df_cat_dropped_cols[['PRIM_CONTRIBUTORY_CAUSE']]
df_cat_dropped_cols.drop(columns=['PRIM_CONTRIBUTORY_CAUSE', 'SEC_CONTRIBUTORY_CAUSE'], inplace=True)
df_targets.to_csv('data/df_targets.csv')

# %%
df_targets.isna().sum()
# Out:
# PRIM_CONTRIBUTORY_CAUSE    0
# dtype: int64

# %%
df_targets.dtypes
# Out:
# PRIM_CONTRIBUTORY_CAUSE    object
# dtype: object

# %%
df_targets.value_counts()

# give me the value counts for each column in df_targets
for col in df_targets.columns:
    print(col)
    print(df_targets[col].value_counts())
    print('')
# Out:
# PRIM_CONTRIBUTORY_CAUSE
# Failures to Follow Traffic Rules    172021
# Driver Behavior and Awareness        27045
# Environmental Factors                 8725
# Vehicle-related Issues                2363
# Other Specific Circumstances          1170
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64

# %% [markdown]
# ## splitting into ordinal and nominal

# %%
'''
assign to df_cat_ordinal 
INTERSECTION_RELATED_I
NOT_RIGHT_OF_WAY_I
HIT_AND_RUN_I
and EXCEED_SPEED_LIMIT_I
'''
df_cat_ordinal = df_cat_dropped_cols[['INTERSECTION_RELATED_I',
                                        'NOT_RIGHT_OF_WAY_I',
                                        'HIT_AND_RUN_I',
                                        'EXCEED_SPEED_LIMIT_I'
                                        ]]

# assign the rest to nominal
df_cat_nominal = df_cat_dropped_cols.drop(columns=['INTERSECTION_RELATED_I',
                                        'NOT_RIGHT_OF_WAY_I',
                                        'HIT_AND_RUN_I',
                                        'EXCEED_SPEED_LIMIT_I'
                                        ])

# %% [markdown]
# ### ordinal

# %%
# list nulls in ordinal
df_cat_ordinal.isna().sum()
# Out:
# INTERSECTION_RELATED_I    149918
# NOT_RIGHT_OF_WAY_I        203603
# HIT_AND_RUN_I             160607
# EXCEED_SPEED_LIMIT_I      210799
# dtype: int64

# %%
for col in df_cat_ordinal.columns:
    print(col)
    print(df_cat_ordinal[col].value_counts())
    print('')
# Out:
# INTERSECTION_RELATED_I
# Y    58740
# N     2666
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# Y    6958
# N     763
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# Y    47982
# N     2735
# Name: HIT_AND_RUN_I, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# Y    407
# N    118
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64

# %%
# fill all nulls in ordinal with 'N'
df_cat_ordinal_filled = df_cat_ordinal.fillna('N')

# %%
df_cat_ordinal_filled.isna().sum()
# Out:
# INTERSECTION_RELATED_I    0
# NOT_RIGHT_OF_WAY_I        0
# HIT_AND_RUN_I             0
# EXCEED_SPEED_LIMIT_I      0
# dtype: int64

# %%
for col in df_cat_ordinal_filled.columns:
    print(col)
    print(df_cat_ordinal_filled[col].value_counts())
    print('')
# Out:
# INTERSECTION_RELATED_I
# N    152584
# Y     58740
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# N    204366
# Y      6958
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# N    163342
# Y     47982
# Name: HIT_AND_RUN_I, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# N    210917
# Y       407
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64

# %% [markdown]
# ### nominal

# %%
# list nulls in nominal
df_cat_nominal.isna().sum()
# Out:
# CRASH_DATE_x                 0
# TRAFFIC_CONTROL_DEVICE       0
# DEVICE_CONDITION             0
# WEATHER_CONDITION            0
# LIGHTING_CONDITION           0
# FIRST_CRASH_TYPE             0
# TRAFFICWAY_TYPE              0
# ALIGNMENT                    0
# ROADWAY_SURFACE_COND         0
# ROAD_DEFECT                  0
# CRASH_TYPE                   0
# DAMAGE                       0
# DATE_POLICE_NOTIFIED         0
# MOST_SEVERE_INJURY         165
# CRASH_DATE_y                 0
# UNIT_TYPE                  298
# MAKE                      4643
# MODEL                     4669
# VEHICLE_DEFECT            4642
# VEHICLE_TYPE              4642
# VEHICLE_USE               4642
# MANEUVER                  4642
# FIRST_CONTACT_POINT       5029
# dtype: int64

# %%
# assign the columnsn in df_cat_nominal with nulls to df_cat_nominal_null
df_cat_nominal_null = df_cat_nominal[['FIRST_CONTACT_POINT',
                                      'MANEUVER',
                                      'VEHICLE_USE',
                                      'VEHICLE_TYPE',
                                      'VEHICLE_DEFECT',
                                      'MODEL',
                                      'MAKE',
                                      'UNIT_TYPE',
                                      'MOST_SEVERE_INJURY']]

# assign the rest to df_cat_nominal_nonull
df_cat_nominal_nonull = df_cat_nominal.drop(columns=['FIRST_CONTACT_POINT',
                                                    'MANEUVER',
                                                    'VEHICLE_USE',
                                                    'VEHICLE_TYPE',
                                                    'VEHICLE_DEFECT',
                                                    'MODEL',
                                                    'MAKE',
                                                    'UNIT_TYPE',
                                                    'MOST_SEVERE_INJURY'])

# %%
# check that the split worked
df_cat_nominal_null.isna().sum()
# Out:
# FIRST_CONTACT_POINT    5029
# MANEUVER               4642
# VEHICLE_USE            4642
# VEHICLE_TYPE           4642
# VEHICLE_DEFECT         4642
# MODEL                  4669
# MAKE                   4643
# UNIT_TYPE               298
# MOST_SEVERE_INJURY      165
# dtype: int64

# %%
df_cat_nominal_nonull.isna().sum()
# Out:
# CRASH_DATE_x              0
# TRAFFIC_CONTROL_DEVICE    0
# DEVICE_CONDITION          0
# WEATHER_CONDITION         0
# LIGHTING_CONDITION        0
# FIRST_CRASH_TYPE          0
# TRAFFICWAY_TYPE           0
# ALIGNMENT                 0
# ROADWAY_SURFACE_COND      0
# ROAD_DEFECT               0
# CRASH_TYPE                0
# DAMAGE                    0
# DATE_POLICE_NOTIFIED      0
# CRASH_DATE_y              0
# dtype: int64

# %%
# how many columns are in df_cat_nominal_null?
print(len(df_cat_nominal_null.columns))

# how many columns are in df_cat_nominal_nonull?
print(len(df_cat_nominal_nonull.columns))
# Out:
# 9
# 14

# %%
print(9 + 15)
# Out:
# 24

# %%
# how many columsn were in df_cat_nominal?
print(len(df_cat_nominal.columns))
# Out:
# 23

# %%
for col in df_cat_nominal_null.columns:
    print(col)
    print(df_cat_nominal_null[col].value_counts())
    print('')
# Out:
# FIRST_CONTACT_POINT
# FRONT                 45193
# REAR                  29586
# SIDE-RIGHT            13504
# SIDE-LEFT             13420
# FRONT-LEFT            12721
# FRONT-LEFT-CORNER     12234
# FRONT-RIGHT           12106
# FRONT-RIGHT-CORNER    11673
# REAR-LEFT             10099
# UNKNOWN                9445
# OTHER                  6198
# REAR-RIGHT             5372
# REAR-LEFT-CORNER       4574
# TOTAL (ALL AREAS)      4037
# REAR-RIGHT-CORNER      3693
# SIDE-LEFT-REAR         2798
# SIDE-RIGHT-REAR        2209
# SIDE-LEFT-FRONT        1819
# SIDE-RIGHT-FRONT       1603
# ROOF                   1590
# NONE                   1535
# UNDER CARRIAGE          700
# TOP                     186
# Name: FIRST_CONTACT_POINT, dtype: int64
#
# MANEUVER
# STRAIGHT AHEAD                        104377
# PARKED                                 18734
# SLOW/STOP IN TRAFFIC                   18695
# TURNING LEFT                           14658
# BACKING                                 9080
# TURNING RIGHT                           7708
# PASSING/OVERTAKING                      6785
# CHANGING LANES                          4911
# UNKNOWN/NA                              4615
# OTHER                                   3136
# ENTERING TRAFFIC LANE FROM PARKING      2779
# MERGING                                 1571
# U-TURN                                  1551
# STARTING IN TRAFFIC                     1423
# SKIDDING/CONTROL LOSS                   1154
# AVOIDING VEHICLES/OBJECTS               1023
# ENTER FROM DRIVE/ALLEY                   966
# LEAVING TRAFFIC LANE TO PARK             906
# PARKED IN TRAFFIC LANE                   546
# SLOW/STOP - LEFT TURN                    504
# DRIVING WRONG WAY                        471
# SLOW/STOP - RIGHT TURN                   322
# NEGOTIATING A CURVE                      285
# SLOW/STOP - LOAD/UNLOAD                  244
# TURNING ON RED                           109
# DRIVERLESS                                74
# DIVERGING                                 32
# DISABLED                                  23
# Name: MANEUVER, dtype: int64
#
# VEHICLE_USE
# PERSONAL                        146668
# UNKNOWN/NA                       30363
# NOT IN USE                        7740
# OTHER                             6502
# TAXI/FOR HIRE                     2915
# COMMERCIAL - SINGLE UNIT          2797
# RIDESHARE SERVICE                 2019
# CTA                               1544
# POLICE                            1468
# CONSTRUCTION/MAINTENANCE          1111
# COMMERCIAL - MULTI-UNIT            946
# OTHER TRANSIT                      600
# SCHOOL BUS                         558
# TOW TRUCK                          453
# AMBULANCE                          212
# STATE OWNED                        172
# FIRE                               170
# DRIVER EDUCATION                   162
# MASS TRANSIT                       135
# LAWN CARE/LANDSCAPING               93
# AGRICULTURE                         26
# CAMPER/RV - SINGLE UNIT             11
# MILITARY                             8
# CAMPER/RV - TOWED/MULTI-UNIT         5
# HOUSE TRAILER                        4
# Name: VEHICLE_USE, dtype: int64
#
# VEHICLE_TYPE
# PASSENGER                                 136495
# SPORT UTILITY VEHICLE (SUV)                29863
# VAN/MINI-VAN                               10663
# UNKNOWN/NA                                 10262
# PICKUP                                      6739
# TRUCK - SINGLE UNIT                         4053
# BUS OVER 15 PASS.                           2365
# OTHER                                       2170
# TRACTOR W/ SEMI-TRAILER                     2007
# MOTORCYCLE (OVER 150CC)                      553
# BUS UP TO 15 PASS.                           512
# TRACTOR W/O SEMI-TRAILER                     290
# SINGLE UNIT TRUCK WITH TRAILER               271
# OTHER VEHICLE WITH TRAILER                   244
# MOPED OR MOTORIZED BICYCLE                    66
# MOTOR DRIVEN CYCLE                            44
# AUTOCYCLE                                     38
# ALL-TERRAIN VEHICLE (ATV)                     19
# FARM EQUIPMENT                                14
# 3-WHEELED MOTORCYCLE (2 REAR WHEELS)           8
# RECREATIONAL OFF-HIGHWAY VEHICLE (ROV)         4
# SNOWMOBILE                                     2
# Name: VEHICLE_TYPE, dtype: int64
#
# VEHICLE_DEFECT
# NONE                125859
# UNKNOWN              78427
# BRAKES                 944
# OTHER                  924
# TIRES                  158
# STEERING               136
# WHEELS                  82
# SUSPENSION              52
# ENGINE/MOTOR            38
# FUEL SYSTEM             18
# LIGHTS                  17
# WINDOWS                 10
# CARGO                    5
# SIGNALS                  4
# EXHAUST                  4
# TRAILER COUPLING         2
# RESTRAINT SYSTEM         2
# Name: VEHICLE_DEFECT, dtype: int64
#
# MODEL
# UNKNOWN                         22321
# OTHER (EXPLAIN IN NARRATIVE)    13144
# CAMRY                            6921
# COROLLA                          4415
# CIVIC                            4233
#                                 ...
# VehiCross                           1
# TRIUMPH                             1
# 360 (various styles)                1
# AMIGO                               1
# ALL TERRAIN - WHEELS ONLY           1
# Name: MODEL, Length: 1709, dtype: int64
#
# MAKE
# CHEVROLET                                25229
# FORD                                     21446
# NISSAN                                   17383
# HONDA                                    15817
# TOYOTA MOTOR COMPANY, LTD.               13782
#                                          ...
# BEE BOB TRAILER                              1
# UTILITY TRAILER MANUFACTURING COMPANY        1
# ECO-BIKE ELEC MOTORCYCLE                     1
# CROSS TRUCK EQUIPMENT COMPANY                1
# ALL TERRAIN - WHEELS ONLY                    1
# Name: MAKE, Length: 572, dtype: int64
#
# UNIT_TYPE
# DRIVER                 187036
# PARKED                  18382
# PEDESTRIAN               2497
# BICYCLE                  1584
# DRIVERLESS               1308
# NON-MOTOR VEHICLE         155
# NON-CONTACT VEHICLE        42
# DISABLED VEHICLE           21
# EQUESTRIAN                  1
# Name: UNIT_TYPE, dtype: int64
#
# MOST_SEVERE_INJURY
# NO INDICATION OF INJURY     174725
# NONINCAPACITATING INJURY     20660
# REPORTED, NOT EVIDENT        10919
# INCAPACITATING INJURY         4593
# FATAL                          262
# Name: MOST_SEVERE_INJURY, dtype: int64

# %%
'''Fill the following columns with 'UNKNOWN' in df_cat_nominal_null:
MOST_SEVERE_INJURY
UNIT_TYPE
MAKE
MODEL
VEHICLE_DEFECT
FIRST_CONTACT_POINT
'''

df_cat_nominal_null['MOST_SEVERE_INJURY'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['UNIT_TYPE'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['MAKE'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['MODEL'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['VEHICLE_DEFECT'].fillna('UNKNOWN', inplace=True)
df_cat_nominal_null['FIRST_CONTACT_POINT'].fillna('UNKNOWN', inplace=True)
# Out:
# C:\Users\gerba\AppData\Local\Temp\ipykernel_15996\848517612.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['MOST_SEVERE_INJURY'].fillna('UNKNOWN', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_15996\848517612.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['UNIT_TYPE'].fillna('UNKNOWN', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_15996\848517612.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['MAKE'].fillna('UNKNOWN', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_15996\848517612.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['MODEL'].fillna('UNKNOWN', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_15996\848517612.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['VEHICLE_DEFECT'].fillna('UNKNOWN', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_15996\848517612.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['FIRST_CONTACT_POINT'].fillna('UNKNOWN', inplace=True)

# %%
'''Fill the following columns with 'UNKNOWN/NA' in df_cat_nominal_null:
VEHICLE_TYPE
VEHICLE_USE
MANUEVER
'''

df_cat_nominal_null['VEHICLE_TYPE'].fillna('UNKNOWN/NA', inplace=True)
df_cat_nominal_null['VEHICLE_USE'].fillna('UNKNOWN/NA', inplace=True)
df_cat_nominal_null['MANEUVER'].fillna('UNKNOWN/NA', inplace=True)
# Out:
# C:\Users\gerba\AppData\Local\Temp\ipykernel_15996\4055445953.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['VEHICLE_TYPE'].fillna('UNKNOWN/NA', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_15996\4055445953.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['VEHICLE_USE'].fillna('UNKNOWN/NA', inplace=True)
# C:\Users\gerba\AppData\Local\Temp\ipykernel_15996\4055445953.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat_nominal_null['MANEUVER'].fillna('UNKNOWN/NA', inplace=True)

# %% [markdown]
# ## Combining nominal and ordinal again

# %% [markdown]
# modifying this because the ordinal columsn don't seem to contribute anything

# %%
# combine df_cat_nominal_null and df_cat_nominal_nonull into df_cat_nominal_filled
df_cat_nominal_filled = pd.concat([df_cat_nominal_null, df_cat_nominal_nonull], axis=1)

# combine df_cat_nominal_filled and df_cat_ordinal_filled into df_cat_filled
df_cat_filled = pd.concat([df_cat_nominal_filled, df_cat_ordinal_filled], axis=1)

# %% [markdown]
# ## Combining everything again

# %%
# Combine df_cat_filled and df_num into df_clean

df_clean = pd.concat([df_num, df_cat_filled], axis=1)

# %%
df_clean.head().T
# Out:
#                                                      0  \
# POSTED_SPEED_LIMIT                                  25
# STREET_NO                                           33
# NUM_UNITS                                            2
# INJURIES_TOTAL                                     0.0
# INJURIES_FATAL                                     0.0
# INJURIES_INCAPACITATING                            0.0
# INJURIES_NON_INCAPACITATING                        0.0
# INJURIES_REPORTED_NOT_EVIDENT                      0.0
# INJURIES_NO_INDICATION                             1.0
# INJURIES_UNKNOWN                                   0.0
# CRASH_HOUR                                          17
# CRASH_DAY_OF_WEEK                                    5
# CRASH_MONTH                                          3
# LATITUDE                                     41.882798
# LONGITUDE                                   -87.632242
# CRASH_UNIT_ID                                   598511
# UNIT_NO                                              2
# NUM_PASSENGERS                                     0.0
# VEHICLE_YEAR                                    2016.0
# OCCUPANT_CNT                                       0.0
# FIRST_CONTACT_POINT                               REAR
# MANEUVER                                        PARKED
# VEHICLE_USE                                   PERSONAL
# VEHICLE_TYPE                                 PASSENGER
# VEHICLE_DEFECT                                    NONE
# MODEL                                              300
# MAKE                                          CHRYSLER
# UNIT_TYPE                                       PARKED
# MOST_SEVERE_INJURY             NO INDICATION OF INJURY
# CRASH_DATE_x                    03/07/2019 05:10:00 PM
# TRAFFIC_CONTROL_DEVICE                     NO CONTROLS
# DEVICE_CONDITION                           NO CONTROLS
# WEATHER_CONDITION                                CLEAR
# LIGHTING_CONDITION                            DAYLIGHT
# FIRST_CRASH_TYPE                  PARKED MOTOR VEHICLE
# TRAFFICWAY_TYPE                                ONE-WAY
# ALIGNMENT                           STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                               DRY
# ROAD_DEFECT                                 NO DEFECTS
# CRASH_TYPE                      NO INJURY / DRIVE AWAY
# DAMAGE                                   $501 - $1,500
# DATE_POLICE_NOTIFIED            03/07/2019 05:35:00 PM
# CRASH_DATE_y                    03/07/2019 05:10:00 PM
# INTERSECTION_RELATED_I                               N
# NOT_RIGHT_OF_WAY_I                                   N
# HIT_AND_RUN_I                                        N
# EXCEED_SPEED_LIMIT_I                                 N
#
#                                                      1  \
# POSTED_SPEED_LIMIT                                  20
# STREET_NO                                         4300
# NUM_UNITS                                            2
# INJURIES_TOTAL                                     0.0
# INJURIES_FATAL                                     0.0
# INJURIES_INCAPACITATING                            0.0
# INJURIES_NON_INCAPACITATING                        0.0
# INJURIES_REPORTED_NOT_EVIDENT                      0.0
# INJURIES_NO_INDICATION                             2.0
# INJURIES_UNKNOWN                                   0.0
# CRASH_HOUR                                          11
# CRASH_DAY_OF_WEEK                                    6
# CRASH_MONTH                                         11
# LATITUDE                                     41.814835
# LONGITUDE                                   -87.742283
# CRASH_UNIT_ID                                   532437
# UNIT_NO                                              2
# NUM_PASSENGERS                                     0.0
# VEHICLE_YEAR                                    1999.0
# OCCUPANT_CNT                                       1.0
# FIRST_CONTACT_POINT                              FRONT
# MANEUVER                                STRAIGHT AHEAD
# VEHICLE_USE                                   PERSONAL
# VEHICLE_TYPE                                    PICKUP
# VEHICLE_DEFECT                                    NONE
# MODEL                                        SILVERADO
# MAKE                                         CHEVROLET
# UNIT_TYPE                                       DRIVER
# MOST_SEVERE_INJURY             NO INDICATION OF INJURY
# CRASH_DATE_x                    11/30/2018 11:30:00 AM
# TRAFFIC_CONTROL_DEVICE               STOP SIGN/FLASHER
# DEVICE_CONDITION                  FUNCTIONING PROPERLY
# WEATHER_CONDITION                                CLEAR
# LIGHTING_CONDITION                            DAYLIGHT
# FIRST_CRASH_TYPE                                 ANGLE
# TRAFFICWAY_TYPE                            NOT DIVIDED
# ALIGNMENT                           STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                               WET
# ROAD_DEFECT                                 NO DEFECTS
# CRASH_TYPE                      NO INJURY / DRIVE AWAY
# DAMAGE                                     OVER $1,500
# DATE_POLICE_NOTIFIED            11/30/2018 11:50:00 AM
# CRASH_DATE_y                    11/30/2018 11:30:00 AM
# INTERSECTION_RELATED_I                               N
# NOT_RIGHT_OF_WAY_I                                   N
# HIT_AND_RUN_I                                        N
# EXCEED_SPEED_LIMIT_I                                 N
#
#                                                               2  \
# POSTED_SPEED_LIMIT                                           30
# STREET_NO                                                  2198
# NUM_UNITS                                                     1
# INJURIES_TOTAL                                              0.0
# INJURIES_FATAL                                              0.0
# INJURIES_INCAPACITATING                                     0.0
# INJURIES_NON_INCAPACITATING                                 0.0
# INJURIES_REPORTED_NOT_EVIDENT                               0.0
# INJURIES_NO_INDICATION                                      1.0
# INJURIES_UNKNOWN                                            0.0
# CRASH_HOUR                                                   19
# CRASH_DAY_OF_WEEK                                             4
# CRASH_MONTH                                                  10
# LATITUDE                                              41.852375
# LONGITUDE                                            -87.666171
# CRASH_UNIT_ID                                            756632
# UNIT_NO                                                       1
# NUM_PASSENGERS                                              0.0
# VEHICLE_YEAR                                             2000.0
# OCCUPANT_CNT                                                1.0
# FIRST_CONTACT_POINT                                       FRONT
# MANEUVER                                         STRAIGHT AHEAD
# VEHICLE_USE                                            PERSONAL
# VEHICLE_TYPE                                          PASSENGER
# VEHICLE_DEFECT                                           BRAKES
# MODEL                                                  Explorer
# MAKE                                                       FORD
# UNIT_TYPE                                                DRIVER
# MOST_SEVERE_INJURY                      NO INDICATION OF INJURY
# CRASH_DATE_x                             10/09/2019 07:00:00 PM
# TRAFFIC_CONTROL_DEVICE                              NO CONTROLS
# DEVICE_CONDITION                                    NO CONTROLS
# WEATHER_CONDITION                                         CLEAR
# LIGHTING_CONDITION                                     DAYLIGHT
# FIRST_CRASH_TYPE                                   FIXED OBJECT
# TRAFFICWAY_TYPE                 DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                    STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                        DRY
# ROAD_DEFECT                                          NO DEFECTS
# CRASH_TYPE                     INJURY AND / OR TOW DUE TO CRASH
# DAMAGE                                              OVER $1,500
# DATE_POLICE_NOTIFIED                     10/09/2019 07:00:00 PM
# CRASH_DATE_y                             10/09/2019 07:00:00 PM
# INTERSECTION_RELATED_I                                        N
# NOT_RIGHT_OF_WAY_I                                            N
# HIT_AND_RUN_I                                                 N
# EXCEED_SPEED_LIMIT_I                                          N
#
#                                                              3  \
# POSTED_SPEED_LIMIT                                          30
# STREET_NO                                                 2800
# NUM_UNITS                                                    2
# INJURIES_TOTAL                                             0.0
# INJURIES_FATAL                                             0.0
# INJURIES_INCAPACITATING                                    0.0
# INJURIES_NON_INCAPACITATING                                0.0
# INJURIES_REPORTED_NOT_EVIDENT                              0.0
# INJURIES_NO_INDICATION                                     2.0
# INJURIES_UNKNOWN                                           0.0
# CRASH_HOUR                                                  10
# CRASH_DAY_OF_WEEK                                            5
# CRASH_MONTH                                                  7
# LATITUDE                                              41.86662
# LONGITUDE                                           -87.695971
# CRASH_UNIT_ID                                           179946
# UNIT_NO                                                      2
# NUM_PASSENGERS                                             0.0
# VEHICLE_YEAR                                               0.0
# OCCUPANT_CNT                                               1.0
# FIRST_CONTACT_POINT                                       REAR
# MANEUVER                                               BACKING
# VEHICLE_USE                                         UNKNOWN/NA
# VEHICLE_TYPE                                        UNKNOWN/NA
# VEHICLE_DEFECT                                         UNKNOWN
# MODEL                                                  UNKNOWN
# MAKE                                                   UNKNOWN
# UNIT_TYPE                                               DRIVER
# MOST_SEVERE_INJURY                     NO INDICATION OF INJURY
# CRASH_DATE_x                            07/06/2017 10:00:00 AM
# TRAFFIC_CONTROL_DEVICE                          TRAFFIC SIGNAL
# DEVICE_CONDITION                          FUNCTIONING PROPERLY
# WEATHER_CONDITION                                        CLEAR
# LIGHTING_CONDITION                                    DAYLIGHT
# FIRST_CRASH_TYPE                                      REAR END
# TRAFFICWAY_TYPE                DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                   STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                       DRY
# ROAD_DEFECT                                         NO DEFECTS
# CRASH_TYPE                              NO INJURY / DRIVE AWAY
# DAMAGE                                             OVER $1,500
# DATE_POLICE_NOTIFIED                    07/06/2017 02:30:00 PM
# CRASH_DATE_y                            07/06/2017 10:00:00 AM
# INTERSECTION_RELATED_I                                       Y
# NOT_RIGHT_OF_WAY_I                                           N
# HIT_AND_RUN_I                                                N
# EXCEED_SPEED_LIMIT_I                                         N
#
#                                                              4
# POSTED_SPEED_LIMIT                                          30
# STREET_NO                                                 7739
# NUM_UNITS                                                    2
# INJURIES_TOTAL                                             0.0
# INJURIES_FATAL                                             0.0
# INJURIES_INCAPACITATING                                    0.0
# INJURIES_NON_INCAPACITATING                                0.0
# INJURIES_REPORTED_NOT_EVIDENT                              0.0
# INJURIES_NO_INDICATION                                     2.0
# INJURIES_UNKNOWN                                           0.0
# CRASH_HOUR                                                  15
# CRASH_DAY_OF_WEEK                                            6
# CRASH_MONTH                                                 11
# LATITUDE                                             42.022164
# LONGITUDE                                           -87.666715
# CRASH_UNIT_ID                                            98704
# UNIT_NO                                                      1
# NUM_PASSENGERS                                             0.0
# VEHICLE_YEAR                                            2016.0
# OCCUPANT_CNT                                               1.0
# FIRST_CONTACT_POINT                                 FRONT-LEFT
# MANEUVER                                                 OTHER
# VEHICLE_USE                                           PERSONAL
# VEHICLE_TYPE                                         PASSENGER
# VEHICLE_DEFECT                                            NONE
# MODEL                                                  MUSTANG
# MAKE                                                      FORD
# UNIT_TYPE                                               DRIVER
# MOST_SEVERE_INJURY                     NO INDICATION OF INJURY
# CRASH_DATE_x                            11/18/2016 03:17:00 PM
# TRAFFIC_CONTROL_DEVICE                             NO CONTROLS
# DEVICE_CONDITION                                   NO CONTROLS
# WEATHER_CONDITION                                        CLEAR
# LIGHTING_CONDITION                                    DAYLIGHT
# FIRST_CRASH_TYPE                      SIDESWIPE SAME DIRECTION
# TRAFFICWAY_TYPE                DIVIDED - W/MEDIAN (NOT RAISED)
# ALIGNMENT                                   STRAIGHT AND LEVEL
# ROADWAY_SURFACE_COND                                       WET
# ROAD_DEFECT                                         NO DEFECTS
# CRASH_TYPE                              NO INJURY / DRIVE AWAY
# DAMAGE                                             OVER $1,500
# DATE_POLICE_NOTIFIED                    11/18/2016 04:05:00 PM
# CRASH_DATE_y                            11/18/2016 03:17:00 PM
# INTERSECTION_RELATED_I                                       N
# NOT_RIGHT_OF_WAY_I                                           N
# HIT_AND_RUN_I                                                N
# EXCEED_SPEED_LIMIT_I                                         N

# %% [markdown]
# # Exporting the cleaned data

# %%
# export df_clean to csv
df_clean.to_csv('data/df_clean.csv')

# %%
df_clean.shape
# Out:
# (211324, 47)

# %%
df_clean.isna().sum()
# Out:
# POSTED_SPEED_LIMIT               0
# STREET_NO                        0
# NUM_UNITS                        0
# INJURIES_TOTAL                   0
# INJURIES_FATAL                   0
# INJURIES_INCAPACITATING          0
# INJURIES_NON_INCAPACITATING      0
# INJURIES_REPORTED_NOT_EVIDENT    0
# INJURIES_NO_INDICATION           0
# INJURIES_UNKNOWN                 0
# CRASH_HOUR                       0
# CRASH_DAY_OF_WEEK                0
# CRASH_MONTH                      0
# LATITUDE                         0
# LONGITUDE                        0
# CRASH_UNIT_ID                    0
# UNIT_NO                          0
# NUM_PASSENGERS                   0
# VEHICLE_YEAR                     0
# OCCUPANT_CNT                     0
# FIRST_CONTACT_POINT              0
# MANEUVER                         0
# VEHICLE_USE                      0
# VEHICLE_TYPE                     0
# VEHICLE_DEFECT                   0
# MODEL                            0
# MAKE                             0
# UNIT_TYPE                        0
# MOST_SEVERE_INJURY               0
# CRASH_DATE_x                     0
# TRAFFIC_CONTROL_DEVICE           0
# DEVICE_CONDITION                 0
# WEATHER_CONDITION                0
# LIGHTING_CONDITION               0
# FIRST_CRASH_TYPE                 0
# TRAFFICWAY_TYPE                  0
# ALIGNMENT                        0
# ROADWAY_SURFACE_COND             0
# ROAD_DEFECT                      0
# CRASH_TYPE                       0
# DAMAGE                           0
# DATE_POLICE_NOTIFIED             0
# CRASH_DATE_y                     0
# INTERSECTION_RELATED_I           0
# NOT_RIGHT_OF_WAY_I               0
# HIT_AND_RUN_I                    0
# EXCEED_SPEED_LIMIT_I             0
# dtype: int64
