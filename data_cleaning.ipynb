# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Data Sources
#
# [crashes](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Crashes/85ca-t3if)
#
# [vehicles](https://data.cityofchicago.org/Transportation/Traffic-Crashes-Vehicles/68nd-jvt3)
#
# [people](https://data.cityofchicago.org/Transportation/Traffic-Crashes-People/u6pd-qa9d)

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Importing The Data

# %%
d_crashes = pd.read_csv('data/Traffic_Crashes_-_Crashes.csv')
d_vehicles = pd.read_csv('data/Traffic_Crashes_-_Vehicles.csv')
# Out:
# c:\Anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (19,21,40,41,42,44,48,49,50,53,55,58,59,61,71) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
d_crashes.shape
# Out:
# (732329, 49)

# %%
d_vehicles.shape
# Out:
# (1491796, 72)

# %% [markdown]
# ### Merging The Frames

# %%
# Merge d_crashes and d_vehicles on CRASH_RECORD_ID
df = pd.merge(d_crashes, d_vehicles, on='CRASH_RECORD_ID')

# %%
df.shape
# Out:
# (1491794, 60)

# %%
'''
drom from df 
CMV_ID
USDOT_NO
CCMC_NO
ILCC_NO
COMMERCIAL_SRC
GVWR
CARRIER_NAME
CARRIER_STATE
CARRIER_CITY
HAZMAT_PLACARDS_I
HAZMAT_NAME
UN_NO
HAZMAT_PRESENT_I
HAZMAT_REPORT_I
HAZMAT_REPORT_NO
MCS_REPORT_I
MCS_REPORT_NO
HAZMAT_VIO_CAUSE_CRASH_I
MCS_VIO_CAUSE_CRASH_I
IDOT_PERMIT_NO
WIDE_LOAD_I
TRAILER1_WIDTH
TRAILER2_WIDTH
TRAILER1_LENGTH
TRAILER2_LENGTH
TOTAL_VEHICLE_LENGTH
AXLE_CNT
VEHICLE_CONFIG
CARGO_BODY_TYPE
LOAD_TYPE
HAZMAT_OUT_OF_SERVICE_I
MCS_OUT_OF_SERVICE_I
HAZMAT_CLASS
PHOTOS_TAKEN_I
STATEMENTS_TAKEN_I
DOORING_I
WORK_ZONE_I
WORK_ZONE_TYPE
WORKERS_PRESENT_I
TOWED_I
FIRE_I
TOWED_BY
TOWED_TO
AREA_00_I
AREA_01_I
AREA_02_I
AREA_03_I
AREA_04_I
AREA_05_I
AREA_06_I
AREA_07_I
AREA_08_I
AREA_09_I
AREA_10_I
AREA_11_I
AREA_12_I
AREA_99_I
'''

df.drop(columns=['CMV_ID',
                 'USDOT_NO',
                 'CCMC_NO',
                 'ILCC_NO',
                 'COMMERCIAL_SRC',
                 'GVWR',
                 'CARRIER_NAME',
                 'CARRIER_STATE',
                 'CARRIER_CITY',
                 'HAZMAT_PLACARDS_I',
                 'HAZMAT_NAME',
                 'UN_NO',
                 'HAZMAT_PRESENT_I',
                 'HAZMAT_REPORT_I',
                 'HAZMAT_REPORT_NO',
                 'MCS_REPORT_I',
                 'MCS_REPORT_NO',
                 'HAZMAT_VIO_CAUSE_CRASH_I',
                 'MCS_VIO_CAUSE_CRASH_I',
                 'IDOT_PERMIT_NO',
                 'WIDE_LOAD_I',
                 'TRAILER1_WIDTH',
                 'TRAILER2_WIDTH',
                 'TRAILER1_LENGTH',
                 'TRAILER2_LENGTH',
                 'TOTAL_VEHICLE_LENGTH',
                 'AXLE_CNT',
                 'VEHICLE_CONFIG',
                 'CARGO_BODY_TYPE',
                 'LOAD_TYPE',
                 'HAZMAT_OUT_OF_SERVICE_I',
                 'MCS_OUT_OF_SERVICE_I',
                 'HAZMAT_CLASS',
                 
                 'PHOTOS_TAKEN_I',
                 'STATEMENTS_TAKEN_I',
                 'DOORING_I',
                 'WORK_ZONE_I',
                 'WORK_ZONE_TYPE',
                 'WORKERS_PRESENT_I',
                 
                 'TOWED_I',
                 'FIRE_I',
                 
                 'TOWED_BY',
                 'TOWED_TO',
                 'AREA_00_I',
                 'AREA_01_I',
                 'AREA_02_I',
                 'AREA_03_I',
                 'AREA_04_I',
                 'AREA_05_I',
                 'AREA_06_I',
                 'AREA_07_I',
                 'AREA_08_I',
                 'AREA_09_I',
                 'AREA_10_I',
                 'AREA_11_I',
                 'AREA_12_I',
                 'AREA_99_I',
                 
                 'BEAT_OF_OCCURRENCE',
                 'VEHICLE_ID',
                 'LANE_CNT',
                 ], inplace=True)

# %%
df.shape
# Out:
# (1491794, 60)

# %% [markdown]
# Okay so all the useless columns have been chopped.
#
# The ones that are left over need to be cleaned up.
#
# ugh

# %%
# output df.head() to csv
df.head().T.to_csv('data/df_head.csv')

# %%
# split df into categorical and numerical dataframes
df_cat = df.select_dtypes(include='object')
df_num = df.select_dtypes(exclude='object')

# %% [markdown]
# # Looking into categorical

# %%
df_cat.isna().sum()
# Out:
# CRASH_RECORD_ID                  0
# RD_NO_x                       8978
# CRASH_DATE_EST_I           1379456
# CRASH_DATE_x                     0
# TRAFFIC_CONTROL_DEVICE           0
# DEVICE_CONDITION                 0
# WEATHER_CONDITION                0
# LIGHTING_CONDITION               0
# FIRST_CRASH_TYPE                 0
# TRAFFICWAY_TYPE                  0
# ALIGNMENT                        0
# ROADWAY_SURFACE_COND             0
# ROAD_DEFECT                      0
# REPORT_TYPE                  47778
# CRASH_TYPE                       0
# INTERSECTION_RELATED_I     1144582
# NOT_RIGHT_OF_WAY_I         1430860
# HIT_AND_RUN_I              1017966
# DAMAGE                           0
# DATE_POLICE_NOTIFIED             0
# PRIM_CONTRIBUTORY_CAUSE          0
# SEC_CONTRIBUTORY_CAUSE           0
# STREET_DIRECTION                 8
# STREET_NAME                      2
# MOST_SEVERE_INJURY            2663
# LOCATION                      9373
# RD_NO_y                       9691
# CRASH_DATE_y                     0
# UNIT_TYPE                     2015
# CMRC_VEH_I                 1463930
# MAKE                         33612
# MODEL                        33756
# LIC_PLATE_STATE             166547
# VEHICLE_DEFECT               33607
# VEHICLE_TYPE                 33607
# VEHICLE_USE                  33607
# TRAVEL_DIRECTION             33607
# MANEUVER                     33607
# EXCEED_SPEED_LIMIT_I       1489397
# FIRST_CONTACT_POINT          36696
# dtype: int64

# %%
# print out the value_counts for every column in df_cat
for col in df_cat.columns:
    print(col)
    print(df_cat[col].value_counts())
    print('')
# Out:
# CRASH_RECORD_ID
# 645cdd6fd3ed2f043eefdc48230464a8ad66127691a2a2781240f5c7570ff5a87aaa6cf887bc1f76e93cfcb770359fb8136d59a40d8c18b62133fec286670279    18
# e4f07da854d2b7be0c4c0903296e6f1a1f0109ddebca9d5b5dc399ffc698f2118f0f658ad5b1e3559714e0a3e2550720e3cb88e9753ce9a93ca3a20fa553fed7    18
# 313777c940c68d531b001269eab36bde9d156e2423cc256d7df03cb2405b50c7e079c26ffc29cc338275d71ed333b069fb95056fa81364c64e71cc27d9f1bc49    18
# fb8d94334f5987710b7aa9cb4b0302f8e4c8f5f6e6d9f50ff0502a143737b3bfe95c37d970bcab190390797ad5c8fb6a9b6909f73186488c9b91267a4b844c65    16
# d4c3f39de39d4f08abf19fb11df98628adc0f6024c7d10d266df234e93f6241fd3f993e1cf002806cced9c88c0cf839fd7cc91ec161e544c4273ed2c7186fd97    16
#                                                                                                                                     ..
# 70b3b935ff4c138023dca2e4af16910e5368fc2766fe4e614f41f8e9fcdea99f9364dfa3072486cf0d1467c66cc3e00950adadca0b99ae82dcbe6cc2a350c1af     1
# 39a3717359a2eb8eaf98764f790ca9a4acd6ab25ebc49bfb9acbc1e12ed2625d4be1f11d37f6c7d41b0654e1ce66f756f78545a49c49d0e29d27c5f54914ccc3     1
# 4cb22b798e663fda7ce9ba979dce82b14cc7216b072905b5fe0432100a895c341bfb1fa38b9511831d08527f4e2a2dd026a1dc415341debd54a657640ed0cf44     1
# 8c70eea357711c31bc6407c72b7a7afe91ff6b997c4741410e03b1eae5490ae99a64f1cf9c66a7b692a629eff69aa072a4e032fe735e3ac47d2540cea1883234     1
# 2f5802e9454fda7daad78d68718086d3893143d8110d51666a05870f957498595d2dce7eef87047678b16d08e4d470b840d3cdd73e3b679d94e4771299e4e6d7     1
# Name: CRASH_RECORD_ID, Length: 732020, dtype: int64
#
# RD_NO_x
# JF346755    18
# JG108188    18
# JB311558    18
# JB330122    16
# JC496496    16
#             ..
# JB184475     1
# JD153480     1
# JE289061     1
# JD185061     1
# JE340016     1
# Name: RD_NO_x, Length: 727652, dtype: int64
#
# CRASH_DATE_EST_I
# Y    97735
# N    14603
# Name: CRASH_DATE_EST_I, dtype: int64
#
# CRASH_DATE_x
# 12/29/2020 05:00:00 PM    60
# 11/10/2017 10:30:00 AM    58
# 02/17/2022 03:30:00 PM    42
# 11/10/2017 10:00:00 AM    42
# 01/12/2019 02:30:00 PM    41
#                           ..
# 07/09/2022 10:15:00 AM     1
# 12/24/2019 09:35:00 AM     1
# 11/30/2016 04:15:00 AM     1
# 04/24/2022 01:07:00 AM     1
# 11/30/2020 01:38:00 PM     1
# Name: CRASH_DATE_x, Length: 479262, dtype: int64
#
# TRAFFIC_CONTROL_DEVICE
# NO CONTROLS                 847582
# TRAFFIC SIGNAL              417886
# STOP SIGN/FLASHER           149768
# UNKNOWN                      55012
# OTHER                         9622
# LANE USE MARKING              2483
# YIELD                         2148
# OTHER REG. SIGN               1508
# OTHER WARNING SIGN            1090
# RAILROAD CROSSING GATE         942
# PEDESTRIAN CROSSING SIGN       887
# SCHOOL ZONE                    575
# DELINEATORS                    561
# FLASHING CONTROL SIGNAL        537
# POLICE/FLAGMAN                 509
# OTHER RAILROAD CROSSING        327
# RR CROSSING SIGN               226
# NO PASSING                      88
# BICYCLE CROSSING SIGN           43
# Name: TRAFFIC_CONTROL_DEVICE, dtype: int64
#
# DEVICE_CONDITION
# NO CONTROLS                 857910
# FUNCTIONING PROPERLY        518344
# UNKNOWN                      91710
# OTHER                        11373
# FUNCTIONING IMPROPERLY        7228
# NOT FUNCTIONING               4537
# WORN REFLECTIVE MATERIAL       528
# MISSING                        164
# Name: DEVICE_CONDITION, dtype: int64
#
# WEATHER_CONDITION
# CLEAR                       1177605
# RAIN                         128516
# UNKNOWN                       75813
# SNOW                          53172
# CLOUDY/OVERCAST               44169
# OTHER                          4661
# FREEZING RAIN/DRIZZLE          2792
# FOG/SMOKE/HAZE                 2124
# SLEET/HAIL                     1868
# BLOWING SNOW                    789
# SEVERE CROSS WIND GATE          275
# BLOWING SAND, SOIL, DIRT         10
# Name: WEATHER_CONDITION, dtype: int64
#
# LIGHTING_CONDITION
# DAYLIGHT                  958535
# DARKNESS, LIGHTED ROAD    331324
# DARKNESS                   70412
# UNKNOWN                    63248
# DUSK                       43406
# DAWN                       24869
# Name: LIGHTING_CONDITION, dtype: int64
#
# FIRST_CRASH_TYPE
# PARKED MOTOR VEHICLE            367343
# REAR END                        351721
# SIDESWIPE SAME DIRECTION        228557
# TURNING                         213310
# ANGLE                           164849
# FIXED OBJECT                     37929
# PEDESTRIAN                       34726
# SIDESWIPE OPPOSITE DIRECTION     21929
# PEDALCYCLIST                     21676
# HEAD ON                          13471
# REAR TO FRONT                    13274
# OTHER OBJECT                      8590
# REAR TO SIDE                      7821
# REAR TO REAR                      2751
# OTHER NONCOLLISION                2655
# ANIMAL                             603
# OVERTURNED                         521
# TRAIN                               68
# Name: FIRST_CRASH_TYPE, dtype: int64
#
# TRAFFICWAY_TYPE
# NOT DIVIDED                        659303
# DIVIDED - W/MEDIAN (NOT RAISED)    245718
# ONE-WAY                            197181
# PARKING LOT                         98078
# FOUR WAY                            84218
# DIVIDED - W/MEDIAN BARRIER          83410
# OTHER                               39433
# ALLEY                               20250
# T-INTERSECTION                      17110
# UNKNOWN                             16429
# CENTER TURN LANE                    11222
# DRIVEWAY                             4266
# RAMP                                 4219
# UNKNOWN INTERSECTION TYPE            4130
# FIVE POINT, OR MORE                  1891
# Y-INTERSECTION                       1840
# TRAFFIC ROUTE                        1529
# NOT REPORTED                          907
# ROUNDABOUT                            386
# L-INTERSECTION                        274
# Name: TRAFFICWAY_TYPE, dtype: int64
#
# ALIGNMENT
# STRAIGHT AND LEVEL       1457055
# STRAIGHT ON GRADE          18659
# CURVE, LEVEL                9564
# STRAIGHT ON HILLCREST       3971
# CURVE ON GRADE              1947
# CURVE ON HILLCREST           598
# Name: ALIGNMENT, dtype: int64
#
# ROADWAY_SURFACE_COND
# DRY                1109885
# WET                 197886
# UNKNOWN             116371
# SNOW OR SLUSH        53295
# ICE                  10339
# OTHER                 3530
# SAND, MUD, DIRT        488
# Name: ROADWAY_SURFACE_COND, dtype: int64
#
# ROAD_DEFECT
# NO DEFECTS           1218633
# UNKNOWN               247731
# RUT, HOLES              8234
# OTHER                   7449
# WORN SURFACE            5926
# SHOULDER DEFECT         2803
# DEBRIS ON ROADWAY       1018
# Name: ROAD_DEFECT, dtype: int64
#
# REPORT_TYPE
# NOT ON SCENE (DESK REPORT)    807685
# ON SCENE                      635839
# AMENDED                          492
# Name: REPORT_TYPE, dtype: int64
#
# CRASH_TYPE
# NO INJURY / DRIVE AWAY              1081233
# INJURY AND / OR TOW DUE TO CRASH     410561
# Name: CRASH_TYPE, dtype: int64
#
# INTERSECTION_RELATED_I
# Y    330950
# N     16262
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# NOT_RIGHT_OF_WAY_I
# Y    55273
# N     5661
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# HIT_AND_RUN_I
# Y    453705
# N     20123
# Name: HIT_AND_RUN_I, dtype: int64
#
# DAMAGE
# OVER $1,500      923973
# $501 - $1,500    399269
# $500 OR LESS     168552
# Name: DAMAGE, dtype: int64
#
# DATE_POLICE_NOTIFIED
# 02/26/2020 08:30:00 AM    25
# 07/01/2021 07:00:00 PM    25
# 10/12/2020 04:00:00 PM    24
# 02/24/2023 11:00:00 PM    24
# 10/25/2021 09:00:00 AM    24
#                           ..
# 06/17/2018 09:03:00 PM     1
# 01/08/2022 06:54:00 PM     1
# 02/13/2023 09:31:00 PM     1
# 08/30/2017 01:42:00 PM     1
# 01/13/2019 11:45:00 PM     1
# Name: DATE_POLICE_NOTIFIED, Length: 555956, dtype: int64
#
# PRIM_CONTRIBUTORY_CAUSE
# UNABLE TO DETERMINE                                                                 571184
# FAILING TO YIELD RIGHT-OF-WAY                                                       164915
# FOLLOWING TOO CLOSELY                                                               151936
# NOT APPLICABLE                                                                       75316
# IMPROPER OVERTAKING/PASSING                                                          73063
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               66695
# IMPROPER BACKING                                                                     58478
# IMPROPER LANE USAGE                                                                  54856
# IMPROPER TURNING/NO SIGNAL                                                           49008
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  47434
# DISREGARDING TRAFFIC SIGNALS                                                         30303
# WEATHER                                                                              21949
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     20053
# DISREGARDING STOP SIGN                                                               16971
# DISTRACTION - FROM INSIDE VEHICLE                                                    10788
# PHYSICAL CONDITION OF DRIVER                                                          9547
# EQUIPMENT - VEHICLE CONDITION                                                         9473
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    8439
# DRIVING ON WRONG SIDE/WRONG WAY                                                       8435
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                  8154
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    6156
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      4166
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   3398
# DISREGARDING OTHER TRAFFIC SIGNS                                                      3083
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                     2547
# ROAD CONSTRUCTION/MAINTENANCE                                                         2414
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                              2344
# CELL PHONE USE OTHER THAN TEXTING                                                     2135
# DISREGARDING ROAD MARKINGS                                                            1786
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       1667
# TURNING RIGHT ON RED                                                                  1092
# ANIMAL                                                                                 984
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)            724
# RELATED TO BUS STOP                                                                    644
# TEXTING                                                                                631
# DISREGARDING YIELD SIGN                                                                509
# PASSING STOPPED SCHOOL BUS                                                             181
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 156
# OBSTRUCTED CROSSWALKS                                                                  138
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                               42
# Name: PRIM_CONTRIBUTORY_CAUSE, dtype: int64
#
# SEC_CONTRIBUTORY_CAUSE
# NOT APPLICABLE                                                                      603404
# UNABLE TO DETERMINE                                                                 540363
# FAILING TO REDUCE SPEED TO AVOID CRASH                                               59443
# FAILING TO YIELD RIGHT-OF-WAY                                                        46524
# DRIVING SKILLS/KNOWLEDGE/EXPERIENCE                                                  45807
# FOLLOWING TOO CLOSELY                                                                41029
# IMPROPER OVERTAKING/PASSING                                                          22757
# IMPROPER LANE USAGE                                                                  21556
# WEATHER                                                                              17416
# IMPROPER TURNING/NO SIGNAL                                                           15015
# IMPROPER BACKING                                                                     11852
# OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER     10093
# DISREGARDING TRAFFIC SIGNALS                                                          6298
# PHYSICAL CONDITION OF DRIVER                                                          4972
# VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)                                  4751
# DISTRACTION - FROM INSIDE VEHICLE                                                     4717
# DISREGARDING STOP SIGN                                                                4561
# DRIVING ON WRONG SIDE/WRONG WAY                                                       3327
# EXCEEDING AUTHORIZED SPEED LIMIT                                                      3137
# EQUIPMENT - VEHICLE CONDITION                                                         3062
# EXCEEDING SAFE SPEED FOR CONDITIONS                                                   3025
# UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)                    2759
# DISTRACTION - FROM OUTSIDE VEHICLE                                                    2505
# HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)                                       1941
# DISREGARDING OTHER TRAFFIC SIGNS                                                      1548
# DISREGARDING ROAD MARKINGS                                                            1528
# ROAD CONSTRUCTION/MAINTENANCE                                                         1462
# CELL PHONE USE OTHER THAN TEXTING                                                     1191
# ROAD ENGINEERING/SURFACE/MARKING DEFECTS                                              1069
# EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST                                      786
# RELATED TO BUS STOP                                                                    684
# ANIMAL                                                                                 602
# TURNING RIGHT ON RED                                                                   560
# DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)            468
# BICYCLE ADVANCING LEGALLY ON RED LIGHT                                                 460
# DISREGARDING YIELD SIGN                                                                399
# TEXTING                                                                                289
# PASSING STOPPED SCHOOL BUS                                                             186
# OBSTRUCTED CROSSWALKS                                                                  139
# MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT                                              109
# Name: SEC_CONTRIBUTORY_CAUSE, dtype: int64
#
# STREET_DIRECTION
# W    534101
# S    499625
# N    356530
# E    101530
# Name: STREET_DIRECTION, dtype: int64
#
# STREET_NAME
# WESTERN AVE             40705
# PULASKI RD              35979
# CICERO AVE              33447
# ASHLAND AVE             32615
# HALSTED ST              28985
#                         ...
# LAFLIN AVE                  1
# WESTERN AVE OVERPASS        1
# LAKE SHORE DR E RAMP        1
# INDEPENDENCE SQ             1
# SEYMOUR AVE                 1
# Name: STREET_NAME, Length: 1624, dtype: int64
#
# MOST_SEVERE_INJURY
# NO INDICATION OF INJURY     1277240
# NONINCAPACITATING INJURY     119557
# REPORTED, NOT EVIDENT         63784
# INCAPACITATING INJURY         26824
# FATAL                          1726
# Name: MOST_SEVERE_INJURY, dtype: int64
#
# LOCATION
# POINT (-87.905309125103 41.976201139024)    2282
# POINT (-87.585971992965 41.751460603167)    1045
# POINT (-87.619928173678 41.900958919109)    1043
# POINT (-87.580147768689 41.791420282098)    1018
# POINT (-87.585275565077 41.722257273006)     807
#                                             ...
# POINT (-87.531511285193 41.717383872305)       1
# POINT (-87.741174431696 41.902541864024)       1
# POINT (-87.734557789944 41.857699988799)       1
# POINT (-87.727825744006 41.789985269636)       1
# POINT (-87.727116327064 41.922755262356)       1
# Name: LOCATION, Length: 279668, dtype: int64
#
# RD_NO_y
# JG108188    18
# JB311558    18
# JF346755    18
# JB330122    16
# JC496496    16
#             ..
# JE289061     1
# JD153480     1
# JD262214     1
# JD185061     1
# JC547602     1
# Name: RD_NO_y, Length: 727303, dtype: int64
#
# CRASH_DATE_y
# 12/29/2020 05:00:00 PM    60
# 11/10/2017 10:30:00 AM    58
# 11/10/2017 10:00:00 AM    42
# 02/17/2022 03:30:00 PM    42
# 01/12/2019 02:30:00 PM    41
#                           ..
# 07/18/2021 07:26:00 PM     1
# 06/21/2020 10:07:00 PM     1
# 02/12/2023 03:27:00 PM     1
# 03/10/2019 06:01:00 PM     1
# 05/04/2021 04:41:00 AM     1
# Name: CRASH_DATE_y, Length: 479281, dtype: int64
#
# UNIT_TYPE
# DRIVER                 1249363
# PARKED                  196474
# PEDESTRIAN               18419
# DRIVERLESS               12773
# BICYCLE                  10961
# NON-MOTOR VEHICLE         1303
# NON-CONTACT VEHICLE        280
# DISABLED VEHICLE           199
# EQUESTRIAN                   7
# Name: UNIT_TYPE, dtype: int64
#
# CMRC_VEH_I
# Y    17972
# N     9892
# Name: CMRC_VEH_I, dtype: int64
#
# MAKE
# CHEVROLET                          170693
# UNKNOWN                            145883
# FORD                               145217
# NISSAN                             119399
# HONDA                              106025
#                                     ...
# KING-CO                                 1
# HALLMARK MOTOR HOME                     1
# NORDIC                                  1
# AMERICAN WAY HOMES CORP.                1
# SPERRY NEW HOLLAND, DIV. SPERRY         1
# Name: MAKE, Length: 1278, dtype: int64
#
# MODEL
# UNKNOWN                           180803
# OTHER (EXPLAIN IN NARRATIVE)      118042
# CAMRY                              46758
# COROLLA                            29058
# CIVIC                              27861
#                                    ...
# PW TRAILER                             1
# TOWMOTOR CORP., (VMA WAS TOMO)         1
# CJ-6                                   1
# IMPERIAL INDUSTRIES                    1
# STARFIRE                               1
# Name: MODEL, Length: 2641, dtype: int64
#
# LIC_PLATE_STATE
# IL    1213363
# XX      28336
# IN      26343
# WI       8427
# MI       5719
# FL       4843
# TX       4153
# OH       3410
# AZ       3017
# MN       2464
# IA       2430
# MO       2261
# CA       2193
# TN       2003
# GA       1713
# OK       1248
# PA       1052
# NY       1020
# VA        865
# KY        853
# NC        813
# NJ        756
# CO        702
# MS        675
# MD        583
# AL        556
# NB        553
# WA        484
# KS        463
# LA        449
# AR        430
# MA        428
# SC        332
# ME        298
# NV        234
# OR        232
# CT        209
# UT        185
# SD        154
# MT        148
# NM        126
# ID        120
# ND        116
# WV         91
# NH         66
# DE         65
# RI         63
# DC         58
# VT         51
# AK         40
# WY         33
# HI         21
# Name: LIC_PLATE_STATE, dtype: int64
#
# VEHICLE_DEFECT
# NONE                803384
# UNKNOWN             639848
# OTHER                 7501
# BRAKES                4729
# TIRES                  731
# STEERING               678
# WHEELS                 373
# SUSPENSION             248
# ENGINE/MOTOR           195
# FUEL SYSTEM            174
# LIGHTS                  91
# WINDOWS                 87
# CARGO                   48
# SIGNALS                 39
# RESTRAINT SYSTEM        22
# TRAILER COUPLING        21
# EXHAUST                 18
# Name: VEHICLE_DEFECT, dtype: int64
#
# VEHICLE_TYPE
# PASSENGER                                 917663
# SPORT UTILITY VEHICLE (SUV)               197497
# UNKNOWN/NA                                137550
# VAN/MINI-VAN                               70378
# PICKUP                                     45994
# TRUCK - SINGLE UNIT                        27589
# OTHER                                      17271
# BUS OVER 15 PASS.                          15402
# TRACTOR W/ SEMI-TRAILER                    13888
# BUS UP TO 15 PASS.                          3801
# MOTORCYCLE (OVER 150CC)                     3372
# SINGLE UNIT TRUCK WITH TRAILER              2300
# OTHER VEHICLE WITH TRAILER                  1904
# TRACTOR W/O SEMI-TRAILER                    1854
# AUTOCYCLE                                    654
# MOPED OR MOTORIZED BICYCLE                   419
# MOTOR DRIVEN CYCLE                           326
# ALL-TERRAIN VEHICLE (ATV)                    166
# FARM EQUIPMENT                                77
# 3-WHEELED MOTORCYCLE (2 REAR WHEELS)          53
# RECREATIONAL OFF-HIGHWAY VEHICLE (ROV)        21
# SNOWMOBILE                                     8
# Name: VEHICLE_TYPE, dtype: int64
#
# VEHICLE_USE
# PERSONAL                        942199
# UNKNOWN/NA                      295473
# NOT IN USE                       75751
# OTHER                            45697
# TAXI/FOR HIRE                    19055
# COMMERCIAL - SINGLE UNIT         17900
# RIDESHARE SERVICE                12167
# CTA                               9918
# POLICE                            9511
# CONSTRUCTION/MAINTENANCE          6588
# COMMERCIAL - MULTI-UNIT           5978
# OTHER TRANSIT                     3964
# SCHOOL BUS                        3949
# TOW TRUCK                         2797
# AMBULANCE                         1720
# FIRE                              1440
# STATE OWNED                       1223
# DRIVER EDUCATION                  1153
# MASS TRANSIT                       832
# LAWN CARE/LANDSCAPING              542
# AGRICULTURE                        154
# CAMPER/RV - SINGLE UNIT             80
# MILITARY                            55
# HOUSE TRAILER                       23
# CAMPER/RV - TOWED/MULTI-UNIT        18
# Name: VEHICLE_USE, dtype: int64
#
# TRAVEL_DIRECTION
# N          343226
# S          335452
# W          303828
# E          297500
# UNKNOWN    115247
# SE          18421
# NW          16810
# SW          13900
# NE          13803
# Name: TRAVEL_DIRECTION, dtype: int64
#
# MANEUVER
# STRAIGHT AHEAD                        666629
# PARKED                                200953
# UNKNOWN/NA                            113584
# SLOW/STOP IN TRAFFIC                  110463
# TURNING LEFT                           85919
# BACKING                                59746
# TURNING RIGHT                          47851
# PASSING/OVERTAKING                     35134
# CHANGING LANES                         28191
# OTHER                                  24319
# ENTERING TRAFFIC LANE FROM PARKING     17147
# MERGING                                10132
# STARTING IN TRAFFIC                     8490
# U-TURN                                  8233
# LEAVING TRAFFIC LANE TO PARK            7031
# AVOIDING VEHICLES/OBJECTS               6290
# SKIDDING/CONTROL LOSS                   5811
# ENTER FROM DRIVE/ALLEY                  5588
# PARKED IN TRAFFIC LANE                  4438
# SLOW/STOP - LEFT TURN                   3042
# DRIVING WRONG WAY                       2133
# SLOW/STOP - RIGHT TURN                  1929
# NEGOTIATING A CURVE                     1927
# SLOW/STOP - LOAD/UNLOAD                 1663
# TURNING ON RED                           567
# DRIVERLESS                               550
# DIVERGING                                228
# DISABLED                                 199
# Name: MANEUVER, dtype: int64
#
# EXCEED_SPEED_LIMIT_I
# Y    1799
# N     598
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64
#
# FIRST_CONTACT_POINT
# FRONT                 284251
# REAR                  192061
# UNKNOWN               139069
# SIDE-LEFT              99334
# SIDE-RIGHT             94233
# FRONT-LEFT             81523
# FRONT-LEFT-CORNER      81434
# FRONT-RIGHT-CORNER     79585
# FRONT-RIGHT            76903
# REAR-LEFT              68088
# OTHER                  39834
# REAR-RIGHT             36487
# REAR-LEFT-CORNER       36329
# REAR-RIGHT-CORNER      26543
# TOTAL (ALL AREAS)      26469
# SIDE-LEFT-REAR         21121
# SIDE-RIGHT-REAR        15836
# SIDE-LEFT-FRONT        13449
# ROOF                   11952
# NONE                   11949
# SIDE-RIGHT-FRONT       11562
# UNDER CARRIAGE          5464
# TOP                     1622
# Name: FIRST_CONTACT_POINT, dtype: int64

# %%
df_cat_dropped_cols = df_cat.drop(columns=['RD_NO_x',
                'CRASH_DATE_EST_I', 
                'REPORT_TYPE', 
                'STREET_DIRECTION',
                'STREET_NAME',
                'LOCATION', 
                'RD_NO_y', 
                'CMRC_VEH_I', 
                'LIC_PLATE_STATE', 
                'TRAVEL_DIRECTION'
                 ])

# %% [markdown]
# # Preprocessing Pipelines:

# %%
preprocessing_pipeline_num = Pipeline([
    ('imputer', SimpleImputer(strategy='constant', fill_value=0)),  # Replace missing values with 0
    ('scaler', StandardScaler())  # Scale the features using standardization
])

# %%
# put df_num through preprocessing_pipeline_num
df_num_processed = preprocessing_pipeline_num.fit_transform(df_num)

# %%
df_num_processed
# Out:
# array([[ 0.25409834, -1.09426593, -0.23036555, ...,  1.18327123,
#          0.46773941,  1.19695084],
#        [ 0.25409834, -1.09426593, -0.23036555, ..., -0.32943142,
#          0.45882345, -0.06903189],
#        [ 0.25409834,  0.39233957, -0.23036555, ..., -0.32943142,
#          0.44863378, -0.06903189],
#        ...,
#        [-1.38371563,  0.0578967 , -0.23036555, ...,  1.18327123,
#          0.45500232,  1.19695084],
#        [-1.38371563,  0.0578967 , -0.23036555, ..., -0.32943142,
#          0.46009716, -0.06903189],
#        [-1.38371563,  0.0578967 , -0.23036555, ..., -0.32943142,
#          0.44226524, -1.33501463]])

# %%
# turn df_num_processed back into a dataframe
df_num_processed = pd.DataFrame(df_num_processed, columns=df_num.columns)

# %%
# Check df_num_processed for nulls
df_num_processed.isna().sum()
# Out:
# POSTED_SPEED_LIMIT               0
# STREET_NO                        0
# NUM_UNITS                        0
# INJURIES_TOTAL                   0
# INJURIES_FATAL                   0
# INJURIES_INCAPACITATING          0
# INJURIES_NON_INCAPACITATING      0
# INJURIES_REPORTED_NOT_EVIDENT    0
# INJURIES_NO_INDICATION           0
# INJURIES_UNKNOWN                 0
# CRASH_HOUR                       0
# CRASH_DAY_OF_WEEK                0
# CRASH_MONTH                      0
# LATITUDE                         0
# LONGITUDE                        0
# CRASH_UNIT_ID                    0
# UNIT_NO                          0
# NUM_PASSENGERS                   0
# VEHICLE_YEAR                     0
# OCCUPANT_CNT                     0
# dtype: int64
